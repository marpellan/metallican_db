# %%
import pandas as pd
import geopandas as gpd
import ee # Google Earth Engine

# %%
# Force re-authentication
ee.Authenticate()
# Out:
# True

# %%
PROJECT_ID = "miningcandb"  
ee.Initialize(project=PROJECT_ID) 
print("✅ Earth Engine is now initialized with project:", PROJECT_ID)
# Out:
# ✅ Earth Engine is now initialized with project: miningcandb

# %% [markdown]
# # Import datasets

# %%
# Canada SHP files
canada_boundary = gpd.read_file("data/Sources/Canada_boundary/Canada_boundary.shp")
canada_provinces = gpd.read_file("data/Sources/Canada_provinces_boundary/lpr_000b21a_e.shp")

# %%
# MinCan datasets
min_can_df = pd.read_csv(
    r'data/cleaned_data/min_can_cleaned_df.csv')

# %%
# NRCan datasets
nrcan_mining_df = pd.read_excel(
    r'data/NRCan/Principal Mineral Areas, Producing Mines, and Oil and Gas Fields (900A)/nrcan_mining_df.xlsx')
nrcan_manufacturing_df = pd.read_excel(
    r'data/NRCan/Principal Mineral Areas, Producing Mines, and Oil and Gas Fields (900A)/nrcan_manufacturing_df.xlsx')
nrcan_critical_df = pd.read_excel(
    r'data/NRCan/Critical minerals advanced projects, mines and processing facilities in Canada/Critical minerals advanced projects, mines and processing facilities.xlsx'
)

# %%
# GHG from large facilities datasets
ghg_facility_metal_mining_df = pd.read_csv(
    r'data/cleaned_data/ghg_facility_metal_mining_df.csv')
ghg_facility_metal_manufacturing_df = pd.read_csv(
    r'data/cleaned_data/ghg_facility_metal_manufacturing_df.csv')

# %%
# NPRI dataset
npri_metal_mining_df = pd.read_csv(
    r'data/cleaned_data/npri_metal_mining_df.csv')
npri_metal_manufacturing_df = pd.read_csv(
    r'data/cleaned_data/npri_metal_manufacturing_df.csv')

# %%
# Tailings dataset
tailings_source_df = pd.read_excel(
    r'data/Sources/WAPHA_global_metal_mines_database/GTD_Single_Table 4.0_March-2021.xlsx',
    skiprows=2
)
tailings_source_df = tailings_source_df[tailings_source_df['country'] == 'Canada']

# %%
# Climate Trace dataset
ctrace_annual = pd.read_csv(
    r'data/cleaned_data/ctrace_annual.csv')

# %%
# EJ Atlas dataset
ej_atlas_df = pd.read_csv(
    r'data/cleaned_data/ej_atlas_df_can.csv')

# %% [markdown]
# # Create parent table

# %% [markdown]
# ## Create main table for facilities

# %%
from db_creation_function import check_duplicate_facilities, convert_to_gdf

# %%
# We drop all industrial minerals, coal and oil mines from the mining dataset
nrcan_mining_df = nrcan_mining_df[~nrcan_mining_df["COM_GROU_E"].isin(["Industrial minerals", "Oil", "Coal"])]

# %%
# We keep only projects to avoid duplicates with the 900A dataset
# We also keep only active projects and remove past producer which are redundant with the 900A dataset
nrcan_critical_df = nrcan_critical_df[
    (nrcan_critical_df['OperationG'] == 'Project') &
    (nrcan_critical_df['ActivitySt'] == 'Active') &
    (nrcan_critical_df['Developmen'] != 'Past producer')
]

# %%
# We also drop some industrial minerals here
nrcan_critical_df = nrcan_critical_df[~nrcan_critical_df["Commoditie"].isin(["Potash", "Potash, magnesium", "Helium"])]

# %%
nrcan_manufacturing_df
# Out:
#     Unnamed: 0              OPERATIO_E              OPERATIO_F  \
# 0            0            Long Harbour            Long Harbour
# 1            1                Alouette                Alouette
# 2            2             Baie-Comeau             Baie-Comeau
# 3            3             Grande-Baie             Grande-Baie
# 4            4              Laterrière              Laterrière
# ..         ...                     ...                     ...
# 68          68  GenAlta Recycling Inc.  GenAlta Recycling Inc.
# 69          69        Calgary Facility    Installation Calgary
# 70          70      Navajo Metals Inc.      Navajo Metals Inc.
# 71          71                Richmond                Richmond
# 72          72          Victoria Depot          Dépôt Victoria
#
#                                               OWNER_E  \
# 0              Vale Newfoundland and Labrador Limited
# 1   Rio Tinto Aluminum Inc., Aluminium Austria Met...
# 2                                   Alcoa Corporation
# 3                             Rio Tinto Aluminum Inc.
# 4                             Rio Tinto Aluminum Inc.
# ..                                                ...
# 68                           EVRAZ North America Inc.
# 69                       Calgary Metal Recycling Inc.
# 70                           EVRAZ North America Inc.
# 71                   Richmond Steel Recycling Limited
# 72                                    Radius Recyling
#
#                                               OWNER_F FAC_TYPE_E  \
# 0              Vale Newfoundland and Labrador Limited   Refinery
# 1   Rio Tinto Aluminum Inc., Aluminium Austria Met...    Smelter
# 2                                   Alcoa Corporation    Smelter
# 3                             Rio Tinto Aluminum Inc.    Smelter
# 4                             Rio Tinto Aluminum Inc.    Smelter
# ..                                                ...        ...
# 68                           EVRAZ North America Inc.        NaN
# 69                       Calgary Metal Recycling Inc.        NaN
# 70                           EVRAZ North America Inc.        NaN
# 71                   Richmond Steel Recycling Limited        NaN
# 72                                    Radius Recyling        NaN
#
#          FAC_TYPE_F   COM_GROU_E      COM_GROU_F                  COM_DESC_E  \
# 0         Affinerie  Base metals  Métaux communs      Nickel, copper, cobalt
# 1   Usine de fusion     Aluminum        Aluminum             Aluminum (pure)
# 2   Usine de fusion     Aluminum        Aluminum  Aluminum (pure or alloyed)
# 3   Usine de fusion     Aluminum        Aluminum  Aluminum (pure or alloyed)
# 4   Usine de fusion     Aluminum        Aluminum  Aluminum (pure or alloyed)
# ..              ...          ...             ...                         ...
# 68              NaN          NaN             NaN                         NaN
# 69              NaN          NaN             NaN                         NaN
# 70              NaN          NaN             NaN                         NaN
# 71              NaN          NaN             NaN                         NaN
# 72              NaN          NaN             NaN                         NaN
#
#                   COM_DESC_F                 PROVINCE_E  \
# 0     Nickel, cuivre, cobalt  Newfoundland and Labrador
# 1            Aluminium (pur)                     Quebec
# 2   Aluminium (pur ou allié)                     Quebec
# 3   Aluminium (pur ou allié)                     Quebec
# 4   Aluminium (pur ou allié)                     Quebec
# ..                       ...                        ...
# 68                       NaN                    Alberta
# 69                       NaN                    Alberta
# 70                       NaN                    Alberta
# 71                       NaN           British Columbia
# 72                       NaN           British Columbia
#
#                  PROVINCE_F   LATITUDE   LONGITUDE  \
# 0   Terre-Neuve et Labrador  47.410938  -53.811792
# 1                    Québec  50.157100  -66.442900
# 2                    Québec  49.256200  -68.149100
# 3                    Québec  48.305800  -70.925800
# 4                    Québec  48.301300  -71.128700
# ..                      ...        ...         ...
# 68                  Alberta  53.588119 -113.274102
# 69                  Alberta  51.024190 -114.031993
# 70                  Alberta  51.001803 -114.032869
# 71     Colombie-Britannique  49.201528 -123.086842
# 72     Colombie-Britannique  48.437320 -123.376920
#
#                                           geometry
# 0     POINT (2914488.0240172655 800801.0438265661)
# 1      POINT (1964342.9738119314 576934.922064024)
# 2    POINT (1895224.1041564415 434554.88668270316)
# 3     POINT (1748359.0083371059 257571.7896260824)
# 4    POINT (1734509.1406380762 251550.16265590955)
# ..                                             ...
# 68   POINT (-1175351.3119179734 676348.0357257416)
# 69   POINT (-1305799.6725797676 421132.0470990939)
# 70    POINT (-1306586.768481397 418787.5859571835)
# 71  POINT (-1979449.5561039916 466683.33904960845)
# 72  POINT (-2035221.4889793585 399033.28522976954)
#
# [73 rows x 16 columns]

# %%
# List of facilities manually identified as being out of scope
recycling_sites = [
'AIM Recycling Atlantic',
'AIM Recycling Hamilton',
'AIM Recycling La Prairie',
'AIM Recycling Laval',
'AIM Recycling Lévis',
'AIM Recycling Montréal-Est',
'AIM Recycling Ottawa East',
'Contrecœur-Feruni',
'Calgary Facility',
'GenAlta Recycling Inc.',
'General Scrap',
'Navajo Metals Inc.',
'Wheat City Metals Inc.',
'Smiths Falls Operation',
'Industrial Metals',
'Richmond',
'Victoria Depot',
'Mississauga',
'Richmond',
'A.S.I. - Ste Catherine',
'Mississauga',
'Sainte-Catherine',
'Brampton Division',
'Hamilton Parkdale Division',
'Sault Ste. Marie Division'
]

nrcan_manufacturing_df = nrcan_manufacturing_df[~nrcan_manufacturing_df["OPERATIO_E"].isin(recycling_sites)]

# %%
from db_creation_function import populate_table_df, assign_id

# %%
main_columns = {
    "facility_name": "text",
    "reported_company": "text",
    "longitude": "float",
    "latitude": "float",
    "city": "text", # not specified in the project df 
    "province": "text",
    "status": "text", # active or projects 
    "activity_status": "text", # only for projects
    "development_stage": "text", # only for projects
    "facility_type": "text", # mining, manufacturing or projects
    "mining_processing_type": "text",
    "commodity_group": "text",
    "primary_commodity": "text",
    "commodities": "text",
    "source_id": "text"  
}

main_df = pd.DataFrame(columns=main_columns.keys())
main_df
# Out:
# Empty DataFrame
# Columns: [facility_name, reported_company, longitude, latitude, city, province, status, activity_status, development_stage, facility_type, mining_processing_type, commodity_group, primary_commodity, commodities, source_id]
# Index: []

# %%
column_mapping_main = {
      "nrcan_mining_df": {
        "OPERATIO_E": "facility_name",
        "OWNER_E": "reported_company",
        "LONGITUDE": "longitude",
        "LATITUDE": "latitude",
        "CITY_E": "city",
        "PROVINCE_E": "province",
        "FAC_DESC_E": "mining_processing_type",
        "COM_GROU_E": "commodity_group", 
        "COM_DESC_E": "commodities"
        
    },
    "nrcan_manufacturing_df": {
        "OPERATIO_E": "facility_name",
        "OWNER_E": "reported_company",
        "LONGITUDE": "longitude",
        "LATITUDE": "latitude",
        "PROVINCE_E": "province",
        "FAC_TYPE_E": "mining_processing_type",
        "COM_GROU_E": "commodity_group",
        "COM_DESC_E": "commodities"
    }, 
    
    "nrcan_critical_df": {
        "PropertyNa": "facility_name",
        "OperatorOw": "reported_company",
        "Longitude": "longitude",
        "Latitude": "latitude",
        "ProvincesE": "province",
        "Developmen": "development_stage",
        "ActivitySt": "activity_status",
        "Commoditie": "commodities",
    }
}

# %%
main_df = populate_table_df(column_mapping_main, 
                                   main_df, 
                                   dynamic_columns = {
                                       "facility_type": {
                                           "nrcan_mining_df": "mining",
                                            "nrcan_manufacturing_df": "manufacturing",
                                           "nrcan_critical_df": "project"
                                                           },
                                       "status": {
                                            "nrcan_mining_df": "active_facility",
                                            "nrcan_manufacturing_df": "active_facility",
                                            "nrcan_critical_df": "project_facility"
                                                           },
                                                      }, 
                            
                                   source_dfs = {"nrcan_mining_df": nrcan_mining_df,
                                                 "nrcan_manufacturing_df": nrcan_manufacturing_df,
                                                 "nrcan_critical_df": nrcan_critical_df}
                                   )
# Out:
# Initial facility_df rows: 0
# Processing DataFrame: nrcan_mining_df
# Temp DF rows to append: 90
# Rows in facility_df after appending nrcan_mining_df: 90
# Processing DataFrame: nrcan_manufacturing_df
# Temp DF rows to append: 48
# Rows in facility_df after appending nrcan_manufacturing_df: 138
# Processing DataFrame: nrcan_critical_df
# Temp DF rows to append: 132
# Rows in facility_df after appending nrcan_critical_df: 270
# Final facility_df rows: 270
# C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\canada_metal_sustainability_db\db_creation_function.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   facility_df = pd.concat([facility_df, temp_df], ignore_index=True)

# %%
# Compute primary_commodity from commodities
if "commodities" in main_df.columns:
    main_df["primary_commodity"] = main_df["commodities"].apply(
            lambda x: x.split(",")[0].strip() if isinstance(x, str) and x else None
        )

# %%
main_gdf = assign_id(
    main_df,
    canada_provinces,
    id_column = "main_id",
    prefix='MAIN'
)

# %%
main_gdf = main_gdf.sort_values(
    by=["reported_company", "facility_name"],
    key=lambda col: col.str.lower()
).reset_index(drop=True)
main_gdf
# Out:
#               main_id      facility_name                     reported_company  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                   Abcourt Mines Inc.
# 1    QC-MAIN-d29e0839     Sleeping Giant                   Abcourt Mines Inc.
# 2    QC-MAIN-f1ff4920       Akasaba West           Agnico Eagle Mines Limited
# 3    NU-MAIN-4ea8ac9d             Amaruq           Agnico Eagle Mines Limited
# 4    QC-MAIN-e7e6a960  Canadian Malartic           Agnico Eagle Mines Limited
# ..                ...                ...                                  ...
# 265  ON-MAIN-c5fefb01              Mishi              Wesdome Gold Mines Ltd.
# 266  BC-MAIN-feb13c30       Record Ridge       West High Yield Resources Ltd.
# 267  YT-MAIN-5e0d8b48             Casino  Western Copper and Gold Corporation
# 268  ON-MAIN-12c68d49       Eagle's Nest                                Wyloo
# 269  BC-MAIN-891d3cb5               Akie                ZincX Resources Corp.
#
#       longitude   latitude           city          province            status  \
# 0    -77.679010  48.521540            NaN            Quebec  project_facility
# 1    -77.974340  49.132590  north of Amos            Quebec   active_facility
# 2    -77.580000  48.040000            NaN            Quebec  project_facility
# 3    -96.697000  65.415000     Baker Lake           Nunavut   active_facility
# 4    -78.130824  48.122223       Malartic            Quebec   active_facility
# ..          ...        ...            ...               ...               ...
# 265  -85.452500  48.110280           Wawa           Ontario   active_facility
# 266 -117.884000  49.082000            NaN  British Columbia  project_facility
# 267 -138.833330  62.733330            NaN             Yukon  project_facility
# 268  -86.303800  52.742020            NaN           Ontario  project_facility
# 269 -124.865990  57.380880            NaN  British Columbia  project_facility
#
#     activity_status development_stage facility_type  mining_processing_type  \
# 0            Active  Advanced project       project                     NaN
# 1               NaN               NaN        mining            Concentrator
# 2            Active  Advanced project       project                     NaN
# 3               NaN               NaN        mining   Open-pit, underground
# 4               NaN               NaN        mining  Open-pit, concentrator
# ..              ...               ...           ...                     ...
# 265             NaN               NaN        mining                Open-pit
# 266          Active  Advanced project       project                     NaN
# 267          Active  Advanced project       project                     NaN
# 268          Active  Advanced project       project                     NaN
# 269          Active  Advanced project       project                     NaN
#
#      commodity_group primary_commodity  \
# 0                NaN              Zinc
# 1    Precious metals              Gold
# 2                NaN              Gold
# 3    Precious metals              Gold
# 4    Precious metals              Gold
# ..               ...               ...
# 265  Precious metals              Gold
# 266              NaN         Magnesium
# 267              NaN            Copper
# 268              NaN            Nickel
# 269              NaN              Zinc
#
#                                    commodities source_id  \
# 0                                 Zinc, silver       NaN
# 1                                 Gold, silver       NaN
# 2                                 Gold, copper       NaN
# 3                                         Gold       NaN
# 4                                 Gold, silver       NaN
# ..                                         ...       ...
# 265                                       Gold       NaN
# 266                                  Magnesium       NaN
# 267           Copper, gold, molybdenum, silver       NaN
# 268  Nickel, copper, gold, platinum, palladium       NaN
# 269                         Zinc, lead, silver       NaN
#
#                         geometry
# 0     POINT (-77.67901 48.52154)
# 1     POINT (-77.97434 49.13259)
# 2     POINT (-77.58000 48.04000)
# 3     POINT (-96.69700 65.41500)
# 4     POINT (-78.13082 48.12222)
# ..                           ...
# 265   POINT (-85.45250 48.11028)
# 266  POINT (-117.88400 49.08200)
# 267  POINT (-138.83333 62.73333)
# 268   POINT (-86.30380 52.74202)
# 269  POINT (-124.86599 57.38088)
#
# [270 rows x 17 columns]

# %%
# We make sure there is no duplicate
duplicates_main_gdf = check_duplicate_facilities(main_gdf)
duplicates_main_gdf
# Out:
# Empty GeoDataFrame
# Columns: [main_id, facility_name, reported_company, longitude, latitude, city, province, status, activity_status, development_stage, facility_type, mining_processing_type, commodity_group, primary_commodity, commodities, source_id, geometry]
# Index: []

# %%
main_gdf['facility_type'].value_counts()
# Out:
# facility_type
# project          132
# mining            90
# manufacturing     48
# Name: count, dtype: int64

# %% [markdown]
# This is the parent table, composed of 90 mines, 48 manufacturing sites and 132 projects.

# %% [markdown]
# ## Create IDs for companies and facility groups

# %%
from db_creation_function import assign_deterministic_id

# %%
companies_df = pd.read_excel(r'data/Tables/Auxiliary_tables/ID_to_create.xlsx', sheet_name='companies')
facility_groups_df = pd.read_excel(r'data/Tables/Auxiliary_tables/ID_to_create.xlsx', sheet_name='facility_groups')

# %%
companies_df
# Out:
#                      company_name_folder                     reported_company  \
# 0                      Abcourt Mines Inc                   Abcourt Mines Inc.
# 1                      Abcourt Mines Inc                   Abcourt Mines Inc.
# 2             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# 3             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# 4             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# ..                                   ...                                  ...
# 265               Wesdome Gold Mines Ltd              Wesdome Gold Mines Ltd.
# 266        West High Yield Resources Ltd       West High Yield Resources Ltd.
# 267  Western Copper and Gold Corporation  Western Copper and Gold Corporation
# 268                                Wyloo                                Wyloo
# 269                 ZincX Resources Corp                ZincX Resources Corp.
#
#          facility_name           main_id            status  company_id
# 0       Abcourt-Barvue  QC-MAIN-5801b453  project_facility         NaN
# 1       Sleeping Giant  QC-MAIN-d29e0839   active_facility         NaN
# 2         Akasaba West  QC-MAIN-f1ff4920  project_facility         NaN
# 3               Amaruq  NU-MAIN-4ea8ac9d   active_facility         NaN
# 4    Canadian Malartic  QC-MAIN-e7e6a960   active_facility         NaN
# ..                 ...               ...               ...         ...
# 265              Mishi  ON-MAIN-c5fefb01   active_facility         NaN
# 266       Record Ridge  BC-MAIN-feb13c30  project_facility         NaN
# 267             Casino  YT-MAIN-5e0d8b48  project_facility         NaN
# 268       Eagle's Nest  ON-MAIN-12c68d49  project_facility         NaN
# 269               Akie  BC-MAIN-891d3cb5  project_facility         NaN
#
# [270 rows x 6 columns]

# %%
facility_groups_df
# Out:
#                                      reported_company  \
# 0                          Agnico Eagle Mines Limited
# 1                          Agnico Eagle Mines Limited
# 2                                       ArcelorMittal
# 3                                       ArcelorMittal
# 4                  ArcelorMittal Long Products Canada
# 5                  ArcelorMittal Long Products Canada
# 6                         ArcelorMittal Mining Canada
# 7                                  Cameco Corporation
# 8                                  Cameco Corporation
# 9                         Glencore Canada Corporation
# 10                        Glencore Canada Corporation
# 11                        Glencore Canada Corporation
# 12                        Glencore Canada Corporation
# 13                        Glencore Canada Corporation
# 14                        Glencore Canada Corporation
# 15                        Glencore Canada Corporation
# 16                               Hudbay Minerals Inc.
# 17                               Hudbay Minerals Inc.
# 18                               Hudbay Minerals Inc.
# 19                                Newmont Corporation
# 20                                Newmont Corporation
# 21                                Newmont Corporation
# 22                          Pan American Silver Corp.
# 23                          Pan American Silver Corp.
# 24                            Rio Tinto Aluminum Inc.
# 25                            Rio Tinto Aluminum Inc.
# 26                            Rio Tinto Aluminum Inc.
# 27                            Rio Tinto Aluminum Inc.
# 28                            Rio Tinto Aluminum Inc.
# 29  Rio Tinto Aluminum Inc., Aluminium Austria Met...
# 30                                    Rio Tinto Group
# 31                                    Rio Tinto Group
# 32                                    Rio Tinto Group
# 33                                    Rio Tinto Group
# 34                                    SSR Mining Inc.
# 35                                    SSR Mining Inc.
# 36                 Tata Steel Minerals Canada Limited
# 37                 Tata Steel Minerals Canada Limited
# 38                                Vale Canada Limited
# 39                                Vale Canada Limited
# 40                                Vale Canada Limited
# 41                                Vale Canada Limited
# 42                                Vale Canada Limited
# 43                                Vale Canada Limited
# 44                                Vale Canada Limited
#
#                    facility_name           main_id  \
# 0                         Amaruq  NU-MAIN-4ea8ac9d
# 1                     Meadowbank  NU-MAIN-730aefe3
# 2                      Fire Lake  QC-MAIN-33c09b8b
# 3                    Mont-Wright  QC-MAIN-084bd95c
# 4                Contrecœur East  QC-MAIN-1eee4ace
# 5                Contrecœur West  QC-MAIN-844dcc47
# 6                   Port-Cartier  QC-MAIN-e25eed27
# 7                       Key Lake  SK-MAIN-bb89158f
# 8                 McArthur River  SK-MAIN-d3c471e8
# 9                            CCR  QC-MAIN-529c96b4
# 10                        Fraser  ON-MAIN-206041d1
# 11                         Horne  QC-MAIN-30c1828c
# 12              Nickel Rim South  ON-MAIN-fcb287a4
# 13                        Raglan  QC-MAIN-a97821c0
# 14                    Strathcona  ON-MAIN-ed85ac94
# 15                       Sudbury  ON-MAIN-40ce0593
# 16                 New Britannia  MB-MAIN-da0b5c3d
# 17                    Stall Lake  MB-MAIN-0898e255
# 18                    Lalor Lake  MB-MAIN-be5b3dc8
# 19                        Borden  ON-MAIN-1c674cd0
# 20                     Hollinger  ON-MAIN-8629a493
# 21                    Hoyle Pond  ON-MAIN-538513cd
# 22                    Bell Creek  ON-MAIN-bfbcd72e
# 23                  Timmins West  ON-MAIN-f3e6ff08
# 24                          Alma  QC-MAIN-3aa117d8
# 25                        Arvida  QC-MAIN-c1c7eb99
# 26                   Grande-Baie  QC-MAIN-01c1e81f
# 27                    Laterrière  QC-MAIN-c0e3a48b
# 28                     Vaudreuil  QC-MAIN-92628f16
# 29                      Alouette  QC-MAIN-8d6616b4
# 30                       Lac Tio  QC-MAIN-e82266c5
# 31   Rio Tinto Iron and Titanium  QC-MAIN-3e146840
# 32   Lithium Demonstration Plant  QC-MAIN-11c40b1f
# 33  Scandium Demonstration Plant  QC-MAIN-7b3b4c8b
# 34                        Santoy  SK-MAIN-22ce14be
# 35                        Seabee  SK-MAIN-29afbdb5
# 36                 DSO (3 and 4)  NL-MAIN-e09881ff
# 37                DSO (Goodwood)  QC-MAIN-b8c826a2
# 38                    Clarabelle  ON-MAIN-de2f9639
# 39                       Coleman  ON-MAIN-6e9b2449
# 40          Copper Cliff Complex  ON-MAIN-f080c409
# 41          Copper Cliff Complex  ON-MAIN-63b394c3
# 42                     Creighton  ON-MAIN-52224e1e
# 43                        Garson  ON-MAIN-48fe2205
# 44                        Totten  ON-MAIN-28f3f0fc
#
#                    facility_group_name  facility_group_id  \
# 0                   Meadowbank complex                NaN
# 1                   Meadowbank complex                NaN
# 2                                 AMMC                NaN
# 3                                 AMMC                NaN
# 4                          Contrecoeur                NaN
# 5                          Contrecoeur                NaN
# 6                                 AMMC                NaN
# 7            Key Lake + McArthur River                NaN
# 8            Key Lake + McArthur River                NaN
# 9                                  CCR                NaN
# 10        Integrated Nickel Operations                NaN
# 11                                 CCR                NaN
# 12        Integrated Nickel Operations                NaN
# 13        Integrated Nickel Operations                NaN
# 14        Integrated Nickel Operations                NaN
# 15        Integrated Nickel Operations                NaN
# 16                           Snow Lake                NaN
# 17                           Snow Lake                NaN
# 18                           Snow Lake                NaN
# 19                   Porcupine complex                NaN
# 20                   Porcupine complex                NaN
# 21                   Porcupine complex                NaN
# 22                   Timmins Operation                NaN
# 23                   Timmins Operation                NaN
# 24  Saguenay–Lac-Saint-Jean Operations                NaN
# 25  Saguenay–Lac-Saint-Jean Operations                NaN
# 26  Saguenay–Lac-Saint-Jean Operations                NaN
# 27  Saguenay–Lac-Saint-Jean Operations                NaN
# 28  Saguenay–Lac-Saint-Jean Operations                NaN
# 29  Saguenay–Lac-Saint-Jean Operations                NaN
# 30              RTFT Operations Quebec                NaN
# 31              RTFT Operations Quebec                NaN
# 32              RTFT Operations Quebec                NaN
# 33              RTFT Operations Quebec                NaN
# 34               Seabee Gold Operation                NaN
# 35               Seabee Gold Operation                NaN
# 36                                 DSO                NaN
# 37                                 DSO                NaN
# 38                   Sudbury Operation                NaN
# 39                   Sudbury Operation                NaN
# 40                   Sudbury Operation                NaN
# 41                   Sudbury Operation                NaN
# 42                   Sudbury Operation                NaN
# 43                   Sudbury Operation                NaN
# 44                   Sudbury Operation                NaN
#
#                                               comment
# 0                                                 NaN
# 1                                                 NaN
# 2   "The raw ore from Fire Lake is sent to our Mon...
# 3   "The raw ore from Fire Lake is sent to our Mon...
# 4                                                 NaN
# 5                                                 NaN
# 6   "The raw ore from Fire Lake is sent to our Mon...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  MDO includes it as 'Sudubury INO operation' bu...
# 11  "At Horne Smelter, we produce 99.1% pure coppe...
# 12                                                NaN
# 13  "The nickel concentrate travels 100 kilometers...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN

# %%
companies_df = assign_deterministic_id(companies_df, 'CMP-', 'company_name_folder', 'company_id')
companies_df
# Out:
#                      company_name_folder                     reported_company  \
# 0                      Abcourt Mines Inc                   Abcourt Mines Inc.
# 1                      Abcourt Mines Inc                   Abcourt Mines Inc.
# 2             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# 3             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# 4             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# ..                                   ...                                  ...
# 265               Wesdome Gold Mines Ltd              Wesdome Gold Mines Ltd.
# 266        West High Yield Resources Ltd       West High Yield Resources Ltd.
# 267  Western Copper and Gold Corporation  Western Copper and Gold Corporation
# 268                                Wyloo                                Wyloo
# 269                 ZincX Resources Corp                ZincX Resources Corp.
#
#          facility_name           main_id            status    company_id
# 0       Abcourt-Barvue  QC-MAIN-5801b453  project_facility  CMP-0a6a3062
# 1       Sleeping Giant  QC-MAIN-d29e0839   active_facility  CMP-0a6a3062
# 2         Akasaba West  QC-MAIN-f1ff4920  project_facility  CMP-6265c407
# 3               Amaruq  NU-MAIN-4ea8ac9d   active_facility  CMP-6265c407
# 4    Canadian Malartic  QC-MAIN-e7e6a960   active_facility  CMP-6265c407
# ..                 ...               ...               ...           ...
# 265              Mishi  ON-MAIN-c5fefb01   active_facility  CMP-3d2c4955
# 266       Record Ridge  BC-MAIN-feb13c30  project_facility  CMP-1023f9c0
# 267             Casino  YT-MAIN-5e0d8b48  project_facility  CMP-2dac9896
# 268       Eagle's Nest  ON-MAIN-12c68d49  project_facility  CMP-65b36728
# 269               Akie  BC-MAIN-891d3cb5  project_facility  CMP-3416049b
#
# [270 rows x 6 columns]

# %%
# To see the number of facilities per companies
active_facility_counts = (
    companies_df[companies_df["status"] == "active_facility"]
    .groupby(["company_id", "company_name_folder"])
    .size()
    .reset_index(name="active_facility_count")
    .sort_values(by="active_facility_count", ascending=False)
)
active_facility_counts
# Out:
#       company_id                company_name_folder  active_facility_count
# 39  CMP-9617aef4                               Vale                     11
# 34  CMP-7a096012                          Rio Tinto                     10
# 55  CMP-d5f1c66b                           Glencore                     10
# 26  CMP-6265c407         Agnico Eagle Mines Limited                      8
# 21  CMP-4a434d72                Newmont Corporation                      8
# ..           ...                                ...                    ...
# 1   CMP-05423572             Trafigura Mining Group                      1
# 36  CMP-84fc7d46  Baffinland Iron Mines Corporation                      1
# 37  CMP-858cc590            Maritime Resources Corp                      1
# 38  CMP-8a99044e               Tacora Resources Inc                      1
# 66  CMP-f2392338                        Sayona Nord                      1
#
# [67 rows x 3 columns]

# %%
facility_groups_df = assign_deterministic_id(facility_groups_df, 'GRP-', 'facility_group_name', 'facility_group_id')
facility_groups_df
# Out:
#                                      reported_company  \
# 0                          Agnico Eagle Mines Limited
# 1                          Agnico Eagle Mines Limited
# 2                                       ArcelorMittal
# 3                                       ArcelorMittal
# 4                  ArcelorMittal Long Products Canada
# 5                  ArcelorMittal Long Products Canada
# 6                         ArcelorMittal Mining Canada
# 7                                  Cameco Corporation
# 8                                  Cameco Corporation
# 9                         Glencore Canada Corporation
# 10                        Glencore Canada Corporation
# 11                        Glencore Canada Corporation
# 12                        Glencore Canada Corporation
# 13                        Glencore Canada Corporation
# 14                        Glencore Canada Corporation
# 15                        Glencore Canada Corporation
# 16                               Hudbay Minerals Inc.
# 17                               Hudbay Minerals Inc.
# 18                               Hudbay Minerals Inc.
# 19                                Newmont Corporation
# 20                                Newmont Corporation
# 21                                Newmont Corporation
# 22                          Pan American Silver Corp.
# 23                          Pan American Silver Corp.
# 24                            Rio Tinto Aluminum Inc.
# 25                            Rio Tinto Aluminum Inc.
# 26                            Rio Tinto Aluminum Inc.
# 27                            Rio Tinto Aluminum Inc.
# 28                            Rio Tinto Aluminum Inc.
# 29  Rio Tinto Aluminum Inc., Aluminium Austria Met...
# 30                                    Rio Tinto Group
# 31                                    Rio Tinto Group
# 32                                    Rio Tinto Group
# 33                                    Rio Tinto Group
# 34                                    SSR Mining Inc.
# 35                                    SSR Mining Inc.
# 36                 Tata Steel Minerals Canada Limited
# 37                 Tata Steel Minerals Canada Limited
# 38                                Vale Canada Limited
# 39                                Vale Canada Limited
# 40                                Vale Canada Limited
# 41                                Vale Canada Limited
# 42                                Vale Canada Limited
# 43                                Vale Canada Limited
# 44                                Vale Canada Limited
#
#                    facility_name           main_id  \
# 0                         Amaruq  NU-MAIN-4ea8ac9d
# 1                     Meadowbank  NU-MAIN-730aefe3
# 2                      Fire Lake  QC-MAIN-33c09b8b
# 3                    Mont-Wright  QC-MAIN-084bd95c
# 4                Contrecœur East  QC-MAIN-1eee4ace
# 5                Contrecœur West  QC-MAIN-844dcc47
# 6                   Port-Cartier  QC-MAIN-e25eed27
# 7                       Key Lake  SK-MAIN-bb89158f
# 8                 McArthur River  SK-MAIN-d3c471e8
# 9                            CCR  QC-MAIN-529c96b4
# 10                        Fraser  ON-MAIN-206041d1
# 11                         Horne  QC-MAIN-30c1828c
# 12              Nickel Rim South  ON-MAIN-fcb287a4
# 13                        Raglan  QC-MAIN-a97821c0
# 14                    Strathcona  ON-MAIN-ed85ac94
# 15                       Sudbury  ON-MAIN-40ce0593
# 16                 New Britannia  MB-MAIN-da0b5c3d
# 17                    Stall Lake  MB-MAIN-0898e255
# 18                    Lalor Lake  MB-MAIN-be5b3dc8
# 19                        Borden  ON-MAIN-1c674cd0
# 20                     Hollinger  ON-MAIN-8629a493
# 21                    Hoyle Pond  ON-MAIN-538513cd
# 22                    Bell Creek  ON-MAIN-bfbcd72e
# 23                  Timmins West  ON-MAIN-f3e6ff08
# 24                          Alma  QC-MAIN-3aa117d8
# 25                        Arvida  QC-MAIN-c1c7eb99
# 26                   Grande-Baie  QC-MAIN-01c1e81f
# 27                    Laterrière  QC-MAIN-c0e3a48b
# 28                     Vaudreuil  QC-MAIN-92628f16
# 29                      Alouette  QC-MAIN-8d6616b4
# 30                       Lac Tio  QC-MAIN-e82266c5
# 31   Rio Tinto Iron and Titanium  QC-MAIN-3e146840
# 32   Lithium Demonstration Plant  QC-MAIN-11c40b1f
# 33  Scandium Demonstration Plant  QC-MAIN-7b3b4c8b
# 34                        Santoy  SK-MAIN-22ce14be
# 35                        Seabee  SK-MAIN-29afbdb5
# 36                 DSO (3 and 4)  NL-MAIN-e09881ff
# 37                DSO (Goodwood)  QC-MAIN-b8c826a2
# 38                    Clarabelle  ON-MAIN-de2f9639
# 39                       Coleman  ON-MAIN-6e9b2449
# 40          Copper Cliff Complex  ON-MAIN-f080c409
# 41          Copper Cliff Complex  ON-MAIN-63b394c3
# 42                     Creighton  ON-MAIN-52224e1e
# 43                        Garson  ON-MAIN-48fe2205
# 44                        Totten  ON-MAIN-28f3f0fc
#
#                    facility_group_name facility_group_id  \
# 0                   Meadowbank complex      GRP-0a2c0d69
# 1                   Meadowbank complex      GRP-0a2c0d69
# 2                                 AMMC      GRP-1402249f
# 3                                 AMMC      GRP-1402249f
# 4                          Contrecoeur      GRP-7a9ba115
# 5                          Contrecoeur      GRP-7a9ba115
# 6                                 AMMC      GRP-1402249f
# 7            Key Lake + McArthur River      GRP-21eee27d
# 8            Key Lake + McArthur River      GRP-21eee27d
# 9                                  CCR      GRP-b48ec279
# 10        Integrated Nickel Operations      GRP-de097f20
# 11                                 CCR      GRP-b48ec279
# 12        Integrated Nickel Operations      GRP-de097f20
# 13        Integrated Nickel Operations      GRP-de097f20
# 14        Integrated Nickel Operations      GRP-de097f20
# 15        Integrated Nickel Operations      GRP-de097f20
# 16                           Snow Lake      GRP-a13779f8
# 17                           Snow Lake      GRP-a13779f8
# 18                           Snow Lake      GRP-a13779f8
# 19                   Porcupine complex      GRP-0d911886
# 20                   Porcupine complex      GRP-0d911886
# 21                   Porcupine complex      GRP-0d911886
# 22                   Timmins Operation      GRP-147b3123
# 23                   Timmins Operation      GRP-147b3123
# 24  Saguenay–Lac-Saint-Jean Operations      GRP-677b5973
# 25  Saguenay–Lac-Saint-Jean Operations      GRP-677b5973
# 26  Saguenay–Lac-Saint-Jean Operations      GRP-677b5973
# 27  Saguenay–Lac-Saint-Jean Operations      GRP-677b5973
# 28  Saguenay–Lac-Saint-Jean Operations      GRP-677b5973
# 29  Saguenay–Lac-Saint-Jean Operations      GRP-677b5973
# 30              RTFT Operations Quebec      GRP-25483238
# 31              RTFT Operations Quebec      GRP-25483238
# 32              RTFT Operations Quebec      GRP-25483238
# 33              RTFT Operations Quebec      GRP-25483238
# 34               Seabee Gold Operation      GRP-14bfbb82
# 35               Seabee Gold Operation      GRP-14bfbb82
# 36                                 DSO      GRP-2a663492
# 37                                 DSO      GRP-2a663492
# 38                   Sudbury Operation      GRP-dc07540b
# 39                   Sudbury Operation      GRP-dc07540b
# 40                   Sudbury Operation      GRP-dc07540b
# 41                   Sudbury Operation      GRP-dc07540b
# 42                   Sudbury Operation      GRP-dc07540b
# 43                   Sudbury Operation      GRP-dc07540b
# 44                   Sudbury Operation      GRP-dc07540b
#
#                                               comment
# 0                                                 NaN
# 1                                                 NaN
# 2   "The raw ore from Fire Lake is sent to our Mon...
# 3   "The raw ore from Fire Lake is sent to our Mon...
# 4                                                 NaN
# 5                                                 NaN
# 6   "The raw ore from Fire Lake is sent to our Mon...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  MDO includes it as 'Sudubury INO operation' bu...
# 11  "At Horne Smelter, we produce 99.1% pure coppe...
# 12                                                NaN
# 13  "The nickel concentrate travels 100 kilometers...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN

# %%
companies_df = companies_df.merge(
    facility_groups_df[["main_id", "facility_group_name", "facility_group_id"]].drop_duplicates(),
    on="main_id",
    how="left"
)

# %%
companies_df
# Out:
#                      company_name_folder                     reported_company  \
# 0                      Abcourt Mines Inc                   Abcourt Mines Inc.
# 1                      Abcourt Mines Inc                   Abcourt Mines Inc.
# 2             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# 3             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# 4             Agnico Eagle Mines Limited           Agnico Eagle Mines Limited
# ..                                   ...                                  ...
# 265               Wesdome Gold Mines Ltd              Wesdome Gold Mines Ltd.
# 266        West High Yield Resources Ltd       West High Yield Resources Ltd.
# 267  Western Copper and Gold Corporation  Western Copper and Gold Corporation
# 268                                Wyloo                                Wyloo
# 269                 ZincX Resources Corp                ZincX Resources Corp.
#
#          facility_name           main_id            status    company_id  \
# 0       Abcourt-Barvue  QC-MAIN-5801b453  project_facility  CMP-0a6a3062
# 1       Sleeping Giant  QC-MAIN-d29e0839   active_facility  CMP-0a6a3062
# 2         Akasaba West  QC-MAIN-f1ff4920  project_facility  CMP-6265c407
# 3               Amaruq  NU-MAIN-4ea8ac9d   active_facility  CMP-6265c407
# 4    Canadian Malartic  QC-MAIN-e7e6a960   active_facility  CMP-6265c407
# ..                 ...               ...               ...           ...
# 265              Mishi  ON-MAIN-c5fefb01   active_facility  CMP-3d2c4955
# 266       Record Ridge  BC-MAIN-feb13c30  project_facility  CMP-1023f9c0
# 267             Casino  YT-MAIN-5e0d8b48  project_facility  CMP-2dac9896
# 268       Eagle's Nest  ON-MAIN-12c68d49  project_facility  CMP-65b36728
# 269               Akie  BC-MAIN-891d3cb5  project_facility  CMP-3416049b
#
#     facility_group_name facility_group_id
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3    Meadowbank complex      GRP-0a2c0d69
# 4                   NaN               NaN
# ..                  ...               ...
# 265                 NaN               NaN
# 266                 NaN               NaN
# 267                 NaN               NaN
# 268                 NaN               NaN
# 269                 NaN               NaN
#
# [270 rows x 8 columns]

# %%
companies_df.to_excel(r'data/Tables/Auxiliary_tables/ID_created.xlsx', index=False)

# %% [markdown]
# ### Merge the created IDs into the main_gdf

# %%
main_gdf = main_gdf.merge(
    companies_df[["reported_company", "company_name_folder", "company_id"]].drop_duplicates(),
    on="reported_company",
    how="left"
)

# %%
main_gdf = main_gdf.merge(
    facility_groups_df[["main_id", "facility_group_name", "facility_group_id"]].drop_duplicates(),
    on="main_id",
    how="left"
)

# %%
col_to_keep = ['main_id', 'facility_name',
               'facility_group_name','facility_group_id',
               'reported_company', 'company_name_folder', 'company_id',
               'longitude', 'latitude', 'geometry',
               'city', 'province', 'status', 'activity_status', 'development_stage', 'facility_type', 'mining_processing_type', 'commodity_group', 'primary_commodity', 'commodities', 'source_id'
]
main_gdf = main_gdf[col_to_keep]
main_gdf
# Out:
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                 NaN
# 1    QC-MAIN-d29e0839     Sleeping Giant                 NaN
# 2    QC-MAIN-f1ff4920       Akasaba West                 NaN
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                 NaN
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                 NaN
# 266  BC-MAIN-feb13c30       Record Ridge                 NaN
# 267  YT-MAIN-5e0d8b48             Casino                 NaN
# 268  ON-MAIN-12c68d49       Eagle's Nest                 NaN
# 269  BC-MAIN-891d3cb5               Akie                 NaN
#
#     facility_group_id                     reported_company  \
# 0                 NaN                   Abcourt Mines Inc.
# 1                 NaN                   Abcourt Mines Inc.
# 2                 NaN           Agnico Eagle Mines Limited
# 3        GRP-0a2c0d69           Agnico Eagle Mines Limited
# 4                 NaN           Agnico Eagle Mines Limited
# ..                ...                                  ...
# 265               NaN              Wesdome Gold Mines Ltd.
# 266               NaN       West High Yield Resources Ltd.
# 267               NaN  Western Copper and Gold Corporation
# 268               NaN                                Wyloo
# 269               NaN                ZincX Resources Corp.
#
#                      company_name_folder    company_id   longitude   latitude  \
# 0                      Abcourt Mines Inc  CMP-0a6a3062  -77.679010  48.521540
# 1                      Abcourt Mines Inc  CMP-0a6a3062  -77.974340  49.132590
# 2             Agnico Eagle Mines Limited  CMP-6265c407  -77.580000  48.040000
# 3             Agnico Eagle Mines Limited  CMP-6265c407  -96.697000  65.415000
# 4             Agnico Eagle Mines Limited  CMP-6265c407  -78.130824  48.122223
# ..                                   ...           ...         ...        ...
# 265               Wesdome Gold Mines Ltd  CMP-3d2c4955  -85.452500  48.110280
# 266        West High Yield Resources Ltd  CMP-1023f9c0 -117.884000  49.082000
# 267  Western Copper and Gold Corporation  CMP-2dac9896 -138.833330  62.733330
# 268                                Wyloo  CMP-65b36728  -86.303800  52.742020
# 269                 ZincX Resources Corp  CMP-3416049b -124.865990  57.380880
#
#                         geometry  ...          province            status  \
# 0     POINT (-77.67901 48.52154)  ...            Quebec  project_facility
# 1     POINT (-77.97434 49.13259)  ...            Quebec   active_facility
# 2     POINT (-77.58000 48.04000)  ...            Quebec  project_facility
# 3     POINT (-96.69700 65.41500)  ...           Nunavut   active_facility
# 4     POINT (-78.13082 48.12222)  ...            Quebec   active_facility
# ..                           ...  ...               ...               ...
# 265   POINT (-85.45250 48.11028)  ...           Ontario   active_facility
# 266  POINT (-117.88400 49.08200)  ...  British Columbia  project_facility
# 267  POINT (-138.83333 62.73333)  ...             Yukon  project_facility
# 268   POINT (-86.30380 52.74202)  ...           Ontario  project_facility
# 269  POINT (-124.86599 57.38088)  ...  British Columbia  project_facility
#
#     activity_status development_stage facility_type  mining_processing_type  \
# 0            Active  Advanced project       project                     NaN
# 1               NaN               NaN        mining            Concentrator
# 2            Active  Advanced project       project                     NaN
# 3               NaN               NaN        mining   Open-pit, underground
# 4               NaN               NaN        mining  Open-pit, concentrator
# ..              ...               ...           ...                     ...
# 265             NaN               NaN        mining                Open-pit
# 266          Active  Advanced project       project                     NaN
# 267          Active  Advanced project       project                     NaN
# 268          Active  Advanced project       project                     NaN
# 269          Active  Advanced project       project                     NaN
#
#      commodity_group primary_commodity  \
# 0                NaN              Zinc
# 1    Precious metals              Gold
# 2                NaN              Gold
# 3    Precious metals              Gold
# 4    Precious metals              Gold
# ..               ...               ...
# 265  Precious metals              Gold
# 266              NaN         Magnesium
# 267              NaN            Copper
# 268              NaN            Nickel
# 269              NaN              Zinc
#
#                                    commodities source_id
# 0                                 Zinc, silver       NaN
# 1                                 Gold, silver       NaN
# 2                                 Gold, copper       NaN
# 3                                         Gold       NaN
# 4                                 Gold, silver       NaN
# ..                                         ...       ...
# 265                                       Gold       NaN
# 266                                  Magnesium       NaN
# 267           Copper, gold, molybdenum, silver       NaN
# 268  Nickel, copper, gold, platinum, palladium       NaN
# 269                         Zinc, lead, silver       NaN
#
# [270 rows x 21 columns]

# %% [markdown]
# # Import and process children datasets

# %%
from db_creation_function import add_year, assign_row_id

# %% [markdown]
# ## Children datasets with coordinates

# %% [markdown]
# ### Tailings dataset

# %%
tailings_columns = {
    "tailing_id": "float",
    "tsf_name": "text",
    "related_mine": "text",
    "main_owner": "text",
    "full_ownership": "text",
    "operator": "text",
    "longitude": "float",
    "latitude": "float",
    "status": "text", 
    "construction_year": "int",
    "raise_type": "text",	
    "current_maximum_height": "int",	
    "current_tailings_storage": "int",	
    "planned_storage_5_years": "int",
    "hazard_categorization": "text",
    "classification_system": "text",
    "link": "text",
    "source_id": "text"  
}

tailings_df = pd.DataFrame(columns=tailings_columns.keys())
tailings_df
# Out:
# Empty DataFrame
# Columns: [tailing_id, tsf_name, related_mine, main_owner, full_ownership, operator, longitude, latitude, status, construction_year, raise_type, current_maximum_height, current_tailings_storage, planned_storage_5_years, hazard_categorization, classification_system, link, source_id]
# Index: []

# %%
column_mapping_tailings = {
    "tailings_source_df": {
    "GRD_No": "tailing_id",    
    "tsf": "tsf_name",
    "mine": "related_mine",
    "Owner_company": "main_owner",
    "partners (not from disclosure)": "full_ownership",
    "operator": "operator",
    "longitude": "longitude",
    "latitude": "latitude",
    "status": "status", 
    "construction_year": "construction_year",
    "raise_type": "raise_type",	
    "current_maximum_height": "current_maximum_height",	
    "current_tailings_storage": "current_tailings_storage",	
    "planned_storage_5_years": "planned_storage_5_years",
    "hazard_categorization": "hazard_categorization",
    "classification_system": "classification_system",
    "link": "link"
    }
}

# %%
tailings_df = populate_table_df(column_mapping_tailings, 
                                   tailings_df, 
                                   source_dfs = {"tailings_source_df": tailings_source_df}
                                   )
# Out:
# Initial facility_df rows: 0
# Processing DataFrame: tailings_source_df
# Temp DF rows to append: 227
# Rows in facility_df after appending tailings_source_df: 227
# Final facility_df rows: 227
# C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\canada_metal_sustainability_db\db_creation_function.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   facility_df = pd.concat([facility_df, temp_df], ignore_index=True)

# %%
tailings_df
# Out:
#      tailing_id                                           tsf_name  \
# 0          12.0                                         North Cell
# 1          13.0                                         South Cell
# 2          14.0                                             In pit
# 3          15.0                                      Meliadine TSF
# 4          16.0                                          South TSF
# ..          ...                                                ...
# 222       701.0       Tailings Storage Facility 1 (Tailings Dam 1)
# 223       702.0       Tailings Storage Facility 2 (Tailings Dam 2)
# 224       703.0       Tailings Storage Facility 3 (Tailings Dam 3)
# 225       704.0  Geco Tailings Facility (CN1, CN2 , CP, CP3, E1...
# 226      1243.0                              Canadian Malartic TSF
#
#           related_mine        main_owner              full_ownership  \
# 0           Meadowbank      Agnico Eagle                         NaN
# 1           Meadowbank      Agnico Eagle                         NaN
# 2           Meadowbank      Agnico Eagle                         NaN
# 3            Meliadine      Agnico Eagle                         NaN
# 4               Goldex      Agnico Eagle                         NaN
# ..                 ...               ...                         ...
# 222        Mines Gaspe       Xstrata plc                         NaN
# 223        Mines Gaspe       Xstrata plc                         NaN
# 224        Mines Gaspe       Xstrata plc                         NaN
# 225               Geco       Xstrata plc                         NaN
# 226  Canadian Malartic  Yamana Gold Inc.  Agnico Eagle Mines Limited
#
#                           operator  longitude   latitude  status  \
# 0                     Agnico Eagle -96.043328  65.021558  Active
# 1                     Agnico Eagle -96.033391  65.013782  Active
# 2                     Agnico Eagle -96.032544  65.001901  Active
# 3                     Agnico Eagle -92.140336  63.020829  Active
# 4                     Agnico Eagle -77.841978  48.054342  Active
# ..                             ...        ...        ...     ...
# 222                    Xstrata plc -65.460833  48.926111  Closed
# 223                    Xstrata plc -65.471389  48.921944  Closed
# 224                    Xstrata plc -65.498889  48.916667  Closed
# 225                    Xstrata plc -85.781111  49.162222  Closed
# 226  Canadian Malartic Corporation -78.103611  48.111389  Active
#
#      construction_year            raise_type  current_maximum_height  \
# 0               2009.0  Downstream, Upstream                    31.0
# 1               2012.0            Downstream                    49.0
# 2               2009.0                   NaN                     NaN
# 3               2019.0                   NaN                     5.0
# 4               2007.0            Not Raised                     5.0
# ..                 ...                   ...                     ...
# 222             1955.0              Upstream                    35.0
# 223             1963.0              Upstream                    44.0
# 224             1972.0            Downstream                    54.0
# 225             1955.0              Upstream                    35.0
# 226             2012.0              Upstream                    40.0
#
#     current_tailings_storage planned_storage_5_years hazard_categorization  \
# 0                   14400000                14400000                Medium
# 1                   10420000                10800000                Medium
# 2                     850000                12500000                   Low
# 3                      89000                 4354000                Medium
# 4                    1664000                 2500000                Medium
# ..                       ...                     ...                   ...
# 222                 26700000                26700000                   Low
# 223                 34900000                34900000                  High
# 224                  5080000                 5080000                   Low
# 225                 40000000                40000000                  High
# 226                 96000000               136500000        Medium to High
#
#         classification_system  \
# 0    Canadian Dam Association
# 1    Canadian Dam Association
# 2                         NaN
# 3    Canadian Dam Association
# 4    Canadian Dam Association
# ..                        ...
# 222           CDA 2007 (2013)
# 223           CDA 2007 (2013)
# 224           CDA 2007 (2013)
# 225           CDA 2007 (2013)
# 226                CDA/Yamana
#
#                                                   link source_id
# 0    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 1    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 2    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 3    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 4    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# ..                                                 ...       ...
# 222  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 223  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 224  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 225  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 226  https://s22.q4cdn.com/899716706/files/doc_down...       NaN
#
# [227 rows x 18 columns]

# %%
tailings_gdf = convert_to_gdf(tailings_df)
#tailings_gdf = assign_id(tailings_df, canada_provinces, id_column='tailing_id', prefix='TAIL', name_col="tsf_name")

# %%
tailings_gdf = add_year(tailings_gdf, 2019)

# %%
tailings_gdf = assign_row_id(tailings_gdf, 
                  facility_id_col='tailing_id',
                  prefix='TAIL',
                  year_col='year'           
                  )

# %%
tailings_gdf
# Out:
#                  row_id  year  tailing_id  \
# 0      TAIL-12.0-2019-1  2019        12.0
# 1      TAIL-13.0-2019-1  2019        13.0
# 2      TAIL-14.0-2019-1  2019        14.0
# 3      TAIL-15.0-2019-1  2019        15.0
# 4      TAIL-16.0-2019-1  2019        16.0
# ..                  ...   ...         ...
# 222   TAIL-701.0-2019-1  2019       701.0
# 223   TAIL-702.0-2019-1  2019       702.0
# 224   TAIL-703.0-2019-1  2019       703.0
# 225   TAIL-704.0-2019-1  2019       704.0
# 226  TAIL-1243.0-2019-1  2019      1243.0
#
#                                               tsf_name       related_mine  \
# 0                                           North Cell         Meadowbank
# 1                                           South Cell         Meadowbank
# 2                                               In pit         Meadowbank
# 3                                        Meliadine TSF          Meliadine
# 4                                            South TSF             Goldex
# ..                                                 ...                ...
# 222       Tailings Storage Facility 1 (Tailings Dam 1)        Mines Gaspe
# 223       Tailings Storage Facility 2 (Tailings Dam 2)        Mines Gaspe
# 224       Tailings Storage Facility 3 (Tailings Dam 3)        Mines Gaspe
# 225  Geco Tailings Facility (CN1, CN2 , CP, CP3, E1...               Geco
# 226                              Canadian Malartic TSF  Canadian Malartic
#
#            main_owner              full_ownership  \
# 0        Agnico Eagle                         NaN
# 1        Agnico Eagle                         NaN
# 2        Agnico Eagle                         NaN
# 3        Agnico Eagle                         NaN
# 4        Agnico Eagle                         NaN
# ..                ...                         ...
# 222       Xstrata plc                         NaN
# 223       Xstrata plc                         NaN
# 224       Xstrata plc                         NaN
# 225       Xstrata plc                         NaN
# 226  Yamana Gold Inc.  Agnico Eagle Mines Limited
#
#                           operator  longitude   latitude  ...  \
# 0                     Agnico Eagle -96.043328  65.021558  ...
# 1                     Agnico Eagle -96.033391  65.013782  ...
# 2                     Agnico Eagle -96.032544  65.001901  ...
# 3                     Agnico Eagle -92.140336  63.020829  ...
# 4                     Agnico Eagle -77.841978  48.054342  ...
# ..                             ...        ...        ...  ...
# 222                    Xstrata plc -65.460833  48.926111  ...
# 223                    Xstrata plc -65.471389  48.921944  ...
# 224                    Xstrata plc -65.498889  48.916667  ...
# 225                    Xstrata plc -85.781111  49.162222  ...
# 226  Canadian Malartic Corporation -78.103611  48.111389  ...
#
#     construction_year            raise_type current_maximum_height  \
# 0              2009.0  Downstream, Upstream                   31.0
# 1              2012.0            Downstream                   49.0
# 2              2009.0                   NaN                    NaN
# 3              2019.0                   NaN                    5.0
# 4              2007.0            Not Raised                    5.0
# ..                ...                   ...                    ...
# 222            1955.0              Upstream                   35.0
# 223            1963.0              Upstream                   44.0
# 224            1972.0            Downstream                   54.0
# 225            1955.0              Upstream                   35.0
# 226            2012.0              Upstream                   40.0
#
#      current_tailings_storage planned_storage_5_years hazard_categorization  \
# 0                    14400000                14400000                Medium
# 1                    10420000                10800000                Medium
# 2                      850000                12500000                   Low
# 3                       89000                 4354000                Medium
# 4                     1664000                 2500000                Medium
# ..                        ...                     ...                   ...
# 222                  26700000                26700000                   Low
# 223                  34900000                34900000                  High
# 224                   5080000                 5080000                   Low
# 225                  40000000                40000000                  High
# 226                  96000000               136500000        Medium to High
#
#         classification_system  \
# 0    Canadian Dam Association
# 1    Canadian Dam Association
# 2                         NaN
# 3    Canadian Dam Association
# 4    Canadian Dam Association
# ..                        ...
# 222           CDA 2007 (2013)
# 223           CDA 2007 (2013)
# 224           CDA 2007 (2013)
# 225           CDA 2007 (2013)
# 226                CDA/Yamana
#
#                                                   link source_id  \
# 0    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 1    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 2    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 3    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# 4    https://s21.q4cdn.com/374334112/files/doc_down...       NaN
# ..                                                 ...       ...
# 222  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 223  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 224  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 225  https://www.glencore.com/dam/jcr:58e3d8ff-97c1...       NaN
# 226  https://s22.q4cdn.com/899716706/files/doc_down...       NaN
#
#                        geometry
# 0    POINT (-96.04333 65.02156)
# 1    POINT (-96.03339 65.01378)
# 2    POINT (-96.03254 65.00190)
# 3    POINT (-92.14034 63.02083)
# 4    POINT (-77.84198 48.05434)
# ..                          ...
# 222  POINT (-65.46083 48.92611)
# 223  POINT (-65.47139 48.92194)
# 224  POINT (-65.49889 48.91667)
# 225  POINT (-85.78111 49.16222)
# 226  POINT (-78.10361 48.11139)
#
# [227 rows x 21 columns]

# %% [markdown]
# ### MinCan dataset

# %%
min_can_gdf = assign_id(min_can_df, 
                              canada_provinces = canada_provinces,
                              id_column="mincan_id", prefix="MINCAN",
                              name_col='namemine')

# %%
min_can_gdf
# Out:
#               mincan_id                                           company1  \
# 0    QC-MINCAN-a8c87336                            Quebec Copper Corp. Ltd
# 1    BC-MINCAN-16652987                                  Noland Mines Ltd.
# 2    BC-MINCAN-d675705f                    Falconbridge Nickel Mines Ltd.
# 3    NS-MINCAN-ca20ef49                           Greenwood Coal Co. Ltd.
# 4    QC-MINCAN-d1e8b6b1                                  Noranda Mines Ltd
# ..                  ...                                                ...
# 942  BC-MINCAN-4611f856  Imperial Metals Corporation, Mitsubishi Materi...
# 943  NT-MINCAN-ea720725                                  BHP Diamonds Inc.
# 944  QC-MINCAN-8f0f7e05                            Magnola Magnesium Inc.
# 945  QC-MINCAN-54661244                   Canadian Johns-Manville Co. Ltd.
# 946  BC-MINCAN-0a623af9                    Crow's Nest Pass Coal Co. Ltd.
#
#                                       company2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4             Normetal Mining Corporation Ltd.
# ..                                         ...
# 942                     Teck Resources Limited
# 943                      Dia Met Minerals Ltd.
# 944  Society generale de financement du Quebec
# 945                              Asbestos Inc.
# 946                                        NaN
#
#                                company3                         company4  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                     Falconbridge Ltd.                          Xstrata
# ..                                  ...                              ...
# 942              Huckleberry Mines Ltd.                              NaN
# 943   Charles Fipke and Stewart Blusson  Arctic Canadian Diamond Company
# 944                                 NaN                              NaN
# 945                                 NaN                              NaN
# 946                                 NaN                              NaN
#
#     company5 company6               namemine                        town  \
# 0        NaN      NaN                    NaN                         NaN
# 1        NaN      NaN           Spruce Creek                       Atlin
# 2        NaN      NaN         Wesfrob (Tasu)             Moresby Island
# 3        NaN      NaN                    NaN                         NaN
# 4        NaN      NaN                  Horne                    Noranda
# ..       ...      ...                    ...                         ...
# 942      NaN      NaN            Huckleberry                      Kemano
# 943      NaN      NaN  Panda (Ekati Project)                 Lac de Gras
# 944      NaN      NaN               Ardorbec                   Danville
# 945      NaN      NaN                Jeffrey  Asbestos (Val-des-Sources)
# 946      NaN      NaN                    NaN                         NaN
#
#                   province  ...  \
# 0                   Quebec  ...
# 1         British Columbia  ...
# 2         British Columbia  ...
# 3              Nova Scotia  ...
# 4                   Quebec  ...
# ..                     ...  ...
# 942       British Columbia  ...
# 943  Northwest Territories  ...
# 944                 Quebec  ...
# 945                 Quebec  ...
# 946       British Columbia  ...
#
#                                           commodityall  \
# 0                                 Copper, Gold, Silver
# 1                                                 Gold
# 2                                         Iron, Copper
# 3                                                 Coal
# 4    Copper, Gold, Silver, Selenium, Tellurium, Pyr...
# ..                                                 ...
# 942                   Copper, Molybdenum, Silver, Gold
# 943                                            Diamond
# 944                                          Magnesium
# 945                                         Chrysotile
# 946                                               Coal
#
#                                            information  source1 source2  \
# 0                                                  NaN        0       1
# 1                                                  NaN        0       1
# 2                                                  NaN        0       1
# 3    The currently entered coordinates are for the ...        0       1
# 4    Alternative names: Horne Mine (1975) The mine ...        0       1
# ..                                                 ...      ...     ...
# 942                                                NaN        1       0
# 943                Brief closure between 2020 and 2021        1       0
# 944                                                NaN        1       0
# 945  FR: En 1992, la mine est l'objet d'une importa...        0       0
# 946  The Crow's Nest Pass Coal Company was establis...        0       0
#
#     source3                                              link1  \
# 0         0                                                NaN
# 1         1        https://www.mindat.org/feature-6088912.html
# 2         1              https://www.mindat.org/loc-26169.html
# 3         1             https://www.mindat.org/loc-290980.html
# 4         1                https://www.mindat.org/loc-609.html
# ..      ...                                                ...
# 942       0                                                NaN
# 943       0                                                NaN
# 944       0                                                NaN
# 945       1  https://miningwatch.ca/sites/default/files/asb...
# 946       1  https://albertaonrecord.ca/crowsnest-resources...
#
#                                                  link2  \
# 0                                                  NaN
# 1               https://www.mindat.org/loc-257276.html
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 942                                                NaN
# 943                                                NaN
# 944                                                NaN
# 945  https://niche-canada.org/2015/11/19/workers-as...
# 946                                                NaN
#
#                                                  link3 mine_status  \
# 0                                                  NaN    Inactive
# 1    https://mrdata.usgs.gov/ardf/show-ardf.php?ard...    Inactive
# 2                                                  NaN    Inactive
# 3                                                  NaN    Inactive
# 4                                                  NaN    Inactive
# ..                                                 ...         ...
# 942                                                NaN    Inactive
# 943                                                NaN      Active
# 944                                                NaN      Active
# 945  https://www.researchgate.net/publication/28664...    Inactive
# 946                                                NaN    Inactive
#
#                         geometry
# 0     POINT (-72.33176 45.26379)
# 1    POINT (-133.27033 59.38272)
# 2    POINT (-132.05000 52.75834)
# 3     POINT (-62.56678 45.55022)
# 4     POINT (-79.01128 48.25427)
# ..                           ...
# 942  POINT (-127.17805 53.68111)
# 943  POINT (-110.60833 64.71667)
# 944   POINT (-71.96130 45.74846)
# 945   POINT (-71.94760 45.77510)
# 946  POINT (-114.71454 49.65448)
#
# [947 rows x 28 columns]

# %%
# To change later, but to avoid having duplicates IDs
min_can_gdf = min_can_gdf.drop_duplicates(subset=['mincan_id'])

# %%
def combine_periods(row):
    periods = []
    for i in range(1, 4):
        open_col = f"open{i}"
        close_col = f"close{i}"
        open_val = str(row[open_col]) if pd.notna(row[open_col]) else ""
        close_val = str(row[close_col]) if pd.notna(row[close_col]) else ""
        if open_val and close_val:
            periods.append(f"{open_val}–{close_val}")
        elif open_val:
            periods.append(f"{open_val}–")
        elif close_val:
            periods.append(f"–{close_val}")
    return "; ".join(periods) if periods else None

# %%
min_can_gdf["operation_periods"] = min_can_gdf.apply(combine_periods, axis=1)
# Out:
# C:\Users\mp_ma\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
columns_to_drop = [f"company{i}" for i in range(1, 7)] + \
                  [f"open{i}" for i in range(1, 4)] + \
                  [f"close{i}" for i in range(1, 4)] + \
                  [f"source{i}" for i in range(1, 4)] + \
                  [f"link{i}" for i in range(1, 4)]
min_can_gdf = min_can_gdf.drop(columns=columns_to_drop)

# %%
min_can_gdf
# Out:
#               mincan_id               namemine                        town  \
# 0    QC-MINCAN-a8c87336                    NaN                         NaN
# 1    BC-MINCAN-16652987           Spruce Creek                       Atlin
# 2    BC-MINCAN-d675705f         Wesfrob (Tasu)             Moresby Island
# 3    NS-MINCAN-ca20ef49                    NaN                         NaN
# 4    QC-MINCAN-d1e8b6b1                  Horne                    Noranda
# ..                  ...                    ...                         ...
# 942  BC-MINCAN-4611f856            Huckleberry                      Kemano
# 943  NT-MINCAN-ea720725  Panda (Ekati Project)                 Lac de Gras
# 944  QC-MINCAN-8f0f7e05               Ardorbec                   Danville
# 945  QC-MINCAN-54661244                Jeffrey  Asbestos (Val-des-Sources)
# 946  BC-MINCAN-0a623af9                    NaN                         NaN
#
#                   province   latitude   longitude  \
# 0                   Quebec  45.263786  -72.331764
# 1         British Columbia  59.382720 -133.270330
# 2         British Columbia  52.758340 -132.050000
# 3              Nova Scotia  45.550219  -62.566780
# 4                   Quebec  48.254270  -79.011280
# ..                     ...        ...         ...
# 942       British Columbia  53.681110 -127.178050
# 943  Northwest Territories  64.716667 -110.608333
# 944                 Quebec  45.748462  -71.961305
# 945                 Quebec  45.775100  -71.947600
# 946       British Columbia  49.654481 -114.714544
#
#                                           commodityall  \
# 0                                 Copper, Gold, Silver
# 1                                                 Gold
# 2                                         Iron, Copper
# 3                                                 Coal
# 4    Copper, Gold, Silver, Selenium, Tellurium, Pyr...
# ..                                                 ...
# 942                   Copper, Molybdenum, Silver, Gold
# 943                                            Diamond
# 944                                          Magnesium
# 945                                         Chrysotile
# 946                                               Coal
#
#                                            information mine_status  \
# 0                                                  NaN    Inactive
# 1                                                  NaN    Inactive
# 2                                                  NaN    Inactive
# 3    The currently entered coordinates are for the ...    Inactive
# 4    Alternative names: Horne Mine (1975) The mine ...    Inactive
# ..                                                 ...         ...
# 942                                                NaN    Inactive
# 943                Brief closure between 2020 and 2021      Active
# 944                                                NaN      Active
# 945  FR: En 1992, la mine est l'objet d'une importa...    Inactive
# 946  The Crow's Nest Pass Coal Company was establis...    Inactive
#
#                         geometry     operation_periods
# 0     POINT (-72.33176 45.26379)             1866–1958
# 1    POINT (-133.27033 59.38272)  1909–1950; 1955–1989
# 2    POINT (-132.05000 52.75834)             1914–1983
# 3     POINT (-62.56678 45.55022)             1918–1966
# 4     POINT (-79.01128 48.25427)             1927–1976
# ..                           ...                   ...
# 942  POINT (-127.17805 53.68111)             1997–2016
# 943  POINT (-110.60833 64.71667)             1997–open
# 944   POINT (-71.96130 45.74846)             1998–open
# 945   POINT (-71.94760 45.77510)             1879–2009
# 946  POINT (-114.71454 49.65448)             1897–1978
#
# [939 rows x 11 columns]

# %% [markdown]
# ### ClimateTRACE dataset

# %%
ctrace_df = ctrace_annual[ctrace_annual['year'] == 2023]

# %%
ctrace_df = ctrace_df.rename(columns={
     'lat': 'latitude',
     'lon': 'longitude'}
)
ctrace_gdf = convert_to_gdf(ctrace_df)

# %%
ctrace_gdf.rename(columns={'source_id': 'ctrace_id'}, inplace=True)

# %%
col_to_keep = ['ctrace_id', 'year', 'source_name', 
               'emissions_quantity', 'gas', 
               'activity', 'activity_units', 
               'capacity', 'capacity_units',
               'latitude', 'longitude', 'geometry']

ctrace_gdf = ctrace_gdf[col_to_keep]
ctrace_gdf
# Out:
#      ctrace_id  year               source_name  emissions_quantity  \
# 114    1754048  2023                  777 Mine        0.000000e+00
# 115    1754049  2023                 Bell Mine        0.000000e+00
# 116    1754050  2023          Bell-Allard Mine        0.000000e+00
# 117    1754051  2023    Bell-Allard South Mine        0.000000e+00
# 118    1754053  2023              Cantung Mine        0.000000e+00
# 119    1754054  2023              Caribou Mine        0.000000e+00
# 120    1754055  2023              Coleman Mine        5.610000e+03
# 121    1754056  2023         Copper Cliff Mine        6.403000e+03
# 122    1754057  2023      Copper Mountain Mine        2.299160e+05
# 123    1754058  2023            Creighton Mine        2.639000e+03
# 124    1754059  2023             Estrades Mine        0.000000e+00
# 125    1754060  2023               Garson Mine        4.225000e+03
# 126    1754061  2023            Gibraltar Mine        1.316380e+05
# 127    1754063  2023             Granisle Mine        0.000000e+00
# 128    1754064  2023             Halfmile Mine        0.000000e+00
# 129    1754065  2023         Heath Steele Mine        0.000000e+00
# 130    1754066  2023      Highland Valley Mine        2.412130e+06
# 131    1754067  2023                Horne Mine        0.000000e+00
# 132    1754068  2023          Huckleberry Mine        0.000000e+00
# 133    1754069  2023            Isle-Dieu Mine        0.000000e+00
# 134    1754070  2023               Joutel Mine        0.000000e+00
# 135    1754071  2023               Kemess Mine        0.000000e+00
# 136    1754074  2023         Lac Matagami Mine        0.000000e+00
# 137    1754075  2023                Lalor Mine        2.408400e+04
# 138    1754076  2023             Langlois Mine        0.000000e+00
# 139    1754077  2023              LaRonde Mine        6.711600e+04
# 140    1754078  2023            Lexington Mine        0.000000e+00
# 141    1754079  2023             Matagami Mine        0.000000e+00
# 142    1754080  2023                  Max Mine        0.000000e+00
# 143    1754081  2023        McCreedy West Mine        7.782000e+03
# 144    1754082  2023                 Ming Mine        0.000000e+00
# 145    1754083  2023                Minto Mine        0.000000e+00
# 146    1754084  2023       Mount Milligan Mine        7.956600e+04
# 147    1754085  2023         Mount Polley Mine        7.137900e+04
# 148    1754086  2023           Myra Falls Mine        5.400000e+02
# 149    1754087  2023            New Afton Mine        1.590800e+04
# 150    1754088  2023            New Hosco Mine        0.000000e+00
# 151    1754089  2023               Norita Mine        0.000000e+00
# 152    1754090  2023  Nunavik Nickel Operation        0.000000e+00
# 153    1754091  2023               Orchan Mine        0.000000e+00
# 154    1754093  2023              Poirier Mine        0.000000e+00
# 155    1754094  2023              Quemont Mine        0.000000e+00
# 156    1754095  2023              Radiore Mine        0.000000e+00
# 157    1754096  2023          Raglan Operation        8.219000e+03
# 158    1754097  2023            Red Chris Mine        8.451100e+04
# 159    1754098  2023          Restigouche Mine        0.000000e+00
# 160    1754099  2023            Samatosum Mine        0.000000e+00
# 161    1754100  2023              Selbaie Mine        0.000000e+00
# 162    1754101  2023               Stobie Mine        0.000000e+00
# 163    1754102  2023     Sudbury INO Operation        1.593900e+04
# 164    1754103  2023             Thompson Mine        4.433000e+03
# 165    1754104  2023               Totten Mine        3.367000e+03
# 166    1754105  2023              Troilus Mine        0.000000e+00
# 167    1754106  2023         Voisey's Bay Mine        1.144000e+04
# 168   25486533  2023           Kidd Creek Mine        1.620000e+04
# 169   25486534  2023         Lac des Iles Mine        5.914500e+04
# 170   36395102  2023               Scully Mine        5.760720e+05
#
#             gas      activity   activity_units      capacity capacity_units  \
# 114  co2e_100yr  0.000000e+00  t of copper ore  1.524000e+06         tonnes
# 115  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 116  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 117  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 118  co2e_100yr  0.000000e+00  t of copper ore  1.818000e+06         tonnes
# 119  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 120  co2e_100yr  8.630000e+05  t of copper ore  4.624000e+06         tonnes
# 121  co2e_100yr  9.850000e+05  t of copper ore  3.554700e+07         tonnes
# 122  co2e_100yr  1.457500e+07  t of copper ore  3.670000e+08         tonnes
# 123  co2e_100yr  4.060000e+05  t of copper ore  1.104100e+07         tonnes
# 124  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 125  co2e_100yr  6.500000e+05  t of copper ore  4.822000e+06         tonnes
# 126  co2e_100yr  8.810000e+07  t of copper ore  6.450000e+08         tonnes
# 127  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 128  co2e_100yr  0.000000e+00  t of copper ore  4.410000e+06         tonnes
# 129  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 130  co2e_100yr  7.288600e+07  t of copper ore  2.631000e+08         tonnes
# 131  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 132  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 133  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 134  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 135  co2e_100yr  0.000000e+00  t of copper ore  1.073810e+08         tonnes
# 136  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 137  co2e_100yr  1.526729e+06  t of copper ore  1.357000e+07         tonnes
# 138  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 139  co2e_100yr  1.501481e+06  t of copper ore  1.988200e+07         tonnes
# 140  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 141  co2e_100yr  0.000000e+00  t of copper ore  1.200000e+06         tonnes
# 142  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 143  co2e_100yr  5.279710e+05  t of copper ore  8.787959e+07         tonnes
# 144  co2e_100yr  0.000000e+00  t of copper ore  7.413000e+06         tonnes
# 145  co2e_100yr  0.000000e+00  t of copper ore  2.313000e+06         tonnes
# 146  co2e_100yr  2.127800e+07  t of copper ore  2.500250e+08         tonnes
# 147  co2e_100yr  5.948239e+06  t of copper ore  4.902900e+07         tonnes
# 148  co2e_100yr  4.500000e+04  t of copper ore  4.110000e+06         tonnes
# 149  co2e_100yr  2.993000e+06  t of copper ore  3.408700e+07         tonnes
# 150  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 151  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 152  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 153  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 154  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 155  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 156  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 157  co2e_100yr  6.848790e+05  t of copper ore  1.500000e+07         tonnes
# 158  co2e_100yr  6.887709e+06  t of copper ore  4.549000e+08         tonnes
# 159  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 160  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 161  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 162  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 163  co2e_100yr  1.431680e+06  t of copper ore  1.690000e+07         tonnes
# 164  co2e_100yr  6.820000e+05  t of copper ore  8.787959e+07         tonnes
# 165  co2e_100yr  5.180000e+05  t of copper ore  2.453000e+06         tonnes
# 166  co2e_100yr  0.000000e+00  t of copper ore  8.787959e+07         tonnes
# 167  co2e_100yr  1.760000e+06  t of copper ore  3.110000e+07         tonnes
# 168  co2e_100yr  1.350000e+06  t of copper ore  2.500000e+06         tonnes
# 169  co2e_100yr  3.798000e+06  t of copper ore  2.200000e+07         tonnes
# 170  co2e_100yr  1.578280e+07    t of iron ore  4.789430e+08         tonnes
#
#       latitude   longitude                     geometry
# 114  54.775408 -101.879304  POINT (-101.87930 54.77541)
# 115  54.994393 -126.229872  POINT (-126.22987 54.99439)
# 116  49.701370  -77.726647   POINT (-77.72665 49.70137)
# 117  49.676477  -77.667660   POINT (-77.66766 49.67648)
# 118  61.968158 -128.230176  POINT (-128.23018 61.96816)
# 119  47.563852  -66.291932   POINT (-66.29193 47.56385)
# 120  46.674583  -81.343080   POINT (-81.34308 46.67458)
# 121  46.480960  -81.052207   POINT (-81.05221 46.48096)
# 122  49.331253 -120.521629  POINT (-120.52163 49.33125)
# 123  46.462958  -81.176038   POINT (-81.17604 46.46296)
# 124  49.586191  -78.870907   POINT (-78.87091 49.58619)
# 125  46.567580  -80.857509   POINT (-80.85751 46.56758)
# 126  52.519137 -122.269260  POINT (-122.26926 52.51914)
# 127  54.940589 -126.157100  POINT (-126.15710 54.94059)
# 128  47.304433  -66.324075   POINT (-66.32407 47.30443)
# 129  47.292613  -66.062529   POINT (-66.06253 47.29261)
# 130  50.486244 -121.042759  POINT (-121.04276 50.48624)
# 131  48.254296  -79.010706   POINT (-79.01071 48.25430)
# 132  53.681321 -127.179631  POINT (-127.17963 53.68132)
# 133  49.720988  -77.748708   POINT (-77.74871 49.72099)
# 134  49.453113  -78.352142   POINT (-78.35214 49.45311)
# 135  57.003206 -126.772517  POINT (-126.77252 57.00321)
# 136  49.718189  -77.714340   POINT (-77.71434 49.71819)
# 137  54.873524 -100.149518  POINT (-100.14952 54.87352)
# 138  49.245370  -76.674411   POINT (-76.67441 49.24537)
# 139  48.249139  -78.441434   POINT (-78.44143 48.24914)
# 140  49.008773 -118.613201  POINT (-118.61320 49.00877)
# 141  49.689045  -77.694108   POINT (-77.69411 49.68905)
# 142  50.649897 -117.569419  POINT (-117.56942 50.64990)
# 143  46.637729  -81.398089   POINT (-81.39809 46.63773)
# 144  49.914219  -56.085819   POINT (-56.08582 49.91422)
# 145  62.617560 -137.256469  POINT (-137.25647 62.61756)
# 146  55.120089 -124.019136  POINT (-124.01914 55.12009)
# 147  52.548922 -121.634586  POINT (-121.63459 52.54892)
# 148  49.570670 -125.591966  POINT (-125.59197 49.57067)
# 149  50.662968 -120.520252  POINT (-120.52025 50.66297)
# 150  49.789786  -77.836128   POINT (-77.83613 49.78979)
# 151  49.775233  -77.655109   POINT (-77.65511 49.77523)
# 152  61.556721  -73.449743   POINT (-73.44974 61.55672)
# 153  49.707436  -77.707900   POINT (-77.70790 49.70744)
# 154  49.444177  -78.397175   POINT (-78.39718 49.44418)
# 155  48.256614  -79.004787   POINT (-79.00479 48.25661)
# 156  49.753583  -77.558927   POINT (-77.55893 49.75358)
# 157  61.687773  -73.678676   POINT (-73.67868 61.68777)
# 158  57.713205 -129.794095  POINT (-129.79409 57.71321)
# 159  47.500875  -66.550582   POINT (-66.55058 47.50088)
# 160  51.151560 -119.813151  POINT (-119.81315 51.15156)
# 161  49.805167  -78.946232   POINT (-78.94623 49.80517)
# 162  46.480960  -81.052207   POINT (-81.05221 46.48096)
# 163  46.657829  -80.796580   POINT (-80.79658 46.65783)
# 164  55.714060  -97.852724   POINT (-97.85272 55.71406)
# 165  46.381870  -81.453631   POINT (-81.45363 46.38187)
# 166  51.012585  -74.466821   POINT (-74.46682 51.01259)
# 167  56.331334  -62.096044   POINT (-62.09604 56.33133)
# 168  48.689104  -81.371982   POINT (-81.37198 48.68910)
# 169  49.164166  -89.622449   POINT (-89.62245 49.16417)
# 170  52.905338  -66.927868   POINT (-66.92787 52.90534)

# %% [markdown]
# ### Conflict dataset from EJ Atlas

# %%
ej_atlas_df
# Out:
#     Conflict.Id                                               Case  \
# 0           384      New Prosperity Goldmine Fish Lake, BC, Canada
# 1           388     Tahltan Nation v. Fortune Minerals, BC, Canada
# 2          1635   Fandora Gold: Tofino-Tranquil (Onadsilth-Eels...
# 3          1852     Imperial Metals, Mount Polley Mine, BC, Canada
# 4          3408  Strateco Resources Inc. Uranium Mine in The Ma...
# 5          3615  Granite quarrying in Cap Breton, Nova Scotia, ...
# 6          3863  Iron Ore mining in Baffin island, Nunavut terr...
# 7          3883  Yellowknife gold mine and arsenic pollution, C...
# 8          4016                       Ring of Fire, Ontario Canada
# 9          4135      Vale Mining in Voisey's Bay, Labrador, Canada
# 10         4145  Port Colborne Class Action Lawsuit Against Val...
# 11         4894  Diavik Diamond mine by Rio Tinto and kimberlit...
# 12         4964  Kitchenuhmaykoosib Inninuwug peoples against p...
# 13         5068  Elk Valley Coal Mines Selenium Pollution in BC...
# 14         5597  Sayona Miningâ€™s Authier Lithium Project in Q...
# 15         5599  Nouveau Mondeâ€™s Matawinie graphite mine in Q...
# 16         5662  Canada Carbon's Miller graphite mine project, ...
# 17         5667  North American Lithium mining project, La Corn...
# 18         5681       Tansim open pit lithium mine project, Canada
# 19         6461                           La Loutre Mining Project
#
#                                                  Site  \
# 0                                       Williams Lake
# 1                                               Iskut
# 2   Tla-o-qui-aht Traditional Territories includin...
# 3                                              Likely
# 4                                          Baie-James
# 5     Canso, Guysborough County, Cap Breton; also ...
# 6                                       Baffin island
# 7                                         Yellowknife
# 8              James Bay Lowlands of Northern Ontario
# 9                                        Voisey's Bay
# 10                                      Port Colborne
# 11                                        Lac de Gras
# 12                                    Big Trout Lake
# 13                                         Elk Valley
# 14                                           La Motte
# 15  Municipality of Saint-Michel-des-Saints  in Ma...
# 16  Canton of Grenville-sur-la Rouge, Regional Cou...
# 17                                           La Corne
# 18                                Moffet municipality
# 19                 Between Duhamel and Lac des Plages
#
#                    Province         Lon           Lat  \
# 0          British Columbia -123.614383     51.450273
# 1          British Colombia -129.978400     57.835699
# 2          British Columbia -125.675538     49.249880
# 3          British Columbia -121.641667     52.554444
# 4                   QuÃ©bec  -72.089537     51.961643
# 5               Nova Scotia  -61.160800     45.340500
# 6                   Nunavut  -79.120000     71.190000
# 7     Northwest Territories -114.371800  62454.000000
# 8                   Ontario  -94.483333     49.766667
# 9     Newfoundland Labrador  -62.103056     56.334722
# 10                  Ontario  -79.250000     42.883333
# 11    Northwest Territories -110.270000  64497.000000
# 12                 Ontario   -90.080659     53.744635
# 13         British Columbia -114.892273     50.165463
# 14                  QuÃ©bec  -78.199994     48.362865
# 15                   Quebec  -73.958848     46.633467
# 16                   Quebec  -74.606781     45.672843
# 17                   Quebec  -77.823200     48.411200
# 18  TÃ©miscamingue, QuÃ©bec  -78.648611     47.685833
# 19                   Quebec  -75.001410     46.033450
#
#        Accuracy.of.location  \
# 0   MEDIUM (Regional level)
# 1        HIGH (Local level)
# 2   MEDIUM (Regional level)
# 3   MEDIUM (Regional level)
# 4   MEDIUM (Regional level)
# 5        HIGH (Local level)
# 6        HIGH (Local level)
# 7        HIGH (Local level)
# 8        HIGH (Local level)
# 9   MEDIUM (Regional level)
# 10  MEDIUM (Regional level)
# 11  MEDIUM (Regional level)
# 12  MEDIUM (Regional level)
# 13       HIGH (Local level)
# 14  MEDIUM (Regional level)
# 15  MEDIUM (Regional level)
# 16  MEDIUM (Regional level)
# 17  MEDIUM (Regional level)
# 18  MEDIUM (Regional level)
# 19  MEDIUM (Regional level)
#
#                                           Description  \
# 0   <p>The New Prosperity mine project is among th...
# 1   <p>The Tahltan First Nation in northern Britis...
# 2   <p>The Fandora mine conflict is a â€˜point of ...
# 3   <p>On August 4, 2014, the retaining dam at the...
# 4   <p>Strateco Resources Inc. Uranium Mine â€“ Th...
# 5   <p>We shall consider two related protests, out...
# 6   <p><b>Nunavut</b> is the largest in area and t...
# 7   <p>Gold was first discovered by prospectors in...
# 8   <p>The Ring of Fire refers to the massive plan...
# 9   <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10  <p>In Pearson (later Smith) v. Inco, the large...
# 11  <p>The Diavik Diamond Mine lays on the Lac de ...
# 12  <p>The Kitchenuhmaykoosib Inninuwug (KI) First...
# 13  <p>The Elk Valley mines are a conglomeration o...
# 14  <p>To fully understand the environmental, soci...
# 15  <p>Five kilometers southwest of the municipali...
# 16  <p>The Canadian company Canada Carbon's Miller...
# 17  <p>The North American Lithium (NAL) mine is lo...
# 18  <p>The Tansim open pit lithium mine project is...
# 19  <p><span id="docs-internal-guid-d2eb2d2d-7fff-...
#
#                                       Project.Details Type.of.Population  \
# 0   The mine is an open pit mine with a 70,000 tpd...              Rural
# 1   The project consists of 16,411 hectares of coa...              Rural
# 2   The area of Imperial Metal's Fandora property ...              Rural
# 3   The mine produced about 40,000,000 pounds of c...              Rural
# 4   Strateco Resources Inc. Uranium Mine â€“ The M...              Rural
# 5   (This refers to one of the proposed quarriesin...                NaN
# 6   "Baffinland Iron Mines Corporation (Baffinland...              Rural
# 7   The remediation project. The Giant Mine produc...              Rural
# 8   The Ring of Fire is a massive planned chromite...              Rural
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...              Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...              Urban
# 11  The Diavik Diamond Mine began production in 20...              Rural
# 12  Platinex is a small scale mineral exploration ...              Rural
# 13  The five mines operate on a 100km stretch of l...         Semi-urban
# 14  The project represents an annual production of...              Rural
# 15  The project includes 319 mining concessions (c...              Rural
# 16  The Miller mine is a historical deposit of gra...         Semi-urban
# 17  Open pit mine whose initial pit dimensions (50...              Rural
# 18  Located 82 kilometres southâ€west of Sayonaâ€...              Rural
# 19  <p dir="ltr" style="line-height:1.38;margin-to...              Rural
#
#                                 Intensity.of.Conflict  Start.Date End.Date  \
# 0      MEDIUM (street protests, visible mobilization)        2010      NaN
# 1      MEDIUM (street protests, visible mobilization)        2005      NaN
# 2                         LOW (some local organising)  21/07/2013      NaN
# 3      MEDIUM (street protests, visible mobilization)  04/05/2014      NaN
# 4                         LOW (some local organising)  01/01/2007      NaN
# 5      MEDIUM (street protests, visible mobilization)        1989      NaN
# 6      MEDIUM (street protests, visible mobilization)        2012      NaN
# 7      MEDIUM (street protests, visible mobilization)        1999      NaN
# 8      MEDIUM (street protests, visible mobilization)     08/2007      NaN
# 9      MEDIUM (street protests, visible mobilization)     11/1994      NaN
# 10                        LOW (some local organising)     06/2000  04/2012
# 11     MEDIUM (street protests, visible mobilization)  01/01/1999      NaN
# 12  HIGH (widespread, mass mobilization, violence,...  01/01/1999      NaN
# 13                        LOW (some local organising)  01/01/2013      NaN
# 14     MEDIUM (street protests, visible mobilization)  01/02/2018      NaN
# 15     MEDIUM (street protests, visible mobilization)  01/01/2017      NaN
# 16     MEDIUM (street protests, visible mobilization)  01/02/2017      NaN
# 17                        LOW (some local organising)        2010      NaN
# 18     MEDIUM (street protests, visible mobilization)  12/05/2021      NaN
# 19                        LOW (some local organising)  2022-05-17      NaN
#
#                                        Project.Status  \
# 0   Planned (decision to go ahead eg EIA undertake...
# 1                        Proposed (exploration phase)
# 2                        Proposed (exploration phase)
# 3                                             Stopped
# 4                                             Stopped
# 5                        Proposed (exploration phase)
# 6                                        In operation
# 7                                             Stopped
# 8   Planned (decision to go ahead eg EIA undertake...
# 9                                        In operation
# 10                                       In operation
# 11                                       In operation
# 12                       Proposed (exploration phase)
# 13                                       In operation
# 14  Planned (decision to go ahead eg EIA undertake...
# 15                                 Under construction
# 16  Planned (decision to go ahead eg EIA undertake...
# 17                                 Under construction
# 18  Planned (decision to go ahead eg EIA undertake...
# 19  Planned (decision to go ahead eg EIA undertake...
#
#                                            References
# 0   Revised Project Description\nhttp://www.newpro...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [1] Strateco Resources: Matoush Project Proper...
# 5   (5) Moving Mountains: Community and Resistance...
# 6   [5] Scobie, W. & Rodgers, K. (2013). Contestat...
# 7   [7] Sci Total Environ. 2018 Mar 15;618:916-926...
# 8   Annual Report from the Environmental Commissio...
# 9   (Mining Data Online, n.d.)\nhttps://miningdata...
# 10                                                NaN
# 11                                                NaN
# 12  [3] Ariss, Rachel. 2017. â€œPlatinex V. Kitche...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  [1] La Loutre Flake Graphite Property\nhttps:/...

# %%
mapping = {
    "ej_atlas_id": "Conflict.Id",
    "facility_name_ejatlas": "Site",
    "case_name": "Case",
    "longitude": "Lon",
    "latitude": "Lat",
    "province": "Province",
    "geolocation_accuracy": "Accuracy.of.location",
    "start_date": "Start.Date",
    "end_date": "End.Date",
    "conflict_description": "Description",
    "conflict_details": "Project.Details",
    "population_affected": "Type.of.Population",
    "conflict_intensity": "Intensity.of.Conflict",
    "project_status": "Project.Status",
    "reference": "References"
}

# Reverse the dictionary to match old name -> new name
reverse_mapping = {v: k for k, v in mapping.items()}

# Apply renaming to your DataFrame
conflict_df = ej_atlas_df.rename(columns=reverse_mapping)

# %%
conflict_gdf = convert_to_gdf(conflict_df)
conflict_gdf
# Out:
#     ej_atlas_id                                          case_name  \
# 0           384      New Prosperity Goldmine Fish Lake, BC, Canada
# 1           388     Tahltan Nation v. Fortune Minerals, BC, Canada
# 2          1635   Fandora Gold: Tofino-Tranquil (Onadsilth-Eels...
# 3          1852     Imperial Metals, Mount Polley Mine, BC, Canada
# 4          3408  Strateco Resources Inc. Uranium Mine in The Ma...
# 5          3615  Granite quarrying in Cap Breton, Nova Scotia, ...
# 6          3863  Iron Ore mining in Baffin island, Nunavut terr...
# 7          3883  Yellowknife gold mine and arsenic pollution, C...
# 8          4016                       Ring of Fire, Ontario Canada
# 9          4135      Vale Mining in Voisey's Bay, Labrador, Canada
# 10         4145  Port Colborne Class Action Lawsuit Against Val...
# 11         4894  Diavik Diamond mine by Rio Tinto and kimberlit...
# 12         4964  Kitchenuhmaykoosib Inninuwug peoples against p...
# 13         5068  Elk Valley Coal Mines Selenium Pollution in BC...
# 14         5597  Sayona Miningâ€™s Authier Lithium Project in Q...
# 15         5599  Nouveau Mondeâ€™s Matawinie graphite mine in Q...
# 16         5662  Canada Carbon's Miller graphite mine project, ...
# 17         5667  North American Lithium mining project, La Corn...
# 18         5681       Tansim open pit lithium mine project, Canada
# 19         6461                           La Loutre Mining Project
#
#                                 facility_name_ejatlas  \
# 0                                       Williams Lake
# 1                                               Iskut
# 2   Tla-o-qui-aht Traditional Territories includin...
# 3                                              Likely
# 4                                          Baie-James
# 5     Canso, Guysborough County, Cap Breton; also ...
# 6                                       Baffin island
# 7                                         Yellowknife
# 8              James Bay Lowlands of Northern Ontario
# 9                                        Voisey's Bay
# 10                                      Port Colborne
# 11                                        Lac de Gras
# 12                                    Big Trout Lake
# 13                                         Elk Valley
# 14                                           La Motte
# 15  Municipality of Saint-Michel-des-Saints  in Ma...
# 16  Canton of Grenville-sur-la Rouge, Regional Cou...
# 17                                           La Corne
# 18                                Moffet municipality
# 19                 Between Duhamel and Lac des Plages
#
#                    province   longitude      latitude  \
# 0          British Columbia -123.614383     51.450273
# 1          British Colombia -129.978400     57.835699
# 2          British Columbia -125.675538     49.249880
# 3          British Columbia -121.641667     52.554444
# 4                   QuÃ©bec  -72.089537     51.961643
# 5               Nova Scotia  -61.160800     45.340500
# 6                   Nunavut  -79.120000     71.190000
# 7     Northwest Territories -114.371800  62454.000000
# 8                   Ontario  -94.483333     49.766667
# 9     Newfoundland Labrador  -62.103056     56.334722
# 10                  Ontario  -79.250000     42.883333
# 11    Northwest Territories -110.270000  64497.000000
# 12                 Ontario   -90.080659     53.744635
# 13         British Columbia -114.892273     50.165463
# 14                  QuÃ©bec  -78.199994     48.362865
# 15                   Quebec  -73.958848     46.633467
# 16                   Quebec  -74.606781     45.672843
# 17                   Quebec  -77.823200     48.411200
# 18  TÃ©miscamingue, QuÃ©bec  -78.648611     47.685833
# 19                   Quebec  -75.001410     46.033450
#
#        geolocation_accuracy  \
# 0   MEDIUM (Regional level)
# 1        HIGH (Local level)
# 2   MEDIUM (Regional level)
# 3   MEDIUM (Regional level)
# 4   MEDIUM (Regional level)
# 5        HIGH (Local level)
# 6        HIGH (Local level)
# 7        HIGH (Local level)
# 8        HIGH (Local level)
# 9   MEDIUM (Regional level)
# 10  MEDIUM (Regional level)
# 11  MEDIUM (Regional level)
# 12  MEDIUM (Regional level)
# 13       HIGH (Local level)
# 14  MEDIUM (Regional level)
# 15  MEDIUM (Regional level)
# 16  MEDIUM (Regional level)
# 17  MEDIUM (Regional level)
# 18  MEDIUM (Regional level)
# 19  MEDIUM (Regional level)
#
#                                  conflict_description  \
# 0   <p>The New Prosperity mine project is among th...
# 1   <p>The Tahltan First Nation in northern Britis...
# 2   <p>The Fandora mine conflict is a â€˜point of ...
# 3   <p>On August 4, 2014, the retaining dam at the...
# 4   <p>Strateco Resources Inc. Uranium Mine â€“ Th...
# 5   <p>We shall consider two related protests, out...
# 6   <p><b>Nunavut</b> is the largest in area and t...
# 7   <p>Gold was first discovered by prospectors in...
# 8   <p>The Ring of Fire refers to the massive plan...
# 9   <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10  <p>In Pearson (later Smith) v. Inco, the large...
# 11  <p>The Diavik Diamond Mine lays on the Lac de ...
# 12  <p>The Kitchenuhmaykoosib Inninuwug (KI) First...
# 13  <p>The Elk Valley mines are a conglomeration o...
# 14  <p>To fully understand the environmental, soci...
# 15  <p>Five kilometers southwest of the municipali...
# 16  <p>The Canadian company Canada Carbon's Miller...
# 17  <p>The North American Lithium (NAL) mine is lo...
# 18  <p>The Tansim open pit lithium mine project is...
# 19  <p><span id="docs-internal-guid-d2eb2d2d-7fff-...
#
#                                      conflict_details population_affected  \
# 0   The mine is an open pit mine with a 70,000 tpd...               Rural
# 1   The project consists of 16,411 hectares of coa...               Rural
# 2   The area of Imperial Metal's Fandora property ...               Rural
# 3   The mine produced about 40,000,000 pounds of c...               Rural
# 4   Strateco Resources Inc. Uranium Mine â€“ The M...               Rural
# 5   (This refers to one of the proposed quarriesin...                 NaN
# 6   "Baffinland Iron Mines Corporation (Baffinland...               Rural
# 7   The remediation project. The Giant Mine produc...               Rural
# 8   The Ring of Fire is a massive planned chromite...               Rural
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...               Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...               Urban
# 11  The Diavik Diamond Mine began production in 20...               Rural
# 12  Platinex is a small scale mineral exploration ...               Rural
# 13  The five mines operate on a 100km stretch of l...          Semi-urban
# 14  The project represents an annual production of...               Rural
# 15  The project includes 319 mining concessions (c...               Rural
# 16  The Miller mine is a historical deposit of gra...          Semi-urban
# 17  Open pit mine whose initial pit dimensions (50...               Rural
# 18  Located 82 kilometres southâ€west of Sayonaâ€...               Rural
# 19  <p dir="ltr" style="line-height:1.38;margin-to...               Rural
#
#                                    conflict_intensity  start_date end_date  \
# 0      MEDIUM (street protests, visible mobilization)        2010      NaN
# 1      MEDIUM (street protests, visible mobilization)        2005      NaN
# 2                         LOW (some local organising)  21/07/2013      NaN
# 3      MEDIUM (street protests, visible mobilization)  04/05/2014      NaN
# 4                         LOW (some local organising)  01/01/2007      NaN
# 5      MEDIUM (street protests, visible mobilization)        1989      NaN
# 6      MEDIUM (street protests, visible mobilization)        2012      NaN
# 7      MEDIUM (street protests, visible mobilization)        1999      NaN
# 8      MEDIUM (street protests, visible mobilization)     08/2007      NaN
# 9      MEDIUM (street protests, visible mobilization)     11/1994      NaN
# 10                        LOW (some local organising)     06/2000  04/2012
# 11     MEDIUM (street protests, visible mobilization)  01/01/1999      NaN
# 12  HIGH (widespread, mass mobilization, violence,...  01/01/1999      NaN
# 13                        LOW (some local organising)  01/01/2013      NaN
# 14     MEDIUM (street protests, visible mobilization)  01/02/2018      NaN
# 15     MEDIUM (street protests, visible mobilization)  01/01/2017      NaN
# 16     MEDIUM (street protests, visible mobilization)  01/02/2017      NaN
# 17                        LOW (some local organising)        2010      NaN
# 18     MEDIUM (street protests, visible mobilization)  12/05/2021      NaN
# 19                        LOW (some local organising)  2022-05-17      NaN
#
#                                        project_status  \
# 0   Planned (decision to go ahead eg EIA undertake...
# 1                        Proposed (exploration phase)
# 2                        Proposed (exploration phase)
# 3                                             Stopped
# 4                                             Stopped
# 5                        Proposed (exploration phase)
# 6                                        In operation
# 7                                             Stopped
# 8   Planned (decision to go ahead eg EIA undertake...
# 9                                        In operation
# 10                                       In operation
# 11                                       In operation
# 12                       Proposed (exploration phase)
# 13                                       In operation
# 14  Planned (decision to go ahead eg EIA undertake...
# 15                                 Under construction
# 16  Planned (decision to go ahead eg EIA undertake...
# 17                                 Under construction
# 18  Planned (decision to go ahead eg EIA undertake...
# 19  Planned (decision to go ahead eg EIA undertake...
#
#                                             reference  \
# 0   Revised Project Description\nhttp://www.newpro...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [1] Strateco Resources: Matoush Project Proper...
# 5   (5) Moving Mountains: Community and Resistance...
# 6   [5] Scobie, W. & Rodgers, K. (2013). Contestat...
# 7   [7] Sci Total Environ. 2018 Mar 15;618:916-926...
# 8   Annual Report from the Environmental Commissio...
# 9   (Mining Data Online, n.d.)\nhttps://miningdata...
# 10                                                NaN
# 11                                                NaN
# 12  [3] Ariss, Rachel. 2017. â€œPlatinex V. Kitche...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  [1] La Loutre Flake Graphite Property\nhttps:/...
#
#                           geometry
# 0      POINT (-123.61438 51.45027)
# 1      POINT (-129.97840 57.83570)
# 2      POINT (-125.67554 49.24988)
# 3      POINT (-121.64167 52.55444)
# 4       POINT (-72.08954 51.96164)
# 5       POINT (-61.16080 45.34050)
# 6       POINT (-79.12000 71.19000)
# 7   POINT (-114.37180 62454.00000)
# 8       POINT (-94.48333 49.76667)
# 9       POINT (-62.10306 56.33472)
# 10      POINT (-79.25000 42.88333)
# 11  POINT (-110.27000 64497.00000)
# 12      POINT (-90.08066 53.74464)
# 13     POINT (-114.89227 50.16546)
# 14      POINT (-78.19999 48.36286)
# 15      POINT (-73.95885 46.63347)
# 16      POINT (-74.60678 45.67284)
# 17      POINT (-77.82320 48.41120)
# 18      POINT (-78.64861 47.68583)
# 19      POINT (-75.00141 46.03345)

# %% [markdown]
# ### GHG dataset from large facilities

# %%
ghg_columns = {
    "ghg_id": "text",
    "facility_name_ghg": "text",
    "longitude": "float",   
    "latitude": "float",
    "city": "text",
    "province": "text",
    "year": "integer",
    "sector": "text",
    "value": "float",
    "unit": "text", 
    "facility_url" : "url",
    "source_id": "text"
}

ghg_df = pd.DataFrame(columns=ghg_columns.keys())
ghg_df
# Out:
# Empty DataFrame
# Columns: [ghg_id, facility_name_ghg, longitude, latitude, city, province, year, sector, value, unit, facility_url, source_id]
# Index: []

# %%
# Based on concordances tables
column_mapping_ghg = {
    "ghg_facility_metal_mining_df": {
        "Facility ID": "ghg_id",
        "Facility name": "facility_name_ghg",
        "Latitude": "latitude",
        "Longitude": "longitude",
        "City": "city",
        "Province": "province",
        "Report year": "year",
        "Industry classification": "sector",
        "Total emissions": "value",
        "Units": "unit",
        "Facility information": "facility_url",
 
    },
    
    "ghg_facility_metal_manufacturing_df": {
        "Facility ID": "ghg_id",
        "Facility name": "facility_name_ghg",
        "Latitude": "latitude",
        "Longitude": "longitude",
        "City": "city",
        "Province": "province",
        "Report year": "year",
        "Industry classification": "sector",
        "Total emissions": "value",
        "Units": "unit",
        "Facility information": "facility_url",
    }, 
    }

# %%
ghg_df = populate_table_df(
                           column_mapping_ghg, 
                           ghg_df,
                            source_dfs = {
                                  "ghg_facility_metal_mining_df": ghg_facility_metal_mining_df,
                                  "ghg_facility_metal_manufacturing_df": ghg_facility_metal_manufacturing_df}
)
# Out:
# Initial facility_df rows: 0
# Processing DataFrame: ghg_facility_metal_mining_df
# Temp DF rows to append: 111
# Rows in facility_df after appending ghg_facility_metal_mining_df: 111
# Processing DataFrame: ghg_facility_metal_manufacturing_df
# Temp DF rows to append: 73
# Rows in facility_df after appending ghg_facility_metal_manufacturing_df: 184
# Final facility_df rows: 184
# C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\canada_metal_sustainability_db\db_creation_function.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   facility_df = pd.concat([facility_df, temp_df], ignore_index=True)

# %%
ghg_df
# Out:
#     ghg_id                      facility_name_ghg  longitude  latitude  \
# 0    10052                          Carol Project  -66.90020  52.95200
# 1    10101                     Ekati Diamond Mine -110.62010  64.71950
# 2    10140   HBMS Flin Flon Metallurgical Complex -101.88400  54.77100
# 3    10164                Kidd Metallurgical Site  -81.09115  48.57373
# 4    10188                    Mine de Mont-Wright  -67.33306  52.76639
# ..     ...                                    ...        ...       ...
# 179  12301              GRIFFIN CANADA - WINNIPEG  -97.00250  49.91300
# 180  12554                 Molycop Canada Plant 2 -120.09703  50.65598
# 181  12555                        Moly-Cop Canada -120.09649  50.65726
# 182  12579                       Fonderie Laperle  -73.13870  45.89470
# 183  12581  Extrusion North America - Mississauga  -79.65750  43.63060
#
#                              city                   province  year  \
# 0                   Labrador City  Newfoundland and Labrador  2022
# 1                     Yellowknife      Northwest Territories  2022
# 2                       Flin Flon                   Manitoba  2022
# 3    Timmins District of Cochrane                    Ontario  2022
# 4                         Fermont                     Quebec  2022
# ..                            ...                        ...   ...
# 179                      Winnipeg                   Manitoba  2022
# 180                      Kamloops           British Columbia  2022
# 181                      Kamloops           British Columbia  2022
# 182                    Saint Ours                     Quebec  2022
# 183                   Mississauga                    Ontario  2022
#
#                                                 sector   value  \
# 0                                      Iron Ore Mining  826.03
# 1                                       Diamond Mining  164.88
# 2                               Copper-Zinc Ore Mining   29.73
# 3                               Copper-Zinc Ore Mining   30.82
# 4                                      Iron Ore Mining  293.10
# ..                                                 ...     ...
# 179                                    Steel Foundries     NaN
# 180                                     Iron Foundries     NaN
# 181                                     Iron Foundries   25.12
# 182                                     Iron Foundries    0.51
# 183  Aluminum Rolling, Drawing, Extruding and Alloying    4.89
#
#                                                   unit  \
# 0    kilotonnes of carbon dioxide equivalents (kt C...
# 1    kilotonnes of carbon dioxide equivalents (kt C...
# 2    kilotonnes of carbon dioxide equivalents (kt C...
# 3    kilotonnes of carbon dioxide equivalents (kt C...
# 4    kilotonnes of carbon dioxide equivalents (kt C...
# ..                                                 ...
# 179  kilotonnes of carbon dioxide equivalents (kt C...
# 180  kilotonnes of carbon dioxide equivalents (kt C...
# 181  kilotonnes of carbon dioxide equivalents (kt C...
# 182  kilotonnes of carbon dioxide equivalents (kt C...
# 183  kilotonnes of carbon dioxide equivalents (kt C...
#
#                                           facility_url source_id
# 0    https://climate-change.canada.ca/facility-emis...       NaN
# 1    https://climate-change.canada.ca/facility-emis...       NaN
# 2    https://climate-change.canada.ca/facility-emis...       NaN
# 3    https://climate-change.canada.ca/facility-emis...       NaN
# 4    https://climate-change.canada.ca/facility-emis...       NaN
# ..                                                 ...       ...
# 179  https://climate-change.canada.ca/facility-emis...       NaN
# 180  https://climate-change.canada.ca/facility-emis...       NaN
# 181  https://climate-change.canada.ca/facility-emis...       NaN
# 182  https://climate-change.canada.ca/facility-emis...       NaN
# 183  https://climate-change.canada.ca/facility-emis...       NaN
#
# [184 rows x 12 columns]

# %%
ghg_gdf = convert_to_gdf(ghg_df)

# %%
ghg_gdf = add_year(ghg_gdf, 2022)

# %%
ghg_gdf = assign_row_id(ghg_gdf,
                        facility_id_col='ghg_id',
                        prefix='GHG', 
                        year_col='year')

# %%
ghg_gdf
# Out:
#                row_id  year ghg_id                      facility_name_ghg  \
# 0    GHG-10052-2022-1  2022  10052                          Carol Project
# 1    GHG-10101-2022-1  2022  10101                     Ekati Diamond Mine
# 2    GHG-10140-2022-1  2022  10140   HBMS Flin Flon Metallurgical Complex
# 3    GHG-10164-2022-1  2022  10164                Kidd Metallurgical Site
# 4    GHG-10188-2022-1  2022  10188                    Mine de Mont-Wright
# ..                ...   ...    ...                                    ...
# 179  GHG-12301-2022-1  2022  12301              GRIFFIN CANADA - WINNIPEG
# 180  GHG-12554-2022-1  2022  12554                 Molycop Canada Plant 2
# 181  GHG-12555-2022-1  2022  12555                        Moly-Cop Canada
# 182  GHG-12579-2022-1  2022  12579                       Fonderie Laperle
# 183  GHG-12581-2022-1  2022  12581  Extrusion North America - Mississauga
#
#      longitude  latitude                          city  \
# 0    -66.90020  52.95200                 Labrador City
# 1   -110.62010  64.71950                   Yellowknife
# 2   -101.88400  54.77100                     Flin Flon
# 3    -81.09115  48.57373  Timmins District of Cochrane
# 4    -67.33306  52.76639                       Fermont
# ..         ...       ...                           ...
# 179  -97.00250  49.91300                      Winnipeg
# 180 -120.09703  50.65598                      Kamloops
# 181 -120.09649  50.65726                      Kamloops
# 182  -73.13870  45.89470                    Saint Ours
# 183  -79.65750  43.63060                   Mississauga
#
#                       province  \
# 0    Newfoundland and Labrador
# 1        Northwest Territories
# 2                     Manitoba
# 3                      Ontario
# 4                       Quebec
# ..                         ...
# 179                   Manitoba
# 180           British Columbia
# 181           British Columbia
# 182                     Quebec
# 183                    Ontario
#
#                                                 sector   value  \
# 0                                      Iron Ore Mining  826.03
# 1                                       Diamond Mining  164.88
# 2                               Copper-Zinc Ore Mining   29.73
# 3                               Copper-Zinc Ore Mining   30.82
# 4                                      Iron Ore Mining  293.10
# ..                                                 ...     ...
# 179                                    Steel Foundries     NaN
# 180                                     Iron Foundries     NaN
# 181                                     Iron Foundries   25.12
# 182                                     Iron Foundries    0.51
# 183  Aluminum Rolling, Drawing, Extruding and Alloying    4.89
#
#                                                   unit  \
# 0    kilotonnes of carbon dioxide equivalents (kt C...
# 1    kilotonnes of carbon dioxide equivalents (kt C...
# 2    kilotonnes of carbon dioxide equivalents (kt C...
# 3    kilotonnes of carbon dioxide equivalents (kt C...
# 4    kilotonnes of carbon dioxide equivalents (kt C...
# ..                                                 ...
# 179  kilotonnes of carbon dioxide equivalents (kt C...
# 180  kilotonnes of carbon dioxide equivalents (kt C...
# 181  kilotonnes of carbon dioxide equivalents (kt C...
# 182  kilotonnes of carbon dioxide equivalents (kt C...
# 183  kilotonnes of carbon dioxide equivalents (kt C...
#
#                                           facility_url source_id  \
# 0    https://climate-change.canada.ca/facility-emis...       NaN
# 1    https://climate-change.canada.ca/facility-emis...       NaN
# 2    https://climate-change.canada.ca/facility-emis...       NaN
# 3    https://climate-change.canada.ca/facility-emis...       NaN
# 4    https://climate-change.canada.ca/facility-emis...       NaN
# ..                                                 ...       ...
# 179  https://climate-change.canada.ca/facility-emis...       NaN
# 180  https://climate-change.canada.ca/facility-emis...       NaN
# 181  https://climate-change.canada.ca/facility-emis...       NaN
# 182  https://climate-change.canada.ca/facility-emis...       NaN
# 183  https://climate-change.canada.ca/facility-emis...       NaN
#
#                         geometry
# 0     POINT (-66.90020 52.95200)
# 1    POINT (-110.62010 64.71950)
# 2    POINT (-101.88400 54.77100)
# 3     POINT (-81.09115 48.57373)
# 4     POINT (-67.33306 52.76639)
# ..                           ...
# 179   POINT (-97.00250 49.91300)
# 180  POINT (-120.09703 50.65598)
# 181  POINT (-120.09649 50.65726)
# 182   POINT (-73.13870 45.89470)
# 183   POINT (-79.65750 43.63060)
#
# [184 rows x 14 columns]

# %% [markdown]
# ### NPRI dataset

# %%
pollutant_columns = {
    "npri_id": "int",
    "facility_name_npri": "text",
    "company_name_npri": "text",
    "facility_type": "text",
    "longitude": "float",
    "latitude": "float",
    "year": "integer",
    "terrestrial_ecozone": "text",
    "watershed": "text",
    "substance_name_npri": "text",
    "substance_name_ecoinvent": "text",
    "substance_unit": "text",
    "emission_type": "text",
    "emission_subtype": "text",
    "value": "float",
    "source_id": "text"
}

# Create an empty DataFrame with the specified columns
pollutant_df = pd.DataFrame(columns=pollutant_columns.keys())

# %%
column_mapping_pollutant = {
    "npri_metal_mining_df": {
        "NPRI ID": "npri_id",
        "Facility Name": "facility_name_npri",
        "Company Name": "company_name_npri", 
        "Latitude": "latitude",
        "Longitude": "longitude",
        "Year": "year",
        "Terrestrial ecozone (English) ": "terrestrial_ecozone", 
        "Watershed (English)": "watershed",
        "Substance Name (English)": "substance_name_npri",
        "EI": "substance_name_ecoinvent",
        "Units": "substance_unit",
        "emission_type": "emission_type",
        "emission_subtype": "emission_subtype",
        "value": "value"
    },
    
    "npri_metal_manufacturing_df": {
        "NPRI ID": "npri_id",
        "Facility Name": "facility_name_npri",
        "Latitude": "latitude",
        "Longitude": "longitude",
        "Year": "year",
        "Terrestrial ecozone (English) ": "terrestrial_ecozone", # space 
        "Watershed (English)": "watershed",
        "Substance Name (English)": "substance_name_npri",
        "EI": "substance_name_ecoinvent",
        "Units": "substance_unit",
        "emission_type": "emission_type",
        "emission_subtype": "emission_subtype",
        "value": "value"
    }
}

# %%
pollutant_df = populate_table_df(column_mapping_pollutant, 
                                    pollutant_df,
                                    dynamic_columns = {
                                        "facility_type": {
                                            "npri_metal_mining_df": "mining",
                                            "npri_metal_manufacturing_df": "manufacturing"
                                        },
                                    },
                                    source_dfs = {
                                  "npri_metal_mining_df": npri_metal_mining_df,
                                  "npri_metal_manufacturing_df": npri_metal_manufacturing_df
                                    }
                                    )
# Out:
# Initial facility_df rows: 0
# Processing DataFrame: npri_metal_mining_df
# Temp DF rows to append: 13284
# Rows in facility_df after appending npri_metal_mining_df: 13284
# Processing DataFrame: npri_metal_manufacturing_df
# Temp DF rows to append: 10846
# C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\canada_metal_sustainability_db\db_creation_function.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   facility_df = pd.concat([facility_df, temp_df], ignore_index=True)
# Rows in facility_df after appending npri_metal_manufacturing_df: 24130
# Final facility_df rows: 24130

# %%
pollutant_gdf = convert_to_gdf(pollutant_df)

# %%
pollutant_gdf = add_year(pollutant_gdf, 2023)

# %%
pollutant_gdf = assign_row_id(pollutant_gdf,
                        facility_id_col='npri_id',
                        prefix='npri',
                        year_col='year'
                              )

# %%
pollutant_gdf
# Out:
#                   row_id  year npri_id     facility_name_npri  \
# 0       npri-1568-2023-1  2023    1568           Macassa Mine
# 1       npri-1568-2023-2  2023    1568           Macassa Mine
# 2       npri-1568-2023-3  2023    1568           Macassa Mine
# 3       npri-1568-2023-4  2023    1568           Macassa Mine
# 4       npri-1568-2023-5  2023    1568           Macassa Mine
# ...                  ...   ...     ...                    ...
# 24125   npri-5697-2023-6  2023    5697  Rayette Manufacturing
# 24126   npri-5698-2023-6  2023    5698    Bowes Manufacturing
# 24127  npri-34697-2023-2  2023   34697    541 Bowes Warehouse
# 24128   npri-5697-2023-7  2023    5697  Rayette Manufacturing
# 24129   npri-5698-2023-7  2023    5698    Bowes Manufacturing
#
#         company_name_npri  facility_type  longitude  latitude  \
# 0      Agnico Eagle Mines         mining  -80.08734  48.13032
# 1      Agnico Eagle Mines         mining  -80.08734  48.13032
# 2      Agnico Eagle Mines         mining  -80.08734  48.13032
# 3      Agnico Eagle Mines         mining  -80.08734  48.13032
# 4      Agnico Eagle Mines         mining  -80.08734  48.13032
# ...                   ...            ...        ...       ...
# 24125                 NaN  manufacturing  -79.49600  43.80800
# 24126                 NaN  manufacturing  -79.49480  43.80360
# 24127                 NaN  manufacturing  -79.49707  43.81726
# 24128                 NaN  manufacturing  -79.49600  43.80800
# 24129                 NaN  manufacturing  -79.49480  43.80360
#
#       terrestrial_ecozone                   watershed  \
# 0           Boreal Shield  St. Lawrence Drainage Area
# 1           Boreal Shield  St. Lawrence Drainage Area
# 2           Boreal Shield  St. Lawrence Drainage Area
# 3           Boreal Shield  St. Lawrence Drainage Area
# 4           Boreal Shield  St. Lawrence Drainage Area
# ...                   ...                         ...
# 24125     Mixedwood Plain  St. Lawrence Drainage Area
# 24126     Mixedwood Plain  St. Lawrence Drainage Area
# 24127     Mixedwood Plain  St. Lawrence Drainage Area
# 24128     Mixedwood Plain  St. Lawrence Drainage Area
# 24129     Mixedwood Plain  St. Lawrence Drainage Area
#
#                               substance_name_npri substance_name_ecoinvent  \
# 0                                 Ammonia (total)                  Ammonia
# 1                     Arsenic (and its compounds)                  Arsenic
# 2                                 Carbon monoxide  Carbon monoxide, fossil
# 3                    Chromium (and its compounds)                 Chromium
# 4                      Cobalt (and its compounds)                   Cobalt
# ...                                           ...                      ...
# 24125  Speciated VOC - Hydrotreated heavy naphtha                      NaN
# 24126  Speciated VOC - Hydrotreated heavy naphtha                      NaN
# 24127  Speciated VOC - Hydrotreated heavy naphtha                      NaN
# 24128          Volatile Organic Compounds (Total)                      NaN
# 24129          Volatile Organic Compounds (Total)                      NaN
#
#       substance_unit                      emission_type  \
# 0             tonnes  Air Emissions / Émissions à l'air
# 1                 kg  Air Emissions / Émissions à l'air
# 2             tonnes  Air Emissions / Émissions à l'air
# 3             tonnes  Air Emissions / Émissions à l'air
# 4                 kg  Air Emissions / Émissions à l'air
# ...              ...                                ...
# 24125         tonnes                        Grand Total
# 24126         tonnes                        Grand Total
# 24127         tonnes                        Grand Total
# 24128         tonnes                        Grand Total
# 24129         tonnes                        Grand Total
#
#                                         emission_subtype      value source_id  \
# 0                                        Stack Emissions      0.636       NaN
# 1                                        Stack Emissions      0.116       NaN
# 2                                        Stack Emissions     76.208       NaN
# 3                                        Stack Emissions    0.00105       NaN
# 4                                        Stack Emissions       0.18       NaN
# ...                                                  ...        ...       ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008       NaN
# 24126  Total Releases, Disposals and Transfers for Re...     23.418       NaN
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746       NaN
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823       NaN
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719       NaN
#
#                          geometry
# 0      POINT (-80.08734 48.13032)
# 1      POINT (-80.08734 48.13032)
# 2      POINT (-80.08734 48.13032)
# 3      POINT (-80.08734 48.13032)
# 4      POINT (-80.08734 48.13032)
# ...                           ...
# 24125  POINT (-79.49600 43.80800)
# 24126  POINT (-79.49480 43.80360)
# 24127  POINT (-79.49707 43.81726)
# 24128  POINT (-79.49600 43.80800)
# 24129  POINT (-79.49480 43.80360)
#
# [24130 rows x 18 columns]

# %% [markdown]
# ## Children datasets with same coordinates as the main (no matching needed)

# %%
import rasterio

# %%
from gee_extraction import load_raster, extract_climate_for_facilities, extract_peatland_presence

# %% [markdown]
# ### Prioritization area from Jung et al. (2021)

# %%
# Correct way (use raw string or forward slashes)
raster_path = r"data/Sources/Jung_2021/5006332/BiodiversityCarbonWater/BiodiversityCarbonWater/10km/minshort_speciestargets_biome.id_withPA_carbon__water__esh10km_repruns10_ranked.tif"

# %%
prioritization_area_gdf = main_gdf.copy()
col_to_keep = ['main_id', 'facility_name', 'longitude', 'latitude', 'geometry']
prioritization_area_gdf = prioritization_area_gdf[col_to_keep]

# %%
from gee_extraction import extract_prioritization_area

# %%
prioritization_area_gdf = extract_prioritization_area(prioritization_area_gdf, raster_path)

# %%
prioritization_area_gdf
# Out:
#               main_id      facility_name                     geometry  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue   POINT (-77.67901 48.52154)
# 1    QC-MAIN-d29e0839     Sleeping Giant   POINT (-77.97434 49.13259)
# 2    QC-MAIN-f1ff4920       Akasaba West   POINT (-77.58000 48.04000)
# 3    NU-MAIN-4ea8ac9d             Amaruq   POINT (-96.69700 65.41500)
# 4    QC-MAIN-e7e6a960  Canadian Malartic   POINT (-78.13082 48.12222)
# ..                ...                ...                          ...
# 265  ON-MAIN-c5fefb01              Mishi   POINT (-85.45250 48.11028)
# 266  BC-MAIN-feb13c30       Record Ridge  POINT (-117.88400 49.08200)
# 267  YT-MAIN-5e0d8b48             Casino  POINT (-138.83333 62.73333)
# 268  ON-MAIN-12c68d49       Eagle's Nest   POINT (-86.30380 52.74202)
# 269  BC-MAIN-891d3cb5               Akie  POINT (-124.86599 57.38088)
#
#      jung_priority_point  jung_priority_mean_50km
# 0              25.926612                22.025641
# 1              13.000000                15.775000
# 2              20.618888                21.125000
# 3              63.927000                58.076923
# 4              21.186758                21.166667
# ..                   ...                      ...
# 265            21.298652                19.614286
# 266            47.846798                41.093333
# 267            67.371530                66.961039
# 268            14.300865                14.189873
# 269            35.079117                35.333333
#
# [270 rows x 5 columns]

# %% [markdown]
# ### Climate categories from Beck et al (2023)

# %%
climate_category_gdf = main_gdf.copy()
col_to_keep = ['main_id', 'facility_name', 'longitude', 'latitude', 'geometry']
climate_category_gdf = climate_category_gdf[col_to_keep]

# %%
periods = ["1991_2020", "2041_2070", "2071_2099"]
scenarios = ["ssp126",
             "ssp245", "ssp370", "ssp585"]
resolution = "0p00833333" #0.00833333°, ~1 km

# Extract climate categories
climate_category_gdf = extract_climate_for_facilities(climate_category_gdf, periods, scenarios, resolution)

# %%
from constants import koppen_dict
climate_category_gdf["category"] = climate_category_gdf["category"].map(koppen_dict)

# %%
climate_category_gdf = assign_row_id(climate_category_gdf,
                  facility_id_col='main_id',
                  prefix='CC',
                  year_col='year',
                  scenario_col='scenario'
                  )

# %%
climate_category_gdf
# Out:
#                                   row_id           main_id               name  \
# 0     CC-5801b453-1991_2020-historical-1  QC-MAIN-5801b453     Abcourt-Barvue
# 1     CC-d29e0839-1991_2020-historical-1  QC-MAIN-d29e0839     Sleeping Giant
# 2     CC-f1ff4920-1991_2020-historical-1  QC-MAIN-f1ff4920       Akasaba West
# 3     CC-4ea8ac9d-1991_2020-historical-1  NU-MAIN-4ea8ac9d             Amaruq
# 4     CC-e7e6a960-1991_2020-historical-1  QC-MAIN-e7e6a960  Canadian Malartic
# ...                                  ...               ...                ...
# 2425      CC-c5fefb01-2071_2099-ssp585-1  ON-MAIN-c5fefb01              Mishi
# 2426      CC-feb13c30-2071_2099-ssp585-1  BC-MAIN-feb13c30       Record Ridge
# 2427      CC-5e0d8b48-2071_2099-ssp585-1  YT-MAIN-5e0d8b48             Casino
# 2428      CC-12c68d49-2071_2099-ssp585-1  ON-MAIN-12c68d49       Eagle's Nest
# 2429      CC-891d3cb5-2071_2099-ssp585-1  BC-MAIN-891d3cb5               Akie
#
#                          geometry       year    scenario  \
# 0      POINT (-77.67901 48.52154)  1991_2020  historical
# 1      POINT (-77.97434 49.13259)  1991_2020  historical
# 2      POINT (-77.58000 48.04000)  1991_2020  historical
# 3      POINT (-96.69700 65.41500)  1991_2020  historical
# 4      POINT (-78.13082 48.12222)  1991_2020  historical
# ...                           ...        ...         ...
# 2425   POINT (-85.45250 48.11028)  2071_2099      ssp585
# 2426  POINT (-117.88400 49.08200)  2071_2099      ssp585
# 2427  POINT (-138.83333 62.73333)  2071_2099      ssp585
# 2428   POINT (-86.30380 52.74202)  2071_2099      ssp585
# 2429  POINT (-124.86599 57.38088)  2071_2099      ssp585
#
#                                     category
# 0     Dfb - Cold, no dry season, warm summer
# 1     Dfb - Cold, no dry season, warm summer
# 2     Dfb - Cold, no dry season, warm summer
# 3     Dfc - Cold, no dry season, cold summer
# 4     Dfb - Cold, no dry season, warm summer
# ...                                      ...
# 2425  Dfb - Cold, no dry season, warm summer
# 2426     Dsb - Cold, dry summer, warm summer
# 2427  Dfc - Cold, no dry season, cold summer
# 2428   Dfa - Cold, no dry season, hot summer
# 2429  Dfc - Cold, no dry season, cold summer
#
# [2430 rows x 7 columns]

# %% [markdown]
# ### Peatland dataset

# %%
peatland_tiff = "data\Sources\Global_Peatland_DB_2022\GLOpeat_GPA22WGS_2cl_1x1km\peatGPA22WGS_2cl.tif"
raster_peatland = rasterio.open(peatland_tiff)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_12512\1711991965.py:1: SyntaxWarning: invalid escape sequence '\S'
#   peatland_tiff = "data\Sources\Global_Peatland_DB_2022\GLOpeat_GPA22WGS_2cl_1x1km\peatGPA22WGS_2cl.tif"

# %%
raster_peatland
# Out:
# <open DatasetReader name='data\Sources\Global_Peatland_DB_2022\GLOpeat_GPA22WGS_2cl_1x1km\peatGPA22WGS_2cl.tif' mode='r'>

# %%
peatland_gdf = main_gdf.copy()
col_to_keep = ['main_id', 'facility_name', 'longitude', 'latitude', 'geometry']
peatland_gdf = peatland_gdf[col_to_keep]

# %%
# Extract peatland values for each point
peatland_gdf["peatland_presence"] = peatland_gdf["geometry"].apply(
    lambda geom: extract_peatland_presence(geom, raster_peatland)
)

# %%
from constants import peatland_dict
peatland_gdf["peatland_presence"] = peatland_gdf["peatland_presence"].map(peatland_dict)

# %%
peatland_gdf
# Out:
#               main_id      facility_name   longitude   latitude  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue  -77.679010  48.521540
# 1    QC-MAIN-d29e0839     Sleeping Giant  -77.974340  49.132590
# 2    QC-MAIN-f1ff4920       Akasaba West  -77.580000  48.040000
# 3    NU-MAIN-4ea8ac9d             Amaruq  -96.697000  65.415000
# 4    QC-MAIN-e7e6a960  Canadian Malartic  -78.130824  48.122223
# ..                ...                ...         ...        ...
# 265  ON-MAIN-c5fefb01              Mishi  -85.452500  48.110280
# 266  BC-MAIN-feb13c30       Record Ridge -117.884000  49.082000
# 267  YT-MAIN-5e0d8b48             Casino -138.833330  62.733330
# 268  ON-MAIN-12c68d49       Eagle's Nest  -86.303800  52.742020
# 269  BC-MAIN-891d3cb5               Akie -124.865990  57.380880
#
#                         geometry    peatland_presence
# 0     POINT (-77.67901 48.52154)              No data
# 1     POINT (-77.97434 49.13259)  peat in soil mosaic
# 2     POINT (-77.58000 48.04000)       peat dominated
# 3     POINT (-96.69700 65.41500)              No data
# 4     POINT (-78.13082 48.12222)              No data
# ..                           ...                  ...
# 265   POINT (-85.45250 48.11028)              No data
# 266  POINT (-117.88400 49.08200)              No data
# 267  POINT (-138.83333 62.73333)              No data
# 268   POINT (-86.30380 52.74202)       peat dominated
# 269  POINT (-124.86599 57.38088)              No data
#
# [270 rows x 6 columns]

# %% [markdown]
# ### Temperature and precipitation change dataset

# %%
from gee_extraction import extract_variable_from_nc

# %%
weather_gdf = main_gdf.copy()
col_to_keep = ['main_id', 'facility_name', 'longitude', 'latitude', 'geometry']
weather_gdf = weather_gdf[col_to_keep]

# %%
# daily temperature range
dtr_path_ssp126 = r'data\Sources\CanDCS\mbcn_dtr_index_m6_ssp126_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'
dtr_path_ssp245 = r'data\Sources\CanDCS\mbcn_dtr_index_m6_ssp245_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'
dtr_path_ssp370 = r'data\Sources\CanDCS\mbcn_dtr_index_m6_ssp370_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'
dtr_path_ssp585 = r'data\Sources\CanDCS\mbcn_dtr_index_m6_ssp585_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'

# %%
# annual total precipitation in wet days
prcptot_path_ssp126 = r'data\Sources\CanDCS\mbcn_prcptot_index_m6_ssp126_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'  
prcptot_path_ssp245 = r'data\Sources\CanDCS\mbcn_prcptot_index_m6_ssp245_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'
prcptot_path_ssp370 = r'data\Sources\CanDCS\mbcn_prcptot_index_m6_ssp370_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'  
prcptot_path_ssp58 = r'data\Sources\CanDCS\mbcn_prcptot_index_m6_ssp585_ens-ensemblemean_145.960W_39.040N_47.040W_85.460N_2025-2100-yearly.nc'

# %%
all_weather = []

for path, var_key, label, scenario, unit in [
    (dtr_path_ssp126, "dtrETCCDI", "Daily Temperature Range", "ssp126", "°C"),
    (dtr_path_ssp245, "dtrETCCDI", "Daily Temperature Range", "ssp245", "°C"),
    (dtr_path_ssp370, "dtrETCCDI", "Daily Temperature Range", "ssp370", "°C"),
    (dtr_path_ssp585, "dtrETCCDI", "Daily Temperature Range", "ssp585", "°C"),
    (prcptot_path_ssp126, "prcptotETCCDI", "Annual Precipitation", "ssp126", "mm"),
    (prcptot_path_ssp245, "prcptotETCCDI", "Annual Precipitation", "ssp245", "mm"),
    (prcptot_path_ssp370, "prcptotETCCDI", "Annual Precipitation", "ssp370", "mm"),
    (prcptot_path_ssp58, "prcptotETCCDI", "Annual Precipitation", "ssp585", "mm")
]:
    gdf = extract_variable_from_nc(
        path,
        variable_label=label,
        var_key=var_key,
        facilities_gdf=weather_gdf,
        scenario=scenario,
        unit=unit
    )
    all_weather.append(gdf)

# Combine all into one GeoDataFrame
weather_gdf = pd.concat(all_weather, ignore_index=True)

# %%
weather_gdf = assign_row_id(weather_gdf,
                  facility_id_col='main_id',
                  prefix='weather',
                  year_col='year',
                  scenario_col='scenario'
                  )

# %%
weather_gdf
# Out:
#                                 row_id           main_id            name  \
# 0       weather-5801b453-2025-ssp126-1  QC-MAIN-5801b453  Abcourt-Barvue
# 1       weather-5801b453-2026-ssp126-1  QC-MAIN-5801b453  Abcourt-Barvue
# 2       weather-5801b453-2027-ssp126-1  QC-MAIN-5801b453  Abcourt-Barvue
# 3       weather-5801b453-2028-ssp126-1  QC-MAIN-5801b453  Abcourt-Barvue
# 4       weather-5801b453-2029-ssp126-1  QC-MAIN-5801b453  Abcourt-Barvue
# ...                                ...               ...             ...
# 164155  weather-891d3cb5-2096-ssp585-2  BC-MAIN-891d3cb5            Akie
# 164156  weather-891d3cb5-2097-ssp585-2  BC-MAIN-891d3cb5            Akie
# 164157  weather-891d3cb5-2098-ssp585-2  BC-MAIN-891d3cb5            Akie
# 164158  weather-891d3cb5-2099-ssp585-2  BC-MAIN-891d3cb5            Akie
# 164159  weather-891d3cb5-2100-ssp585-2  BC-MAIN-891d3cb5            Akie
#
#                            geometry  year                 variable  \
# 0        POINT (-77.67901 48.52154)  2025  Daily Temperature Range
# 1        POINT (-77.67901 48.52154)  2026  Daily Temperature Range
# 2        POINT (-77.67901 48.52154)  2027  Daily Temperature Range
# 3        POINT (-77.67901 48.52154)  2028  Daily Temperature Range
# 4        POINT (-77.67901 48.52154)  2029  Daily Temperature Range
# ...                             ...   ...                      ...
# 164155  POINT (-124.86599 57.38088)  2096     Annual Precipitation
# 164156  POINT (-124.86599 57.38088)  2097     Annual Precipitation
# 164157  POINT (-124.86599 57.38088)  2098     Annual Precipitation
# 164158  POINT (-124.86599 57.38088)  2099     Annual Precipitation
# 164159  POINT (-124.86599 57.38088)  2100     Annual Precipitation
#
#              value unit scenario
# 0        11.632902   °C   ssp126
# 1        11.764147   °C   ssp126
# 2        11.555113   °C   ssp126
# 3        11.603318   °C   ssp126
# 4        11.685084   °C   ssp126
# ...            ...  ...      ...
# 164155  833.395142   mm   ssp585
# 164156  820.639160   mm   ssp585
# 164157  812.977905   mm   ssp585
# 164158  831.112976   mm   ssp585
# 164159  841.397217   mm   ssp585
#
# [164160 rows x 9 columns]

# %%
# Let's keep data every 5 years for simplicity and size
weather_gdf = weather_gdf[weather_gdf['year'].isin(range(2025, 2101, 5))]

# %% [markdown]
# ### Population dataset

# %%
from gee_extraction import extract_ghsl_population

# %%
population_gdf = main_gdf.copy()
col_to_keep = ['main_id', 'facility_name', 'longitude', 'latitude', 'geometry']
population_gdf = population_gdf[col_to_keep]

# %%
population_gdf = extract_ghsl_population(population_gdf)
# Out:
# ✅ GHSL population (GeoDataFrame, long format) done in 346.04s

# %%
population_gdf = assign_row_id(population_gdf,
                  facility_id_col='main_id',
                  prefix='population',
                  year_col='year'
                  )

# %%
population_gdf
# Out:
#                           row_id           main_id            name  year  \
# 0     population-5801b453-2025-1  QC-MAIN-5801b453  Abcourt-Barvue  2025
# 1     population-5801b453-2025-2  QC-MAIN-5801b453  Abcourt-Barvue  2025
# 2     population-5801b453-2030-1  QC-MAIN-5801b453  Abcourt-Barvue  2030
# 3     population-5801b453-2030-2  QC-MAIN-5801b453  Abcourt-Barvue  2030
# 4     population-d29e0839-2025-1  QC-MAIN-d29e0839  Sleeping Giant  2025
# ...                          ...               ...             ...   ...
# 1075  population-12c68d49-2030-2  ON-MAIN-12c68d49    Eagle's Nest  2030
# 1076  population-891d3cb5-2025-1  BC-MAIN-891d3cb5            Akie  2025
# 1077  population-891d3cb5-2025-2  BC-MAIN-891d3cb5            Akie  2025
# 1078  population-891d3cb5-2030-1  BC-MAIN-891d3cb5            Akie  2030
# 1079  population-891d3cb5-2030-2  BC-MAIN-891d3cb5            Akie  2030
#
#      buffer_size  total_population                     geometry
# 0           10km       1305.901860   POINT (-77.67901 48.52154)
# 1           50km      63977.830574   POINT (-77.67901 48.52154)
# 2           10km       1338.088985   POINT (-77.67901 48.52154)
# 3           50km      65434.154098   POINT (-77.67901 48.52154)
# 4           10km          0.000000   POINT (-77.97434 49.13259)
# ...          ...               ...                          ...
# 1075        50km          0.000000   POINT (-86.30380 52.74202)
# 1076        10km          0.000000  POINT (-124.86599 57.38088)
# 1077        50km        297.622460  POINT (-124.86599 57.38088)
# 1078        10km          0.000000  POINT (-124.86599 57.38088)
# 1079        50km        309.797150  POINT (-124.86599 57.38088)
#
# [1080 rows x 7 columns]

# %% [markdown]
# ### Natural Potential Vegetation dataset

# %%
from gee_extraction import extract_npv

# %%
npv_gdf = extract_npv(main_gdf)
# Out:
# Processed 1/270 facilities...
# Processed 11/270 facilities...
# Processed 21/270 facilities...
# Processed 31/270 facilities...
# Processed 41/270 facilities...
# Processed 51/270 facilities...
# Processed 61/270 facilities...
# Processed 71/270 facilities...
# Processed 81/270 facilities...
# Processed 91/270 facilities...
# Processed 101/270 facilities...
# Processed 111/270 facilities...
# Processed 121/270 facilities...
# Processed 131/270 facilities...
# Processed 141/270 facilities...
# Processed 151/270 facilities...
# Processed 161/270 facilities...
# Processed 171/270 facilities...
# Processed 181/270 facilities...
# Processed 191/270 facilities...
# Processed 201/270 facilities...
# Processed 211/270 facilities...
# Processed 221/270 facilities...
# Processed 231/270 facilities...
# Processed 241/270 facilities...
# Processed 251/270 facilities...
# Processed 261/270 facilities...
# ✅ Extraction completed in 43.74 seconds (0.73 minutes)

# %%
from constants import biome_dict
npv_gdf['biome_type'] = npv_gdf['biome_type'].map(biome_dict)

# %%
npv_gdf
# Out:
#               main_id               name   latitude   longitude  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue  48.521540  -77.679010
# 1    QC-MAIN-d29e0839     Sleeping Giant  49.132590  -77.974340
# 2    QC-MAIN-f1ff4920       Akasaba West  48.040000  -77.580000
# 3    NU-MAIN-4ea8ac9d             Amaruq  65.415000  -96.697000
# 4    QC-MAIN-e7e6a960  Canadian Malartic  48.122223  -78.130824
# ..                ...                ...        ...         ...
# 265  ON-MAIN-c5fefb01              Mishi  48.110280  -85.452500
# 266  BC-MAIN-feb13c30       Record Ridge  49.082000 -117.884000
# 267  YT-MAIN-5e0d8b48             Casino  62.733330 -138.833330
# 268  ON-MAIN-12c68d49       Eagle's Nest  52.742020  -86.303800
# 269  BC-MAIN-891d3cb5               Akie  57.380880 -124.865990
#
#                            biome_type                     geometry
# 0                                 NaN   POINT (-77.67901 48.52154)
# 1                   Cool Mixed Forest   POINT (-77.97434 49.13259)
# 2                   Cool Mixed Forest   POINT (-77.58000 48.04000)
# 3                                 NaN   POINT (-96.69700 65.41500)
# 4                   Cool Mixed Forest   POINT (-78.13082 48.12222)
# ..                                ...                          ...
# 265                 Cool Mixed Forest   POINT (-85.45250 48.11028)
# 266  Cool Evergreen Needleleaf Forest  POINT (-117.88400 49.08200)
# 267  Cold Evergreen Needleleaf Forest  POINT (-138.83333 62.73333)
# 268                 Cool Mixed Forest   POINT (-86.30380 52.74202)
# 269  Cold Evergreen Needleleaf Forest  POINT (-124.86599 57.38088)
#
# [270 rows x 6 columns]

# %% [markdown]
# ### Land cover datasets

# %%
from gee_extraction import extract_land_cover_type

# %%
land_cover_gdf = extract_land_cover_type(main_gdf)
# Out:
# ✅ Combined MODIS & ESA land cover (2021) completed in 111.26 seconds

# %%
land_cover_gdf
# Out:
#               main_id               name  year                     geometry  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue  2021   POINT (-77.67901 48.52154)
# 1    QC-MAIN-d29e0839     Sleeping Giant  2021   POINT (-77.97434 49.13259)
# 2    QC-MAIN-f1ff4920       Akasaba West  2021   POINT (-77.58000 48.04000)
# 3    NU-MAIN-4ea8ac9d             Amaruq  2021   POINT (-96.69700 65.41500)
# 4    QC-MAIN-e7e6a960  Canadian Malartic  2021   POINT (-78.13082 48.12222)
# ..                ...                ...   ...                          ...
# 265  ON-MAIN-c5fefb01              Mishi  2021   POINT (-85.45250 48.11028)
# 266  BC-MAIN-feb13c30       Record Ridge  2021  POINT (-117.88400 49.08200)
# 267  YT-MAIN-5e0d8b48             Casino  2021  POINT (-138.83333 62.73333)
# 268  ON-MAIN-12c68d49       Eagle's Nest  2021   POINT (-86.30380 52.74202)
# 269  BC-MAIN-891d3cb5               Akie  2021  POINT (-124.86599 57.38088)
#
#                 modis_land_cover          esa_land_cover
# 0                 Woody Savannas                Built-up
# 1                 Woody Savannas  Bare/Sparse Vegetation
# 2                 Woody Savannas              Tree Cover
# 3                     Grasslands           Moss & Lichen
# 4                     Grasslands  Bare/Sparse Vegetation
# ..                           ...                     ...
# 265               Woody Savannas  Permanent Water Bodies
# 266               Woody Savannas              Tree Cover
# 267              Open Shrublands               Grassland
# 268               Woody Savannas               Grassland
# 269  Evergreen Needleleaf Forest              Tree Cover
#
# [270 rows x 6 columns]

# %% [markdown]
# ### Water risk dataset

# %%
from gee_extraction import extract_aqueduct

# %%
water_risk_gdf = main_gdf.copy()
col_to_keep = ['main_id', 'facility_name', 'longitude', 'latitude', 'geometry']
water_risk_gdf = water_risk_gdf[col_to_keep]

# %%
water_risk_gdf = extract_aqueduct(water_risk_gdf)
# Out:
# Processed 1/270 facilities...
# Processed 11/270 facilities...
# Processed 21/270 facilities...
# Processed 31/270 facilities...
# Processed 41/270 facilities...
# Processed 51/270 facilities...
# Processed 61/270 facilities...
# Processed 71/270 facilities...
# Processed 81/270 facilities...
# Processed 91/270 facilities...
# Processed 101/270 facilities...
# Processed 111/270 facilities...
# Processed 121/270 facilities...
# Processed 131/270 facilities...
# Processed 141/270 facilities...
# Processed 151/270 facilities...
# Processed 161/270 facilities...
# Processed 171/270 facilities...
# Processed 181/270 facilities...
# Processed 191/270 facilities...
# Processed 201/270 facilities...
# Processed 211/270 facilities...
# Processed 221/270 facilities...
# Processed 231/270 facilities...
# Processed 241/270 facilities...
# Processed 251/270 facilities...
# Processed 261/270 facilities...
# ✅ Aqueduct extraction completed in 203.81s

# %%
from constants import water_risk_dict
water_risk_gdf["indicator"] = water_risk_gdf["indicator"].map(water_risk_dict)

# %%
water_risk_gdf = assign_row_id(water_risk_gdf,
                  facility_id_col='main_id',
                  prefix='water_risk',
                  year_col='year',
                  scenario_col='scenario'             
                  )

# %%
water_risk_gdf
# Out:
#                                    row_id           main_id            name  \
# 0     water_risk-5801b453-2020-baseline-1  QC-MAIN-5801b453  Abcourt-Barvue
# 1     water_risk-5801b453-2020-baseline-2  QC-MAIN-5801b453  Abcourt-Barvue
# 2     water_risk-5801b453-2020-baseline-3  QC-MAIN-5801b453  Abcourt-Barvue
# 3     water_risk-5801b453-2020-baseline-4  QC-MAIN-5801b453  Abcourt-Barvue
# 4     water_risk-5801b453-2020-baseline-5  QC-MAIN-5801b453  Abcourt-Barvue
# ...                                   ...               ...             ...
# 8635       water_risk-891d3cb5-2080-pes-2  BC-MAIN-891d3cb5            Akie
# 8636       water_risk-891d3cb5-2080-pes-3  BC-MAIN-891d3cb5            Akie
# 8637       water_risk-891d3cb5-2080-opt-1  BC-MAIN-891d3cb5            Akie
# 8638       water_risk-891d3cb5-2080-opt-2  BC-MAIN-891d3cb5            Akie
# 8639       water_risk-891d3cb5-2080-opt-3  BC-MAIN-891d3cb5            Akie
#
#                                    indicator                      value  year  \
# 0                         Water Stress Label                 Low (<10%)  2020
# 1                      Water Depletion Label                  Low (<5%)  2020
# 2              Interannual Variability Label  Medium - High (0.50-0.75)  2020
# 3            Groundwater Table Decline Label        Insignificant Trend  2020
# 4     Coastal Eutrophication Potential Label                  Low (<-5)  2020
# ...                                      ...                        ...   ...
# 8635                   Water Depletion Label                  Low (<5%)  2080
# 8636           Interannual Variability Label   Low - Medium (0.25-0.50)  2080
# 8637                      Water Stress Label                 Low (<10%)  2080
# 8638                   Water Depletion Label                  Low (<5%)  2080
# 8639           Interannual Variability Label   Low - Medium (0.25-0.50)  2080
#
#       scenario                     geometry
# 0     baseline   POINT (-77.67901 48.52154)
# 1     baseline   POINT (-77.67901 48.52154)
# 2     baseline   POINT (-77.67901 48.52154)
# 3     baseline   POINT (-77.67901 48.52154)
# 4     baseline   POINT (-77.67901 48.52154)
# ...        ...                          ...
# 8635       pes  POINT (-124.86599 57.38088)
# 8636       pes  POINT (-124.86599 57.38088)
# 8637       opt  POINT (-124.86599 57.38088)
# 8638       opt  POINT (-124.86599 57.38088)
# 8639       opt  POINT (-124.86599 57.38088)
#
# [8640 rows x 8 columns]

# %% [markdown]
# ## Children datasets with polygons

# %% [markdown]
# ### Land occupation datasets

# %%
tang_gdf = gpd.read_file("data/Sources/Tang_Werner_2023/7894216/74548_projected polygons.shp")
maus_polygons_gdf = gpd.read_file("data/Sources/Maus_2022/global_mining_polygons_v2.gpkg")
maus_validation_points_gdf = gpd.read_file("data/Sources/Maus_2022/validation_points_v2.gpkg")

# %% [markdown]
# Maus et al directly provide an ISO3 country code so it is easy to filter it for Canada.
# Tanger & Werner do not provide it so we have to use a SHP file to have the borders for Canada

# %%
maus_canada_gdf = maus_polygons_gdf[maus_polygons_gdf['ISO3_CODE'] == 'CAN']
maus_canada_gdf = maus_canada_gdf.reset_index(drop=True)

# %%
### We fix the invalid geometries in the Tang & Werner dataset
invalid_geoms = tang_gdf[~tang_gdf.is_valid]
if not invalid_geoms.empty:
    print(f"⚠️ Warning: {len(invalid_geoms)} invalid geometries found. Fixing them...")
    tang_gdf["geometry"] = tang_gdf.buffer(0)  # Attempt to fix invalid geometries
else:
    print("✅ All geometries are valid.")
# Out:
# ⚠️ Warning: 627 invalid geometries found. Fixing them...

# %%
# Ensure both datasets are in the same CRS before clipping (convert to EPSG:4326)
if tang_gdf.crs != "EPSG:4326":
    tang_gdf = tang_gdf.to_crs(epsg=4326)

if canada_boundary.crs != "EPSG:4326":
    canada_boundary = canada_boundary.to_crs(epsg=4326)

# Clip the global dataset to Canada
tang_canada_gdf = gpd.clip(tang_gdf, canada_boundary)
tang_canada_gdf = tang_canada_gdf.reset_index(drop=True)

# %%
tang_canada_gdf.rename(columns={'OBJECTID': 'tang_id'}, inplace=True)
# tang_canada_gdf = assign_id(tang_canada_gdf,
#                             canada_provinces,
#                                      id_column = 'tang_id',
#                                      prefix="TANG")

# %%
maus_canada_gdf = assign_id(maus_canada_gdf, 
                            canada_provinces,
                                     id_column = 'maus_id',
                                     prefix="MAUS")

# %%
# Drop useless columns
tang_canada_gdf = tang_canada_gdf.drop(columns=['Name', 'Shape_Le_1', 'Shape_Area'])
maus_canada_gdf = maus_canada_gdf.drop(columns=['ISO3_CODE', 'COUNTRY_NAME', 'AREA', 'longitude', 'latitude'])

# %%
from db_creation_function import add_surface_area_polygons

# %%
tang_canada_gdf = add_surface_area_polygons(tang_canada_gdf)
maus_canada_gdf = add_surface_area_polygons(maus_canada_gdf)

# %%
tang_canada_gdf
# Out:
#       tang_id                                           geometry  area_km2
# 0        6383  POLYGON Z ((1795479.979 -83564.531 0.000, 1795...  0.026130
# 1        6388  POLYGON Z ((1796123.448 -80625.526 0.000, 1796...  0.671399
# 2        6390  POLYGON Z ((1796791.634 -80270.697 0.000, 1796...  0.050909
# 3       45954  POLYGON Z ((2466485.124 185586.547 0.000, 2466...  2.622800
# 4       45955  POLYGON Z ((2465809.682 185862.507 0.000, 2465...  0.441869
# ...       ...                                                ...       ...
# 1880     3399  POLYGON Z ((-717210.659 1915423.857 0.000, -71...  0.541024
# 1881     3401  POLYGON Z ((-715648.337 1916385.463 0.000, -71...  1.053173
# 1882    26364  POLYGON Z ((-717332.782 1916999.286 0.000, -71...  0.079894
# 1883    43739  POLYGON Z ((-713032.430 1919630.086 0.000, -71...  1.519488
# 1884    44287  POLYGON Z ((-466746.640 2074582.808 0.000, -46...  0.121349
#
# [1885 rows x 3 columns]

# %%
maus_canada_gdf
# Out:
#                maus_id                                           geometry  \
# 0     NS-MAUS-034be517  POLYGON ((2465825.133 185240.921, 2465693.221 ...
# 1     NS-MAUS-c031164b  POLYGON ((2465555.107 185647.257, 2465581.632 ...
# 2     NS-MAUS-762a8381  POLYGON ((2428808.304 168666.573, 2428907.630 ...
# 3     NS-MAUS-f1edad6c  POLYGON ((2437073.487 174014.156, 2437162.524 ...
# 4     NS-MAUS-ed05db90  POLYGON ((2434470.669 174168.980, 2434007.898 ...
# ...                ...                                                ...
# 2823  BC-MAUS-1abc81f5  POLYGON ((-1982091.318 1778268.106, -1981900.1...
# 2824  YT-MAUS-92599456  POLYGON ((-1973421.054 2230266.454, -1973420.7...
# 2825  QC-MAUS-e8c1eb5a  POLYGON ((1706909.046 64729.850, 1706922.333 6...
# 2826  QC-MAUS-b1c97c97  POLYGON ((1306624.016 112249.835, 1306585.548 ...
# 2827  YT-MAUS-76bbe4dd  POLYGON ((-2001476.871 2253868.244, -2001493.7...
#
#       area_km2
# 0     2.616761
# 1     0.442222
# 2     3.426307
# 3     0.141739
# 4     1.705000
# ...        ...
# 2823  4.753832
# 2824  5.086882
# 2825  0.580958
# 2826  3.025293
# 2827  1.649434
#
# [2828 rows x 3 columns]

# %% [markdown]
# #### A bit of inspection of the polygons

# %%
from db_creation_function import analyze_and_compare_polygon_areas

# %%
polygons_areas = analyze_and_compare_polygon_areas(maus_canada_gdf, 
                                  tang_canada_gdf,
                                  'Maus et al (2022)', 
                                  'Tang & Werner et al (2023)',
                                  save_path=r'results/maus_tang_comparison_polygons.png'
                                  )
polygons_areas
# Out:
#                       Dataset  Polygon Count  Min Area (km²)  Mean Area (km²)  \
# 0           Maus et al (2022)           2828        0.000353         1.756474
# 1  Tang & Werner et al (2023)           1885        0.001375         1.709219
#
#    Median Area (km²)  Max Area (km²)
# 0           0.150263      585.820363
# 1           0.212094      203.353532

# %% [markdown]
# ### Indigenous lands dataset

# %%
indigenous_gdf = gpd.read_file(r'data/Sources/Indigenous_lands/Indigenous_comm_lands_v202411/Indigenous_comm_lands_v202411/CommunityLevelData_poly_202411.shp')
indigenous_can_gdf = indigenous_gdf[indigenous_gdf['Country'] == 'Canada']

# %%
indigenous_can_gdf
# Out:
#                                      Name    Identity              Form_Rec  \
# 2864                        Nicola Lake 1  Indigenous  Acknowledged by govt
# 2865                      Piikani Reserve  Indigenous  Acknowledged by govt
# 2866   Suwannee Lake Indian Reserve 09924  Indigenous  Acknowledged by govt
# 2867                 Chitek Lake I.r. 191  Indigenous  Acknowledged by govt
# 2868   Couchiching Indian Reserve No. 16a  Indigenous  Acknowledged by govt
# ...                                   ...         ...                   ...
# 53214                           Maa-nulth  Indigenous  Acknowledged by govt
# 53215                           Maa-nulth  Indigenous  Acknowledged by govt
# 53216                           Maa-nulth  Indigenous  Acknowledged by govt
# 53217                           Maa-nulth  Indigenous  Acknowledged by govt
# 53218                           Maa-nulth  Indigenous  Acknowledged by govt
#
#        Doc_Status   Stat_Date Stat_Note Country ISO_Code  \
# 2864   Documented        None      None  Canada      CAN
# 2865   Documented        None      None  Canada      CAN
# 2866   Documented        None      None  Canada      CAN
# 2867   Documented        None      None  Canada      CAN
# 2868   Documented        None      None  Canada      CAN
# ...           ...         ...       ...     ...      ...
# 53214  Documented  2011/04/01      None  Canada      CAN
# 53215  Documented  2011/04/01      None  Canada      CAN
# 53216  Documented  2011/04/01      None  Canada      CAN
# 53217  Documented  2011/04/01      None  Canada      CAN
# 53218  Documented  2014/10/31      None  Canada      CAN
#
#                          Category              Ethncty_1  ...  \
# 2864               Indian Reserve                   None  ...
# 2865               Indian Reserve                   None  ...
# 2866               Indian Reserve                   None  ...
# 2867               Indian Reserve                   None  ...
# 2868               Indian Reserve                   None  ...
# ...                           ...                    ...  ...
# 53214  First Nations Treaty Lands  Ucluelet First Nation  ...
# 53215  First Nations Treaty Lands  Ucluelet First Nation  ...
# 53216  First Nations Treaty Lands  Ucluelet First Nation  ...
# 53217  First Nations Treaty Lands  Ucluelet First Nation  ...
# 53218  First Nations Treaty Lands         Toquaht Nation  ...
#
#                 Data_Ctrb                                           Data_Src  \
# 2864   Publicly available  Natural Resources Canada, Earth Sciences Secto...
# 2865   Publicly available  Natural Resources Canada, Earth Sciences Secto...
# 2866   Publicly available  Natural Resources Canada, Earth Sciences Secto...
# 2867   Publicly available  Natural Resources Canada, Earth Sciences Secto...
# 2868   Publicly available  Natural Resources Canada, Earth Sciences Secto...
# ...                   ...                                                ...
# 53214  Publicly Available  Ministry of Aboriginal Relations and Reconcili...
# 53215  Publicly Available  Ministry of Aboriginal Relations and Reconcili...
# 53216  Publicly Available  Ministry of Aboriginal Relations and Reconcili...
# 53217  Publicly Available  Ministry of Aboriginal Relations and Reconcili...
# 53218  Publicly Available  Ministry of Aboriginal Relations and Reconcili...
#
#                                               Data_Src_S  \
# 2864                            Natural Resources Canada
# 2865                            Natural Resources Canada
# 2866                            Natural Resources Canada
# 2867                            Natural Resources Canada
# 2868                            Natural Resources Canada
# ...                                                  ...
# 53214  Ministry of Aboriginal Relations and Reconcili...
# 53215  Ministry of Aboriginal Relations and Reconcili...
# 53216  Ministry of Aboriginal Relations and Reconcili...
# 53217  Ministry of Aboriginal Relations and Reconcili...
# 53218  Ministry of Aboriginal Relations and Reconcili...
#
#                                               Data_Src_L   Data_Date Add_Note  \
# 2864   Natural Resources Canada, Earth Sciences Secto...  2012/09/05     None
# 2865   Natural Resources Canada, Earth Sciences Secto...  2012/09/05     None
# 2866   Natural Resources Canada, Earth Sciences Secto...  2013/05/30     None
# 2867   Natural Resources Canada, Earth Sciences Secto...  2013/09/09     None
# 2868   Natural Resources Canada, Earth Sciences Secto...  2013/09/09     None
# ...                                                  ...         ...      ...
# 53214  Government of British Columbia, Ministry of Ab...  2016/06/09     None
# 53215  Government of British Columbia, Ministry of Ab...  2016/06/09     None
# 53216  Government of British Columbia, Ministry of Ab...  2016/06/09     None
# 53217  Government of British Columbia, Ministry of Ab...  2016/06/09     None
# 53218  Government of British Columbia, Ministry of Ab...  2016/06/09     None
#
#                                                More_info  \
# 2864   http://clss.nrcan.gc.ca/map-carte-eng.php?can=...
# 2865   http://clss.nrcan.gc.ca/map-carte-eng.php?can=...
# 2866   http://clss.nrcan.gc.ca/map-carte-eng.php?can=...
# 2867   http://clss.nrcan.gc.ca/map-carte-eng.php?can=...
# 2868   http://clss.nrcan.gc.ca/map-carte-eng.php?can=...
# ...                                                  ...
# 53214  https://catalogue.data.gov.bc.ca/dataset/first...
# 53215  https://catalogue.data.gov.bc.ca/dataset/first...
# 53216  https://catalogue.data.gov.bc.ca/dataset/first...
# 53217  https://catalogue.data.gov.bc.ca/dataset/first...
# 53218  https://catalogue.data.gov.bc.ca/dataset/first...
#
#                            Layer Download  \
# 2864   Indigenous & Community La      Yes
# 2865   Indigenous & Community La      Yes
# 2866   Indigenous & Community La      Yes
# 2867   Indigenous & Community La      Yes
# 2868   Indigenous & Community La      Yes
# ...                          ...      ...
# 53214  Indigenous & Community La      Yes
# 53215  Indigenous & Community La      Yes
# 53216  Indigenous & Community La      Yes
# 53217  Indigenous & Community La      Yes
# 53218  Indigenous & Community La      Yes
#
#                                                 geometry
# 2864   MULTIPOLYGON Z (((-13411703.632 6478826.437 0....
# 2865   MULTIPOLYGON Z (((-12662303.780 6356833.571 0....
# 2866   POLYGON Z ((-11149110.724 7581557.313 0.000, -...
# 2867   MULTIPOLYGON Z (((-11998607.890 7110898.048 0....
# 2868   MULTIPOLYGON Z (((-10393249.315 6212569.016 0....
# ...                                                  ...
# 53214  MULTIPOLYGON Z (((-13935183.390 6271232.271 0....
# 53215  MULTIPOLYGON Z (((-13915849.512 6301673.475 0....
# 53216  MULTIPOLYGON Z (((-13912007.673 6290368.700 0....
# 53217  MULTIPOLYGON Z (((-13981167.298 6267857.450 0....
# 53218  POLYGON Z ((-13964810.696 6267119.654 0.000, -...
#
# [3258 rows x 27 columns]

# %%
col_to_keep = ['Name', 'Category', 'Data_Src', 'Data_Date', 'geometry']
indigenous_can_gdf = indigenous_can_gdf[col_to_keep]

# %%
# Simplify geometries while keeping essential shape 
tolerance = 100  # 100 meters simplification tolerance
indigenous_can_gdf["geometry"] = indigenous_can_gdf["geometry"].apply(lambda geom: geom.simplify(tolerance, preserve_topology=True))
# Fix invalid geometries after simplification
indigenous_can_gdf["geometry"] = indigenous_can_gdf["geometry"].buffer(0)
# Out:
# C:\Users\mp_ma\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
indigenous_can_gdf = assign_id(
    indigenous_can_gdf,
    canada_provinces,
    id_column = "indigenous_land_id",
    prefix='IND',
    name_col='Name'
)
# Out:
# C:\Users\mp_ma\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mp_ma\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mp_ma\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
indigenous_can_gdf
# Out:
#       indigenous_land_id                                Name  \
# 2864     ZZ-IND-65515118                       Nicola Lake 1
# 2865     ZZ-IND-822586b0                     Piikani Reserve
# 2866     ZZ-IND-cf5cc3a8  Suwannee Lake Indian Reserve 09924
# 2867     ZZ-IND-d4241875                Chitek Lake I.r. 191
# 2868     ZZ-IND-ee5d19c4  Couchiching Indian Reserve No. 16a
# ...                  ...                                 ...
# 53214    ZZ-IND-ace3fb37                           Maa-nulth
# 53215    ZZ-IND-07b0f9d4                           Maa-nulth
# 53216    ZZ-IND-2cec7703                           Maa-nulth
# 53217    ZZ-IND-a914af3f                           Maa-nulth
# 53218    ZZ-IND-9ac73bcb                           Maa-nulth
#
#                          Category  \
# 2864               Indian Reserve
# 2865               Indian Reserve
# 2866               Indian Reserve
# 2867               Indian Reserve
# 2868               Indian Reserve
# ...                           ...
# 53214  First Nations Treaty Lands
# 53215  First Nations Treaty Lands
# 53216  First Nations Treaty Lands
# 53217  First Nations Treaty Lands
# 53218  First Nations Treaty Lands
#
#                                                 Data_Src   Data_Date  \
# 2864   Natural Resources Canada, Earth Sciences Secto...  2012/09/05
# 2865   Natural Resources Canada, Earth Sciences Secto...  2012/09/05
# 2866   Natural Resources Canada, Earth Sciences Secto...  2013/05/30
# 2867   Natural Resources Canada, Earth Sciences Secto...  2013/09/09
# 2868   Natural Resources Canada, Earth Sciences Secto...  2013/09/09
# ...                                                  ...         ...
# 53214  Ministry of Aboriginal Relations and Reconcili...  2016/06/09
# 53215  Ministry of Aboriginal Relations and Reconcili...  2016/06/09
# 53216  Ministry of Aboriginal Relations and Reconcili...  2016/06/09
# 53217  Ministry of Aboriginal Relations and Reconcili...  2016/06/09
# 53218  Ministry of Aboriginal Relations and Reconcili...  2016/06/09
#
#                                                 geometry     longitude  \
# 2864   MULTIPOLYGON Z (((-13412001.078 6484020.720 0.... -1.340968e+07
# 2865   MULTIPOLYGON Z (((-12638644.679 6375535.364 0.... -1.265128e+07
# 2866   POLYGON Z ((-11149110.724 7581557.313 0.000, -... -1.114723e+07
# 2867   MULTIPOLYGON Z (((-11991380.215 7116416.576 0.... -1.199724e+07
# 2868   MULTIPOLYGON Z (((-10398281.993 6223676.777 0.... -1.040011e+07
# ...                                                  ...           ...
# 53214  MULTIPOLYGON Z (((-13935109.163 6271300.023 0.... -1.393595e+07
# 53215  MULTIPOLYGON Z (((-13915849.512 6301673.475 0.... -1.391666e+07
# 53216  MULTIPOLYGON Z (((-13900991.756 6286092.967 0.... -1.390820e+07
# 53217  MULTIPOLYGON Z (((-13981167.298 6267857.450 0.... -1.398181e+07
# 53218  POLYGON Z ((-13964810.696 6267119.654 0.000, -... -1.396536e+07
#
#            latitude
# 2864   6.482531e+06
# 2865   6.375071e+06
# 2866   7.586468e+06
# 2867   7.113774e+06
# 2868   6.221741e+06
# ...             ...
# 53214  6.271393e+06
# 53215  6.302849e+06
# 53216  6.289657e+06
# 53217  6.269168e+06
# 53218  6.266851e+06
#
# [3258 rows x 8 columns]

# %% [markdown]
# ### Protected areas dataset

# %%
# Polygons
wpda_gdf_polygons_1 = gpd.read_file(r'data\Sources\Protected_areas\WDPA_WDOECM_Mar2025_Public_CAN_shp\WDPA_WDOECM_Mar2025_Public_CAN_shp_0\WDPA_WDOECM_Mar2025_Public_CAN_shp-polygons.shp')
wpda_gdf_polygons_2 = gpd.read_file(r'data\Sources\Protected_areas\WDPA_WDOECM_Mar2025_Public_CAN_shp\WDPA_WDOECM_Mar2025_Public_CAN_shp_1\WDPA_WDOECM_Mar2025_Public_CAN_shp-polygons.shp')
wpda_gdf_polygons_3 = gpd.read_file(r'data\Sources\Protected_areas\WDPA_WDOECM_Mar2025_Public_CAN_shp\WDPA_WDOECM_Mar2025_Public_CAN_shp_2\WDPA_WDOECM_Mar2025_Public_CAN_shp-polygons.shp')

# Points
wpda_gdf_points_1 = gpd.read_file(r'data\Sources\Protected_areas\WDPA_WDOECM_Mar2025_Public_CAN_shp\WDPA_WDOECM_Mar2025_Public_CAN_shp_0\WDPA_WDOECM_Mar2025_Public_CAN_shp-points.shp')
wpda_gdf_points_2 = gpd.read_file(r'data\Sources\Protected_areas\WDPA_WDOECM_Mar2025_Public_CAN_shp\WDPA_WDOECM_Mar2025_Public_CAN_shp_1\WDPA_WDOECM_Mar2025_Public_CAN_shp-points.shp')
wpda_gdf_points_3 = gpd.read_file(r'data\Sources\Protected_areas\WDPA_WDOECM_Mar2025_Public_CAN_shp\WDPA_WDOECM_Mar2025_Public_CAN_shp_2\WDPA_WDOECM_Mar2025_Public_CAN_shp-points.shp')

# %%
# We merge the 3 files together
wpda_gdf_polygons = gpd.GeoDataFrame(pd.concat([
    wpda_gdf_polygons_1, wpda_gdf_polygons_2, wpda_gdf_polygons_3], 
    ignore_index=True))

wpda_gdf_points = gpd.GeoDataFrame(pd.concat([
    wpda_gdf_points_1, wpda_gdf_points_2, wpda_gdf_points_3], 
    ignore_index=True))

# %%
# Convert MULTIPOINT geometries to POINT
def multipoint_to_point(geom):
    """Extracts the first point from a MULTIPOINT."""
    if geom.geom_type == "MultiPoint":
        return geom.geoms[0]  # Extract first point
    return geom  # Return as-is if it's already a Point

# %%
wpda_gdf_points["geometry"] = wpda_gdf_points["geometry"].apply(multipoint_to_point)

# %%
wpda_gdf_polygons
# Out:
#             WDPAID   WDPA_PID PA_DEF  \
# 0            611.0      611_A      1
# 1            611.0      611_B      1
# 2            612.0        612      1
# 3            613.0      613_B      1
# 4            613.0      613_A      1
# ...            ...        ...    ...
# 13463  555785733.0  555785733      0
# 13464  555785734.0  555785734      0
# 13465  555785735.0  555785735      0
# 13466  555785736.0  555785736      0
# 13467  555785737.0  555785737      0
#
#                                                     NAME  \
# 0                   Wood Buffalo National Park Of Canada
# 1                   Wood Buffalo National Park Of Canada
# 2                 Kluane National Park Reserve Of Canada
# 3                      Auyuittuq National Park Of Canada
# 4                      Auyuittuq National Park Of Canada
# ...                                                  ...
# 13463  Grosse Île and the Irish Memorial National His...
# 13464                 Navy Island National Historic Site
# 13465  Fort George National Historic Site (Paradise G...
# 13466                Rideau Canal National Historic Site
# 13467                            Capital Recreation Area
#
#                                                ORIG_NAME  \
# 0                   Wood Buffalo National Park Of Canada
# 1                   Wood Buffalo National Park Of Canada
# 2                 Kluane National Park Reserve Of Canada
# 3                      Auyuittuq National Park Of Canada
# 4                      Auyuittuq National Park Of Canada
# ...                                                  ...
# 13463  Lieu historique national de la Grosse-Île-et-l...
# 13464                 Navy Island National Historic Site
# 13465  Fort George National Historic Site (Paradise G...
# 13466                Rideau Canal National Historic Site
# 13467                            Capital Recreation Area
#
#                           DESIG               DESIG_ENG DESIG_TYPE  \
# 0                 National Park           National Park   National
# 1                 National Park           National Park   National
# 2                 National Park           National Park   National
# 3                 National Park           National Park   National
# 4                 National Park           National Park   National
# ...                         ...                     ...        ...
# 13463  Lieu historique national  National Historic Site   National
# 13464    National Historic Site  National Historic Site   National
# 13465    National Historic Site  National Historic Site   National
# 13466    National Historic Site  National Historic Site   National
# 13467                      OECM                    OECM   National
#
#              IUCN_CAT        INT_CRIT  ...                          MANG_AUTH  \
# 0                  II  Not Applicable  ...                Parks Canada Agency
# 1                  II  Not Applicable  ...                Parks Canada Agency
# 2                  II  Not Applicable  ...                Parks Canada Agency
# 3                  II  Not Applicable  ...                Parks Canada Agency
# 4                  II  Not Applicable  ...                Parks Canada Agency
# ...               ...             ...  ...                                ...
# 13463  Not Applicable  Not Applicable  ...                Parks Canada Agency
# 13464  Not Applicable  Not Applicable  ...                Parks Canada Agency
# 13465  Not Applicable  Not Applicable  ...                Parks Canada Agency
# 13466  Not Applicable  Not Applicable  ...                Parks Canada Agency
# 13467  Not Applicable  Not Applicable  ...  National Capital Commission (NCC)
#
#                                                MANG_PLAN           VERIF  \
# 0                                   http://www.pc.gc.ca/  State Verified
# 1                                   http://www.pc.gc.ca/  State Verified
# 2                                   http://www.pc.gc.ca/  State Verified
# 3                                   http://www.pc.gc.ca/  State Verified
# 4                                   http://www.pc.gc.ca/  State Verified
# ...                                                  ...             ...
# 13463                               http://www.pc.gc.ca/  State Verified
# 13464                               http://www.pc.gc.ca/  State Verified
# 13465                               http://www.pc.gc.ca/  State Verified
# 13466                               http://www.pc.gc.ca/  State Verified
# 13467  https://ncc-ccn.gc.ca/our-plans/greenbelt-mast...  State Verified
#
#        METADATAID  SUB_LOC PARENT_ISO  ISO3       SUPP_INFO        CONS_OBJ  \
# 0            1868    CA-AB        CAN   CAN  Not Applicable  Not Applicable
# 1            1868    CA-NT        CAN   CAN  Not Applicable  Not Applicable
# 2            1868    CA-YT        CAN   CAN  Not Applicable  Not Applicable
# 3            1868    CA-NU        CAN   CAN  Not Applicable  Not Applicable
# 4            1868    CA-NU        CAN   CAN  Not Applicable  Not Applicable
# ...           ...      ...        ...   ...             ...             ...
# 13463        1868    CA-QC        CAN   CAN    Not Reported       Ancillary
# 13464        1868    CA-ON        CAN   CAN    Not Reported       Ancillary
# 13465        1868    CA-ON        CAN   CAN    Not Reported       Ancillary
# 13466        1868    CA-ON        CAN   CAN    Not Reported       Ancillary
# 13467        1868    CA-ON        CAN   CAN    Not Reported    Not Reported
#
#                                                 geometry
# 0      POLYGON ((-112.87253 59.99877, -112.86600 59.9...
# 1      POLYGON ((-112.87253 59.99877, -115.57021 59.9...
# 2      POLYGON ((-139.22933 61.23289, -139.22871 61.2...
# 3      MULTIPOLYGON (((-64.02380 67.31413, -63.95370 ...
# 4      MULTIPOLYGON (((-67.01225 68.28855, -67.00854 ...
# ...                                                  ...
# 13463  MULTIPOLYGON (((-70.67700 47.02266, -70.67721 ...
# 13464  POLYGON ((-79.02213 43.06083, -79.02228 43.061...
# 13465  POLYGON ((-79.06321 43.24562, -79.06291 43.245...
# 13466  MULTIPOLYGON (((-76.23992 44.89998, -76.23966 ...
# 13467  POLYGON ((-75.60694 45.33604, -75.60797 45.335...
#
# [13468 rows x 31 columns]

# %%
wpda_gdf_points
# Out:
#          WDPAID   WDPA_PID PA_DEF                                   NAME  \
# 0       67855.0      67855      1    Tabusintac Lagoon and River Estuary
# 1      166868.0     166868      1                         Minesing Swamp
# 2      166867.0     166867      1                         Matchedash Bay
# 3      166866.0     166866      1                       Lac Saint Pierre
# 4      902694.0     902694      1                      Columbia Wetlands
# 5        2058.0       2058      1                     Mont Saint Hilaire
# 6       11586.0      11586      1      Riding Mountain Biosphere Reserve
# 7       11587.0      11587      1           Long Point Biosphere Reserve
# 8       18922.0      18922      1  Réserve de la biosphère de Charlevoix
# 9       20014.0      20014      1   Niagara Escarpment Biosphere Reserve
# 10     198338.0     198338      1                          Redberry Lake
# 11     220256.0     220256      1                       Lac Saint-Pierre
# 12     900664.0     900664      1                        South West Nova
# 13     900714.0     900714      1       Thousands Islands Frontenac Arch
# 14     902536.0     902536      1                  Georgian Bay Littoral
# 15     198337.0     198337      1                        Clayoquot Sound
# 16     220257.0     220257      1                       Mount Arrowsmith
# 17  555547532.0  555547532      1                                  Fundy
# 18  555547533.0  555547533      1                   Manicouagan-Uapishka
# 19  555547579.0  555547579      1                              Bras d'Or
#
#                                 ORIG_NAME  \
# 0     Tabusintac Lagoon and River Estuary
# 1                          Minesing Swamp
# 2                          Matchedash Bay
# 3                        Lac Saint Pierre
# 4                       Columbia Wetlands
# 5                      Mont Saint Hilaire
# 6       Riding Mountain Biosphere Reserve
# 7            Long Point Biosphere Reserve
# 8   Réserve de la biosphère de Charlevoix
# 9    Niagara Escarpment Biosphere Reserve
# 10                          Redberry Lake
# 11                       Lac Saint-Pierre
# 12                        South West Nova
# 13       Thousands Islands Frontenac Arch
# 14                  Georgian Bay Littoral
# 15                        Clayoquot Sound
# 16                       Mount Arrowsmith
# 17                                  Fundy
# 18                   Manicouagan-Uapishka
# 19                              Bras d'Or
#
#                                                DESIG  \
# 0   Ramsar Site, Wetland of International Importance
# 1   Ramsar Site, Wetland of International Importance
# 2   Ramsar Site, Wetland of International Importance
# 3   Ramsar Site, Wetland of International Importance
# 4   Ramsar Site, Wetland of International Importance
# 5                       UNESCO-MAB Biosphere Reserve
# 6                       UNESCO-MAB Biosphere Reserve
# 7                       UNESCO-MAB Biosphere Reserve
# 8                       UNESCO-MAB Biosphere Reserve
# 9                       UNESCO-MAB Biosphere Reserve
# 10                      UNESCO-MAB Biosphere Reserve
# 11                      UNESCO-MAB Biosphere Reserve
# 12                      UNESCO-MAB Biosphere Reserve
# 13                      UNESCO-MAB Biosphere Reserve
# 14                      UNESCO-MAB Biosphere Reserve
# 15                      UNESCO-MAB Biosphere Reserve
# 16                      UNESCO-MAB Biosphere Reserve
# 17                      UNESCO-MAB Biosphere Reserve
# 18                      UNESCO-MAB Biosphere Reserve
# 19                      UNESCO-MAB Biosphere Reserve
#
#                                            DESIG_ENG     DESIG_TYPE  \
# 0   Ramsar Site, Wetland of International Importance  International
# 1   Ramsar Site, Wetland of International Importance  International
# 2   Ramsar Site, Wetland of International Importance  International
# 3   Ramsar Site, Wetland of International Importance  International
# 4   Ramsar Site, Wetland of International Importance  International
# 5                       UNESCO-MAB Biosphere Reserve  International
# 6                       UNESCO-MAB Biosphere Reserve  International
# 7                       UNESCO-MAB Biosphere Reserve  International
# 8                       UNESCO-MAB Biosphere Reserve  International
# 9                       UNESCO-MAB Biosphere Reserve  International
# 10                      UNESCO-MAB Biosphere Reserve  International
# 11                      UNESCO-MAB Biosphere Reserve  International
# 12                      UNESCO-MAB Biosphere Reserve  International
# 13                      UNESCO-MAB Biosphere Reserve  International
# 14                      UNESCO-MAB Biosphere Reserve  International
# 15                      UNESCO-MAB Biosphere Reserve  International
# 16                      UNESCO-MAB Biosphere Reserve  International
# 17                      UNESCO-MAB Biosphere Reserve  International
# 18                      UNESCO-MAB Biosphere Reserve  International
# 19                      UNESCO-MAB Biosphere Reserve  International
#
#           IUCN_CAT                            INT_CRIT  ...     MANG_AUTH  \
# 0     Not Reported                             (i)(iv)  ...  Not Reported
# 1     Not Reported                        (i)(ii)(iii)  ...  Not Reported
# 2     Not Reported              (i)(ii)(iii)(iv)(viii)  ...  Not Reported
# 3     Not Reported             (i)(ii)(iii)(iv)(v)(vi)  ...  Not Reported
# 4     Not Reported  (i)(ii)(iii)(iv)(v)(vi)(vii)(viii)  ...  Not Reported
# 5   Not Applicable                      Not Applicable  ...  Not Reported
# 6   Not Applicable                      Not Applicable  ...  Not Reported
# 7   Not Applicable                      Not Applicable  ...  Not Reported
# 8   Not Applicable                      Not Applicable  ...  Not Reported
# 9   Not Applicable                      Not Applicable  ...  Not Reported
# 10  Not Applicable                      Not Applicable  ...  Not Reported
# 11  Not Applicable                      Not Applicable  ...  Not Reported
# 12  Not Applicable                      Not Applicable  ...  Not Reported
# 13  Not Applicable                      Not Applicable  ...  Not Reported
# 14  Not Applicable                      Not Applicable  ...  Not Reported
# 15  Not Applicable                      Not Applicable  ...  Not Reported
# 16  Not Applicable                      Not Applicable  ...  Not Reported
# 17  Not Applicable                      Not Applicable  ...  Not Reported
# 18  Not Applicable                      Not Applicable  ...  Not Reported
# 19  Not Applicable                      Not Applicable  ...  Not Reported
#
#                                             MANG_PLAN           VERIF  \
# 0   Management plan is not implemented and not ava...  State Verified
# 1     Management plan is implemented and is available  State Verified
# 2     Management plan is implemented and is available  State Verified
# 3   Management plan is not implemented and not ava...  State Verified
# 4     Management plan is implemented and is available  State Verified
# 5                                        Not Reported  State Verified
# 6                                        Not Reported  State Verified
# 7                                        Not Reported  State Verified
# 8                                        Not Reported  State Verified
# 9                                        Not Reported  State Verified
# 10                                       Not Reported  State Verified
# 11                                       Not Reported  State Verified
# 12                                       Not Reported  State Verified
# 13                                       Not Reported  State Verified
# 14                                       Not Reported  State Verified
# 15                                       Not Reported  State Verified
# 16                                       Not Reported  State Verified
# 17                                       Not Reported  State Verified
# 18                                       Not Reported  State Verified
# 19                                       Not Reported  State Verified
#
#    METADATAID       SUB_LOC PARENT_ISO  ISO3       SUPP_INFO        CONS_OBJ  \
# 0        1856         CA-NB        CAN   CAN  Not Applicable  Not Applicable
# 1        1856         CA-ON        CAN   CAN  Not Applicable  Not Applicable
# 2        1856         CA-ON        CAN   CAN  Not Applicable  Not Applicable
# 3        1856         CA-QC        CAN   CAN  Not Applicable  Not Applicable
# 4        1856         CA-BC        CAN   CAN  Not Applicable  Not Applicable
# 5         988         CA-ON        CAN   CAN  Not Applicable  Not Applicable
# 6         988         CA-MB        CAN   CAN  Not Applicable  Not Applicable
# 7         988         CA-ON        CAN   CAN  Not Applicable  Not Applicable
# 8         988         CA-QC        CAN   CAN  Not Applicable  Not Applicable
# 9         988         CA-ON        CAN   CAN  Not Applicable  Not Applicable
# 10        988         CA-SK        CAN   CAN  Not Applicable  Not Applicable
# 11        988  Not Reported        CAN   CAN  Not Applicable  Not Applicable
# 12        988         CA-NS        CAN   CAN  Not Applicable  Not Applicable
# 13        928         CA-ON        CAN   CAN  Not Applicable  Not Applicable
# 14       1251  Not Reported        CAN   CAN  Not Applicable  Not Applicable
# 15        988         CA-BC        CAN   CAN  Not Applicable  Not Applicable
# 16        988         CA-BC        CAN   CAN  Not Applicable  Not Applicable
# 17       1688         CA-NB        CAN   CAN  Not Applicable  Not Applicable
# 18       1688         CA-QC        CAN   CAN  Not Applicable  Not Applicable
# 19       1688         CA-NS        CAN   CAN  Not Applicable  Not Applicable
#
#                        geometry
# 0    POINT (-64.93333 47.33333)
# 1    POINT (-80.86667 44.38333)
# 2    POINT (-79.66667 44.73333)
# 3    POINT (-72.65000 46.13333)
# 4   POINT (-115.21667 50.68333)
# 5    POINT (-75.16667 45.55000)
# 6   POINT (-100.30000 50.76670)
# 7    POINT (-80.33000 43.58000)
# 8    POINT (-70.55000 47.66667)
# 9    POINT (-79.93000 43.62000)
# 10  POINT (-107.00000 52.70000)
# 11   POINT (-72.91667 46.15000)
# 12   POINT (-65.83333 44.21667)
# 13   POINT (-76.16667 44.33333)
# 14   POINT (-81.00000 45.25000)
# 15  POINT (-126.00000 49.28333)
# 16  POINT (-124.38333 49.25000)
# 17   POINT (-65.03000 45.61000)
# 18   POINT (-68.14000 49.24000)
# 19   POINT (-60.70380 45.88690)
#
# [20 rows x 29 columns]

# %%
col_to_keep = ['WDPA_PID', 'NAME', 'DESIG', 'OWN_TYPE', 'MANG_AUTH', 'STATUS_YR', 'geometry']
wpda_gdf_polygons = wpda_gdf_polygons[col_to_keep]
wpda_gdf_points = wpda_gdf_points[col_to_keep]

# %%
# Simplify geometries while keeping essential shape 
tolerance = 100  # 100 meters simplification tolerance
wpda_gdf_polygons["geometry"] = wpda_gdf_polygons["geometry"].apply(lambda geom: geom.simplify(tolerance, preserve_topology=True))
# Fix invalid geometries after simplification
wpda_gdf_polygons["geometry"] = wpda_gdf_polygons["geometry"].buffer(0)
# Out:
# C:\Users\mp_ma\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
wpda_gdf_polygons
# Out:
#         WDPA_PID                                               NAME  \
# 0          611_A               Wood Buffalo National Park Of Canada
# 1          611_B               Wood Buffalo National Park Of Canada
# 2            612             Kluane National Park Reserve Of Canada
# 3          613_B                  Auyuittuq National Park Of Canada
# 4          613_A                  Auyuittuq National Park Of Canada
# ...          ...                                                ...
# 13463  555785733  Grosse Île and the Irish Memorial National His...
# 13464  555785734                 Navy Island National Historic Site
# 13465  555785735  Fort George National Historic Site (Paradise G...
# 13466  555785736                Rideau Canal National Historic Site
# 13467  555785737                            Capital Recreation Area
#
#                           DESIG OWN_TYPE                          MANG_AUTH  \
# 0                 National Park    State                Parks Canada Agency
# 1                 National Park    State                Parks Canada Agency
# 2                 National Park    State                Parks Canada Agency
# 3                 National Park    State                Parks Canada Agency
# 4                 National Park    State                Parks Canada Agency
# ...                         ...      ...                                ...
# 13463  Lieu historique national    State                Parks Canada Agency
# 13464    National Historic Site    State                Parks Canada Agency
# 13465    National Historic Site    State                Parks Canada Agency
# 13466    National Historic Site    State                Parks Canada Agency
# 13467                      OECM    State  National Capital Commission (NCC)
#
#        STATUS_YR                                           geometry
# 0           1922  POLYGON ((-112.87253 59.99877, -111.53006 59.7...
# 1           1922  POLYGON ((-112.87253 59.99877, -115.58450 59.9...
# 2           1972  POLYGON ((-141.00187 60.30634, -137.43466 60.7...
# 3           1972  MULTIPOLYGON (((-64.62292 67.13706, -63.92605 ...
# 4           1972  MULTIPOLYGON (((-68.23194 67.76712, -67.56846 ...
# ...          ...                                                ...
# 13463       2023  MULTIPOLYGON (((-70.67843 47.01639, -70.67802 ...
# 13464       2023  POLYGON ((-79.01037 43.04900, -79.00871 43.060...
# 13465       2023  POLYGON ((-79.06782 43.24368, -79.05901 43.248...
# 13466       2023  MULTIPOLYGON (((-76.24341 44.90190, -76.19385 ...
# 13467       2023  POLYGON ((-75.60920 45.33843, -75.61502 45.332...
#
# [13468 rows x 7 columns]

# %%
wpda_gdf_points
# Out:
#      WDPA_PID                                   NAME  \
# 0       67855    Tabusintac Lagoon and River Estuary
# 1      166868                         Minesing Swamp
# 2      166867                         Matchedash Bay
# 3      166866                       Lac Saint Pierre
# 4      902694                      Columbia Wetlands
# 5        2058                     Mont Saint Hilaire
# 6       11586      Riding Mountain Biosphere Reserve
# 7       11587           Long Point Biosphere Reserve
# 8       18922  Réserve de la biosphère de Charlevoix
# 9       20014   Niagara Escarpment Biosphere Reserve
# 10     198338                          Redberry Lake
# 11     220256                       Lac Saint-Pierre
# 12     900664                        South West Nova
# 13     900714       Thousands Islands Frontenac Arch
# 14     902536                  Georgian Bay Littoral
# 15     198337                        Clayoquot Sound
# 16     220257                       Mount Arrowsmith
# 17  555547532                                  Fundy
# 18  555547533                   Manicouagan-Uapishka
# 19  555547579                              Bras d'Or
#
#                                                DESIG      OWN_TYPE  \
# 0   Ramsar Site, Wetland of International Importance  Not Reported
# 1   Ramsar Site, Wetland of International Importance  Not Reported
# 2   Ramsar Site, Wetland of International Importance  Not Reported
# 3   Ramsar Site, Wetland of International Importance  Not Reported
# 4   Ramsar Site, Wetland of International Importance  Not Reported
# 5                       UNESCO-MAB Biosphere Reserve  Not Reported
# 6                       UNESCO-MAB Biosphere Reserve  Not Reported
# 7                       UNESCO-MAB Biosphere Reserve  Not Reported
# 8                       UNESCO-MAB Biosphere Reserve  Not Reported
# 9                       UNESCO-MAB Biosphere Reserve  Not Reported
# 10                      UNESCO-MAB Biosphere Reserve  Not Reported
# 11                      UNESCO-MAB Biosphere Reserve  Not Reported
# 12                      UNESCO-MAB Biosphere Reserve  Not Reported
# 13                      UNESCO-MAB Biosphere Reserve  Not Reported
# 14                      UNESCO-MAB Biosphere Reserve  Not Reported
# 15                      UNESCO-MAB Biosphere Reserve  Not Reported
# 16                      UNESCO-MAB Biosphere Reserve  Not Reported
# 17                      UNESCO-MAB Biosphere Reserve  Not Reported
# 18                      UNESCO-MAB Biosphere Reserve  Not Reported
# 19                      UNESCO-MAB Biosphere Reserve  Not Reported
#
#        MANG_AUTH  STATUS_YR                     geometry
# 0   Not Reported       1993   POINT (-64.93333 47.33333)
# 1   Not Reported       1996   POINT (-80.86667 44.38333)
# 2   Not Reported       1996   POINT (-79.66667 44.73333)
# 3   Not Reported       1998   POINT (-72.65000 46.13333)
# 4   Not Reported       2005  POINT (-115.21667 50.68333)
# 5   Not Reported       1978   POINT (-75.16667 45.55000)
# 6   Not Reported       1986  POINT (-100.30000 50.76670)
# 7   Not Reported       1986   POINT (-80.33000 43.58000)
# 8   Not Reported       1988   POINT (-70.55000 47.66667)
# 9   Not Reported       1990   POINT (-79.93000 43.62000)
# 10  Not Reported       2000  POINT (-107.00000 52.70000)
# 11  Not Reported       2000   POINT (-72.91667 46.15000)
# 12  Not Reported       2001   POINT (-65.83333 44.21667)
# 13  Not Reported       2002   POINT (-76.16667 44.33333)
# 14  Not Reported       2004   POINT (-81.00000 45.25000)
# 15  Not Reported       2000  POINT (-126.00000 49.28333)
# 16  Not Reported       2000  POINT (-124.38333 49.25000)
# 17  Not Reported       2007   POINT (-65.03000 45.61000)
# 18  Not Reported       2007   POINT (-68.14000 49.24000)
# 19  Not Reported       2011   POINT (-60.70380 45.88690)

# %% [markdown]
# # Exports raw datasets to GeoParquet format

# %%
# to avoid error
tailings_gdf["longitude"] = pd.to_numeric(tailings_gdf["longitude"], errors="coerce")
tailings_gdf["latitude"] = pd.to_numeric(tailings_gdf["latitude"], errors="coerce")
tailings_gdf["current_tailings_storage"] = tailings_gdf["current_tailings_storage"].astype(str)
tailings_gdf["planned_storage_5_years"] = tailings_gdf["current_tailings_storage"].astype(str)

# %%
output_dir = "data/Tables/Raw_datasets/GeoParquet/"
main_gdf.to_parquet(output_dir + "main_gdf.parquet", index=False)
#tailings_gdf.to_parquet(output_dir + "tailings_gdf.parquet", index=False)
min_can_gdf.to_parquet(output_dir + "min_can_gdf.parquet", index=False)
ctrace_gdf.to_parquet(output_dir + "ctrace_gdf.parquet", index=False)
conflict_gdf.to_parquet(output_dir + "conflict_gdf.parquet", index=False)
ghg_gdf.to_parquet(output_dir + "ghg_gdf.parquet", index=False)
pollutant_gdf.to_parquet(output_dir + "pollutant_gdf.parquet", index=False)
prioritization_area_gdf.to_parquet(output_dir + "prioritization_area_gdf.parquet", index=False)
climate_category_gdf.to_parquet(output_dir + "climate_category_gdf.parquet", index=False)
weather_gdf.to_parquet(output_dir + "weather_gdf.parquet", index=False)
peatland_gdf.to_parquet(output_dir + "peatland_gdf.parquet", index=False)
population_gdf.to_parquet(output_dir + "population_gdf.parquet", index=False)
water_risk_gdf.to_parquet(output_dir + "water_risk_gdf.parquet", index=False)
land_cover_gdf.to_parquet(output_dir + "land_cover_gdf.parquet", index=False)
npv_gdf.to_parquet(output_dir + "npv_gdf.parquet", index=False)
indigenous_can_gdf.to_parquet(output_dir + "indigenous_can_gdf.parquet", index=False)
wpda_gdf_polygons.to_parquet(output_dir + "wpda_gdf_polygons.parquet", index=False)
wpda_gdf_points.to_parquet(output_dir + "wpda_gdf_points.parquet", index=False)
tang_canada_gdf.to_parquet(output_dir + "tang_canada_gdf.parquet", index=False)
maus_canada_gdf.to_parquet(output_dir + "maus_canada_gdf.parquet", index=False)
