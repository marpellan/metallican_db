# %%
import pandas as pd
import os

# %% [markdown]
# # From BGS

# %%
df_bgs = pd.read_csv('data/BGS/Minerals_Data_Export_Canada_2020_2023.csv')

# %%
col_to_keep = ['yearbook_table_trans', 'units', 'bgs_commodity_trans', 'erml_group', 'erml_commodity', 'year', 'cgi_commodity_url', 'quantity']

# %%
df_bgs_can = df_bgs[col_to_keep]

# %%
df_bgs_can
# Out:
#                           yearbook_table_trans                      units  \
# 0     Mine production of platinum group metals  kilograms (metal content)
# 1                      Production of magnesite            tonnes (metric)
# 2              Production of nepheline syenite            tonnes (metric)
# 3                 Production of phosphate rock            tonnes (metric)
# 4                   Production of ferro-alloys            tonnes (metric)
# ...                                        ...                        ...
# 1284                Production of ferro-alloys            tonnes (metric)
# 1285             Mine production of molybdenum     tonnes (metal content)
# 1286                Production of ferro-alloys            tonnes (metric)
# 1287              Production of refined copper            tonnes (metric)
# 1288              Production of refined cobalt            tonnes (metric)
#
#               bgs_commodity_trans             erml_group  \
# 0     platinum group metals, mine  Platinum group metals
# 1                       magnesite              Magnesite
# 2               nepheline syenite      Nepheline syenite
# 3                  phosphate rock         Phosphate rock
# 4                    ferro-alloys                    NaN
# ...                           ...                    ...
# 1284                 ferro-alloys                    NaN
# 1285             molybdenum, mine             Molybdenum
# 1286                 ferro-alloys                    NaN
# 1287              copper, refined                 Copper
# 1288              cobalt, refined                 Cobalt
#
#                                          erml_commodity        year  \
# 0     Platinum group metals (mine production, metal ...  2000-01-01
# 1                                Magnesite and magnesia  2000-01-01
# 2                                     Nepheline syenite  2000-01-01
# 3                                        Phosphate rock  2000-01-01
# 4                                                   NaN  2000-01-01
# ...                                                 ...         ...
# 1284                                                NaN  2022-01-01
# 1285        Molybdenum (mine production, metal content)  2022-01-01
# 1286                                                NaN  2022-01-01
# 1287                                    Copper, refined  2022-01-01
# 1288                                   Cobalt (refined)  2022-01-01
#
#                                       cgi_commodity_url  quantity
# 0     http://resource.geosciml.org/classifier/cgi/co...    6000.0
# 1     http://resource.geosciml.org/classifier/cgi/co...  165000.0
# 2     http://resource.geosciml.org/classifier/cgi/co...  721000.0
# 3     http://resource.geosciml.org/classifier/cgi/co...  486000.0
# 4                                                   NaN    3300.0
# ...                                                 ...       ...
# 1284                                                NaN    7400.0
# 1285  http://resource.geosciml.org/classifier/cgi/co...    1146.0
# 1286                                                NaN   30000.0
# 1287  http://resource.geosciml.org/classifier/cgi/co...  278000.0
# 1288  http://resource.geosciml.org/classifier/cgi/co...    5501.0
#
# [1289 rows x 8 columns]

# %% [markdown]
# # From World Mining Data 2024

# %%
def get_canada_production_data_wmd(file_path):
    """
    Reads an Excel file with multiple sheets, each representing a commodity.
    Extracts Canada's production, world share, and unit for each commodity, returning a DataFrame.
    Commodities are listed in alphabetical order, with 0s for missing data.
    
    Parameters:
    - file_path (str): Path to the Excel file containing the data.
    
    Returns:
    - pd.DataFrame: DataFrame with columns: ['Commodity', 'Production Volume', 'World Share (%)', 'Unit']
    """
    # Load the Excel file
    excel_data = pd.ExcelFile(file_path)
    
    # Initialize a dictionary to store production volume, world share data, and units for Canada
    canada_production_data = {'Commodity': [], 'Production Volume': [], 'World Share (%)': [], 'Unit': []}
    
    # Loop through each sheet, extract Canada's data if present
    for sheet in excel_data.sheet_names:
        df = excel_data.parse(sheet, skiprows=1)  # Start reading from the second row with corrected column headers
        canada_row = df[df['Country'].str.contains("Canada", na=False)]
        
        # Get the unit if present, default to 'tonnes' if not specified
        unit = df['unit'].iloc[0] if 'unit' in df.columns else 'tonnes'
        
        # Add data or fill with 0 if Canada data is missing
        canada_production_data['Commodity'].append(sheet)
        canada_production_data['Unit'].append(unit)
        if not canada_row.empty:
            canada_production_data['Production Volume'].append(float(canada_row['Production 2022'].values[0]))
            canada_production_data['World Share (%)'].append(float(canada_row['Share in %'].values[0]))
        else:
            canada_production_data['Production Volume'].append(0)
            canada_production_data['World Share (%)'].append(0)

    # Convert the dictionary to a DataFrame and sort alphabetically by Commodity
    canada_production_df = pd.DataFrame(canada_production_data).sort_values(by="Commodity").reset_index(drop=True)
    
    return canada_production_df

# %%
file_path_wmd = 'data/WMD/6.5. Share_of_World_Mineral_Production_2022_by_Countries.xlsx'

# %%
# We keep only non 0 production volume
canada_production_df = get_canada_production_data_wmd(file_path_wmd)
canada_production_df = canada_production_df[canada_production_df['Production Volume'] != 0]
canada_production_df
# Out:
#                           Commodity  Production Volume  World Share (%)  \
# 0                         Aluminium          3033966.0         4.408193
# 1                          Antimony                2.0         0.002409
# 4                            Baryte            50000.0         0.603986
# 10                          Cadmium             1800.0         7.825066
# 12                           Cobalt             3063.0         1.844847
# 13                      Coking Coal         26461240.0         2.539750
# 14                           Copper           510782.0         2.298189
# 15                   Diamonds (Gem)         17728144.0        22.325758
# 19                        Fluorspar            20000.0         0.216534
# 22                             Gold           205831.0         6.193863
# 23                         Graphite            13000.0         0.752539
# 24             Gypsum and Anhydrite          3174070.0         1.793377
# 25                           Indium               39.0         3.869048
# 26                        Iron (Fe)         42073900.0         2.718035
# 28                             Lead             8247.0         0.175694
# 29                          Lignite          6427680.0         0.897231
# 31                        Magnesite           230000.0         0.861561
# 34                       Molybdenum             1146.0         0.431703
# 35                      Natural Gas           186121.0         4.475801
# 36                           Nickel           143266.0         4.409683
# 37                  Niobium (Nb2O5)             6800.0         5.752523
# 38    Oil Sands (part of Petroleum)        179386500.0        90.880835
# 40                        Palladium            16099.0         7.969329
# 42                        Petroleum        271233300.0         6.122785
# 44                         Platinum             5490.0         2.999639
# 45                     Potash (K2O)         15116101.0        36.027157
# 48                          Rhodium              500.0         2.199639
# 49      Salt (rock, brines, marine)         14640779.0         5.384908
# 50                         Selenium              110.0         2.945114
# 51                           Silver           334480.0         1.258184
# 52                      Steam Coal          12201040.0         0.184292
# 53  Sulfur (elementar & industrial)          4898600.0         5.918407
# 54    Talc, Steatite & Pyrophyllite           200000.0         2.563910
# 56                        Tellurium               24.0         3.524229
# 58                  Titanium (TiO2)           540000.0         6.038246
# 60                   Uranium (U3O8)             6168.0        11.019796
# 63                             Zinc           208147.0         1.630981
#
#        Unit
# 0   metr. t
# 1   metr. t
# 4   metr. t
# 10  metr. t
# 12  metr. t
# 13  metr. t
# 14  metr. t
# 15       ct
# 19  metr. t
# 22       kg
# 23  metr. t
# 24  metr. t
# 25  metr. t
# 26  metr. t
# 28  metr. t
# 29  metr. t
# 31  metr. t
# 34  metr. t
# 35   Mio m3
# 36  metr. t
# 37  metr. t
# 38  metr. t
# 40       kg
# 42  metr. t
# 44       kg
# 45  metr. t
# 48       kg
# 49  metr. t
# 50  metr. t
# 51       kg
# 52  metr. t
# 53  metr. t
# 54  metr. t
# 56  metr. t
# 58  metr. t
# 60  metr. t
# 63  metr. t

# %%
# We put everything in kg
canada_production_df_kg = canada_production_df.copy()
canada_production_df_kg.loc[canada_production_df_kg['Unit'] == 'metr. t', 'Production Volume'] *= 1000
canada_production_df_kg.loc[canada_production_df_kg['Unit'] == 'metr. t', 'Unit'] = 'kg'
canada_production_df_kg.rename(columns={'Production Volume': 'Production Volume (kg)'}, inplace=True)
canada_production_df_kg.drop(columns=['Unit'], inplace=True)
canada_production_df_kg

# %%
canada_production_df_kg.to_csv(r'data/World_mining_data_2024/canada_production_wmd2024_kg.csv', index=False)

# %% [markdown]
# # From USGS MCS2025

# %%
df_usgs_mcs = pd.read_csv('data/USGS/Mineral_commodity_summary_2025/MCS2025_World_Data.csv')

# %%
df_usgs_mcs
# Out:
#        SOURCE              COMMODITY                   COUNTRY  \
# 0     MCS2025              Abrasives             United States
# 1     MCS2025              Abrasives  United States and Canada
# 2     MCS2025              Abrasives                 Australia
# 3     MCS2025              Abrasives                   Austria
# 4     MCS2025              Abrasives                    Brazil
# ...       ...                    ...                       ...
# 1245  MCS2025  Zirconium and Hafnium                   Senegal
# 1246  MCS2025  Zirconium and Hafnium              Sierra Leone
# 1247  MCS2025  Zirconium and Hafnium             South Africa
# 1248  MCS2025  Zirconium and Hafnium           Other Countries
# 1249  MCS2025  Zirconium and Hafnium     World total (rounded)
#
#                                           TYPE             UNIT_MEAS  \
# 0         Plant capacity, fused aluminum oxide           metric tons
# 1         Plant capacity, fused aluminum oxide           metric tons
# 2         Plant capacity, fused aluminum oxide           metric tons
# 3         Plant capacity, fused aluminum oxide           metric tons
# 4         Plant capacity, fused aluminum oxide           metric tons
# ...                                        ...                   ...
# 1245  Mine production, zirconium, gross weight  thousand metric tons
# 1246  Mine production, zirconium, gross weight  thousand metric tons
# 1247  Mine production, zirconium, gross weight  thousand metric tons
# 1248  Mine production, zirconium, gross weight  thousand metric tons
# 1249  Mine production, zirconium, gross weight  thousand metric tons
#
#       PROD_2023  PROD_EST_ 2024          PROD_NOTES  CAP_2023  CAP_EST_ 2024  \
# 0           NaN             NaN  estimated for 2023       NaN            NaN
# 1           NaN             NaN                       60000.0        60000.0
# 2           NaN             NaN                 NaN   50000.0        50000.0
# 3           NaN             NaN                 NaN   90000.0        90000.0
# 4           NaN             NaN                 NaN   50000.0        50000.0
# ...         ...             ...                 ...       ...            ...
# 1245       48.0            60.0            reported       NaN            NaN
# 1246       28.0            20.0            reported       NaN            NaN
# 1247      289.0           300.0            reported       NaN            NaN
# 1248       86.0           110.0                 NaN       NaN            NaN
# 1249     1440.0          1500.0                 NaN       NaN            NaN
#
#      CAP_NOTES RESERVES_2024 RESERVE_NOTES
# 0          NaN           NaN           NaN
# 1          NaN           NaN           NaN
# 2          NaN           NaN           NaN
# 3          NaN           NaN           NaN
# 4          NaN           NaN           NaN
# ...        ...           ...           ...
# 1245       NaN          2600  ZrO2 content
# 1246       NaN           290  ZrO2 content
# 1247       NaN          5300  ZrO2 content
# 1248       NaN          5700  ZrO2 content
# 1249       NaN         70000  ZrO2 content
#
# [1250 rows x 13 columns]

# %%
df_usgs_mcs_can = df_usgs_mcs[df_usgs_mcs['COUNTRY'].str.contains('Canada', case=False, na=False)]

# %%
df_usgs_mcs_can
# Out:
#        SOURCE                      COMMODITY                        COUNTRY  \
# 1     MCS2025                      Abrasives       United States and Canada
# 16    MCS2025                      Abrasives       United States and Canada
# 34    MCS2025                       Aluminum                        Canada
# 48    MCS2025                       Antimony                        Canada
# 92    MCS2025                        Bauxite                        Canada
# 113   MCS2025                        Bauxite                        Canada
# 169   MCS2025                       Cadmium                         Canada
# 265   MCS2025                         Cobalt                        Canada
# 279   MCS2025                        Copper                         Canada
# 298   MCS2025                        Copper                         Canada
# 386   MCS2025                      Gemstones                        Canada
# 401   MCS2025                       Gemanium                        Canada
# 411   MCS2025                          Gold                         Canada
# 429   MCS2025                       Graphite                        Canada
# 449   MCS2025                         Gypsum                        Canada
# 471   MCS2025                         Helium                        Canada
# 480   MCS2025                         Indium                        Canada
# 500   MCS2025                 Iron and Steel                        Canada
# 518   MCS2025                 Iron and Steel                        Canada
# 537   MCS2025                     Iron Ore                          Canada
# 556   MCS2025                     Iron Ore                          Canada
# 607   MCS2025                           Lime             Canada (shipments)
# 630   MCS2025                       Lithium                         Canada
# 642   MCS2025            Magnesium Compounds                        Canada
# 684   MCS2025                 Mica (Natural)                        Canada
# 695   MCS2025                 Mica (Natural)                        Canada
# 709   MCS2025                    Molybdenum                         Canada
# 725   MCS2025                         Nickel                        Canada
# 735   MCS2025                        Niobium                        Canada
# 744   MCS2025      Nitrogen(fixed) - Ammonia                        Canada
# 767   MCS2025                          Peat                         Canada
# 821   MCS2025          Platinum-Group metals                        Canada
# 828   MCS2025          Platinum-Group metals                        Canada
# 837   MCS2025                       Potash                          Canada
# 851   MCS2025                       Potash                          Canada
# 882   MCS2025                    Rare earths                        Canada
# 911   MCS2025                          Salt                         Canada
# 935   MCS2025   Sand and gravel (industrial)                        Canada
# 955   MCS2025                       Selenium                        Canada
# 975   MCS2025                        Silicon                        Canada
# 994   MCS2025                        Silicon                        Canada
# 1014  MCS2025                         Silver                        Canada
# 1043  MCS2025                         Sulfur                        Canada
# 1063  MCS2025                    Talc, crude  Canada (unspecified minerals)
# 1091  MCS2025                      Tellurium                        Canada
# 1121  MCS2025  Titanium Mineral Concentrates                        Canada
# 1143  MCS2025    Titanium & titanium dioxide                        Canada
# 1158  MCS2025    Titanium & titanium dioxide                        Canada
# 1203  MCS2025                   Wollastonite                        Canada
#
#                                                    TYPE  \
# 1                  Plant capacity, fused aluminum oxide
# 16                      Plant capacity, silicon carbide
# 34                         Smelter production, aluminum
# 48                    Mine production, antimony content
# 92    Refinery production, alumina - calcined equiva...
# 113                  Mine production, bauxite, dry tons
# 169                      Refinery production, estimated
# 265          Mine production, cobalt content, estimated
# 279         Mine production, recoverable copper content
# 298                         Refinery production, copper
# 386   Mine production, thousand carats of gem-qualit...
# 401           Primary and secondary refinery production
# 411                       mine production, gold content
# 429                                     Mine production
# 449                          Mine production, estimated
# 471                      Production, helium gas content
# 480                                 Refinery production
# 500                                            Pig iron
# 518                                           Raw steel
# 537                         Mine production, usable ore
# 556                       Mine production, iron content
# 607                              Plant production, lime
# 630                    Mine production, lithium content
# 642           Mine production, magnesite - gross weight
# 684               Mine production, mica scrap and flake
# 695                         Mine production, mica sheet
# 709                 Mine production, molybdenum content
# 725                     Mine production, nickel content
# 735                    Mine production, niobium content
# 744                  Plant production, nitrogen content
# 767                                     Mine production
# 821                  Mine production, Palladium content
# 828                   Mine production, Platinum content
# 837   Mine production, potassium oxide (K2O) equivalent
# 851                           Reserves, recoverable ore
# 882        Mine production, rare-earth-oxide equivalent
# 911                          Mine production, estimated
# 935                          Mine production, estimated
# 955               Refinery production, selenium content
# 975     Plant production, Ferosilicon, silicon content
# 994                     Plant production, silicon metal
# 1014                    Mine production, silver content
# 1043              Production, all forms, sulfur content
# 1063                         Mine production, estimated
# 1091             Refinery production, tellurium content
# 1121  Mine production, ilmentite, titanium dioxide (...
# 1143                            Sponge Metal Production
# 1158                                   Pigment Capacity
# 1203                                    Mine production
#
#                      UNIT_MEAS  PROD_2023  PROD_EST_ 2024  \
# 1                  metric tons        NaN             NaN
# 16                 metric tons        NaN             NaN
# 34        thousand metric tons     3200.0          3300.0
# 48                 metric tons        NaN             NaN
# 92    thousand metric dry tons     1500.0          1500.0
# 113   thousand metric dry tons        NaN             NaN
# 169                metric tons     1800.0          1700.0
# 265                metric tons     4220.0          4500.0
# 279       thousand metric tons      500.0           450.0
# 298       thousand metric tons      315.0           320.0
# 386            thousand carats    16000.0         16000.0
# 401                  kilograms        NaN             NaN
# 411                metric tons      198.0           200.0
# 429                metric tons     5470.0         20000.0
# 449       thousand metric tons     2400.0          2400.0
# 471       million cubic meters        5.0             6.0
# 480                metric tons       40.0            35.0
# 500        million metric tons        6.0             6.0
# 518        million metric tons       12.0            12.0
# 537       thousand metric tons    59400.0         54000.0
# 556       thousand metric tons    35700.0         32000.0
# 607       thousand metric tons     1920.0          1900.0
# 630                metric tons     3240.0          4300.0
# 642       thousand metric tons      150.0           150.0
# 684                metric tons    15000.0         15000.0
# 695                metric tons        NaN             NaN
# 709                metric tons     1150.0          1200.0
# 725                metric tons   159000.0        190000.0
# 735                metric tons     6700.0          7100.0
# 744       thousand metric tons     3600.0          3600.0
# 767       thousand metric tons     3030.0          3000.0
# 821                  kilograms    16100.0         15000.0
# 828                  kilograms     5170.0          5200.0
# 837       thousand metric tons    13500.0         15000.0
# 851       thousand metric tons        NaN             NaN
# 882                metric tons        NaN             NaN
# 911       thousand metric tons    12000.0         12000.0
# 935                metric tons     4100.0          4100.0
# 955                metric tons      130.0           130.0
# 975       thousand metric tons       23.0            20.0
# 994       thousand metric tons       29.0            30.0
# 1014               metric tons      306.0           300.0
# 1043      thousand metric tons     4980.0          5000.0
# 1063      thousand metric tons      200.0           200.0
# 1091               metric tons       27.0            27.0
# 1121               metric tons      350.0           350.0
# 1143               metric tons        NaN             NaN
# 1158               metric tons        NaN             NaN
# 1203               metric tons    20000.0         20000.0
#
#                                              PROD_NOTES  CAP_2023  \
# 1                                                         60000.0
# 16                                                  NaN       NaN
# 34                                       estimated 2023    3270.0
# 48                                                  NaN       NaN
# 92                                                  NaN       NaN
# 113                                                 NaN       NaN
# 169                                                 NaN       NaN
# 265                                                 NaN       NaN
# 279                                                 NaN       NaN
# 298                                                 NaN       NaN
# 386                                                 NaN       NaN
# 401                                                 NaN       NaN
# 411                                                 NaN       NaN
# 429                                                 NaN       NaN
# 449                                                 NaN       NaN
# 471                                                 NaN       NaN
# 480                                                 NaN       NaN
# 500                                                 NaN       NaN
# 518                                                 NaN       NaN
# 537                                                 NaN       NaN
# 556                                                 NaN       NaN
# 607                                                 NaN       NaN
# 630                                      estimated 2023       NaN
# 642                                                 NaN       NaN
# 684                                                 NaN       NaN
# 695                                                 NaN       NaN
# 709                                                 NaN       NaN
# 725                                                 NaN       NaN
# 735                                                 NaN       NaN
# 744                                                 NaN       NaN
# 767                                                 NaN       NaN
# 821                                                 NaN       NaN
# 828                                                 NaN       NaN
# 837                                                 NaN       NaN
# 851                                                 NaN       NaN
# 882                                                 NaN       NaN
# 911                                                 NaN       NaN
# 935                                                 NaN       NaN
# 955                                                 NaN       NaN
# 975                                                 NaN       NaN
# 994                                                 NaN       NaN
# 1014                                                NaN       NaN
# 1043                                                NaN       NaN
# 1063                                                NaN       NaN
# 1091                                                NaN       NaN
# 1121  Mine production of titaniferous magnetite is p...       NaN
# 1143                                                NaN       NaN
# 1158                                                NaN       NaN
# 1203                                                NaN       NaN
#
#       CAP_EST_ 2024 CAP_NOTES RESERVES_2024                      RESERVE_NOTES
# 1           60000.0       NaN           NaN                                NaN
# 16              NaN       NaN           NaN                                NaN
# 34           3270.0       NaN           NaN                                NaN
# 48              NaN       NaN         78000                                NaN
# 92              NaN       NaN           NaN                                NaN
# 113             NaN       NaN           NaN                                NaN
# 169             NaN       NaN           NaN                                NaN
# 265             NaN       NaN        220000                                NaN
# 279             NaN       NaN          8300                                NaN
# 298             NaN       NaN           NaN                                NaN
# 386             NaN       NaN        110000                                NaN
# 401             NaN       NaN           NaN                                NaN
# 411             NaN       NaN          3200                                NaN
# 429             NaN       NaN       5900000                                NaN
# 449             NaN       NaN        450000                                NaN
# 471             NaN       NaN           NaN                                NaN
# 480             NaN       NaN            70                                NaN
# 500             NaN       NaN           NaN                                NaN
# 518             NaN       NaN           NaN                                NaN
# 537             NaN       NaN          6000     Crude Ore, million metric tons
# 556             NaN       NaN          2300  Iron Content, million metric tons
# 607             NaN       NaN           NaN                                NaN
# 630             NaN       NaN       1200000                                NaN
# 642             NaN       NaN           NaN                                NaN
# 684             NaN       NaN           NaN                              Large
# 695             NaN       NaN           NaN                                NaN
# 709             NaN       NaN            64                                NaN
# 725             NaN       NaN       2200000                                NaN
# 735             NaN       NaN       1600000                                NaN
# 744             NaN       NaN           NaN                                NaN
# 767             NaN       NaN        720000                                NaN
# 821             NaN       NaN        310000                                NaN
# 828             NaN       NaN           NaN                                NaN
# 837             NaN       NaN       1100000                                NaN
# 851             NaN       NaN       4500000                                NaN
# 882             NaN       NaN        830000                                NaN
# 911             NaN       NaN           NaN                                NaN
# 935             NaN       NaN           NaN                                NaN
# 955             NaN       NaN          6500                                NaN
# 975             NaN       NaN           NaN                                NaN
# 994             NaN       NaN           NaN                                NaN
# 1014            NaN       NaN          4900                                NaN
# 1043            NaN       NaN           NaN                                NaN
# 1063            NaN       NaN           NaN                                NaN
# 1091            NaN       NaN           900                                NaN
# 1121            NaN       NaN         51000                                NaN
# 1143            NaN       NaN           NaN                                NaN
# 1158       180000.0       NaN           NaN                                NaN
# 1203            NaN       NaN           NaN                                NaN
