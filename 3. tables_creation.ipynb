# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %% [markdown]
# # Imports

# %%
# From datasets see dataset_processing.ipynb
main_gdf = gpd.read_file(r'data/Tables/GeoJSON/main_gdf.geojson')
tailings_gdf = gpd.read_file(r'data/Tables/GeoJSON/tailings_gdf.geojson')
min_can_gdf = gpd.read_file(r'data/Tables/GeoJSON/min_can_gdf.geojson')
ctrace_gdf = gpd.read_file(r'data/Tables/GeoJSON/ctrace_gdf.geojson')
conflict_gdf = gpd.read_file(r'data/Tables/GeoJSON/conflict_gdf.geojson')
ghg_gdf = gpd.read_file(r'data/Tables/GeoJSON/ghg_gdf.geojson')
pollutant_gdf = gpd.read_file(r'data/Tables/GeoJSON/pollutant_gdf.geojson')
climate_category_gdf = gpd.read_file(r'data/Tables/GeoJSON/climate_category_gdf.geojson')
weather_gdf = gpd.read_file(r'data/Tables/GeoJSON/weather_gdf.geojson')
peatland_gdf = gpd.read_file(r'data/Tables/GeoJSON/peatland_gdf.geojson')
prioritization_area_gdf = gpd.read_file(r'data/Tables/GeoJSON/prioritization_area_gdf.geojson')
population_gdf = gpd.read_file(r'data/Tables/GeoJSON/population_gdf.geojson')
water_risk_gdf = gpd.read_file(r'data/Tables/GeoJSON/water_risk_gdf.geojson')
land_cover_gdf = gpd.read_file(r'data/Tables/GeoJSON/land_cover_gdf.geojson')
npv_gdf = gpd.read_file(r'data/Tables/GeoJSON/npv_gdf.geojson')
indigenous_can_gdf = gpd.read_file(r'data/Tables/GeoJSON/indigenous_can_gdf.geojson')
wpda_gdf_polygons = gpd.read_file(r'data/Tables/GeoJSON/wpda_gdf_polygons.geojson')
tang_canada_gdf = gpd.read_file(r'data/Tables/GeoJSON/tang_canada_gdf.geojson')

# %%
main_gdf.drop(columns=["longitude", "latitude"], inplace=True)

# %%
# From manually collected data
production_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Production')
reserves_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Production')
energy_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Energy')
env_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Env')
env_int_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Env_int')
archetypes_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Archetype')

# %%
from db_creation_function import assign_row_id

# %%
def assign_row_id_to_collected_data(
    df,
    facility_id_col="main_id",
    row_id_col="row_id",
    prefix="ROW",
    year_col=None,
    scenario_col=None,
    fallback_cols=["facility_group_id", "company_id"]
):
    df = df.copy()

    def is_valid(val):
        return pd.notna(val) and str(val).strip() not in ["", "-"]

    def resolve_facility_id(row):
        val = row.get(facility_id_col)
        if is_valid(val):
            return str(val).strip()
        for col in fallback_cols:
            fallback_val = row.get(col)
            if is_valid(fallback_val):
                return str(fallback_val).strip()
        return "UNKNOWN"

    def extract_hash(fac_id):
        s = str(fac_id)
        parts = s.split("-")
        if len(parts) >= 3:
            return parts[-1]
        else:
            return s

    df["_facility_resolved"] = df.apply(resolve_facility_id, axis=1)
    df["_hash"] = df["_facility_resolved"].apply(extract_hash)

    group_cols = ["_facility_resolved"]
    if year_col:
        group_cols.append(year_col)
    if scenario_col:
        group_cols.append(scenario_col)

    df["_row_index"] = df.groupby(group_cols).cumcount() + 1

    def build_id(row):
        parts = [prefix, row["_hash"]]
        if year_col:
            parts.append(str(row[year_col]))
        if scenario_col:
            parts.append(str(row[scenario_col]))
        parts.append(str(row["_row_index"]))
        return "-".join(parts)

    df[row_id_col] = df.apply(build_id, axis=1)
    df.drop(columns=["_row_index", "_hash", "_facility_resolved"], inplace=True)

    cols = [row_id_col] + [col for col in df.columns if col != row_id_col]
    return df[cols]

# %%
# We need to assign row_ids to the manually collected data
production_df = assign_row_id_to_collected_data(production_df, 
                  facility_id_col='main_id',
                  prefix='PROD',
                  year_col='year'           
                  )

reserves_df = assign_row_id_to_collected_data(reserves_df, 
                  facility_id_col='main_id',
                  prefix='RES',
                  year_col='year'           
                  )

energy_df = assign_row_id_to_collected_data(energy_df, 
                  facility_id_col='main_id',
                  prefix='NRJ',
                  year_col='year'           
                  )

env_df = assign_row_id_to_collected_data(env_df, 
                  facility_id_col='main_id',
                  prefix='ENV',
                  year_col='year'           
                  )

env_int_df = assign_row_id_to_collected_data(env_int_df, 
                  facility_id_col='main_id',
                  prefix='ENV_INT',
                  year_col='year'           
                  )

archetypes_df = assign_row_id_to_collected_data(archetypes_df, 
                  facility_id_col='main_id',
                  prefix='ARCH',
                  )

# %% [markdown]
# # Create auxiliary tables

# %% [markdown]
# ## Source table

# %%
# For the main table
source_map = {
    "project": "https://open.canada.ca/data/en/dataset/22b2db8a-dc12-47f2-9737-99d3da921751",
    "mining": "https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720",
    "manufacturing": "https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720"
}
main_gdf["source_id"] = main_gdf["facility_type"].map(source_map)
main_gdf
# Out:
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# 2                None           Agnico Eagle Mines Limited
# 3        GRP-0a2c0d69           Agnico Eagle Mines Limited
# 4                None           Agnico Eagle Mines Limited
# ..                ...                                  ...
# 265              None              Wesdome Gold Mines Ltd.
# 266              None       West High Yield Resources Ltd.
# 267              None  Western Copper and Gold Corporation
# 268              None                                Wyloo
# 269              None                ZincX Resources Corp.
#
#                      company_name_folder    company_id   longitude   latitude  \
# 0                      Abcourt Mines Inc  CMP-0a6a3062  -77.679010  48.521540
# 1                      Abcourt Mines Inc  CMP-0a6a3062  -77.974340  49.132590
# 2             Agnico Eagle Mines Limited  CMP-6265c407  -77.580000  48.040000
# 3             Agnico Eagle Mines Limited  CMP-6265c407  -96.697000  65.415000
# 4             Agnico Eagle Mines Limited  CMP-6265c407  -78.130824  48.122223
# ..                                   ...           ...         ...        ...
# 265               Wesdome Gold Mines Ltd  CMP-3d2c4955  -85.452500  48.110280
# 266        West High Yield Resources Ltd  CMP-1023f9c0 -117.884000  49.082000
# 267  Western Copper and Gold Corporation  CMP-2dac9896 -138.833330  62.733330
# 268                                Wyloo  CMP-65b36728  -86.303800  52.742020
# 269                 ZincX Resources Corp  CMP-3416049b -124.865990  57.380880
#
#               city  ...            status activity_status development_stage  \
# 0             None  ...  project_facility          Active  Advanced project
# 1    north of Amos  ...   active_facility            None              None
# 2             None  ...  project_facility          Active  Advanced project
# 3       Baker Lake  ...   active_facility            None              None
# 4         Malartic  ...   active_facility            None              None
# ..             ...  ...               ...             ...               ...
# 265           Wawa  ...   active_facility            None              None
# 266           None  ...  project_facility          Active  Advanced project
# 267           None  ...  project_facility          Active  Advanced project
# 268           None  ...  project_facility          Active  Advanced project
# 269           None  ...  project_facility          Active  Advanced project
#
#     facility_type  mining_processing_type  commodity_group primary_commodity  \
# 0         project                    None             None              Zinc
# 1          mining            Concentrator  Precious metals              Gold
# 2         project                    None             None              Gold
# 3          mining   Open-pit, underground  Precious metals              Gold
# 4          mining  Open-pit, concentrator  Precious metals              Gold
# ..            ...                     ...              ...               ...
# 265        mining                Open-pit  Precious metals              Gold
# 266       project                    None             None         Magnesium
# 267       project                    None             None            Copper
# 268       project                    None             None            Nickel
# 269       project                    None             None              Zinc
#
#                                    commodities  \
# 0                                 Zinc, silver
# 1                                 Gold, silver
# 2                                 Gold, copper
# 3                                         Gold
# 4                                 Gold, silver
# ..                                         ...
# 265                                       Gold
# 266                                  Magnesium
# 267           Copper, gold, molybdenum, silver
# 268  Nickel, copper, gold, platinum, palladium
# 269                         Zinc, lead, silver
#
#                                              source_id  \
# 0    https://open.canada.ca/data/en/dataset/22b2db8...
# 1    https://open.canada.ca/data/en/dataset/000183e...
# 2    https://open.canada.ca/data/en/dataset/22b2db8...
# 3    https://open.canada.ca/data/en/dataset/000183e...
# 4    https://open.canada.ca/data/en/dataset/000183e...
# ..                                                 ...
# 265  https://open.canada.ca/data/en/dataset/000183e...
# 266  https://open.canada.ca/data/en/dataset/22b2db8...
# 267  https://open.canada.ca/data/en/dataset/22b2db8...
# 268  https://open.canada.ca/data/en/dataset/22b2db8...
# 269  https://open.canada.ca/data/en/dataset/22b2db8...
#
#                         geometry
# 0     POINT (-77.67901 48.52154)
# 1     POINT (-77.97434 49.13259)
# 2     POINT (-77.58000 48.04000)
# 3     POINT (-96.69700 65.41500)
# 4     POINT (-78.13082 48.12222)
# ..                           ...
# 265   POINT (-85.45250 48.11028)
# 266  POINT (-117.88400 49.08200)
# 267  POINT (-138.83333 62.73333)
# 268   POINT (-86.30380 52.74202)
# 269  POINT (-124.86599 57.38088)
#
# [270 rows x 21 columns]

# %%
# For the datasets
tailings_gdf["source_id"] = 'https://tailing.grida.no/'
min_can_gdf["source_id"] = '10.1038/s41597-024-03116-3'
ctrace_gdf["source_id"] = 'Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory'
conflict_gdf["source_id"] = 'http://journals.librarypublishing.arizona.edu/jpe/article/id/1932/'
ghg_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/greenhouse-gas-emissions/large-facilities.html'
pollutant_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html' 
prioritization_area_gdf['source_id'] = 'https://doi.org/10.5281/zenodo.5006332'
climate_category_gdf['source_id'] = 'https://doi.org/10.1038/s41597-023-02549-6'
weather_gdf['source_id'] = 'https://climate-scenarios.canada.ca/?page=CanDCS6-indices'
peatland_gdf['source_id'] = 'https://greifswaldmoor.de/global-peatland-database-en.html'
population_gdf['source_id'] = 'https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F40-C41DA8332CFE' 
water_risk_gdf['source_id'] = 'https://www.wri.org/data/aqueduct-global-maps-40-data'
land_cover_gdf['source_id'] = 'https://doi.org/10.5067/MODIS/MCD12Q1.061 + https://doi.org/10.5281/zenodo.7254221'
npv_gdf['source_id'] = 'https://doi.org/10.7717/peerj.5457'
indigenous_can_gdf['source_id'] = 'http://www.landmarkmap.org'
wpda_gdf_polygons['source_id'] = 'https://www.protectedplanet.net'
tang_canada_gdf['source_id'] = 'https://doi.org/10.1038/s43247-023-00805-6'
#maus_canada_gdf['source_id'] = 'https://doi.org/10.1038/s41597-022-01547-4'

# %%
from db_creation_function import add_source_id_to_collected_data, create_source_table_from_datasets

# %%
def add_source_id_to_collected_data(df, company_col="company", facility_col="facility", source_col="source", source_id_col="source_id"):
    """
    Add a human-readable source_id column to a DataFrame using company, facility, and source file name.

    Parameters:
    - df: pandas DataFrame
    - company_col: column name for the company
    - facility_col: column name for the facility
    - source_col: column name for the source file (e.g. PDF, Excel)
    - source_id_col: name of the output column to be added

    Returns:
    - df with a new 'source_id' column (if not already present)
    """
    import pandas as pd
    from pathlib import Path

    if source_id_col not in df.columns:
        def create_source_id(row):
            company = str(row[company_col]).strip().replace(" ", "")
            file_stem = Path(str(row[source_col])).stem.strip().replace(" ", "")
            return f"SRC_{company}_{file_stem}"

        df[source_id_col] = df.apply(create_source_id, axis=1)
    else:
        print(f"ℹ️ '{source_id_col}' already exists. No changes made.")

    return df

# %%
reserves_df
# Out:
#                   row_id  year          level geography  \
# 0    RES-1f126a43-2023-1  2023  Site-specific    Canada
# 1    RES-1f126a44-2023-1  2023  Site-specific    Canada
# 2    RES-1f126a45-2023-1  2023  Site-specific    Canada
# 3    RES-e7e6a960-2023-1  2023  Site-specific    Canada
# 4    RES-e7e6a963-2023-1  2023  Site-specific    Canada
# ..                   ...   ...            ...       ...
# 338  RES-c5fefb01-2023-1  2023  Site-specific    Canada
# 339  RES-c5fefb01-2023-2  2023  Site-specific    Canada
# 340  RES-c5fefb01-2023-3  2023  Site-specific    Canada
# 341  RES-c5fefb01-2023-4  2023  Site-specific    Canada
# 342  RES-c5fefb01-2023-5  2023  Site-specific    Canada
#
#          reported_company_nrcan               name           main_id  \
# 0    Agnico Eagle Mines Limited  Canadian Malartic  ON-MAIN-1f126a43
# 1    Agnico Eagle Mines Limited  Canadian Malartic  ON-MAIN-1f126a44
# 2    Agnico Eagle Mines Limited  Canadian Malartic  ON-MAIN-1f126a45
# 3    Agnico Eagle Mines Limited        Detour Lake  QC-MAIN-e7e6a960
# 4    Agnico Eagle Mines Limited        Detour Lake  QC-MAIN-e7e6a963
# ..                          ...                ...               ...
# 338      Wesdome Gold Mines Ltd              Kiena  ON-MAIN-c5fefb01
# 339      Wesdome Gold Mines Ltd              Kiena  ON-MAIN-c5fefb01
# 340      Wesdome Gold Mines Ltd              Kiena  ON-MAIN-c5fefb01
# 341      Wesdome Gold Mines Ltd              Kiena  ON-MAIN-c5fefb01
# 342      Wesdome Gold Mines Ltd              Kiena  ON-MAIN-c5fefb01
#
#     facility_group_id company_id facility_type     mining_processing_type  \
# 0                   -        NaN        mining  Underground, concentrator
# 1                   -        NaN        mining  Underground, concentrator
# 2                   -        NaN        mining  Underground, concentrator
# 3                   -        NaN        mining     Open-pit, concentrator
# 4                   -        NaN        mining     Open-pit, concentrator
# ..                ...        ...           ...                        ...
# 338                 -        NaN        mining     Open-pit, concentrator
# 339                 -        NaN        mining     Open-pit, concentrator
# 340                 -        NaN        mining     Open-pit, concentrator
# 341                 -        NaN        mining     Open-pit, concentrator
# 342                 -        NaN        mining     Open-pit, concentrator
#
#     commodities_nrcan commodity reference_point       material_type  \
# 0        Gold, silver       Ore               2       Ore processed
# 1        Gold, silver      Gold               4  Intermediate metal
# 2        Gold, silver    Silver               4  Intermediate metal
# 3                Gold      Gold               2       Ore processed
# 4                Gold      Gold               4  Intermediate metal
# ..                ...       ...             ...                 ...
# 338              Gold      Gold               2          Head grade
# 339              Gold      Gold               2       Recovery rate
# 340              Gold      Gold               4  Intermediate metal
# 341              Gold      Gold               2          Ore milled
# 342              Gold      Gold               2       Ore processed
#
#                data_type unit         value  \
# 0             Production    t  1.959493e+07
# 1             Production   oz  6.846400e+05
# 2             Production  koz  3.100000e+02
# 3             Production    t  2.543485e+07
# 4             Production   oz  6.774460e+05
# ..                   ...  ...           ...
# 338  Technical attribute  g/t  5.900000e+00
# 339  Technical attribute    %  9.830000e+01
# 340           Production   Oz  3.553700e+04
# 341           Production    t  1.911480e+05
# 342           Production    t  1.100000e+00
#
#                                                comment  \
# 0                                                  NaN
# 1    "Production reflects Agnico Eagle's 50% intere...
# 2    "Production reflects Agnico Eagle's 50% intere...
# 3                                                  NaN
# 4                              Like intermediate metal
# ..                                                 ...
# 338                                                NaN
# 339                                                NaN
# 340                                                NaN
# 341                                                NaN
# 342                                                NaN
#
#                                    source
# 0    2023-Sustainability-Performance_data
# 1    2023-Sustainability-Performance_data
# 2    2023-Sustainability-Performance_data
# 3    2023-Sustainability-Performance_data
# 4    2023-Sustainability-Performance_data
# ..                                    ...
# 338                        2024-MDA-FINAL
# 339                        2024-MDA-FINAL
# 340                        2024-MDA-FINAL
# 341                        2024-MDA-FINAL
# 342                  2023-ESG-Data-Tables
#
# [343 rows x 20 columns]

# %%
production_df = add_source_id_to_collected_data(production_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

reserves_df = add_source_id_to_collected_data(reserves_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

energy_df = add_source_id_to_collected_data(energy_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

env_df = add_source_id_to_collected_data(env_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

env_int_df = add_source_id_to_collected_data(env_int_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

archetypes_df = add_source_id_to_collected_data(archetypes_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

# %%
def create_source_table_from_datasets(dataset_dict, manually_collected_dfs, source_col="source", company_col="company", facility_col="facility"):
    """
    Create a consolidated source table from multiple GeoDataFrames and manually collected data.

    Parameters:
    - dataset_dict: dict mapping GeoDataFrame name (str) to actual df with a single source_id value
    - manually_collected_dfs: list of dataframes that use the 'add_source_id' function
    - source_col, company_col, facility_col: column names in manually collected dfs

    Returns:
    - A pandas DataFrame with columns: source_id, source_provenance, source_name
    """

    import pandas as pd
    from pathlib import Path

    # Step 1: Add known datasets
    dataset_sources = []
    for name, df in dataset_dict.items():
        unique_ids = df['source_id'].dropna().unique()
        for sid in unique_ids:
            dataset_sources.append({
                "source_id": sid.strip(),
                "source_provenance": "dataset",
                "source_name": name
            })

    # Step 2: Add manually collected sources
    manual_sources = []
    for df in manually_collected_dfs:
        if "source_id" not in df.columns:
            continue  # skip if not processed yet
        for _, row in df.dropna(subset=["source_id"]).drop_duplicates(subset=["source_id"]).iterrows():
            source_id = row["source_id"]
            company = str(row.get(company_col, "")).strip()
            facility = str(row.get(facility_col, "")).strip()
            file_path = Path(str(row.get(source_col, "")))
            file_name = file_path.name
            source_name = f"{company} – {facility} ({file_name})".strip(" –()")
            manual_sources.append({
                "source_id": source_id,
                "source_provenance": "report",
                "source_name": source_name
            })

    # Combine, deduplicate
    full_source_table = pd.DataFrame(dataset_sources + manual_sources)
    full_source_table = full_source_table.drop_duplicates(subset=["source_id"]).sort_values("source_provenance")

    return full_source_table

# %%
dataset_dict = {
    "Global Tailings Portal": tailings_gdf,
    "A Comprehensive Historical and Geolocalized Database of Mining Activities in Canada": min_can_gdf,
    "ClimateTRACE mineral extraction sector": ctrace_gdf,
    "Environmental Justice Atlas": conflict_gdf,
    "GHG from large facilities": ghg_gdf,
    "National Pollutant Inventory Report (NPRI)": pollutant_gdf,
    "Areas of global importance for conserving terrestrial biodiversity, carbon and water": prioritization_area_gdf,
    "High-Resolution (1 km) Koppen-Geiger Maps for 1901–2099 Based on Constrained CMIP6 Projections": climate_category_gdf,
    "CMIP6 statistically downscaled climate indices (CanDCS-M6)": weather_gdf,
    "Global Peatland Database": peatland_gdf,
    "Global Human Settlement Layer (GHSL)": population_gdf,
    "Aqueduct 4.0": water_risk_gdf,
    "Modis Land Cover and ESA World Cover": land_cover_gdf,
    "Potential Natural Vegetation (NPV)": npv_gdf,
    "Indigenous Peoples’ and Local Community Lands and Territories": indigenous_can_gdf,
    "World Database on Protected Areas (WDPA)": wpda_gdf_polygons,
    "Global Mining Footprint Mapped from High-Resolution Satellite Imagery": tang_canada_gdf,
}

manual_dfs = [production_df, reserves_df, energy_df, env_df, env_int_df, archetypes_df] 

source_table = create_source_table_from_datasets(dataset_dict, manual_dfs)

# %%
source_table
# Out:
#                                       source_id source_provenance  \
# 0                     https://tailing.grida.no/           dataset
# 16   https://doi.org/10.1038/s43247-023-00805-6           dataset
# 15              https://www.protectedplanet.net           dataset
# 14                   http://www.landmarkmap.org           dataset
# 13           https://doi.org/10.7717/peerj.5457           dataset
# ..                                          ...               ...
# 70   SRC_SilverLakeResourcesLtd_MDI42C14SE00005            report
# 71   SRC_SilverLakeResourcesLtd_MDI42C14SE00006            report
# 72                      SRC_SSRMiningInc_FY2024            report
# 65           SRC_RioTinto_rt-fact-book-addendum            report
# 283                 SRC_WesdomeGoldMinesLtd_MDO            report
#
#                                            source_name
# 0                               Global Tailings Portal
# 16   Global Mining Footprint Mapped from High-Resol...
# 15            World Database on Protected Areas (WDPA)
# 14   Indigenous Peoples’ and Local Community Lands ...
# 13                  Potential Natural Vegetation (NPV)
# ..                                                 ...
# 70                                     MDI42C14SE00005
# 71                                     MDI42C14SE00006
# 72                                              FY2024
# 65                          rt-fact-book-addendum.xlsx
# 283                                                MDO
#
# [175 rows x 3 columns]

# %% [markdown]
# ## Substance table

# %%
from db_creation_function import create_substance_table

# %%
def create_substance_table(pollutant_gdf, env_df):
    """
    Combine and clean substance names from NPRI and manually collected datasets,
    apply harmonized naming, assign stable substance IDs, and return a master substance table.
    """

    # Step 1: Concatenate and tag provenance
    npri_sub = pollutant_gdf[['substance_name_npri']].copy()
    npri_sub['source'] = 'NPRI'
    npri_sub = npri_sub.rename(columns={'substance_name_npri': 'original_name'})

    manual_sub = env_df[['substance_name']].copy()
    manual_sub['source'] = 'Manual'
    manual_sub = manual_sub.rename(columns={'substance_name': 'original_name'})

    all_substances = pd.concat([npri_sub, manual_sub], ignore_index=True)

    # Step 2: Clean and exclude irrelevant entries
    all_substances['original_name'] = all_substances['original_name'].astype(str).str.strip()
    all_substances = all_substances[all_substances['original_name'] != '-']
    all_substances = all_substances[all_substances['original_name'] != 'nan']

    # Step 3: Harmonization dictionary
    harmonized_map = {
        "Ammonia (total)": "Ammonia",
        "Antimony (and its compounds)": "Antimony",
        "Arsenic (and its compounds)": "Arsenic",
        "Lead (and its compounds)": "Lead",
        "Mercury (and its compounds)": "Mercury",
        "PM10 - Particulate Matter <= 10 Micrometers": "PM10",
        "PM2.5 - Particulate Matter <= 2.5 Micrometers": "PM2.5",
        "Volatile Organic Compounds (Total)": "VOCs",
    }

    all_substances['harmonized_name'] = all_substances['original_name'].replace(harmonized_map)

    # Step 4: Drop duplicates
    substance_table = (
        all_substances
        .drop_duplicates(subset=['harmonized_name'])
        .sort_values('harmonized_name')
        .reset_index(drop=True)
    )

    # Step 5: Generate stable substance_id using SHA1 hash
    def make_id(row):
        raw = f"{row['harmonized_name']}"
        return "SUB" + hashlib.sha1(raw.encode('utf-8')).hexdigest()[:10]

    substance_table['substance_id'] = substance_table.apply(make_id, axis=1)

    # Step 6: Reorder columns
    substance_table = substance_table[[
        'substance_id', 'harmonized_name', 'original_name', 'source'
    ]]

    return substance_table

# %%
substance_table = create_substance_table(pollutant_gdf, env_df)

# %%
substance_table
# Out:
#       substance_id                 harmonized_name  \
# 0    SUB07971a0766          1,2,4-Trimethylbenzene
# 1    SUBbdfdffeb95                   1-Nitropyrene
# 2    SUB0f01e7c1d0                 2-Butoxyethanol
# 3    SUB324959500a  7,12-Dimethylbenz[a]anthracene
# 4    SUBfee6b26acd        7H-Dibenzo[c,g]carbazole
# ..             ...                             ...
# 169  SUB787e5ac1a2    Vanadium (and its compounds)
# 170  SUBe849a2ff09            Xylene (all isomers)
# 171  SUBae95939c3f        Zinc (and its compounds)
# 172  SUB090a1237c1                 i-Butyl alcohol
# 173  SUBd049575022                        n-Hexane
#
#                       original_name source
# 0            1,2,4-Trimethylbenzene   NPRI
# 1                     1-Nitropyrene   NPRI
# 2                   2-Butoxyethanol   NPRI
# 3    7,12-Dimethylbenz[a]anthracene   NPRI
# 4          7H-Dibenzo[c,g]carbazole   NPRI
# ..                              ...    ...
# 169    Vanadium (and its compounds)   NPRI
# 170            Xylene (all isomers)   NPRI
# 171        Zinc (and its compounds)   NPRI
# 172                 i-Butyl alcohol   NPRI
# 173                        n-Hexane   NPRI
#
# [174 rows x 4 columns]

# %%
pollutant_gdf_a = pollutant_gdf.merge(
    substance_table[['substance_id', 'original_name']],
    how='left',
    left_on='substance_name_npri',
    right_on='original_name'
).drop(columns='original_name')

# %%
env_df
# Out:
#      year reporting_level      reported_company_nrcan               name  \
# 0    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 1    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 2    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 3    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 4    2023   Site-specific  Agnico Eagle Mines Limited             Goldex
# ..    ...             ...                         ...                ...
# 745  2023   Site-specific      Wesdome Gold Mines Ltd        Eagle River
# 746  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 747  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 748  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 749  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
#
#               main_id facility_group_id company_id facility_type  \
# 0    ON-MAIN-1f126a43                 -        NaN        mining
# 1    ON-MAIN-1f126a43                 -        NaN        mining
# 2    QC-MAIN-e7e6a960                 -        NaN        mining
# 3    QC-MAIN-e7e6a960                 -        NaN        mining
# 4    NU-MAIN-8b0264c9                 -        NaN        mining
# ..                ...               ...        ...           ...
# 745  QC-MAIN-9de9bb0d                 -        NaN        mining
# 746  ON-MAIN-c5fefb01                 -        NaN        mining
# 747  ON-MAIN-c5fefb01                 -        NaN        mining
# 748  ON-MAIN-c5fefb01                 -        NaN        mining
# 749  ON-MAIN-c5fefb01                 -        NaN        mining
#
#         mining_processing_type     commodity compartment      flow_type  \
# 0    Underground, concentrator  Gold, silver         Air  air_pollution
# 1    Underground, concentrator  Gold, silver         Air  air_pollution
# 2       Open-pit, concentrator          Gold         Air  air_pollution
# 3       Open-pit, concentrator          Gold         Air  air_pollution
# 4    Underground, concentrator  Gold, silver         Air  air_pollution
# ..                         ...           ...         ...            ...
# 745  Underground, concentrator          Gold       Water          water
# 746     Open-pit, concentrator          Gold       Water          water
# 747     Open-pit, concentrator          Gold       Water          water
# 748     Open-pit, concentrator          Gold       Water          water
# 749     Open-pit, concentrator          Gold       Water          water
#
#                               subflow_type substance_name unit   value  \
# 0                                        -            SOx    t     315
# 1                                        -            NOx    t    4802
# 2                                        -            SOx    t     486
# 3                                        -            NOx    t    7414
# 4                                        -            SOx    t      38
# ..                                     ...            ...  ...     ...
# 745                 Total water discharged              -   m3  324347
# 746                       Water withdrawal              -   m3  168115
# 747  Water withdrawal|Freshwater withdrawn              -   m3  168115
# 748                Total water consumption              -   m3   82144
# 749                 Total water discharged              -   m3  536420
#
#                                                comment  \
# 0    "In absence of site-level monitoring emission ...
# 1    "In absence of site-level monitoring emission ...
# 2    "In absence of site-level monitoring emission ...
# 3    "In absence of site-level monitoring emission ...
# 4    "In absence of site-level monitoring emission ...
# ..                                                 ...
# 745                                                NaN
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
#
#                                         source
# 0    2023-Sustainability-Performance_data.xlsx
# 1    2023-Sustainability-Performance_data.xlsx
# 2    2023-Sustainability-Performance_data.xlsx
# 3    2023-Sustainability-Performance_data.xlsx
# 4    2023-Sustainability-Performance_data.xlsx
# ..                                         ...
# 745                  2023-ESG-Data-Tables.xlsx
# 746                  2023-ESG-Data-Tables.xlsx
# 747                  2023-ESG-Data-Tables.xlsx
# 748                  2023-ESG-Data-Tables.xlsx
# 749                  2023-ESG-Data-Tables.xlsx
#
# [750 rows x 18 columns]

# %%
substance_table
# Out:
#       substance_id                 harmonized_name  \
# 0    SUB07971a0766          1,2,4-Trimethylbenzene
# 1    SUBbdfdffeb95                   1-Nitropyrene
# 2    SUB0f01e7c1d0                 2-Butoxyethanol
# 3    SUB324959500a  7,12-Dimethylbenz[a]anthracene
# 4    SUBfee6b26acd        7H-Dibenzo[c,g]carbazole
# ..             ...                             ...
# 169  SUB787e5ac1a2    Vanadium (and its compounds)
# 170  SUBe849a2ff09            Xylene (all isomers)
# 171  SUBae95939c3f        Zinc (and its compounds)
# 172  SUB090a1237c1                 i-Butyl alcohol
# 173  SUBd049575022                        n-Hexane
#
#                       original_name source
# 0            1,2,4-Trimethylbenzene   NPRI
# 1                     1-Nitropyrene   NPRI
# 2                   2-Butoxyethanol   NPRI
# 3    7,12-Dimethylbenz[a]anthracene   NPRI
# 4          7H-Dibenzo[c,g]carbazole   NPRI
# ..                              ...    ...
# 169    Vanadium (and its compounds)   NPRI
# 170            Xylene (all isomers)   NPRI
# 171        Zinc (and its compounds)   NPRI
# 172                 i-Butyl alcohol   NPRI
# 173                        n-Hexane   NPRI
#
# [174 rows x 4 columns]

# %%
env_df.merge(
    substance_table[['substance_id', 'original_name']],
    how='left',
    left_on='substance_name',
    right_on='original_name'
).drop(columns='original_name')
# Out:
#      year reporting_level      reported_company_nrcan               name  \
# 0    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 1    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 2    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 3    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 4    2023   Site-specific  Agnico Eagle Mines Limited             Goldex
# ..    ...             ...                         ...                ...
# 745  2023   Site-specific      Wesdome Gold Mines Ltd        Eagle River
# 746  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 747  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 748  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 749  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
#
#               main_id facility_group_id company_id facility_type  \
# 0    ON-MAIN-1f126a43                 -        NaN        mining
# 1    ON-MAIN-1f126a43                 -        NaN        mining
# 2    QC-MAIN-e7e6a960                 -        NaN        mining
# 3    QC-MAIN-e7e6a960                 -        NaN        mining
# 4    NU-MAIN-8b0264c9                 -        NaN        mining
# ..                ...               ...        ...           ...
# 745  QC-MAIN-9de9bb0d                 -        NaN        mining
# 746  ON-MAIN-c5fefb01                 -        NaN        mining
# 747  ON-MAIN-c5fefb01                 -        NaN        mining
# 748  ON-MAIN-c5fefb01                 -        NaN        mining
# 749  ON-MAIN-c5fefb01                 -        NaN        mining
#
#         mining_processing_type     commodity compartment      flow_type  \
# 0    Underground, concentrator  Gold, silver         Air  air_pollution
# 1    Underground, concentrator  Gold, silver         Air  air_pollution
# 2       Open-pit, concentrator          Gold         Air  air_pollution
# 3       Open-pit, concentrator          Gold         Air  air_pollution
# 4    Underground, concentrator  Gold, silver         Air  air_pollution
# ..                         ...           ...         ...            ...
# 745  Underground, concentrator          Gold       Water          water
# 746     Open-pit, concentrator          Gold       Water          water
# 747     Open-pit, concentrator          Gold       Water          water
# 748     Open-pit, concentrator          Gold       Water          water
# 749     Open-pit, concentrator          Gold       Water          water
#
#                               subflow_type substance_name unit   value  \
# 0                                        -            SOx    t     315
# 1                                        -            NOx    t    4802
# 2                                        -            SOx    t     486
# 3                                        -            NOx    t    7414
# 4                                        -            SOx    t      38
# ..                                     ...            ...  ...     ...
# 745                 Total water discharged              -   m3  324347
# 746                       Water withdrawal              -   m3  168115
# 747  Water withdrawal|Freshwater withdrawn              -   m3  168115
# 748                Total water consumption              -   m3   82144
# 749                 Total water discharged              -   m3  536420
#
#                                                comment  \
# 0    "In absence of site-level monitoring emission ...
# 1    "In absence of site-level monitoring emission ...
# 2    "In absence of site-level monitoring emission ...
# 3    "In absence of site-level monitoring emission ...
# 4    "In absence of site-level monitoring emission ...
# ..                                                 ...
# 745                                                NaN
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
#
#                                         source   substance_id
# 0    2023-Sustainability-Performance_data.xlsx  SUB2c1715b8f1
# 1    2023-Sustainability-Performance_data.xlsx  SUB515573c582
# 2    2023-Sustainability-Performance_data.xlsx  SUB2c1715b8f1
# 3    2023-Sustainability-Performance_data.xlsx  SUB515573c582
# 4    2023-Sustainability-Performance_data.xlsx  SUB2c1715b8f1
# ..                                         ...            ...
# 745                  2023-ESG-Data-Tables.xlsx            NaN
# 746                  2023-ESG-Data-Tables.xlsx            NaN
# 747                  2023-ESG-Data-Tables.xlsx            NaN
# 748                  2023-ESG-Data-Tables.xlsx            NaN
# 749                  2023-ESG-Data-Tables.xlsx            NaN
#
# [750 rows x 19 columns]

# %%
substance_table.to_csv(r'data/Tables/Auxiliary_tables/substance_table.csv', index=False)

# %% [markdown]
# ## Compartment table

# %%
pollutant_gdf[pollutant_gdf['emission_type'] == 'Water Releases / Rejets à l\'eau']['emission_subtype'].unique()
# Out:
# array(['Direct Discharge', 'Total', 'Receiving Waterbody (English)',
#        'Receiving Waterbody (French)', 'Spills'], dtype=object)

# %%
# Change the value to 'None' for emission_subtype when emission_type = 'Water Releases / Rejets à l'eau' and 'emission_subtype' is 'Receiving Waterbody (English)' or 'Receiving Waterbody (French)'
pollutant_gdf.loc[
    (pollutant_gdf['emission_type'] == 'Water Releases / Rejets à l\'eau') & 
    (pollutant_gdf['emission_subtype'].isin(['Receiving Waterbody (English)', 'Receiving Waterbody (French)'])),
    'emission_subtype'
] = None

# %%
from db_creation_function import create_compartment_table

# %%
import pandas as pd
import hashlib

def create_compartment_table(pollutant_gdf, env_df):
    """
    Build a harmonized compartment table with traceable raw labels for merging.
    """

    # --- Define mapping from emission_type to (compartment, pathway)
    compartment_mapping_clean = {
        "Air Emissions / Émissions à l'air": ("Air", "Unspecified"),
        "Water Releases / Rejets à l'eau": ("Water", "Unspecified"),
        "Land Releases /  Rejets au sol": ("Land", "Unspecified"),
        "On-Site Disposal / Élimination sur le site": ("Land", "On-site disposal"),
        "Off-Site Disposal / Élimination hors site": ("Land", "Off-site disposal"),
        "Total Releases / Rejets totaux": (None, "Aggregate"),
        "Transfers for Treatment / Transferts pour traitement": (None, "Transfer for treatment"),
        "Transfers for Recycling / Transferts pour recyclage": (None, "Transfer for recycling"),
        "Total On-Site, Off-Site and Treatment Disposal /\n Élimination sur le site, hors site et pour traitement totale": (None, "Aggregate"),
        "Grand Total": (None, "Grand total")
    }

    # --- NPRI data
    npri_comp = pollutant_gdf[['emission_type', 'emission_subtype']].dropna(subset=['emission_type']).copy()
    npri_comp['source'] = 'NPRI'
    npri_comp[['compartment', 'default_pathway']] = npri_comp['emission_type'].map(compartment_mapping_clean).apply(pd.Series)
    npri_comp['compartment_pathway'] = npri_comp['emission_subtype'].fillna('').str.strip()
    npri_comp.loc[npri_comp['compartment_pathway'] == '', 'compartment_pathway'] = npri_comp['default_pathway']
    npri_comp['raw_compartment_label'] = npri_comp['emission_type']
    npri_comp['raw_pathway_label'] = npri_comp['emission_subtype'].fillna('Unspecified')
    npri_comp = npri_comp.drop(columns=['default_pathway'])

    # --- Manual data
    env_comp = env_df[['compartment']].dropna().copy()
    env_comp = env_comp[env_comp['compartment'] != '-']
    env_comp['compartment_pathway'] = 'Unspecified'
    env_comp['raw_compartment_label'] = env_comp['compartment']
    env_comp['raw_pathway_label'] = 'Unspecified'
    env_comp['source'] = 'Manually collected data'

    # --- Align columns
    env_comp['compartment'] = env_comp['compartment']
    manual_cols = ['compartment', 'compartment_pathway', 'raw_compartment_label', 'raw_pathway_label', 'source']
    npri_cols = manual_cols

    # --- Combine all
    all_comps = pd.concat([
        npri_comp[npri_cols],
        env_comp[manual_cols]
    ], ignore_index=True).drop_duplicates().reset_index(drop=True)

    # --- Create hashed ID
    def make_id(row):
        raw = f"{row['compartment']}_{row['compartment_pathway']}"
        return "CMP" + hashlib.sha1(raw.encode('utf-8')).hexdigest()[:10]

    all_comps['compartment_id'] = all_comps.apply(make_id, axis=1)

    # --- Final structure
    return all_comps[[
        'compartment_id', 'compartment', 'compartment_pathway',
        'raw_compartment_label', 'raw_pathway_label', 'source'
    ]].sort_values(['compartment', 'compartment_pathway'])

# %%
compartment_table = create_compartment_table(pollutant_gdf, env_df)

# %%
pollutant_gdf_a = pollutant_gdf.merge(
    compartment_table[[
        'compartment_id', 'raw_compartment_label', 'raw_pathway_label'
    ]],
    how='left',
    left_on=['emission_type', 'emission_subtype'],
    right_on=['raw_compartment_label', 'raw_pathway_label']
).drop(columns=['raw_compartment_label', 'raw_pathway_label'])

# %%
pollutant_gdf_a
# Out:
#                   row_id  year  npri_id     facility_name_npri  \
# 0       npri-1568-2023-1  2023     1568           Macassa Mine
# 1       npri-1568-2023-2  2023     1568           Macassa Mine
# 2       npri-1568-2023-3  2023     1568           Macassa Mine
# 3       npri-1568-2023-4  2023     1568           Macassa Mine
# 4       npri-1568-2023-5  2023     1568           Macassa Mine
# ...                  ...   ...      ...                    ...
# 24125   npri-5697-2023-6  2023     5697  Rayette Manufacturing
# 24126   npri-5698-2023-6  2023     5698    Bowes Manufacturing
# 24127  npri-34697-2023-2  2023    34697    541 Bowes Warehouse
# 24128   npri-5697-2023-7  2023     5697  Rayette Manufacturing
# 24129   npri-5698-2023-7  2023     5698    Bowes Manufacturing
#
#         company_name_npri  facility_type  longitude  latitude  \
# 0      Agnico Eagle Mines         mining  -80.08734  48.13032
# 1      Agnico Eagle Mines         mining  -80.08734  48.13032
# 2      Agnico Eagle Mines         mining  -80.08734  48.13032
# 3      Agnico Eagle Mines         mining  -80.08734  48.13032
# 4      Agnico Eagle Mines         mining  -80.08734  48.13032
# ...                   ...            ...        ...       ...
# 24125                None  manufacturing  -79.49600  43.80800
# 24126                None  manufacturing  -79.49480  43.80360
# 24127                None  manufacturing  -79.49707  43.81726
# 24128                None  manufacturing  -79.49600  43.80800
# 24129                None  manufacturing  -79.49480  43.80360
#
#       terrestrial_ecozone                   watershed  \
# 0           Boreal Shield  St. Lawrence Drainage Area
# 1           Boreal Shield  St. Lawrence Drainage Area
# 2           Boreal Shield  St. Lawrence Drainage Area
# 3           Boreal Shield  St. Lawrence Drainage Area
# 4           Boreal Shield  St. Lawrence Drainage Area
# ...                   ...                         ...
# 24125     Mixedwood Plain  St. Lawrence Drainage Area
# 24126     Mixedwood Plain  St. Lawrence Drainage Area
# 24127     Mixedwood Plain  St. Lawrence Drainage Area
# 24128     Mixedwood Plain  St. Lawrence Drainage Area
# 24129     Mixedwood Plain  St. Lawrence Drainage Area
#
#                               substance_name_npri substance_name_ecoinvent  \
# 0                                 Ammonia (total)                  Ammonia
# 1                     Arsenic (and its compounds)                  Arsenic
# 2                                 Carbon monoxide  Carbon monoxide, fossil
# 3                    Chromium (and its compounds)                 Chromium
# 4                      Cobalt (and its compounds)                   Cobalt
# ...                                           ...                      ...
# 24125  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24126  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24127  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24128          Volatile Organic Compounds (Total)                     None
# 24129          Volatile Organic Compounds (Total)                     None
#
#       substance_unit                      emission_type  \
# 0             tonnes  Air Emissions / Émissions à l'air
# 1                 kg  Air Emissions / Émissions à l'air
# 2             tonnes  Air Emissions / Émissions à l'air
# 3             tonnes  Air Emissions / Émissions à l'air
# 4                 kg  Air Emissions / Émissions à l'air
# ...              ...                                ...
# 24125         tonnes                        Grand Total
# 24126         tonnes                        Grand Total
# 24127         tonnes                        Grand Total
# 24128         tonnes                        Grand Total
# 24129         tonnes                        Grand Total
#
#                                         emission_subtype      value  \
# 0                                        Stack Emissions      0.636
# 1                                        Stack Emissions      0.116
# 2                                        Stack Emissions     76.208
# 3                                        Stack Emissions    0.00105
# 4                                        Stack Emissions       0.18
# ...                                                  ...        ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008
# 24126  Total Releases, Disposals and Transfers for Re...     23.418
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719
#
#                                                source_id   substance_id  \
# 0      https://www.canada.ca/en/environment-climate-c...  SUBa2c74fdce8
# 1      https://www.canada.ca/en/environment-climate-c...  SUB526607d180
# 2      https://www.canada.ca/en/environment-climate-c...  SUB92570cece4
# 3      https://www.canada.ca/en/environment-climate-c...  SUB075f575023
# 4      https://www.canada.ca/en/environment-climate-c...  SUB481f3889a8
# ...                                                  ...            ...
# 24125  https://www.canada.ca/en/environment-climate-c...  SUB4a14c4c889
# 24126  https://www.canada.ca/en/environment-climate-c...  SUB4a14c4c889
# 24127  https://www.canada.ca/en/environment-climate-c...  SUB4a14c4c889
# 24128  https://www.canada.ca/en/environment-climate-c...  SUB0d60783c59
# 24129  https://www.canada.ca/en/environment-climate-c...  SUB0d60783c59
#
#                          geometry compartment_id
# 0      POINT (-80.08734 48.13032)  CMP1718f4466d
# 1      POINT (-80.08734 48.13032)  CMP1718f4466d
# 2      POINT (-80.08734 48.13032)  CMP1718f4466d
# 3      POINT (-80.08734 48.13032)  CMP1718f4466d
# 4      POINT (-80.08734 48.13032)  CMP1718f4466d
# ...                           ...            ...
# 24125  POINT (-79.49600 43.80800)  CMP281acc6045
# 24126  POINT (-79.49480 43.80360)  CMP281acc6045
# 24127  POINT (-79.49707 43.81726)  CMP281acc6045
# 24128  POINT (-79.49600 43.80800)  CMP281acc6045
# 24129  POINT (-79.49480 43.80360)  CMP281acc6045
#
# [24130 rows x 20 columns]

# %%
env_df['compartment_pathway'] = 'Unspecified'
env_df = env_df.merge(
    compartment_table[[
        'compartment_id', 'raw_compartment_label', 'raw_pathway_label'
    ]],
    how='left',
    left_on=['compartment', 'compartment_pathway'],
    right_on=['raw_compartment_label', 'raw_pathway_label']
).drop(columns=['raw_compartment_label', 'raw_pathway_label'])

# %%
env_df
# Out:
#      year reporting_level      reported_company_nrcan               name  \
# 0    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 1    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 2    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 3    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 4    2023   Site-specific  Agnico Eagle Mines Limited             Goldex
# ..    ...             ...                         ...                ...
# 745  2023   Site-specific      Wesdome Gold Mines Ltd        Eagle River
# 746  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 747  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 748  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 749  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
#
#               main_id facility_group_id company_id facility_type  \
# 0    ON-MAIN-1f126a43                 -        NaN        mining
# 1    ON-MAIN-1f126a43                 -        NaN        mining
# 2    QC-MAIN-e7e6a960                 -        NaN        mining
# 3    QC-MAIN-e7e6a960                 -        NaN        mining
# 4    NU-MAIN-8b0264c9                 -        NaN        mining
# ..                ...               ...        ...           ...
# 745  QC-MAIN-9de9bb0d                 -        NaN        mining
# 746  ON-MAIN-c5fefb01                 -        NaN        mining
# 747  ON-MAIN-c5fefb01                 -        NaN        mining
# 748  ON-MAIN-c5fefb01                 -        NaN        mining
# 749  ON-MAIN-c5fefb01                 -        NaN        mining
#
#         mining_processing_type     commodity compartment      flow_type  \
# 0    Underground, concentrator  Gold, silver         Air  air_pollution
# 1    Underground, concentrator  Gold, silver         Air  air_pollution
# 2       Open-pit, concentrator          Gold         Air  air_pollution
# 3       Open-pit, concentrator          Gold         Air  air_pollution
# 4    Underground, concentrator  Gold, silver         Air  air_pollution
# ..                         ...           ...         ...            ...
# 745  Underground, concentrator          Gold       Water          water
# 746     Open-pit, concentrator          Gold       Water          water
# 747     Open-pit, concentrator          Gold       Water          water
# 748     Open-pit, concentrator          Gold       Water          water
# 749     Open-pit, concentrator          Gold       Water          water
#
#                               subflow_type substance_name unit   value  \
# 0                                        -            SOx    t     315
# 1                                        -            NOx    t    4802
# 2                                        -            SOx    t     486
# 3                                        -            NOx    t    7414
# 4                                        -            SOx    t      38
# ..                                     ...            ...  ...     ...
# 745                 Total water discharged              -   m3  324347
# 746                       Water withdrawal              -   m3  168115
# 747  Water withdrawal|Freshwater withdrawn              -   m3  168115
# 748                Total water consumption              -   m3   82144
# 749                 Total water discharged              -   m3  536420
#
#                                                comment  \
# 0    "In absence of site-level monitoring emission ...
# 1    "In absence of site-level monitoring emission ...
# 2    "In absence of site-level monitoring emission ...
# 3    "In absence of site-level monitoring emission ...
# 4    "In absence of site-level monitoring emission ...
# ..                                                 ...
# 745                                                NaN
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
#
#                                         source compartment_pathway  \
# 0    2023-Sustainability-Performance_data.xlsx         Unspecified
# 1    2023-Sustainability-Performance_data.xlsx         Unspecified
# 2    2023-Sustainability-Performance_data.xlsx         Unspecified
# 3    2023-Sustainability-Performance_data.xlsx         Unspecified
# 4    2023-Sustainability-Performance_data.xlsx         Unspecified
# ..                                         ...                 ...
# 745                  2023-ESG-Data-Tables.xlsx         Unspecified
# 746                  2023-ESG-Data-Tables.xlsx         Unspecified
# 747                  2023-ESG-Data-Tables.xlsx         Unspecified
# 748                  2023-ESG-Data-Tables.xlsx         Unspecified
# 749                  2023-ESG-Data-Tables.xlsx         Unspecified
#
#     compartment_id
# 0    CMPf3265e9fca
# 1    CMPf3265e9fca
# 2    CMPf3265e9fca
# 3    CMPf3265e9fca
# 4    CMPf3265e9fca
# ..             ...
# 745  CMP68bd334352
# 746  CMP68bd334352
# 747  CMP68bd334352
# 748  CMP68bd334352
# 749  CMP68bd334352
#
# [750 rows x 20 columns]

# %% [markdown]
# # Matching

# %% [markdown]
# ## Point to point matching

# %%
from matching_functions import match_facilities, one_to_many_relationships

# %% [markdown]
# ### MinCan

# %% [markdown]
# Some mines in MinCan dataset have very slightly different name (e.g. LaRonde - Zone 5 and LaRonde), or several companies for the same mines.

# %%
lt_main_mincan = match_facilities(main_gdf, min_can_gdf,
                     id_col1='main_id', id_col2='mincan_id',
                     name_col1='facility_name', name_col2='namemine'
                     )

# %%
matches_main_mincan = one_to_many_relationships(
    lt_main_mincan,
    id_main_col='main_id',
    id_sat_col='mincan_id',
    distance_threshold_m=2000,
    similarity_threshold=80,
    similarity_metric="token_set"  
)

# %%
min_can_gdf = min_can_gdf.merge(
    matches_main_mincan,
    on="mincan_id", 
    how="left"
)

# %%
# For SQL
min_can_gdf = min_can_gdf[min_can_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["mincan_id", "main_id", "mine_status", "operation_periods"]
min_can_gdf = min_can_gdf[col_to_keep]
min_can_gdf
# Out:
#               mincan_id           main_id mine_status  \
# 4    QC-MINCAN-d1e8b6b1  QC-MAIN-30c1828c    Inactive
# 53   NL-MINCAN-01316355  NL-MAIN-842ba1b4    Inactive
# 55   QC-MINCAN-494c7715  QC-MAIN-9de9bb0d      Active
# 117  BC-MINCAN-8cc41b53  BC-MAIN-6b4800fe      Active
# 136  QC-MINCAN-8321e85e  QC-MAIN-e51eda66      Active
# ..                  ...               ...         ...
# 871  NL-MINCAN-a34e9244  NL-MAIN-c139de6d    Inactive
# 872  BC-MINCAN-3e33555f  BC-MAIN-b1fe389a    Inactive
# 897  SK-MINCAN-b20ab2db  SK-MAIN-bb89158f    Inactive
# 906  ON-MINCAN-7b29d7b3  ON-MAIN-bfbcd72e      Active
# 914  NB-MINCAN-35aef61d  NB-MAIN-8e04eb21    Inactive
#
#                    operation_periods
# 4                          1927–1976
# 53                         1997–2010
# 55   1936–1996; 2005–2013; 2021–open
# 117             1972–1998; 2004–open
# 136                        1988–open
# ..                               ...
# 871                        1971–2019
# 872                        1971–2008
# 897                        1983–2018
# 906             1987–1994; 2012–open
# 914                        1989–1993
#
# [69 rows x 4 columns]

# %% [markdown]
# ### CTrace

# %%
lt_main_ctrace = match_facilities(main_gdf, ctrace_gdf,
                     id_col1='main_id', id_col2='ctrace_id',
                     name_col1='facility_name', name_col2='source_name'
                     )

# %%
matches_main_ctrace = one_to_many_relationships(
    lt_main_ctrace,
    id_main_col='main_id',
    id_sat_col='ctrace_id',
    distance_threshold_m=2000,
    similarity_threshold=80,
    similarity_metric="token_set"  
)

# %%
ctrace_gdf = ctrace_gdf.merge(
    matches_main_ctrace,
    on="ctrace_id", 
    how="left"
)

# %%
# For SQL
ctrace_gdf = ctrace_gdf[ctrace_gdf["main_id"].notna()].copy()

# %%
# We separate emissions and production data
ctrace_ghg_gdf = ctrace_gdf.drop(columns=['activity', 'activity_units', 'capacity', 'capacity_units'])
ctrace_prod_gdf = ctrace_gdf.drop(columns=['emissions_quantity', 'gas'])

# %% [markdown]
# ### Conflict

# %%
lt_main_conflict = match_facilities(main_gdf, conflict_gdf,
                     id_col1='main_id', id_col2='conflict_id',
                     name_col1='facility_name', name_col2='facility_name_ejatlas'
                     )

# %%
matches_main_conflict = one_to_many_relationships(
    lt_main_conflict,
    id_main_col='main_id',
    id_sat_col='conflict_id',
    distance_threshold_m=20000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
conflict_gdf = conflict_gdf.merge(
    matches_main_conflict,
    on="conflict_id",  
    how="left"
)

# %%
# For SQL
conflict_gdf = conflict_gdf[conflict_gdf["main_id"].notna()].copy()

# %%
conflict_gdf
# Out:
#              conflict_id  ej_atlas_id  \
# 9   NL-CONFLICT-fd990d3e         4135
# 10  ON-CONFLICT-928fd562         4145
# 15  QC-CONFLICT-93cab570         5599
#
#                                             case_name  \
# 9       Vale Mining in Voisey's Bay, Labrador, Canada
# 10  Port Colborne Class Action Lawsuit Against Val...
# 15  Nouveau Mondeâ€™s Matawinie graphite mine in Q...
#
#                                 facility_name_ejatlas               province  \
# 9                                        Voisey's Bay  Newfoundland Labrador
# 10                                      Port Colborne                Ontario
# 15  Municipality of Saint-Michel-des-Saints  in Ma...                 Quebec
#
#     longitude   latitude     geolocation_accuracy  \
# 9  -62.103056  56.334722  MEDIUM (Regional level)
# 10 -79.250000  42.883333  MEDIUM (Regional level)
# 15 -73.958848  46.633467  MEDIUM (Regional level)
#
#                                  conflict_description  \
# 9   <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10  <p>In Pearson (later Smith) v. Inco, the large...
# 15  <p>Five kilometers southwest of the municipali...
#
#                                      conflict_details population_affected  \
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...               Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...               Urban
# 15  The project includes 319 mining concessions (c...               Rural
#
#                                 conflict_intensity  start_date end_date  \
# 9   MEDIUM (street protests, visible mobilization)     11/1994     None
# 10                     LOW (some local organising)     06/2000  04/2012
# 15  MEDIUM (street protests, visible mobilization)  01/01/2017     None
#
#         project_status                                          reference  \
# 9         In operation  (Mining Data Online, n.d.)\nhttps://miningdata...
# 10        In operation                                               None
# 15  Under construction                                               None
#
#                       geometry           main_id
# 9   POINT (-62.10306 56.33472)  NL-MAIN-2d8801d6
# 10  POINT (-79.25000 42.88333)  ON-MAIN-2e13aaa0
# 15  POINT (-73.95885 46.63347)  QC-MAIN-d6748d40

# %%
col_to_keep = ["ej_atlas_id",
  "main_id",
  "case_name",
  "start_date",
  "end_date",
  "conflict_description",
  "conflict_details",
  "population_affected",
  "conflict_intensity",
  "project_status"
               ]
conflict_gdf = conflict_gdf[col_to_keep]
conflict_gdf
# Out:
#     ej_atlas_id           main_id  \
# 9          4135  NL-MAIN-2d8801d6
# 10         4145  ON-MAIN-2e13aaa0
# 15         5599  QC-MAIN-d6748d40
#
#                                             case_name  start_date end_date  \
# 9       Vale Mining in Voisey's Bay, Labrador, Canada     11/1994     None
# 10  Port Colborne Class Action Lawsuit Against Val...     06/2000  04/2012
# 15  Nouveau Mondeâ€™s Matawinie graphite mine in Q...  01/01/2017     None
#
#                                  conflict_description  \
# 9   <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10  <p>In Pearson (later Smith) v. Inco, the large...
# 15  <p>Five kilometers southwest of the municipali...
#
#                                      conflict_details population_affected  \
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...               Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...               Urban
# 15  The project includes 319 mining concessions (c...               Rural
#
#                                 conflict_intensity      project_status
# 9   MEDIUM (street protests, visible mobilization)        In operation
# 10                     LOW (some local organising)        In operation
# 15  MEDIUM (street protests, visible mobilization)  Under construction

# %% [markdown]
# ### Tailings

# %%
lt_main_tailings = match_facilities(main_gdf, tailings_gdf,
                     id_col1='main_id', id_col2='tailing_id',
                     name_col1='facility_name', name_col2='related_mine'
                     )

# %%
matches_main_tailings = one_to_many_relationships(
    lt_main_tailings,
    id_main_col='main_id',
    id_sat_col='tailing_id',
    distance_threshold_m=20000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
tailings_gdf = tailings_gdf.merge(
    matches_main_tailings,
    on="tailing_id",  
    how="left"
)

# %%
# For SQL
tailings_gdf = tailings_gdf[tailings_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["row_id",
  "main_id",
  "year",
  "tailing_id",
  "tsf_name",
  "status",
  "construction_year",
  "raise_type",
  "current_maximum_height",
  "current_tailings_storage",
  "planned_storage_5_years",
  "hazard_categorization",
  "classification_system",
  "geometry"
               ]
tailings_gdf = tailings_gdf[col_to_keep]
tailings_gdf
# Out:
#                  row_id           main_id  year  tailing_id  \
# 0      TAIL-12.0-2019-1  NU-MAIN-730aefe3  2019        12.0
# 1      TAIL-13.0-2019-1  NU-MAIN-730aefe3  2019        13.0
# 2      TAIL-14.0-2019-1  NU-MAIN-730aefe3  2019        14.0
# 3      TAIL-15.0-2019-1  NU-MAIN-8b0264c9  2019        15.0
# 4      TAIL-16.0-2019-1  QC-MAIN-c0660aec  2019        16.0
# ..                  ...               ...   ...         ...
# 215  TAIL-1126.0-2019-1  ON-MAIN-f080c409  2019      1126.0
# 216  TAIL-1127.0-2019-1  ON-MAIN-f080c409  2019      1127.0
# 217  TAIL-1128.0-2019-1  ON-MAIN-f080c409  2019      1128.0
# 218  TAIL-1129.0-2019-1  ON-MAIN-f080c409  2019      1129.0
# 226  TAIL-1243.0-2019-1  QC-MAIN-e7e6a960  2019      1243.0
#
#                   tsf_name  status  construction_year              raise_type  \
# 0               North Cell  Active             2009.0    Downstream, Upstream
# 1               South Cell  Active             2012.0              Downstream
# 2                   In pit  Active             2009.0                    None
# 3            Meliadine TSF  Active             2019.0                    None
# 4                South TSF  Active             2007.0              Not Raised
# ..                     ...     ...                ...                     ...
# 215            R1 Tailings  Active             1985.0  Compacted\nOuter Shell
# 216            R2 Tailings  Active             1985.0  Compacted\nOuter Shell
# 217            R3 Tailings  Active             1985.0  Compacted\nOuter Shell
# 218            R4 Tailings  Active             1990.0  Compacted\nOuter Shell
# 226  Canadian Malartic TSF  Active             2012.0                Upstream
#
#      current_maximum_height current_tailings_storage planned_storage_5_years  \
# 0                      31.0                 14400000                14400000
# 1                      49.0                 10420000                10800000
# 2                       NaN                   850000                12500000
# 3                       5.0                    89000                 4354000
# 4                       5.0                  1664000                 2500000
# ..                      ...                      ...                     ...
# 215                    14.0                  2900000                 4000000
# 216                    13.0                 18000000                18000000
# 217                    27.0                 39000000                42000000
# 218                    22.0                 59000000                63000000
# 226                    40.0                 96000000               136500000
#
#     hazard_categorization     classification_system  \
# 0                  Medium  Canadian Dam Association
# 1                  Medium  Canadian Dam Association
# 2                     Low                      None
# 3                  Medium  Canadian Dam Association
# 4                  Medium  Canadian Dam Association
# ..                    ...                       ...
# 215               Extreme  Canadian Dam Association
# 216               Extreme  Canadian Dam Association
# 217               Extreme  Canadian Dam Association
# 218               Extreme  Canadian Dam Association
# 226        Medium to High                CDA/Yamana
#
#                        geometry
# 0    POINT (-96.04333 65.02156)
# 1    POINT (-96.03339 65.01378)
# 2    POINT (-96.03254 65.00190)
# 3    POINT (-92.14034 63.02083)
# 4    POINT (-77.84198 48.05434)
# ..                          ...
# 215  POINT (-81.14058 46.47142)
# 216  POINT (-81.14058 46.47142)
# 217  POINT (-81.14058 46.47142)
# 218  POINT (-81.14058 46.47142)
# 226  POINT (-78.10361 48.11139)
#
# [86 rows x 14 columns]

# %% [markdown]
# ### GHG

# %%
lt_main_ghg = match_facilities(main_gdf, ghg_gdf,
                     id_col1='main_id', id_col2='ghg_id',
                     name_col1='facility_name', name_col2='facility_name_ghg'
                     )

# %%
matches_main_ghg = one_to_many_relationships(
    lt_main_ghg,
    id_main_col='main_id',
    id_sat_col='ghg_id',
    distance_threshold_m=10000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
ghg_gdf = ghg_gdf.merge(
    matches_main_ghg,
    on="ghg_id",  
    how="left"
)

# %%
# For SQL
ghg_gdf = ghg_gdf[ghg_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["row_id",
  "ghg_id",             
  "main_id",
  "year",
  "sector",
  "value",
  "unit"
               ]
ghg_gdf = ghg_gdf[col_to_keep]
ghg_gdf
# Out:
#                row_id  ghg_id           main_id  year  \
# 1    GHG-10101-2022-1   10101  NT-MAIN-6c1d6ee6  2022
# 4    GHG-10188-2022-1   10188  QC-MAIN-084bd95c  2022
# 7    GHG-10240-2022-1   10240  QC-MAIN-a97821c0  2022
# 8    GHG-10299-2022-1   10299  QC-MAIN-e25eed27  2022
# 9    GHG-10350-2022-1   10350  NL-MAIN-b64bae7a  2022
# ..                ...     ...               ...   ...
# 158  GHG-11042-2022-1   11042  ON-MAIN-b466361f  2022
# 169  GHG-11723-2022-1   11723  ON-MAIN-2e13aaa0  2022
# 170  GHG-11730-2022-1   11730  QC-MAIN-92628f16  2022
# 178  GHG-12298-2022-1   12298  ON-MAIN-63b394c3  2022
# 183  GHG-12581-2022-1   12581  ON-MAIN-137bbc71  2022
#
#                                                 sector   value  \
# 1                                       Diamond Mining  164.88
# 4                                      Iron Ore Mining  293.10
# 7                             Nickel-Copper Ore Mining  129.26
# 8                                      Iron Ore Mining  909.89
# 9                                      Iron Ore Mining  110.93
# ..                                                 ...     ...
# 158  Aluminum Rolling, Drawing, Extruding and Alloying   14.92
# 169  Non-Ferrous Metal (except Aluminum) Smelting a...   14.17
# 170         Primary Production of Alumina and Aluminum  380.82
# 178  Non-Ferrous Metal (except Aluminum) Smelting a...  330.67
# 183  Aluminum Rolling, Drawing, Extruding and Alloying    4.89
#
#                                                   unit
# 1    kilotonnes of carbon dioxide equivalents (kt C...
# 4    kilotonnes of carbon dioxide equivalents (kt C...
# 7    kilotonnes of carbon dioxide equivalents (kt C...
# 8    kilotonnes of carbon dioxide equivalents (kt C...
# 9    kilotonnes of carbon dioxide equivalents (kt C...
# ..                                                 ...
# 158  kilotonnes of carbon dioxide equivalents (kt C...
# 169  kilotonnes of carbon dioxide equivalents (kt C...
# 170  kilotonnes of carbon dioxide equivalents (kt C...
# 178  kilotonnes of carbon dioxide equivalents (kt C...
# 183  kilotonnes of carbon dioxide equivalents (kt C...
#
# [68 rows x 7 columns]

# %% [markdown]
# ### Pollution

# %%
pollutant_gdf
# Out:
#                   row_id  year  npri_id     facility_name_npri  \
# 0       npri-1568-2023-1  2023     1568           Macassa Mine
# 1       npri-1568-2023-2  2023     1568           Macassa Mine
# 2       npri-1568-2023-3  2023     1568           Macassa Mine
# 3       npri-1568-2023-4  2023     1568           Macassa Mine
# 4       npri-1568-2023-5  2023     1568           Macassa Mine
# ...                  ...   ...      ...                    ...
# 24125   npri-5697-2023-6  2023     5697  Rayette Manufacturing
# 24126   npri-5698-2023-6  2023     5698    Bowes Manufacturing
# 24127  npri-34697-2023-2  2023    34697    541 Bowes Warehouse
# 24128   npri-5697-2023-7  2023     5697  Rayette Manufacturing
# 24129   npri-5698-2023-7  2023     5698    Bowes Manufacturing
#
#         company_name_npri  facility_type  longitude  latitude  \
# 0      Agnico Eagle Mines         mining  -80.08734  48.13032
# 1      Agnico Eagle Mines         mining  -80.08734  48.13032
# 2      Agnico Eagle Mines         mining  -80.08734  48.13032
# 3      Agnico Eagle Mines         mining  -80.08734  48.13032
# 4      Agnico Eagle Mines         mining  -80.08734  48.13032
# ...                   ...            ...        ...       ...
# 24125                None  manufacturing  -79.49600  43.80800
# 24126                None  manufacturing  -79.49480  43.80360
# 24127                None  manufacturing  -79.49707  43.81726
# 24128                None  manufacturing  -79.49600  43.80800
# 24129                None  manufacturing  -79.49480  43.80360
#
#       terrestrial_ecozone                   watershed  \
# 0           Boreal Shield  St. Lawrence Drainage Area
# 1           Boreal Shield  St. Lawrence Drainage Area
# 2           Boreal Shield  St. Lawrence Drainage Area
# 3           Boreal Shield  St. Lawrence Drainage Area
# 4           Boreal Shield  St. Lawrence Drainage Area
# ...                   ...                         ...
# 24125     Mixedwood Plain  St. Lawrence Drainage Area
# 24126     Mixedwood Plain  St. Lawrence Drainage Area
# 24127     Mixedwood Plain  St. Lawrence Drainage Area
# 24128     Mixedwood Plain  St. Lawrence Drainage Area
# 24129     Mixedwood Plain  St. Lawrence Drainage Area
#
#                               substance_name_npri substance_name_ecoinvent  \
# 0                                 Ammonia (total)                  Ammonia
# 1                     Arsenic (and its compounds)                  Arsenic
# 2                                 Carbon monoxide  Carbon monoxide, fossil
# 3                    Chromium (and its compounds)                 Chromium
# 4                      Cobalt (and its compounds)                   Cobalt
# ...                                           ...                      ...
# 24125  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24126  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24127  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24128          Volatile Organic Compounds (Total)                     None
# 24129          Volatile Organic Compounds (Total)                     None
#
#       substance_unit                      emission_type  \
# 0             tonnes  Air Emissions / Émissions à l'air
# 1                 kg  Air Emissions / Émissions à l'air
# 2             tonnes  Air Emissions / Émissions à l'air
# 3             tonnes  Air Emissions / Émissions à l'air
# 4                 kg  Air Emissions / Émissions à l'air
# ...              ...                                ...
# 24125         tonnes                        Grand Total
# 24126         tonnes                        Grand Total
# 24127         tonnes                        Grand Total
# 24128         tonnes                        Grand Total
# 24129         tonnes                        Grand Total
#
#                                         emission_subtype      value  \
# 0                                        Stack Emissions      0.636
# 1                                        Stack Emissions      0.116
# 2                                        Stack Emissions     76.208
# 3                                        Stack Emissions    0.00105
# 4                                        Stack Emissions       0.18
# ...                                                  ...        ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008
# 24126  Total Releases, Disposals and Transfers for Re...     23.418
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719
#
#                          source_df                    geometry
# 0             npri_metal_mining_df  POINT (-80.08734 48.13032)
# 1             npri_metal_mining_df  POINT (-80.08734 48.13032)
# 2             npri_metal_mining_df  POINT (-80.08734 48.13032)
# 3             npri_metal_mining_df  POINT (-80.08734 48.13032)
# 4             npri_metal_mining_df  POINT (-80.08734 48.13032)
# ...                            ...                         ...
# 24125  npri_metal_manufacturing_df  POINT (-79.49600 43.80800)
# 24126  npri_metal_manufacturing_df  POINT (-79.49480 43.80360)
# 24127  npri_metal_manufacturing_df  POINT (-79.49707 43.81726)
# 24128  npri_metal_manufacturing_df  POINT (-79.49600 43.80800)
# 24129  npri_metal_manufacturing_df  POINT (-79.49480 43.80360)
#
# [24130 rows x 18 columns]

# %%
lt_main_pollution = match_facilities(main_gdf, pollutant_gdf,
                     id_col1='main_id', id_col2='npri_id',
                     name_col1='facility_name', name_col2='facility_name_npri'
                     )

# %%
matches_main_pollution = one_to_many_relationships(
    lt_main_pollution,
    id_main_col='main_id',
    id_sat_col='npri_id',
    distance_threshold_m=10000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
pollutant_gdf = pollutant_gdf.merge(
    matches_main_pollution,
    on="npri_id",  
    how="left"
)

# %%
# For SQL
pollutant_gdf = pollutant_gdf[pollutant_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["row_id",
  "npri_id",
  "main_id",
  "year",
  "terrestrial_ecozone",
  "watershed",
  "substance_name_npri",
  "substance_name_ecoinvent",
  "substance_unit",
  "emission_type",
  "emission_subtype",
  "value"
 ]
pollutant_gdf = pollutant_gdf[col_to_keep]
pollutant_gdf
# Out:
#                     row_id  npri_id           main_id  year  \
# 0         npri-1568-2023-1     1568  ON-MAIN-1f126a43  2023
# 1         npri-1568-2023-2     1568  ON-MAIN-1f126a43  2023
# 2         npri-1568-2023-3     1568  ON-MAIN-1f126a43  2023
# 3         npri-1568-2023-4     1568  ON-MAIN-1f126a43  2023
# 4         npri-1568-2023-5     1568  ON-MAIN-1f126a43  2023
# ...                    ...      ...               ...   ...
# 24116  npri-28761-2023-117    28761  NL-MAIN-d9036091  2023
# 24117  npri-28761-2023-118    28761  NL-MAIN-d9036091  2023
# 24118  npri-28761-2023-119    28761  NL-MAIN-d9036091  2023
# 24119  npri-28761-2023-120    28761  NL-MAIN-d9036091  2023
# 24120  npri-28761-2023-121    28761  NL-MAIN-d9036091  2023
#
#       terrestrial_ecozone                   watershed  \
# 0           Boreal Shield  St. Lawrence Drainage Area
# 1           Boreal Shield  St. Lawrence Drainage Area
# 2           Boreal Shield  St. Lawrence Drainage Area
# 3           Boreal Shield  St. Lawrence Drainage Area
# 4           Boreal Shield  St. Lawrence Drainage Area
# ...                   ...                         ...
# 24116       Boreal Shield  St. Lawrence Drainage Area
# 24117       Boreal Shield  St. Lawrence Drainage Area
# 24118       Boreal Shield  St. Lawrence Drainage Area
# 24119       Boreal Shield  St. Lawrence Drainage Area
# 24120       Boreal Shield  St. Lawrence Drainage Area
#
#                                      substance_name_npri  \
# 0                                        Ammonia (total)
# 1                            Arsenic (and its compounds)
# 2                                        Carbon monoxide
# 3                           Chromium (and its compounds)
# 4                             Cobalt (and its compounds)
# ...                                                  ...
# 24116                                    Sulphur dioxide
# 24117                                     Sulphuric acid
# 24118                           Total particulate matter
# 24119  Total reduced sulphur (expressed as hydrogen s...
# 24120                           Zinc (and its compounds)
#
#       substance_name_ecoinvent substance_unit  \
# 0                      Ammonia         tonnes
# 1                      Arsenic             kg
# 2      Carbon monoxide, fossil         tonnes
# 3                     Chromium         tonnes
# 4                       Cobalt             kg
# ...                        ...            ...
# 24116           Sulfur dioxide         tonnes
# 24117            Sulfuric acid         tonnes
# 24118           No match found         tonnes
# 24119           No match found         tonnes
# 24120                     Zinc         tonnes
#
#                            emission_type  \
# 0      Air Emissions / Émissions à l'air
# 1      Air Emissions / Émissions à l'air
# 2      Air Emissions / Émissions à l'air
# 3      Air Emissions / Émissions à l'air
# 4      Air Emissions / Émissions à l'air
# ...                                  ...
# 24116                        Grand Total
# 24117                        Grand Total
# 24118                        Grand Total
# 24119                        Grand Total
# 24120                        Grand Total
#
#                                         emission_subtype               value
# 0                                        Stack Emissions               0.636
# 1                                        Stack Emissions               0.116
# 2                                        Stack Emissions              76.208
# 3                                        Stack Emissions             0.00105
# 4                                        Stack Emissions                0.18
# ...                                                  ...                 ...
# 24116  Total Releases, Disposals and Transfers for Re...               4.405
# 24117  Total Releases, Disposals and Transfers for Re...              0.2475
# 24118  Total Releases, Disposals and Transfers for Re...  29.277299999999997
# 24119  Total Releases, Disposals and Transfers for Re...               0.485
# 24120  Total Releases, Disposals and Transfers for Re...  39.214054000000004
#
# [13777 rows x 12 columns]

# %% [markdown]
# ## Point to polygon matching

# %% [markdown]
# ### Protected lands datasets

# %%
from matching_functions import associate_facilities_near_polygons

# %%
wpda_gdf_polygons
# Out:
#         WDPA_PID                                               NAME  \
# 0          611_A               Wood Buffalo National Park Of Canada
# 1          611_B               Wood Buffalo National Park Of Canada
# 2            612             Kluane National Park Reserve Of Canada
# 3          613_B                  Auyuittuq National Park Of Canada
# 4          613_A                  Auyuittuq National Park Of Canada
# ...          ...                                                ...
# 13463  555785733  Grosse Île and the Irish Memorial National His...
# 13464  555785734                 Navy Island National Historic Site
# 13465  555785735  Fort George National Historic Site (Paradise G...
# 13466  555785736                Rideau Canal National Historic Site
# 13467  555785737                            Capital Recreation Area
#
#                           DESIG OWN_TYPE                          MANG_AUTH  \
# 0                 National Park    State                Parks Canada Agency
# 1                 National Park    State                Parks Canada Agency
# 2                 National Park    State                Parks Canada Agency
# 3                 National Park    State                Parks Canada Agency
# 4                 National Park    State                Parks Canada Agency
# ...                         ...      ...                                ...
# 13463  Lieu historique national    State                Parks Canada Agency
# 13464    National Historic Site    State                Parks Canada Agency
# 13465    National Historic Site    State                Parks Canada Agency
# 13466    National Historic Site    State                Parks Canada Agency
# 13467                      OECM    State  National Capital Commission (NCC)
#
#        STATUS_YR                        source_id  \
# 0           1922  https://www.protectedplanet.net
# 1           1922  https://www.protectedplanet.net
# 2           1972  https://www.protectedplanet.net
# 3           1972  https://www.protectedplanet.net
# 4           1972  https://www.protectedplanet.net
# ...          ...                              ...
# 13463       2023  https://www.protectedplanet.net
# 13464       2023  https://www.protectedplanet.net
# 13465       2023  https://www.protectedplanet.net
# 13466       2023  https://www.protectedplanet.net
# 13467       2023  https://www.protectedplanet.net
#
#                                                 geometry
# 0      POLYGON ((-112.87253 59.99877, -111.53006 59.7...
# 1      POLYGON ((-112.87253 59.99877, -115.58450 59.9...
# 2      POLYGON ((-141.00187 60.30634, -137.43466 60.7...
# 3      MULTIPOLYGON (((-64.62292 67.13706, -63.92605 ...
# 4      MULTIPOLYGON (((-68.23194 67.76712, -67.56846 ...
# ...                                                  ...
# 13463  MULTIPOLYGON (((-70.67843 47.01639, -70.67803 ...
# 13464  POLYGON ((-79.01037 43.04900, -79.00871 43.060...
# 13465  POLYGON ((-79.06782 43.24368, -79.05901 43.248...
# 13466  MULTIPOLYGON (((-76.24341 44.90190, -76.19385 ...
# 13467  POLYGON ((-75.60920 45.33843, -75.61502 45.332...
#
# [13468 rows x 8 columns]

# %%
lt_wpda = associate_facilities_near_polygons(
    main_gdf,
    wpda_gdf_polygons,
    facility_id_col="main_id",
    polygon_id_col="WDPA_PID",
    buffer_km=50,
    crs="EPSG:3978"
)

# %%
wpda_gdf_polygons = wpda_gdf_polygons.merge(lt_wpda, on="WDPA_PID", how="left")

# %%
# For SQL
wpda_gdf_polygons = wpda_gdf_polygons[wpda_gdf_polygons["main_id"].notna()].copy()

# %%
lt_indigenous = associate_facilities_near_polygons(
    main_gdf,
    indigenous_can_gdf,
    facility_id_col="main_id",
    polygon_id_col="indigenous_land_id",
    buffer_km=50,
    crs="EPSG:3978"
)

# %%
indigenous_can_gdf = indigenous_can_gdf.merge(lt_indigenous, on="indigenous_land_id", how="left")

# %%
# For SQL
indigenous_can_gdf = indigenous_can_gdf[indigenous_can_gdf["main_id"].notna()].copy()

# %% [markdown]
# ### Land occupation footprint datasets

# %%
from matching_functions import assign_polygons_to_points

# %%
assigned_df = assign_polygons(
    main_gdf,
    tailings_gdf,
    tang_canada_gdf,
    max_dist_km=10
)

# %%
assigned_df
# Out:
#               main_id  tailing_id  tang_id  distance_km relation_type
# 0    NS-MAIN-c9c77a59         NaN    45954     0.000000   one-to-many
# 1    NS-MAIN-c9c77a59         NaN    45955     1.186584   one-to-many
# 2    NL-MAIN-d9036091         NaN     7631     0.811781   one-to-many
# 3    NL-MAIN-d9036091         NaN     7641     4.647047   one-to-many
# 4    NL-MAIN-d9036091         NaN     7633     0.000000   many-to-one
# ..                ...         ...      ...          ...           ...
# 789  NT-MAIN-6c1d6ee6         NaN    26078     2.857250   one-to-many
# 790  NT-MAIN-6c1d6ee6         NaN    43740     0.833606   one-to-many
# 791  NT-MAIN-6c1d6ee6         NaN     3479     0.000000   one-to-many
# 792  NT-MAIN-6c1d6ee6         NaN    50385     2.150861   one-to-many
# 793  NT-MAIN-6c1d6ee6         NaN    26137     4.650487   one-to-many
#
# [794 rows x 5 columns]

# %%
assigned_df['relation_type'].value_counts()
# Out:
# relation_type
# one-to-many    707
# many-to-one     56
# one-to-one      31
# Name: count, dtype: int64

# %%
polygon_gdf = tang_canada_gdf.merge(assigned_df, on="tang_id", how="left")

# %%
polygon_gdf
# Out:
#       tang_id  area_km2                                           geometry  \
# 0        6383  0.026130  POLYGON Z ((1795479.979 -83564.531 0.000, 1795...
# 1        6388  0.671399  POLYGON Z ((1796123.448 -80625.526 0.000, 1796...
# 2        6390  0.050909  POLYGON Z ((1796791.634 -80270.697 0.000, 1796...
# 3       45954  2.622800  POLYGON Z ((2466485.124 185586.547 0.000, 2466...
# 4       45955  0.441869  POLYGON Z ((2465809.682 185862.507 0.000, 2465...
# ...       ...       ...                                                ...
# 1915     3399  0.541024  POLYGON Z ((-717210.659 1915423.857 0.000, -71...
# 1916     3401  1.053173  POLYGON Z ((-715648.337 1916385.463 0.000, -71...
# 1917    26364  0.079894  POLYGON Z ((-717332.782 1916999.286 0.000, -71...
# 1918    43739  1.519488  POLYGON Z ((-713032.430 1919630.086 0.000, -71...
# 1919    44287  0.121349  POLYGON Z ((-466746.640 2074582.808 0.000, -46...
#
#                main_id  tailing_id  distance_km relation_type
# 0                  NaN         NaN          NaN           NaN
# 1                  NaN         NaN          NaN           NaN
# 2                  NaN         NaN          NaN           NaN
# 3     NS-MAIN-c9c77a59         NaN     0.000000   one-to-many
# 4     NS-MAIN-c9c77a59         NaN     1.186584   one-to-many
# ...                ...         ...          ...           ...
# 1915               NaN         NaN          NaN           NaN
# 1916               NaN         NaN          NaN           NaN
# 1917               NaN         NaN          NaN           NaN
# 1918               NaN         NaN          NaN           NaN
# 1919               NaN         NaN          NaN           NaN
#
# [1920 rows x 7 columns]

# %% [markdown]
# # Create final tables

# %% [markdown]
# ## Environment table

# %%
env_id
year
commodity ## do we need it?
compartment_id
flow_type == ghg 
substance_id
unit
value
comment

# %% [markdown]
# ### CTrace dataset

# %%
ctrace_ghg_gdf
# Out:
#     ctrace_id  year           source_name  emissions_quantity         gas  \
# 6     1754055  2023          Coleman Mine        5.610000e+03  co2e_100yr
# 7     1754056  2023     Copper Cliff Mine        6.403000e+03  co2e_100yr
# 8     1754057  2023  Copper Mountain Mine        2.299160e+05  co2e_100yr
# 9     1754058  2023        Creighton Mine        2.639000e+03  co2e_100yr
# 11    1754060  2023           Garson Mine        4.225000e+03  co2e_100yr
# 12    1754061  2023        Gibraltar Mine        1.316380e+05  co2e_100yr
# 16    1754066  2023  Highland Valley Mine        2.412130e+06  co2e_100yr
# 17    1754067  2023            Horne Mine        0.000000e+00  co2e_100yr
# 25    1754077  2023          LaRonde Mine        6.711600e+04  co2e_100yr
# 29    1754081  2023    McCreedy West Mine        7.782000e+03  co2e_100yr
# 30    1754082  2023             Ming Mine        0.000000e+00  co2e_100yr
# 31    1754083  2023            Minto Mine        0.000000e+00  co2e_100yr
# 32    1754084  2023   Mount Milligan Mine        7.956600e+04  co2e_100yr
# 33    1754085  2023     Mount Polley Mine        7.137900e+04  co2e_100yr
# 34    1754086  2023       Myra Falls Mine        5.400000e+02  co2e_100yr
# 35    1754087  2023        New Afton Mine        1.590800e+04  co2e_100yr
# 43    1754096  2023      Raglan Operation        8.219000e+03  co2e_100yr
# 44    1754097  2023        Red Chris Mine        8.451100e+04  co2e_100yr
# 51    1754104  2023           Totten Mine        3.367000e+03  co2e_100yr
# 52    1754105  2023          Troilus Mine        0.000000e+00  co2e_100yr
# 54   25486533  2023       Kidd Creek Mine        1.620000e+04  co2e_100yr
# 55   25486534  2023     Lac des Iles Mine        5.914500e+04  co2e_100yr
# 56   36395102  2023           Scully Mine        5.760720e+05  co2e_100yr
#
#      latitude   longitude                                          source_id  \
# 6   46.674583  -81.343080  Jolleys, M. et al (2024). Mineral Extraction s...
# 7   46.480960  -81.052207  Jolleys, M. et al (2024). Mineral Extraction s...
# 8   49.331253 -120.521629  Jolleys, M. et al (2024). Mineral Extraction s...
# 9   46.462958  -81.176038  Jolleys, M. et al (2024). Mineral Extraction s...
# 11  46.567580  -80.857509  Jolleys, M. et al (2024). Mineral Extraction s...
# 12  52.519137 -122.269260  Jolleys, M. et al (2024). Mineral Extraction s...
# 16  50.486244 -121.042759  Jolleys, M. et al (2024). Mineral Extraction s...
# 17  48.254296  -79.010706  Jolleys, M. et al (2024). Mineral Extraction s...
# 25  48.249139  -78.441434  Jolleys, M. et al (2024). Mineral Extraction s...
# 29  46.637729  -81.398089  Jolleys, M. et al (2024). Mineral Extraction s...
# 30  49.914219  -56.085819  Jolleys, M. et al (2024). Mineral Extraction s...
# 31  62.617560 -137.256469  Jolleys, M. et al (2024). Mineral Extraction s...
# 32  55.120089 -124.019136  Jolleys, M. et al (2024). Mineral Extraction s...
# 33  52.548922 -121.634586  Jolleys, M. et al (2024). Mineral Extraction s...
# 34  49.570670 -125.591966  Jolleys, M. et al (2024). Mineral Extraction s...
# 35  50.662968 -120.520252  Jolleys, M. et al (2024). Mineral Extraction s...
# 43  61.687773  -73.678676  Jolleys, M. et al (2024). Mineral Extraction s...
# 44  57.713205 -129.794095  Jolleys, M. et al (2024). Mineral Extraction s...
# 51  46.381870  -81.453631  Jolleys, M. et al (2024). Mineral Extraction s...
# 52  51.012585  -74.466821  Jolleys, M. et al (2024). Mineral Extraction s...
# 54  48.689104  -81.371982  Jolleys, M. et al (2024). Mineral Extraction s...
# 55  49.164166  -89.622449  Jolleys, M. et al (2024). Mineral Extraction s...
# 56  52.905338  -66.927868  Jolleys, M. et al (2024). Mineral Extraction s...
#
#                        geometry           main_id
# 6    POINT (-81.34308 46.67458)  ON-MAIN-6e9b2449
# 7    POINT (-81.05221 46.48096)  ON-MAIN-63b394c3
# 8   POINT (-120.52163 49.33125)  BC-MAIN-599152a0
# 9    POINT (-81.17604 46.46296)  ON-MAIN-52224e1e
# 11   POINT (-80.85751 46.56758)  ON-MAIN-48fe2205
# 12  POINT (-122.26926 52.51914)  BC-MAIN-6b4800fe
# 16  POINT (-121.04276 50.48624)  BC-MAIN-bf503b6b
# 17   POINT (-79.01071 48.25430)  QC-MAIN-30c1828c
# 25   POINT (-78.44143 48.24914)  QC-MAIN-e51eda66
# 29   POINT (-81.39809 46.63773)  ON-MAIN-7001a391
# 30   POINT (-56.08582 49.91422)  NL-MAIN-c139de6d
# 31  POINT (-137.25647 62.61756)  YT-MAIN-752fbcae
# 32  POINT (-124.01914 55.12009)  BC-MAIN-ed23117f
# 33  POINT (-121.63459 52.54892)  BC-MAIN-3f490561
# 34  POINT (-125.59197 49.57067)  BC-MAIN-23155c25
# 35  POINT (-120.52025 50.66297)  BC-MAIN-aa76f6f2
# 43   POINT (-73.67868 61.68777)  QC-MAIN-a97821c0
# 44  POINT (-129.79409 57.71321)  BC-MAIN-8eb8be0d
# 51   POINT (-81.45363 46.38187)  ON-MAIN-28f3f0fc
# 52   POINT (-74.46682 51.01259)  QC-MAIN-b2148882
# 54   POINT (-81.37198 48.68910)  ON-MAIN-f8313ebd
# 55   POINT (-89.62245 49.16417)  ON-MAIN-a3c56a83
# 56   POINT (-66.92787 52.90534)  NL-MAIN-b64bae7a

# %%
ctrace_ghg_gdf.rename(columns={
    'ctrace_id': 'env_id',
    'emissions_quantity': 'value',
    'gas': 'unit'}, inplace=True)

ctrace_ghg_gdf.drop(columns=['source_name', 'latitude', 'longitude', 'geometry'], inplace=True)

# %%
ctrace_ghg_gdf
# Out:
#       env_id  year         value        unit  \
# 6    1754055  2023  5.610000e+03  co2e_100yr
# 7    1754056  2023  6.403000e+03  co2e_100yr
# 8    1754057  2023  2.299160e+05  co2e_100yr
# 9    1754058  2023  2.639000e+03  co2e_100yr
# 11   1754060  2023  4.225000e+03  co2e_100yr
# 12   1754061  2023  1.316380e+05  co2e_100yr
# 16   1754066  2023  2.412130e+06  co2e_100yr
# 17   1754067  2023  0.000000e+00  co2e_100yr
# 25   1754077  2023  6.711600e+04  co2e_100yr
# 29   1754081  2023  7.782000e+03  co2e_100yr
# 30   1754082  2023  0.000000e+00  co2e_100yr
# 31   1754083  2023  0.000000e+00  co2e_100yr
# 32   1754084  2023  7.956600e+04  co2e_100yr
# 33   1754085  2023  7.137900e+04  co2e_100yr
# 34   1754086  2023  5.400000e+02  co2e_100yr
# 35   1754087  2023  1.590800e+04  co2e_100yr
# 43   1754096  2023  8.219000e+03  co2e_100yr
# 44   1754097  2023  8.451100e+04  co2e_100yr
# 51   1754104  2023  3.367000e+03  co2e_100yr
# 52   1754105  2023  0.000000e+00  co2e_100yr
# 54  25486533  2023  1.620000e+04  co2e_100yr
# 55  25486534  2023  5.914500e+04  co2e_100yr
# 56  36395102  2023  5.760720e+05  co2e_100yr
#
#                                             source_id           main_id
# 6   Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-6e9b2449
# 7   Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-63b394c3
# 8   Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-599152a0
# 9   Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-52224e1e
# 11  Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-48fe2205
# 12  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-6b4800fe
# 16  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-bf503b6b
# 17  Jolleys, M. et al (2024). Mineral Extraction s...  QC-MAIN-30c1828c
# 25  Jolleys, M. et al (2024). Mineral Extraction s...  QC-MAIN-e51eda66
# 29  Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-7001a391
# 30  Jolleys, M. et al (2024). Mineral Extraction s...  NL-MAIN-c139de6d
# 31  Jolleys, M. et al (2024). Mineral Extraction s...  YT-MAIN-752fbcae
# 32  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-ed23117f
# 33  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-3f490561
# 34  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-23155c25
# 35  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-aa76f6f2
# 43  Jolleys, M. et al (2024). Mineral Extraction s...  QC-MAIN-a97821c0
# 44  Jolleys, M. et al (2024). Mineral Extraction s...  BC-MAIN-8eb8be0d
# 51  Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-28f3f0fc
# 52  Jolleys, M. et al (2024). Mineral Extraction s...  QC-MAIN-b2148882
# 54  Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-f8313ebd
# 55  Jolleys, M. et al (2024). Mineral Extraction s...  ON-MAIN-a3c56a83
# 56  Jolleys, M. et al (2024). Mineral Extraction s...  NL-MAIN-b64bae7a

# %%
## We miss commodity, flow_type, compartment id and substance id
#ctrace_ghg_gdf['compartment_id'] = 
#ctrace_ghg_gdf['flow_type'] =
#ctrace_ghg_gdf['substance_id'] =

# %% [markdown]
# ### NPRI dataset

# %%
pollutant_gdf.rename(columns={
    'row_id': 'env_id',
    'substance_unit': 'unit'}, inplace=True)

pollutant_gdf.drop(columns=['npri_id', 'facility_name_npri', 'company_name_npri',
       'emission_type', 'emission_subtype',
       'facility_type', 'longitude', 'latitude', 'terrestrial_ecozone',
       'watershed', 'substance_name_npri', 'substance_name_ecoinvent', 'geometry'], inplace=True)

# %%
pollutant_gdf
# Out:
#                   env_id  year    unit                      emission_type  \
# 0       npri-1568-2023-1  2023  tonnes  Air Emissions / Émissions à l'air
# 1       npri-1568-2023-2  2023      kg  Air Emissions / Émissions à l'air
# 2       npri-1568-2023-3  2023  tonnes  Air Emissions / Émissions à l'air
# 3       npri-1568-2023-4  2023  tonnes  Air Emissions / Émissions à l'air
# 4       npri-1568-2023-5  2023      kg  Air Emissions / Émissions à l'air
# ...                  ...   ...     ...                                ...
# 24125   npri-5697-2023-6  2023  tonnes                        Grand Total
# 24126   npri-5698-2023-6  2023  tonnes                        Grand Total
# 24127  npri-34697-2023-2  2023  tonnes                        Grand Total
# 24128   npri-5697-2023-7  2023  tonnes                        Grand Total
# 24129   npri-5698-2023-7  2023  tonnes                        Grand Total
#
#                                         emission_subtype      value  \
# 0                                        Stack Emissions      0.636
# 1                                        Stack Emissions      0.116
# 2                                        Stack Emissions     76.208
# 3                                        Stack Emissions    0.00105
# 4                                        Stack Emissions       0.18
# ...                                                  ...        ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008
# 24126  Total Releases, Disposals and Transfers for Re...     23.418
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719
#
#                                                source_id   substance_id
# 0      https://www.canada.ca/en/environment-climate-c...  SUBa2c74fdce8
# 1      https://www.canada.ca/en/environment-climate-c...  SUB526607d180
# 2      https://www.canada.ca/en/environment-climate-c...  SUB92570cece4
# 3      https://www.canada.ca/en/environment-climate-c...  SUB075f575023
# 4      https://www.canada.ca/en/environment-climate-c...  SUB481f3889a8
# ...                                                  ...            ...
# 24125  https://www.canada.ca/en/environment-climate-c...  SUB4a14c4c889
# 24126  https://www.canada.ca/en/environment-climate-c...  SUB4a14c4c889
# 24127  https://www.canada.ca/en/environment-climate-c...  SUB4a14c4c889
# 24128  https://www.canada.ca/en/environment-climate-c...  SUB0d60783c59
# 24129  https://www.canada.ca/en/environment-climate-c...  SUB0d60783c59
#
# [24130 rows x 8 columns]

# %%
pollutant_gdf.columns
# Out:
# Index(['row_id', 'year', 'npri_id', 'facility_name_npri', 'company_name_npri',
#        'facility_type', 'longitude', 'latitude', 'terrestrial_ecozone',
#        'watershed', 'substance_name_npri', 'substance_name_ecoinvent',
#        'substance_unit', 'emission_type', 'emission_subtype', 'value',
#        'source_id', 'substance_id', 'geometry'],
#       dtype='object')

# %% [markdown]
# ### GHG dataset

# %%
ghg_gdf
# Out:
#                row_id  year  ghg_id                      facility_name_ghg  \
# 0    GHG-10052-2022-1  2022   10052                          Carol Project
# 1    GHG-10101-2022-1  2022   10101                     Ekati Diamond Mine
# 2    GHG-10140-2022-1  2022   10140   HBMS Flin Flon Metallurgical Complex
# 3    GHG-10164-2022-1  2022   10164                Kidd Metallurgical Site
# 4    GHG-10188-2022-1  2022   10188                    Mine de Mont-Wright
# ..                ...   ...     ...                                    ...
# 179  GHG-12301-2022-1  2022   12301              GRIFFIN CANADA - WINNIPEG
# 180  GHG-12554-2022-1  2022   12554                 Molycop Canada Plant 2
# 181  GHG-12555-2022-1  2022   12555                        Moly-Cop Canada
# 182  GHG-12579-2022-1  2022   12579                       Fonderie Laperle
# 183  GHG-12581-2022-1  2022   12581  Extrusion North America - Mississauga
#
#      longitude  latitude                          city  \
# 0    -66.90020  52.95200                 Labrador City
# 1   -110.62010  64.71950                   Yellowknife
# 2   -101.88400  54.77100                     Flin Flon
# 3    -81.09115  48.57373  Timmins District of Cochrane
# 4    -67.33306  52.76639                       Fermont
# ..         ...       ...                           ...
# 179  -97.00250  49.91300                      Winnipeg
# 180 -120.09703  50.65598                      Kamloops
# 181 -120.09649  50.65726                      Kamloops
# 182  -73.13870  45.89470                    Saint Ours
# 183  -79.65750  43.63060                   Mississauga
#
#                       province  \
# 0    Newfoundland and Labrador
# 1        Northwest Territories
# 2                     Manitoba
# 3                      Ontario
# 4                       Quebec
# ..                         ...
# 179                   Manitoba
# 180           British Columbia
# 181           British Columbia
# 182                     Quebec
# 183                    Ontario
#
#                                                 sector   value  \
# 0                                      Iron Ore Mining  826.03
# 1                                       Diamond Mining  164.88
# 2                               Copper-Zinc Ore Mining   29.73
# 3                               Copper-Zinc Ore Mining   30.82
# 4                                      Iron Ore Mining  293.10
# ..                                                 ...     ...
# 179                                    Steel Foundries     NaN
# 180                                     Iron Foundries     NaN
# 181                                     Iron Foundries   25.12
# 182                                     Iron Foundries    0.51
# 183  Aluminum Rolling, Drawing, Extruding and Alloying    4.89
#
#                                                   unit  \
# 0    kilotonnes of carbon dioxide equivalents (kt C...
# 1    kilotonnes of carbon dioxide equivalents (kt C...
# 2    kilotonnes of carbon dioxide equivalents (kt C...
# 3    kilotonnes of carbon dioxide equivalents (kt C...
# 4    kilotonnes of carbon dioxide equivalents (kt C...
# ..                                                 ...
# 179  kilotonnes of carbon dioxide equivalents (kt C...
# 180  kilotonnes of carbon dioxide equivalents (kt C...
# 181  kilotonnes of carbon dioxide equivalents (kt C...
# 182  kilotonnes of carbon dioxide equivalents (kt C...
# 183  kilotonnes of carbon dioxide equivalents (kt C...
#
#                                           facility_url  \
# 0    https://climate-change.canada.ca/facility-emis...
# 1    https://climate-change.canada.ca/facility-emis...
# 2    https://climate-change.canada.ca/facility-emis...
# 3    https://climate-change.canada.ca/facility-emis...
# 4    https://climate-change.canada.ca/facility-emis...
# ..                                                 ...
# 179  https://climate-change.canada.ca/facility-emis...
# 180  https://climate-change.canada.ca/facility-emis...
# 181  https://climate-change.canada.ca/facility-emis...
# 182  https://climate-change.canada.ca/facility-emis...
# 183  https://climate-change.canada.ca/facility-emis...
#
#                                              source_id  \
# 0    https://www.canada.ca/en/environment-climate-c...
# 1    https://www.canada.ca/en/environment-climate-c...
# 2    https://www.canada.ca/en/environment-climate-c...
# 3    https://www.canada.ca/en/environment-climate-c...
# 4    https://www.canada.ca/en/environment-climate-c...
# ..                                                 ...
# 179  https://www.canada.ca/en/environment-climate-c...
# 180  https://www.canada.ca/en/environment-climate-c...
# 181  https://www.canada.ca/en/environment-climate-c...
# 182  https://www.canada.ca/en/environment-climate-c...
# 183  https://www.canada.ca/en/environment-climate-c...
#
#                         geometry
# 0     POINT (-66.90020 52.95200)
# 1    POINT (-110.62010 64.71950)
# 2    POINT (-101.88400 54.77100)
# 3     POINT (-81.09115 48.57373)
# 4     POINT (-67.33306 52.76639)
# ..                           ...
# 179   POINT (-97.00250 49.91300)
# 180  POINT (-120.09703 50.65598)
# 181  POINT (-120.09649 50.65726)
# 182   POINT (-73.13870 45.89470)
# 183   POINT (-79.65750 43.63060)
#
# [184 rows x 14 columns]

# %%
ghg_gdf.rename(columns={'row_id': 'env_id'}, inplace=True)
ghg_gdf.drop(columns=['ghg_id', 'facility_name_ghg', 'longitude',
       'latitude', 'city', 'province', 'sector', 'facility_url', 'geometry'], inplace=True)

# %%
ghg_gdf['compartment_id'] = 
ghg_gdf['flow_type'] = 'ghg, scope 1'
ghg_gdf['substance_id'] = # nothing
# Out:
#                env_id  year   value  \
# 0    GHG-10052-2022-1  2022  826.03
# 1    GHG-10101-2022-1  2022  164.88
# 2    GHG-10140-2022-1  2022   29.73
# 3    GHG-10164-2022-1  2022   30.82
# 4    GHG-10188-2022-1  2022  293.10
# ..                ...   ...     ...
# 179  GHG-12301-2022-1  2022     NaN
# 180  GHG-12554-2022-1  2022     NaN
# 181  GHG-12555-2022-1  2022   25.12
# 182  GHG-12579-2022-1  2022    0.51
# 183  GHG-12581-2022-1  2022    4.89
#
#                                                   unit  \
# 0    kilotonnes of carbon dioxide equivalents (kt C...
# 1    kilotonnes of carbon dioxide equivalents (kt C...
# 2    kilotonnes of carbon dioxide equivalents (kt C...
# 3    kilotonnes of carbon dioxide equivalents (kt C...
# 4    kilotonnes of carbon dioxide equivalents (kt C...
# ..                                                 ...
# 179  kilotonnes of carbon dioxide equivalents (kt C...
# 180  kilotonnes of carbon dioxide equivalents (kt C...
# 181  kilotonnes of carbon dioxide equivalents (kt C...
# 182  kilotonnes of carbon dioxide equivalents (kt C...
# 183  kilotonnes of carbon dioxide equivalents (kt C...
#
#                                              source_id
# 0    https://www.canada.ca/en/environment-climate-c...
# 1    https://www.canada.ca/en/environment-climate-c...
# 2    https://www.canada.ca/en/environment-climate-c...
# 3    https://www.canada.ca/en/environment-climate-c...
# 4    https://www.canada.ca/en/environment-climate-c...
# ..                                                 ...
# 179  https://www.canada.ca/en/environment-climate-c...
# 180  https://www.canada.ca/en/environment-climate-c...
# 181  https://www.canada.ca/en/environment-climate-c...
# 182  https://www.canada.ca/en/environment-climate-c...
# 183  https://www.canada.ca/en/environment-climate-c...
#
# [184 rows x 5 columns]

# %% [markdown]
# ### Manually collected data

# %%
env_df
# Out:
#      year reporting_level      reported_company_nrcan               name  \
# 0    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 1    2023   Site-specific  Agnico Eagle Mines Limited  Canadian Malartic
# 2    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 3    2023   Site-specific  Agnico Eagle Mines Limited        Detour Lake
# 4    2023   Site-specific  Agnico Eagle Mines Limited             Goldex
# ..    ...             ...                         ...                ...
# 746  2023   Site-specific      Wesdome Gold Mines Ltd        Eagle River
# 747  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 748  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 749  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
# 750  2023   Site-specific      Wesdome Gold Mines Ltd              Kiena
#
#               main_id facility_group_id company_id facility_type  \
# 0    ON-MAIN-1f126a43                 -        NaN        mining
# 1    ON-MAIN-1f126a43                 -        NaN        mining
# 2    QC-MAIN-e7e6a960                 -        NaN        mining
# 3    QC-MAIN-e7e6a960                 -        NaN        mining
# 4    NU-MAIN-8b0264c9                 -        NaN        mining
# ..                ...               ...        ...           ...
# 746  QC-MAIN-9de9bb0d                 -        NaN        mining
# 747  ON-MAIN-c5fefb01                 -        NaN        mining
# 748  ON-MAIN-c5fefb01                 -        NaN        mining
# 749  ON-MAIN-c5fefb01                 -        NaN        mining
# 750  ON-MAIN-c5fefb01                 -        NaN        mining
#
#         mining_processing_type     commodity compartment      flow_type  \
# 0    Underground, concentrator  Gold, silver         Air  air_pollution
# 1    Underground, concentrator  Gold, silver         Air  air_pollution
# 2       Open-pit, concentrator          Gold         Air  air_pollution
# 3       Open-pit, concentrator          Gold         Air  air_pollution
# 4    Underground, concentrator  Gold, silver         Air  air_pollution
# ..                         ...           ...         ...            ...
# 746  Underground, concentrator          Gold       Water          water
# 747     Open-pit, concentrator          Gold       Water          water
# 748     Open-pit, concentrator          Gold       Water          water
# 749     Open-pit, concentrator          Gold       Water          water
# 750     Open-pit, concentrator          Gold       Water          water
#
#                               subflow_type substance_name unit   value  \
# 0                                        -            Sox    t     315
# 1                                        -            Nox    t    4802
# 2                                        -            Sox    t     486
# 3                                        -            Nox    t    7414
# 4                                        -            Sox    t      38
# ..                                     ...            ...  ...     ...
# 746                 Total water discharged              -   m3  324347
# 747                       Water withdrawal              -   m3  168115
# 748  Water withdrawal|Freshwater withdrawn              -   m3  168115
# 749                Total water consumption              -   m3   82144
# 750                 Total water discharged              -   m3  536420
#
#                                                comment  \
# 0    "In absence of site-level monitoring emission ...
# 1    "In absence of site-level monitoring emission ...
# 2    "In absence of site-level monitoring emission ...
# 3    "In absence of site-level monitoring emission ...
# 4    "In absence of site-level monitoring emission ...
# ..                                                 ...
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
# 750                                                NaN
#
#                                         source
# 0    2023-Sustainability-Performance_data.xlsx
# 1    2023-Sustainability-Performance_data.xlsx
# 2    2023-Sustainability-Performance_data.xlsx
# 3    2023-Sustainability-Performance_data.xlsx
# 4    2023-Sustainability-Performance_data.xlsx
# ..                                         ...
# 746                  2023-ESG-Data-Tables.xlsx
# 747                  2023-ESG-Data-Tables.xlsx
# 748                  2023-ESG-Data-Tables.xlsx
# 749                  2023-ESG-Data-Tables.xlsx
# 750                  2023-ESG-Data-Tables.xlsx
#
# [751 rows x 18 columns]

# %%
env_df.columns
# Out:
# Index(['year', 'reporting_level', 'reported_company_nrcan', 'name', 'main_id',
#        'facility_group_id', 'company_id', 'facility_type',
#        'mining_processing_type', 'commodity', 'compartment', 'flow_type',
#        'subflow_type', 'substance_name', 'unit', 'value', 'comment', 'source'],
#       dtype='object')

# %%
env_df.drop(columns=['reporting_level', 'reported_company_nrcan', 'name', 'facility_type',
       'mining_processing_type', 'commodity' ])

# %% [markdown]
# ## Production table

# %%
production_df.rename(columns={'row_id': 'prod_id'}, inplace=True)

# %%
production_df.drop(columns=['level', 'reported_company_nrcan', 'name', 
                            'facility_type', 'mining_processing_type', 'commodities_nrcan'], inplace=True)

# %%
ctrace_prod_gdf.rename(columns={'ctrace_id': 'prod_id'}, inplace=True)

# %%
# Save units before melting
activity_units = ctrace_prod_gdf['activity_units']
capacity_units = ctrace_prod_gdf['capacity_units']

# Melt
ctrace_prod_gdf = pd.melt(
    ctrace_prod_gdf,
    id_vars=['prod_id', 'year', 'source_name', 'latitude', 'longitude', 'source_id', 'geometry', 'main_id'],
    value_vars=['activity', 'capacity'],
    var_name='data_type',
    value_name='value'
)

# Set data_type labels
ctrace_prod_gdf['data_type'] = ctrace_prod_gdf['data_type'].replace({
    'activity': 'Production',
    'capacity': 'Capacity'
})

# Concatenate units in correct order (activity first, then capacity)
ctrace_prod_gdf['unit'] = list(activity_units) + list(capacity_units)

# %%
ctrace_prod_gdf.drop(columns=['source_name', 'latitude', 'longitude', 'geometry'], inplace=True)

# %%
ctrace_prod_gdf['geography'] = 'Canada'
ctrace_prod_gdf['reference_point'] = 'Ore processed'

# %%
# Concatenate production and ctrace data 
production_table = pd.concat([production_df, ctrace_prod_gdf], ignore_index=True)

# %%
production_table
# Out:
#                   prod_id  year geography           main_id facility_group_id  \
# 0    PROD-1f126a43-2023-1  2023    Canada  ON-MAIN-1f126a43                 -
# 1    PROD-1f126a44-2023-1  2023    Canada  ON-MAIN-1f126a44                 -
# 2    PROD-1f126a45-2023-1  2023    Canada  ON-MAIN-1f126a45                 -
# 3    PROD-e7e6a960-2023-1  2023    Canada  QC-MAIN-e7e6a960                 -
# 4    PROD-e7e6a963-2023-1  2023    Canada  QC-MAIN-e7e6a963                 -
# ..                    ...   ...       ...               ...               ...
# 384               1754104  2023    Canada  ON-MAIN-28f3f0fc               NaN
# 385               1754105  2023    Canada  QC-MAIN-b2148882               NaN
# 386              25486533  2023    Canada  ON-MAIN-f8313ebd               NaN
# 387              25486534  2023    Canada  ON-MAIN-a3c56a83               NaN
# 388              36395102  2023    Canada  NL-MAIN-b64bae7a               NaN
#
#     company_id commodity reference_point       material_type   data_type  \
# 0          NaN       Ore               2       Ore processed  Production
# 1          NaN      Gold               4  Intermediate metal  Production
# 2          NaN    Silver               4  Intermediate metal  Production
# 3          NaN      Gold               2       Ore processed  Production
# 4          NaN      Gold               4  Intermediate metal  Production
# ..         ...       ...             ...                 ...         ...
# 384        NaN       NaN   Ore processed                 NaN    Capacity
# 385        NaN       NaN   Ore processed                 NaN    Capacity
# 386        NaN       NaN   Ore processed                 NaN    Capacity
# 387        NaN       NaN   Ore processed                 NaN    Capacity
# 388        NaN       NaN   Ore processed                 NaN    Capacity
#
#        unit         value                                            comment  \
# 0         t  1.959493e+07                                                NaN
# 1        oz  6.846400e+05  "Production reflects Agnico Eagle's 50% intere...
# 2       koz  3.100000e+02  "Production reflects Agnico Eagle's 50% intere...
# 3         t  2.543485e+07                                                NaN
# 4        oz  6.774460e+05                            Like intermediate metal
# ..      ...           ...                                                ...
# 384  tonnes  2.453000e+06                                                NaN
# 385  tonnes  8.787959e+07                                                NaN
# 386  tonnes  2.500000e+06                                                NaN
# 387  tonnes  2.200000e+07                                                NaN
# 388  tonnes  4.789430e+08                                                NaN
#
#                                    source  \
# 0    2023-Sustainability-Performance_data
# 1    2023-Sustainability-Performance_data
# 2    2023-Sustainability-Performance_data
# 3    2023-Sustainability-Performance_data
# 4    2023-Sustainability-Performance_data
# ..                                    ...
# 384                                   NaN
# 385                                   NaN
# 386                                   NaN
# 387                                   NaN
# 388                                   NaN
#
#                                              source_id
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 384  Jolleys, M. et al (2024). Mineral Extraction s...
# 385  Jolleys, M. et al (2024). Mineral Extraction s...
# 386  Jolleys, M. et al (2024). Mineral Extraction s...
# 387  Jolleys, M. et al (2024). Mineral Extraction s...
# 388  Jolleys, M. et al (2024). Mineral Extraction s...
#
# [389 rows x 15 columns]

# %%
production_table['value_tonnes'] =

# %% [markdown]
# ## Protected & Indigenous table

# %%
protected_mapping = {
    "WDPA_PID": "protected_area_id",
    "NAME": "land_name",
    "DESIG": "land_type",
    "STATUS_YR": "date"
}

indigenous_mapping = {
    "indigenous_land_id": "protected_area_id",
    "Name": "land_name",
    "Category": "land_type",
    "Data_Date": "date"
}

# %%
protected_clean = wpda_gdf_polygons.rename(columns=protected_mapping)[["protected_area_id", "land_name", "land_type", "distance_km", "geometry", "main_id"]].copy()

# %%
indigenous_clean = indigenous_can_gdf.rename(columns=indigenous_mapping)[["protected_area_id", "land_name", "land_type", "distance_km", "geometry", "main_id"]].copy()

# %%
target_crs = "EPSG:4326"
protected_clean = protected_clean.to_crs(target_crs)
indigenous_clean = indigenous_clean.to_crs(target_crs)

# %%
protected_land_table = pd.concat([protected_clean, indigenous_clean], ignore_index=True)
protected_land_table = gpd.GeoDataFrame(protected_land_table, geometry="geometry", crs=wpda_gdf_polygons.crs)

# %%
protected_land_table
# Out:
#      protected_area_id                                land_name  \
# 0                611_B     Wood Buffalo National Park Of Canada
# 1                  615            Banff National Park Of Canada
# 2                  616  Nahanni National Park Reserve Of Canada
# 3                  616  Nahanni National Park Reserve Of Canada
# 4                  620         Pukaskwa National Park Of Canada
# ...                ...                                      ...
# 8790   ZZ-IND-40a2ea30        Six Nations Indian Reserve No. 40
# 8791   ZZ-IND-40a2ea30        Six Nations Indian Reserve No. 40
# 8792   ZZ-IND-4e299f50                             Mashteuiatsh
# 8793   ZZ-IND-74ac0e34                                  Nisga'a
# 8794   ZZ-IND-74ac0e34                                  Nisga'a
#
#                        land_type  distance_km  \
# 0                  National Park       27.397
# 1                  National Park        2.153
# 2                  National Park        0.000
# 3                  National Park       31.820
# 4                  National Park       19.001
# ...                          ...          ...
# 8790              Indian Reserve       25.954
# 8791              Indian Reserve       20.924
# 8792              Indian Reserve       39.343
# 8793  First Nations Treaty Lands       16.458
# 8794  First Nations Treaty Lands       43.499
#
#                                                geometry           main_id
# 0     POLYGON ((-112.87253 59.99877, -115.58450 59.9...  NT-MAIN-b99d4cb2
# 1     POLYGON ((-117.30592 52.07417, -115.17460 51.2...  AB-MAIN-8434dce0
# 2     MULTIPOLYGON (((-124.02111 60.89056, -128.7980...  NT-MAIN-b3681e03
# 3     MULTIPOLYGON (((-124.02111 60.89056, -128.7980...  YT-MAIN-03a159d7
# 4     MULTIPOLYGON (((-86.25133 48.57798, -85.62889 ...  ON-MAIN-6e9be24e
# ...                                                 ...               ...
# 8790  MULTIPOLYGON Z (((-79.99308 43.08630 0.00003, ...  ON-MAIN-020a683c
# 8791  MULTIPOLYGON Z (((-79.99308 43.08630 0.00003, ...  ON-MAIN-b2e5c9bb
# 8792  MULTIPOLYGON Z (((-72.27116 48.58552 0.00003, ...  QC-MAIN-3aa117d8
# 8793  MULTIPOLYGON Z (((-129.07569 55.20853 0.00003,...  BC-MAIN-3ef4f421
# 8794  MULTIPOLYGON Z (((-129.07569 55.20853 0.00003,...  BC-MAIN-51068f3b
#
# [8795 rows x 6 columns]

# %% [markdown]
# ## Land cover table

# %%
land_cover_table = land_cover_gdf.copy()
land_cover_table['npv_biome_type'] = npv_gdf['biome_type']
land_cover_table['source_id'] = land_cover_table['source_id'].astype(str) + ';' + npv_gdf['source_id'].astype(str)

# %%
land_cover_table = assign_row_id(land_cover_table,
                                 facility_id_col='main_id', 
                                 prefix='land_cover_id')

# %%
land_cover_table.drop(columns=['name', 'geometry'], inplace=True)
land_cover_table.rename(columns={'row_id': 'land_cover_id'}, inplace=True)
land_cover_table = land_cover_table[['land_cover_id', 'main_id', 'year', 'modis_land_cover',
       'esa_land_cover', 'npv_biome_type', 'source_id']]

# %%
land_cover_table
# Out:
#                 land_cover_id           main_id  year  \
# 0    land_cover_id-5801b453-1  QC-MAIN-5801b453  2021
# 1    land_cover_id-d29e0839-1  QC-MAIN-d29e0839  2021
# 2    land_cover_id-f1ff4920-1  QC-MAIN-f1ff4920  2021
# 3    land_cover_id-4ea8ac9d-1  NU-MAIN-4ea8ac9d  2021
# 4    land_cover_id-e7e6a960-1  QC-MAIN-e7e6a960  2021
# ..                        ...               ...   ...
# 265  land_cover_id-c5fefb01-1  ON-MAIN-c5fefb01  2021
# 266  land_cover_id-feb13c30-1  BC-MAIN-feb13c30  2021
# 267  land_cover_id-5e0d8b48-1  YT-MAIN-5e0d8b48  2021
# 268  land_cover_id-12c68d49-1  ON-MAIN-12c68d49  2021
# 269  land_cover_id-891d3cb5-1  BC-MAIN-891d3cb5  2021
#
#                 modis_land_cover          esa_land_cover  \
# 0                 Woody Savannas                Built-up
# 1                 Woody Savannas  Bare/Sparse Vegetation
# 2                 Woody Savannas              Tree Cover
# 3                     Grasslands           Moss & Lichen
# 4                     Grasslands  Bare/Sparse Vegetation
# ..                           ...                     ...
# 265               Woody Savannas  Permanent Water Bodies
# 266               Woody Savannas              Tree Cover
# 267              Open Shrublands               Grassland
# 268               Woody Savannas               Grassland
# 269  Evergreen Needleleaf Forest              Tree Cover
#
#                        npv_biome_type  \
# 0                                None
# 1                   Cool Mixed Forest
# 2                   Cool Mixed Forest
# 3                                None
# 4                   Cool Mixed Forest
# ..                                ...
# 265                 Cool Mixed Forest
# 266  Cool Evergreen Needleleaf Forest
# 267  Cold Evergreen Needleleaf Forest
# 268                 Cool Mixed Forest
# 269  Cold Evergreen Needleleaf Forest
#
#                                              source_id
# 0    https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 1    https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 2    https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 3    https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 4    https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# ..                                                 ...
# 265  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 266  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 267  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 268  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 269  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
#
# [270 rows x 7 columns]

# %% [markdown]
# # Exports

# %% [markdown]
# ## Simple format

# %%
from matching_functions import export_sqlite_db

# %%
export_sqlite_db(
    "data/Tables/metallican.sqlite", 
    tables_dict={
    "main": main_gdf,
    "tailings": tailings_gdf,
    "mincan": min_can_gdf,
    "conflict": conflict_gdf,   
    "ghg": ghg_gdf,
    "pollution": pollutant_gdf,
    "climate_categories": climate_category_gdf,
    "peatland": peatland_gdf,
    "weather": weather_gdf,
    "population": population_gdf,
    "natural_potential_vegetation": npv_gdf,
    "land_cover": land_cover_gdf,
    "water_risk": water_risk_gdf,
    "land_occupation": tang_canada_gdf,
    "indigenous_land": indigenous_can_gdf,
    "protected_land": wpda_gdf_polygons,
    "lt_protected_land": matching_main_wpda,
    "lt_indigenous_land": matching_main_indigenous,
    "lt_clusters": lt_land_occupation
},
    keep_geometry_tables=['main', 'tailings'], 
    csv_dir='data/Tables/csv'
)
# Out:
# ✅ Exported 'main' → SQLite + CSV
# ✅ Exported 'tailings' → SQLite + CSV
# C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\canada_metal_sustainability_db\db_creation_function.py:607: UserWarning: Geometry column does not contain geometry.
#   df_export["geometry"] = df_export.geometry.to_wkt()
# C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\canada_metal_sustainability_db\db_creation_function.py:607: UserWarning: Geometry column does not contain geometry.
#   df_export["geometry"] = df_export.geometry.to_wkt()
# ✅ Exported 'mincan' → SQLite + CSV
# ✅ Exported 'conflict' → SQLite + CSV
# ✅ Exported 'ghg' → SQLite + CSV
# ✅ Exported 'pollution' → SQLite + CSV
# ✅ Exported 'climate_categories' → SQLite + CSV
# ✅ Exported 'peatland' → SQLite + CSV
# ✅ Exported 'weather' → SQLite + CSV
# ✅ Exported 'population' → SQLite + CSV
# ✅ Exported 'natural_potential_vegetation' → SQLite + CSV
# ✅ Exported 'land_cover' → SQLite + CSV
# ✅ Exported 'water_risk' → SQLite + CSV
# ✅ Exported 'land_occupation' → SQLite + CSV
# ✅ Exported 'indigenous_land' → SQLite + CSV
# ✅ Exported 'protected_land' → SQLite + CSV
# ✅ Exported 'lt_protected_land' → SQLite + CSV
# ✅ Exported 'lt_indigenous_land' → SQLite + CSV
# ✅ Exported 'lt_clusters' → SQLite + CSV
# ✅ All exports completed to SQLite and CSVs in: data/Tables/csv

# %% [markdown]
# ## More advanced setting

# %%
from matching_functions import create_and_populate_database

# %%
tables_dict = {
    "main": main_gdf,
    "tailings": tailings_gdf,
    "mincan": min_can_gdf,
    "conflict": conflict_gdf,
    "ghg": ghg_gdf,
    "pollution": pollutant_gdf,
    "climate_categories": climate_category_gdf,
    "weather": weather_gdf,
    "peatland": peatland_gdf,
    "population": population_gdf,
    "water_risk": water_risk_gdf,
    "land_cover": land_cover_gdf,
    "natural_potential_vegetation": npv_gdf,
    "indigenous_land": indigenous_can_gdf,
    "protected_land": wpda_gdf_polygons,
    "land_occupation": tang_canada_gdf
}

# Run the function
create_and_populate_database(
    db_path="data/Tables/metallican.sqlite",
    schema_path="schema.sql",
    tables_dict=tables_dict,
    keep_geometry_tables=["main", "tailings"]
)
# Out:
# ℹ️ No old database found at 'data/Tables/metallican.sqlite'
# ✅ Empty database structure created at 'data/Tables/metallican.sqlite'
# 🔄 Converting geometries...
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_25408\3645026473.py:68: UserWarning: Geometry column does not contain geometry.
#   df["geometry"] = df["geometry"].to_wkt()
# ✅ Geometries handled (kept only where needed)
# ✅ New connection opened
# ✅ Inserted 305 rows into 'main'
# ✅ Inserted 227 rows into 'tailings'
# ✅ Inserted 939 rows into 'mincan'
# ✅ Inserted 20 rows into 'conflict'
# ✅ Inserted 184 rows into 'ghg'
# ✅ Inserted 24130 rows into 'pollution'
# ✅ Inserted 2745 rows into 'climate_categories'
# ✅ Inserted 39040 rows into 'weather'
# ✅ Inserted 305 rows into 'peatland'
# ✅ Inserted 1220 rows into 'population'
# ✅ Inserted 9760 rows into 'water_risk'
# ✅ Inserted 305 rows into 'land_cover'
# ✅ Inserted 305 rows into 'natural_potential_vegetation'
# ✅ Inserted 3258 rows into 'indigenous_land'
# ✅ Inserted 13468 rows into 'protected_land'
# ✅ Inserted 1885 rows into 'land_occupation'
# ✅ No foreign key problems found!
# ✅ Connection closed properly
