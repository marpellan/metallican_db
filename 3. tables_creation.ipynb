# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %% [markdown]
# # Imports

# %%
main_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/main_gdf.parquet")
tailings_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/tailings_gdf.parquet")
min_can_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/min_can_gdf.parquet")
ctrace_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/ctrace_gdf.parquet")
conflict_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/conflict_gdf.parquet")
ghg_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/ghg_gdf.parquet")
pollutant_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/pollutant_gdf.parquet")
climate_category_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/climate_category_gdf.parquet")
weather_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/weather_gdf.parquet")
peatland_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/peatland_gdf.parquet")
prioritization_area_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/prioritization_area_gdf.parquet")
population_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/population_gdf.parquet")
water_risk_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/water_risk_gdf.parquet")
land_cover_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/land_cover_gdf.parquet")
npv_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/npv_gdf.parquet")
indigenous_can_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/indigenous_can_gdf.parquet")
wpda_gdf_polygons = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/wpda_gdf_polygons.parquet")
tang_canada_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/tang_canada_gdf.parquet")
li_canada_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/li_canada_gdf.parquet")

# %%
bth_df = pd.read_excel(r'data/Sources/Greffe_2024/BtH_mapped_sites.xlsx')

# %%
# From manually collected data
production_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Production')
reserves_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Reserves')
energy_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Energy')
env_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Env')
env_int_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Env_int')
archetypes_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Archetype')

# %%
from db_creation_function import assign_row_id_to_collected_data

# %%
# We need to assign row_ids to the manually collected data
production_df = assign_row_id_to_collected_data(production_df, 
                  facility_id_col='main_id',
                  prefix='PROD',
                  year_col='year'           
                  )

reserves_df = assign_row_id_to_collected_data(reserves_df, 
                  facility_id_col='main_id',
                  prefix='RES',
                  year_col='year'           
                  )

energy_df = assign_row_id_to_collected_data(energy_df, 
                  facility_id_col='main_id',
                  prefix='NRJ',
                  year_col='year'           
                  )

env_df = assign_row_id_to_collected_data(env_df, 
                  facility_id_col='main_id',
                  prefix='ENV',
                  year_col='year'           
                  )

env_int_df = assign_row_id_to_collected_data(env_int_df, 
                  facility_id_col='main_id',
                  prefix='ENV_INT',
                  year_col='year'           
                  )

archetypes_df = assign_row_id_to_collected_data(archetypes_df, 
                  facility_id_col='main_id',
                  prefix='ARCH',
                  )

# %% [markdown]
# # Create auxiliary tables

# %% [markdown]
# ## Source table

# %%
# For the main table
source_map = {
    "project": "https://open.canada.ca/data/en/dataset/22b2db8a-dc12-47f2-9737-99d3da921751",
    "mining": "https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720",
    "manufacturing": "https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720"
}
main_gdf["source_id"] = main_gdf["facility_type"].map(source_map)
main_gdf
# Out:
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# 2                None           Agnico Eagle Mines Limited
# 3        GRP-0a2c0d69           Agnico Eagle Mines Limited
# 4                None           Agnico Eagle Mines Limited
# ..                ...                                  ...
# 265              None              Wesdome Gold Mines Ltd.
# 266              None       West High Yield Resources Ltd.
# 267              None  Western Copper and Gold Corporation
# 268              None                                Wyloo
# 269              None                ZincX Resources Corp.
#
#                      company_name_folder    company_id   longitude   latitude  \
# 0                      Abcourt Mines Inc  CMP-0a6a3062  -77.679010  48.521540
# 1                      Abcourt Mines Inc  CMP-0a6a3062  -77.974340  49.132590
# 2             Agnico Eagle Mines Limited  CMP-6265c407  -77.580000  48.040000
# 3             Agnico Eagle Mines Limited  CMP-6265c407  -96.697000  65.415000
# 4             Agnico Eagle Mines Limited  CMP-6265c407  -78.130824  48.122223
# ..                                   ...           ...         ...        ...
# 265               Wesdome Gold Mines Ltd  CMP-3d2c4955  -85.452500  48.110280
# 266        West High Yield Resources Ltd  CMP-1023f9c0 -117.884000  49.082000
# 267  Western Copper and Gold Corporation  CMP-2dac9896 -138.833330  62.733330
# 268                                Wyloo  CMP-65b36728  -86.303800  52.742020
# 269                 ZincX Resources Corp  CMP-3416049b -124.865990  57.380880
#
#                         geometry  ...          province            status  \
# 0     POINT (-77.67901 48.52154)  ...            Quebec  project_facility
# 1     POINT (-77.97434 49.13259)  ...            Quebec   active_facility
# 2     POINT (-77.58000 48.04000)  ...            Quebec  project_facility
# 3     POINT (-96.69700 65.41500)  ...           Nunavut   active_facility
# 4     POINT (-78.13082 48.12222)  ...            Quebec   active_facility
# ..                           ...  ...               ...               ...
# 265   POINT (-85.45250 48.11028)  ...           Ontario   active_facility
# 266  POINT (-117.88400 49.08200)  ...  British Columbia  project_facility
# 267  POINT (-138.83333 62.73333)  ...             Yukon  project_facility
# 268   POINT (-86.30380 52.74202)  ...           Ontario  project_facility
# 269  POINT (-124.86599 57.38088)  ...  British Columbia  project_facility
#
#     activity_status development_stage facility_type  mining_processing_type  \
# 0            Active  Advanced project       project                    None
# 1              None              None        mining            Concentrator
# 2            Active  Advanced project       project                    None
# 3              None              None        mining   Open-pit, underground
# 4              None              None        mining  Open-pit, concentrator
# ..              ...               ...           ...                     ...
# 265            None              None        mining                Open-pit
# 266          Active  Advanced project       project                    None
# 267          Active  Advanced project       project                    None
# 268          Active  Advanced project       project                    None
# 269          Active  Advanced project       project                    None
#
#      commodity_group primary_commodity  \
# 0               None              Zinc
# 1    Precious metals              Gold
# 2               None              Gold
# 3    Precious metals              Gold
# 4    Precious metals              Gold
# ..               ...               ...
# 265  Precious metals              Gold
# 266             None         Magnesium
# 267             None            Copper
# 268             None            Nickel
# 269             None              Zinc
#
#                                    commodities  \
# 0                                 Zinc, silver
# 1                                 Gold, silver
# 2                                 Gold, copper
# 3                                         Gold
# 4                                 Gold, silver
# ..                                         ...
# 265                                       Gold
# 266                                  Magnesium
# 267           Copper, gold, molybdenum, silver
# 268  Nickel, copper, gold, platinum, palladium
# 269                         Zinc, lead, silver
#
#                                              source_id
# 0    https://open.canada.ca/data/en/dataset/22b2db8...
# 1    https://open.canada.ca/data/en/dataset/000183e...
# 2    https://open.canada.ca/data/en/dataset/22b2db8...
# 3    https://open.canada.ca/data/en/dataset/000183e...
# 4    https://open.canada.ca/data/en/dataset/000183e...
# ..                                                 ...
# 265  https://open.canada.ca/data/en/dataset/000183e...
# 266  https://open.canada.ca/data/en/dataset/22b2db8...
# 267  https://open.canada.ca/data/en/dataset/22b2db8...
# 268  https://open.canada.ca/data/en/dataset/22b2db8...
# 269  https://open.canada.ca/data/en/dataset/22b2db8...
#
# [270 rows x 21 columns]

# %%
# For the datasets
tailings_gdf["source_id"] = 'https://tailing.grida.no/'
min_can_gdf["source_id"] = '10.1038/s41597-024-03116-3'
ctrace_gdf["source_id"] = 'Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory'
conflict_gdf["source_id"] = 'http://journals.librarypublishing.arizona.edu/jpe/article/id/1932/'
ghg_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/greenhouse-gas-emissions/large-facilities.html'
pollutant_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html' 
prioritization_area_gdf['source_id'] = 'https://doi.org/10.5281/zenodo.5006332'
climate_category_gdf['source_id'] = 'https://doi.org/10.1038/s41597-023-02549-6'
weather_gdf['source_id'] = 'https://climate-scenarios.canada.ca/?page=CanDCS6-indices'
peatland_gdf['source_id'] = 'https://greifswaldmoor.de/global-peatland-database-en.html'
population_gdf['source_id'] = 'https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F40-C41DA8332CFE' 
water_risk_gdf['source_id'] = 'https://www.wri.org/data/aqueduct-global-maps-40-data'
land_cover_gdf['source_id'] = 'https://doi.org/10.5067/MODIS/MCD12Q1.061 + https://doi.org/10.5281/zenodo.7254221'
npv_gdf['source_id'] = 'https://doi.org/10.7717/peerj.5457'
indigenous_can_gdf['source_id'] = 'http://www.landmarkmap.org'
wpda_gdf_polygons['source_id'] = 'https://www.protectedplanet.net'
tang_canada_gdf['source_id'] = 'https://doi.org/10.1038/s43247-023-00805-6'
#maus_canada_gdf['source_id'] = 'https://doi.org/10.1038/s41597-022-01547-4'
li_canada_gdf['source_id'] = 'https://www.nature.com/articles/s41597-025-05296-y'
bth_df['source_id'] = 'https://pubs.acs.org/doi/10.1021/acs.est.4c05293'

# %%
from db_creation_function import add_source_id_to_collected_data

# %%
production_df = add_source_id_to_collected_data(production_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

reserves_df = add_source_id_to_collected_data(reserves_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

energy_df = add_source_id_to_collected_data(energy_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

env_df = add_source_id_to_collected_data(env_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

env_int_df = add_source_id_to_collected_data(env_int_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

archetypes_df = add_source_id_to_collected_data(archetypes_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

# %%
from db_creation_function import create_source_table_from_datasets

# %%
dataset_dict = {
    "Global Tailings Portal": tailings_gdf,
    "A Comprehensive Historical and Geolocalized Database of Mining Activities in Canada": min_can_gdf,
    "ClimateTRACE mineral extraction sector": ctrace_gdf,
    "Environmental Justice Atlas": conflict_gdf,
    "GHG from large facilities": ghg_gdf,
    "National Pollutant Inventory Report (NPRI)": pollutant_gdf,
    "Areas of global importance for conserving terrestrial biodiversity, carbon and water": prioritization_area_gdf,
    "High-Resolution (1 km) Koppen-Geiger Maps for 1901–2099 Based on Constrained CMIP6 Projections": climate_category_gdf,
    "CMIP6 statistically downscaled climate indices (CanDCS-M6)": weather_gdf,
    "Global Peatland Database": peatland_gdf,
    "Global Human Settlement Layer (GHSL)": population_gdf,
    "Aqueduct 4.0": water_risk_gdf,
    "Modis Land Cover and ESA World Cover": land_cover_gdf,
    "Potential Natural Vegetation (NPV)": npv_gdf,
    "Indigenous Peoples’ and Local Community Lands and Territories": indigenous_can_gdf,
    "World Database on Protected Areas (WDPA)": wpda_gdf_polygons,
    "Global Mining Footprint Mapped from High-Resolution Satellite Imagery": tang_canada_gdf,
    "Machine learning-enhanced monitoring of global copper mining areas": li_canada_gdf,
    "Byproduct-to-Host Ratios for Assessing the Accessibility of Mineral Resources": bth_df,
}

manual_dfs = [production_df, reserves_df, energy_df, env_df, env_int_df, archetypes_df] 

source_table = create_source_table_from_datasets(dataset_dict, manual_dfs)

# %%
source_table
# Out:
#                                              source_id source_provenance  \
# 0                            https://tailing.grida.no/           dataset
# 18    https://pubs.acs.org/doi/10.1021/acs.est.4c05293           dataset
# 17   https://www.nature.com/articles/s41597-025-052...           dataset
# 16          https://doi.org/10.1038/s43247-023-00805-6           dataset
# 15                     https://www.protectedplanet.net           dataset
# ..                                                 ...               ...
# 84   SRC_BaffinlandIronMinesCorporation_4q24-analys...            report
# 85            SRC_BarrickGoldCorporation_Reserves_2024            report
# 86   SRC_BurgundyDiamondMines_2024-Annual-Mineral-R...            report
# 76   SRC_SherrittInternationalCorporationandGeneral...            report
# 258                        SRC_WesdomeGoldMinesLtd_MDO            report
#
#                                            source_name
# 0                               Global Tailings Portal
# 18   Byproduct-to-Host Ratios for Assessing the Acc...
# 17   Machine learning-enhanced monitoring of global...
# 16   Global Mining Footprint Mapped from High-Resol...
# 15            World Database on Protected Areas (WDPA)
# ..                                                 ...
# 84           4q24-analyst-model-with-factbook-app.xlsx
# 85                                       Reserves_2024
# 86   2024-Annual-Mineral-Resouces-and-Ore-Reserves-...
# 76                                         TR_2023.pdf
# 258                                                MDO
#
# [205 rows x 3 columns]

# %%
source_table.to_csv(r'database/CSV/sources_table.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Substance table

# %%
from db_creation_function import create_substance_table

# %%
substance_table = create_substance_table(pollutant_gdf, env_df)

# %%
substance_table
# Out:
#       substance_id                 harmonized_name  \
# 0    SUB07971a0766          1,2,4-Trimethylbenzene
# 1    SUBbdfdffeb95                   1-Nitropyrene
# 2    SUB0f01e7c1d0                 2-Butoxyethanol
# 3    SUB324959500a  7,12-Dimethylbenz[a]anthracene
# 4    SUBfee6b26acd        7H-Dibenzo[c,g]carbazole
# ..             ...                             ...
# 169  SUB787e5ac1a2    Vanadium (and its compounds)
# 170  SUBe849a2ff09            Xylene (all isomers)
# 171  SUBae95939c3f        Zinc (and its compounds)
# 172  SUB090a1237c1                 i-Butyl alcohol
# 173  SUBd049575022                        n-Hexane
#
#                       original_name source
# 0            1,2,4-Trimethylbenzene   NPRI
# 1                     1-Nitropyrene   NPRI
# 2                   2-Butoxyethanol   NPRI
# 3    7,12-Dimethylbenz[a]anthracene   NPRI
# 4          7H-Dibenzo[c,g]carbazole   NPRI
# ..                              ...    ...
# 169    Vanadium (and its compounds)   NPRI
# 170            Xylene (all isomers)   NPRI
# 171        Zinc (and its compounds)   NPRI
# 172                 i-Butyl alcohol   NPRI
# 173                        n-Hexane   NPRI
#
# [174 rows x 4 columns]

# %%
pollutant_gdf = pollutant_gdf.merge(
    substance_table[['substance_id', 'original_name']],
    how='left',
    left_on='substance_name_npri',
    right_on='original_name'
).drop(columns='original_name')

# %%
pollutant_gdf
# Out:
#                   row_id  year  npri_id     facility_name_npri  \
# 0       npri-1568-2023-1  2023     1568           Macassa Mine
# 1       npri-1568-2023-2  2023     1568           Macassa Mine
# 2       npri-1568-2023-3  2023     1568           Macassa Mine
# 3       npri-1568-2023-4  2023     1568           Macassa Mine
# 4       npri-1568-2023-5  2023     1568           Macassa Mine
# ...                  ...   ...      ...                    ...
# 24125   npri-5697-2023-6  2023     5697  Rayette Manufacturing
# 24126   npri-5698-2023-6  2023     5698    Bowes Manufacturing
# 24127  npri-34697-2023-2  2023    34697    541 Bowes Warehouse
# 24128   npri-5697-2023-7  2023     5697  Rayette Manufacturing
# 24129   npri-5698-2023-7  2023     5698    Bowes Manufacturing
#
#         company_name_npri  facility_type  longitude  latitude  \
# 0      Agnico Eagle Mines         mining  -80.08734  48.13032
# 1      Agnico Eagle Mines         mining  -80.08734  48.13032
# 2      Agnico Eagle Mines         mining  -80.08734  48.13032
# 3      Agnico Eagle Mines         mining  -80.08734  48.13032
# 4      Agnico Eagle Mines         mining  -80.08734  48.13032
# ...                   ...            ...        ...       ...
# 24125                None  manufacturing  -79.49600  43.80800
# 24126                None  manufacturing  -79.49480  43.80360
# 24127                None  manufacturing  -79.49707  43.81726
# 24128                None  manufacturing  -79.49600  43.80800
# 24129                None  manufacturing  -79.49480  43.80360
#
#       terrestrial_ecozone                   watershed  \
# 0           Boreal Shield  St. Lawrence Drainage Area
# 1           Boreal Shield  St. Lawrence Drainage Area
# 2           Boreal Shield  St. Lawrence Drainage Area
# 3           Boreal Shield  St. Lawrence Drainage Area
# 4           Boreal Shield  St. Lawrence Drainage Area
# ...                   ...                         ...
# 24125     Mixedwood Plain  St. Lawrence Drainage Area
# 24126     Mixedwood Plain  St. Lawrence Drainage Area
# 24127     Mixedwood Plain  St. Lawrence Drainage Area
# 24128     Mixedwood Plain  St. Lawrence Drainage Area
# 24129     Mixedwood Plain  St. Lawrence Drainage Area
#
#                               substance_name_npri substance_name_ecoinvent  \
# 0                                 Ammonia (total)                  Ammonia
# 1                     Arsenic (and its compounds)                  Arsenic
# 2                                 Carbon monoxide  Carbon monoxide, fossil
# 3                    Chromium (and its compounds)                 Chromium
# 4                      Cobalt (and its compounds)                   Cobalt
# ...                                           ...                      ...
# 24125  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24126  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24127  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24128          Volatile Organic Compounds (Total)                     None
# 24129          Volatile Organic Compounds (Total)                     None
#
#       substance_unit                      emission_type  \
# 0             tonnes  Air Emissions / Émissions à l'air
# 1                 kg  Air Emissions / Émissions à l'air
# 2             tonnes  Air Emissions / Émissions à l'air
# 3             tonnes  Air Emissions / Émissions à l'air
# 4                 kg  Air Emissions / Émissions à l'air
# ...              ...                                ...
# 24125         tonnes                        Grand Total
# 24126         tonnes                        Grand Total
# 24127         tonnes                        Grand Total
# 24128         tonnes                        Grand Total
# 24129         tonnes                        Grand Total
#
#                                         emission_subtype      value  \
# 0                                        Stack Emissions      0.636
# 1                                        Stack Emissions      0.116
# 2                                        Stack Emissions     76.208
# 3                                        Stack Emissions    0.00105
# 4                                        Stack Emissions       0.18
# ...                                                  ...        ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008
# 24126  Total Releases, Disposals and Transfers for Re...     23.418
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719
#
#                                                source_id  \
# 0      https://www.canada.ca/en/environment-climate-c...
# 1      https://www.canada.ca/en/environment-climate-c...
# 2      https://www.canada.ca/en/environment-climate-c...
# 3      https://www.canada.ca/en/environment-climate-c...
# 4      https://www.canada.ca/en/environment-climate-c...
# ...                                                  ...
# 24125  https://www.canada.ca/en/environment-climate-c...
# 24126  https://www.canada.ca/en/environment-climate-c...
# 24127  https://www.canada.ca/en/environment-climate-c...
# 24128  https://www.canada.ca/en/environment-climate-c...
# 24129  https://www.canada.ca/en/environment-climate-c...
#
#                          geometry   substance_id
# 0      POINT (-80.08734 48.13032)  SUB1c6e015419
# 1      POINT (-80.08734 48.13032)  SUB0cbc90a094
# 2      POINT (-80.08734 48.13032)  SUB642eab0862
# 3      POINT (-80.08734 48.13032)  SUB7e3f017a30
# 4      POINT (-80.08734 48.13032)  SUBd94d47b1d8
# ...                           ...            ...
# 24125  POINT (-79.49600 43.80800)  SUBb215244183
# 24126  POINT (-79.49480 43.80360)  SUBb215244183
# 24127  POINT (-79.49707 43.81726)  SUBb215244183
# 24128  POINT (-79.49600 43.80800)  SUB8319f60a2f
# 24129  POINT (-79.49480 43.80360)  SUB8319f60a2f
#
# [24130 rows x 19 columns]

# %%
env_df = env_df.merge(
    substance_table[['substance_id', 'original_name']],
    how='left',
    left_on='substance_name',
    right_on='original_name'
).drop(columns='original_name')

# %%
env_int_df = env_int_df.merge(
    substance_table[['substance_id', 'original_name']],
    how='left',
    left_on='substance_name',
    right_on='original_name'
).drop(columns='original_name')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# For CTrace and GHG datasets, we create a substance_id column = NaN because we do not have substance names, only flow_tyoe
ctrace_gdf['substance_id'] = np.nan
ghg_gdf['substance_id'] = np.nan

# %%
substance_table = substance_table.rename(columns={'harmonized_name': 'substance_name'})
substance_table = substance_table[['substance_id', 'substance_name']]

# %%
substance_table.to_csv(r'database/CSV/substances_table.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Compartment table

# %%
pollutant_gdf[pollutant_gdf['emission_type'] == 'Water Releases / Rejets à l\'eau']['emission_subtype'].unique()
# Out:
# array(['Direct Discharge', 'Total', 'Receiving Waterbody (English)',
#        'Receiving Waterbody (French)', 'Spills'], dtype=object)

# %%
# Change the value to 'None' for emission_subtype when emission_type = 'Water Releases / Rejets à l'eau' and 'emission_subtype' is 'Receiving Waterbody (English)' or 'Receiving Waterbody (French)'
pollutant_gdf.loc[
    (pollutant_gdf['emission_type'] == 'Water Releases / Rejets à l\'eau') & 
    (pollutant_gdf['emission_subtype'].isin(['Receiving Waterbody (English)', 'Receiving Waterbody (French)'])),
    'emission_subtype'
] = None

# %%
from db_creation_function import create_compartment_table

# %%
compartment_table = create_compartment_table(pollutant_gdf, env_df)

# %%
pollutant_gdf = pollutant_gdf.merge(
    compartment_table[[
        'compartment_id', 'raw_compartment_label', 'raw_pathway_label'
    ]],
    how='left',
    left_on=['emission_type', 'emission_subtype'],
    right_on=['raw_compartment_label', 'raw_pathway_label']
).drop(columns=['raw_compartment_label', 'raw_pathway_label'])

# %%
env_df['compartment_pathway'] = 'Unspecified'
env_df = env_df.merge(
    compartment_table[[
        'compartment_id', 'raw_compartment_label', 'raw_pathway_label'
    ]],
    how='left',
    left_on=['compartment', 'compartment_pathway'],
    right_on=['raw_compartment_label', 'raw_pathway_label']
).drop(columns=['raw_compartment_label', 'raw_pathway_label'])

# %%
env_int_df['compartment_pathway'] = 'Unspecified'
env_int_df = env_int_df.merge(
    compartment_table[[
        'compartment_id', 'raw_compartment_label', 'raw_pathway_label'
    ]],
    how='left',
    left_on=['compartment', 'compartment_pathway'],
    right_on=['raw_compartment_label', 'raw_pathway_label']
).drop(columns=['raw_compartment_label', 'raw_pathway_label'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# For CTrace and GHG datasets, we assign the compartment_id corresponding to 'Air' and 'Unspecified' pathway
ctrace_gdf['compartment_id'] = 'CMPf3265e9fca'
ghg_gdf['compartment_id'] = 'CMPf3265e9fca'

# %%
compartment_table = compartment_table.rename(columns={'compartment': 'compartment_name'})
compartment_table = compartment_table[['compartment_id', 'compartment_name', 'compartment_pathway']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
compartment_table = compartment_table.drop_duplicates().reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
compartment_table.to_csv(r'database/CSV/compartments_table.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Matching

# %% [markdown]
# ## Point to point matching

# %%
from matching_functions import match_facilities, one_to_many_relationships

# %% [markdown]
# ### MinCan

# %%
# Let's keep only Active mines
min_can_gdf = min_can_gdf[min_can_gdf['mine_status'] == 'Active'].copy()

# %% [markdown]
# Some mines in MinCan dataset have very slightly different name (e.g. LaRonde - Zone 5 and LaRonde), the same name but one without town (e.g. Detour Lake) or several companies for the same mines.

# %%
# min_can_id = ON-MINCAN-6316d452 = Detour Lake = 2013 - open
# min_can_id = ON-MINCAN-7b832414 = Detour Lake = 1983 - open
# min_can_id = QC-MINCAN-775312a1 = LaRonde - Zone 5 = 2018 - open
# min_can_id = QC-MINCAN-8321e85e = LaRonde = 1988 - open

# %%
# We delete the duplicates, aligned with information from MDO for Detour Lake and LaRonde
min_can_gdf = min_can_gdf[~min_can_gdf['mincan_id'].isin(['ON-MINCAN-6316d452', 'QC-MINCAN-775312a1'])].copy()

# %%
min_can_gdf
# Out:
#               mincan_id               namemine                       town  \
# 7    ON-MINCAN-ccf2bf99                  Haley                     Haley
# 13   NB-MINCAN-63ccd128    Stratmat (Halfmile)                       None
# 18   ON-MINCAN-9abb16ea       Calcite Division                      Perth
# 23   QC-MINCAN-06b1f129    Parent Mica Deposit                      Suzor
# 24   QC-MINCAN-227d3d18             Charlevoix  Charlevoix (Saint-Urbain)
# ..                  ...                    ...                        ...
# 923  BC-MINCAN-d8cf3b3a                   None               Fort Langley
# 924  AB-MINCAN-bab4efd2                   None                     Exshaw
# 927  SK-MINCAN-2aefa179                   None                Hudson Bay
# 935  NT-MINCAN-ea720725  Panda (Ekati Project)                Lac de Gras
# 936  QC-MINCAN-8f0f7e05               Ardorbec                  Danville
#
#                   province   latitude   longitude  \
# 7                  Ontario  45.598880  -76.751710
# 13           New Brunswick  47.305278  -66.320000
# 18                 Ontario  45.149689  -76.498756
# 23                  Quebec  47.938412  -74.634602
# 24                  Quebec  47.749900  -70.696711
# ..                     ...        ...         ...
# 923       British Columbia  49.189659 -122.660599
# 924                Alberta  51.071389 -115.135199
# 927           Saskatchewan  52.985830 -101.744038
# 935  Northwest Territories  64.716667 -110.608333
# 936                 Quebec  45.748462  -71.961305
#
#                          commodityall  \
# 7                           Magnesium
# 13   Zinc, Lead, Copper, Gold, Silver
# 18                  Calcium Carbonate
# 23                               Mica
# 24                             Silica
# ..                                ...
# 923                              Lime
# 924                              Lime
# 927                            Silica
# 935                           Diamond
# 936                         Magnesium
#
#                                            information mine_status  \
# 7                                                 None      Active
# 13                            indigenous participation      Active
# 18                                                None      Active
# 23   Changed name in Lacana Mines Inc. "In late 198...      Active
# 24                                                None      Active
# ..                                                 ...         ...
# 923                                               None      Active
# 924                                               None      Active
# 927  small scale /// Lower Cretaceous Mannville Gro...      Active
# 935                Brief closure between 2020 and 2021      Active
# 936                                               None      Active
#
#                         geometry operation_periods                   source_id
# 7     POINT (-76.75171 45.59888)         1942–open  10.1038/s41597-024-03116-3
# 13    POINT (-66.32000 47.30528)         1951–open  10.1038/s41597-024-03116-3
# 18    POINT (-76.49876 45.14969)         1962–open  10.1038/s41597-024-03116-3
# 23    POINT (-74.63460 47.93841)         1976–open  10.1038/s41597-024-03116-3
# 24    POINT (-70.69671 47.74990)         1977–open  10.1038/s41597-024-03116-3
# ..                           ...               ...                         ...
# 923  POINT (-122.66060 49.18966)         1991–open  10.1038/s41597-024-03116-3
# 924  POINT (-115.13520 51.07139)         1991–open  10.1038/s41597-024-03116-3
# 927  POINT (-101.74404 52.98583)         1993–open  10.1038/s41597-024-03116-3
# 935  POINT (-110.60833 64.71667)         1997–open  10.1038/s41597-024-03116-3
# 936   POINT (-71.96130 45.74846)         1998–open  10.1038/s41597-024-03116-3
#
# [167 rows x 12 columns]

# %%
lt_main_mincan = match_facilities(main_gdf, min_can_gdf,
                     id_col1='main_id', id_col2='mincan_id',
                     name_col1='facility_name', name_col2='namemine'
                     )

# %%
matches_main_mincan = one_to_many_relationships(
    lt_main_mincan,
    id_main_col='main_id',
    id_sat_col='mincan_id',
    distance_threshold_m=2000,
    similarity_threshold=80,
    similarity_metric="token_set"  
)

# %%
min_can_gdf = min_can_gdf.merge(
    matches_main_mincan,
    on="mincan_id", 
    how="left"
)

# %%
# For SQL
min_can_gdf = min_can_gdf[min_can_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["mincan_id", "main_id", "mine_status", "operation_periods"]
min_can_gdf = min_can_gdf[col_to_keep]
min_can_gdf
# Out:
#               mincan_id           main_id mine_status  \
# 11   QC-MINCAN-494c7715  QC-MAIN-9de9bb0d      Active
# 21   BC-MINCAN-8cc41b53  BC-MAIN-6b4800fe      Active
# 28   QC-MINCAN-8321e85e  QC-MAIN-e51eda66      Active
# 29   ON-MINCAN-97f916de  ON-MAIN-c5fefb01      Active
# 31   ON-MINCAN-49811fe2  ON-MAIN-687b8c8d      Active
# 34   QC-MINCAN-44904232  QC-MAIN-c0660aec      Active
# 39   NU-MINCAN-1d9e43a7  NU-MAIN-730aefe3      Active
# 41   ON-MINCAN-643672f4  ON-MAIN-f3e6ff08      Active
# 42   SK-MINCAN-5ac4b2dd  SK-MAIN-22ce14be      Active
# 44   BC-MINCAN-72fabc94  BC-MAIN-aa76f6f2      Active
# 47   MB-MINCAN-15965632  MB-MAIN-be5b3dc8      Active
# 48   ON-MINCAN-07ece30d  ON-MAIN-28f3f0fc      Active
# 51   BC-MINCAN-4eaf1f96  BC-MAIN-ed23117f      Active
# 53   QC-MINCAN-1c16c912  QC-MAIN-6dc537e6      Active
# 54   BC-MINCAN-496a2682  BC-MAIN-8eb8be0d      Active
# 55   SK-MINCAN-7501c939  SK-MAIN-91cf5448      Active
# 56   QC-MINCAN-72adc1b6  QC-MAIN-3032c251      Active
# 57   NS-MINCAN-21b5fbce  NS-MAIN-c9c77a59      Active
# 58   ON-MINCAN-ddd10f1c  ON-MAIN-0aadf28f      Active
# 60   BC-MINCAN-492cfeba  BC-MAIN-857b7b89      Active
# 61   NT-MINCAN-ecb9b239  NT-MAIN-94e652a5      Active
# 64   ON-MINCAN-079b81a1  ON-MAIN-f4fc3276      Active
# 66   ON-MINCAN-b94b1f25  ON-MAIN-1c674cd0      Active
# 68   QC-MINCAN-a6cbac08  QC-MAIN-b8c826a2      Active
# 69   NU-MINCAN-6ca88e12  NU-MAIN-8b0264c9      Active
# 70   YT-MINCAN-8fada64a  YT-MAIN-e05ed9fe      Active
# 71   NU-MINCAN-4efe1cae  NU-MAIN-4ea8ac9d      Active
# 80   NL-MINCAN-d8d4cf69  NL-MAIN-2d8801d6      Active
# 84   QC-MINCAN-6f83c124  QC-MAIN-e7e6a960      Active
# 87   QC-MINCAN-a6163f93  QC-MAIN-d29e0839      Active
# 91   QC-MINCAN-548f03a9  QC-MAIN-084bd95c      Active
# 92   QC-MINCAN-cf418fe9  QC-MAIN-b86f7d07      Active
# 95   QC-MINCAN-a90e8433  QC-MAIN-a97821c0      Active
# 102  BC-MINCAN-14ce4b06  BC-MAIN-599152a0      Active
# 103  ON-MINCAN-8c35080f  ON-MAIN-7607a50e      Active
# 104  ON-MINCAN-838ef03f  ON-MAIN-206041d1      Active
# 105  BC-MINCAN-595f5049  BC-MAIN-23155c25      Active
# 114  ON-MINCAN-cf9a5c80  ON-MAIN-1f126a43      Active
# 125  QC-MINCAN-13530c4c  QC-MAIN-649d2873      Active
# 130  ON-MINCAN-1c3b8f14  ON-MAIN-cb85213a      Active
# 132  ON-MINCAN-7b832414  ON-MAIN-aeafbb59      Active
# 140  ON-MINCAN-69e999a0  ON-MAIN-fefeaee4      Active
# 143  ON-MINCAN-fc444118  ON-MAIN-7f050560      Active
# 149  ON-MINCAN-08e05315  ON-MAIN-f8313ebd      Active
# 157  ON-MINCAN-7b29d7b3  ON-MAIN-bfbcd72e      Active
#
#                    operation_periods
# 11   1936–1996; 2005–2013; 2021–open
# 21              1972–1998; 2004–open
# 28                         1988–open
# 29                         2002–open
# 31                         2007–open
# 34              2008–2011; 2013–open
# 39                         2010–open
# 41                         2011–open
# 42                         2011–open
# 44                         2012–open
# 47                         2013–open
# 48                         2014–open
# 51                         2014–open
# 53                         2015–open
# 54                         2015–open
# 55                         2015–open
# 56                         2016–open
# 57                         2017–open
# 58                         2017–open
# 60                         2017–open
# 61                         2017–open
# 64                         2018–open
# 66                         2019–open
# 68                         2019–open
# 69                         2019–open
# 70                         2019–open
# 71                         2019–open
# 80                         2005–open
# 84              1935–1965; 2011–open
# 87   1956–1959; 1974–1975; 1988–open
# 91                         1976–open
# 92              1988–1991; 1993–open
# 95                         1998–open
# 102             1884–1958; 2011–open
# 103             1917–1957; 2010–open
# 104  1962–1991; 2007–2009; 2010–open
# 105  1966–1985; 2002–2015; 2019–open
# 114             1933–1999; 2002–open
# 125                        1976–open
# 130                        1983–open
# 132                        1983–open
# 140                        1997–open
# 143                        1949–open
# 149                        1963–open
# 157             1987–1994; 2012–open

# %% [markdown]
# ### CTrace

# %%
lt_main_ctrace = match_facilities(main_gdf, ctrace_gdf,
                     id_col1='main_id', id_col2='ctrace_id',
                     name_col1='facility_name', name_col2='source_name'
                     )

# %%
matches_main_ctrace = one_to_many_relationships(
    lt_main_ctrace,
    id_main_col='main_id',
    id_sat_col='ctrace_id',
    distance_threshold_m=2000,
    similarity_threshold=80,
    similarity_metric="token_set"  
)

# %%
ctrace_gdf = ctrace_gdf.merge(
    matches_main_ctrace,
    on="ctrace_id", 
    how="left"
)

# %%
# For SQL
ctrace_gdf = ctrace_gdf[ctrace_gdf["main_id"].notna()].copy()

# %%
ctrace_gdf.columns
# Out:
# Index(['ctrace_id', 'year', 'source_name', 'emissions_quantity', 'gas',
#        'activity', 'activity_units', 'capacity', 'capacity_units', 'latitude',
#        'longitude', 'geometry', 'source_id', 'substance_id', 'compartment_id',
#        'main_id'],
#       dtype='object')

# %%
col_to_keep = [
'ctrace_id', 
'year',
'emissions_quantity', 
'gas',
'activity', 'activity_units', 
'capacity', 'capacity_units', 
'source_id',  'substance_id', 'compartment_id',
'main_id'           
]
ctrace_gdf = ctrace_gdf[col_to_keep]
ctrace_gdf
# Out:
#     ctrace_id  year  emissions_quantity         gas      activity  \
# 6     1754055  2023        5.610000e+03  co2e_100yr  8.630000e+05
# 7     1754056  2023        6.403000e+03  co2e_100yr  9.850000e+05
# 8     1754057  2023        2.299160e+05  co2e_100yr  1.457500e+07
# 9     1754058  2023        2.639000e+03  co2e_100yr  4.060000e+05
# 11    1754060  2023        4.225000e+03  co2e_100yr  6.500000e+05
# 12    1754061  2023        1.316380e+05  co2e_100yr  8.810000e+07
# 16    1754066  2023        2.412130e+06  co2e_100yr  7.288600e+07
# 17    1754067  2023        0.000000e+00  co2e_100yr  0.000000e+00
# 25    1754077  2023        6.711600e+04  co2e_100yr  1.501481e+06
# 29    1754081  2023        7.782000e+03  co2e_100yr  5.279710e+05
# 30    1754082  2023        0.000000e+00  co2e_100yr  0.000000e+00
# 31    1754083  2023        0.000000e+00  co2e_100yr  0.000000e+00
# 32    1754084  2023        7.956600e+04  co2e_100yr  2.127800e+07
# 33    1754085  2023        7.137900e+04  co2e_100yr  5.948239e+06
# 34    1754086  2023        5.400000e+02  co2e_100yr  4.500000e+04
# 35    1754087  2023        1.590800e+04  co2e_100yr  2.993000e+06
# 43    1754096  2023        8.219000e+03  co2e_100yr  6.848790e+05
# 44    1754097  2023        8.451100e+04  co2e_100yr  6.887709e+06
# 51    1754104  2023        3.367000e+03  co2e_100yr  5.180000e+05
# 52    1754105  2023        0.000000e+00  co2e_100yr  0.000000e+00
# 54   25486533  2023        1.620000e+04  co2e_100yr  1.350000e+06
# 55   25486534  2023        5.914500e+04  co2e_100yr  3.798000e+06
# 56   36395102  2023        5.760720e+05  co2e_100yr  1.578280e+07
#
#      activity_units      capacity capacity_units  \
# 6   t of copper ore  4.624000e+06         tonnes
# 7   t of copper ore  3.554700e+07         tonnes
# 8   t of copper ore  3.670000e+08         tonnes
# 9   t of copper ore  1.104100e+07         tonnes
# 11  t of copper ore  4.822000e+06         tonnes
# 12  t of copper ore  6.450000e+08         tonnes
# 16  t of copper ore  2.631000e+08         tonnes
# 17  t of copper ore  8.787959e+07         tonnes
# 25  t of copper ore  1.988200e+07         tonnes
# 29  t of copper ore  8.787959e+07         tonnes
# 30  t of copper ore  7.413000e+06         tonnes
# 31  t of copper ore  2.313000e+06         tonnes
# 32  t of copper ore  2.500250e+08         tonnes
# 33  t of copper ore  4.902900e+07         tonnes
# 34  t of copper ore  4.110000e+06         tonnes
# 35  t of copper ore  3.408700e+07         tonnes
# 43  t of copper ore  1.500000e+07         tonnes
# 44  t of copper ore  4.549000e+08         tonnes
# 51  t of copper ore  2.453000e+06         tonnes
# 52  t of copper ore  8.787959e+07         tonnes
# 54  t of copper ore  2.500000e+06         tonnes
# 55  t of copper ore  2.200000e+07         tonnes
# 56    t of iron ore  4.789430e+08         tonnes
#
#                                             source_id  substance_id  \
# 6   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 7   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 8   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 9   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 11  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 12  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 16  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 17  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 25  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 29  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 30  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 31  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 32  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 33  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 34  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 35  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 43  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 44  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 51  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 52  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 54  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 55  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 56  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
#
#    compartment_id           main_id
# 6   CMPf3265e9fca  ON-MAIN-6e9b2449
# 7   CMPf3265e9fca  ON-MAIN-63b394c3
# 8   CMPf3265e9fca  BC-MAIN-599152a0
# 9   CMPf3265e9fca  ON-MAIN-52224e1e
# 11  CMPf3265e9fca  ON-MAIN-48fe2205
# 12  CMPf3265e9fca  BC-MAIN-6b4800fe
# 16  CMPf3265e9fca  BC-MAIN-bf503b6b
# 17  CMPf3265e9fca  QC-MAIN-30c1828c
# 25  CMPf3265e9fca  QC-MAIN-e51eda66
# 29  CMPf3265e9fca  ON-MAIN-7001a391
# 30  CMPf3265e9fca  NL-MAIN-c139de6d
# 31  CMPf3265e9fca  YT-MAIN-752fbcae
# 32  CMPf3265e9fca  BC-MAIN-ed23117f
# 33  CMPf3265e9fca  BC-MAIN-3f490561
# 34  CMPf3265e9fca  BC-MAIN-23155c25
# 35  CMPf3265e9fca  BC-MAIN-aa76f6f2
# 43  CMPf3265e9fca  QC-MAIN-a97821c0
# 44  CMPf3265e9fca  BC-MAIN-8eb8be0d
# 51  CMPf3265e9fca  ON-MAIN-28f3f0fc
# 52  CMPf3265e9fca  QC-MAIN-b2148882
# 54  CMPf3265e9fca  ON-MAIN-f8313ebd
# 55  CMPf3265e9fca  ON-MAIN-a3c56a83
# 56  CMPf3265e9fca  NL-MAIN-b64bae7a

# %%
# We separate emissions and production data
ctrace_ghg_gdf = ctrace_gdf.drop(columns=['activity', 'activity_units', 'capacity', 'capacity_units'])
ctrace_prod_gdf = ctrace_gdf.drop(columns=['emissions_quantity', 'gas'])

# %% [markdown]
# ### Conflict

# %%
lt_main_conflict = match_facilities(main_gdf, conflict_gdf,
                     id_col1='main_id', id_col2='ej_atlas_id',
                     name_col1='facility_name', name_col2='facility_name_ejatlas'
                     )

# %%
matches_main_conflict = one_to_many_relationships(
    lt_main_conflict,
    id_main_col='main_id',
    id_sat_col='ej_atlas_id',
    distance_threshold_m=20000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
conflict_gdf = conflict_gdf.merge(
    matches_main_conflict,
    on="ej_atlas_id",  
    how="left"
)

# %%
# For SQL
conflict_gdf = conflict_gdf[conflict_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["ej_atlas_id",
  "main_id",
  "case_name",
  "start_date",
  "end_date",
  "conflict_description",
  "conflict_details",
  "population_affected",
  "conflict_intensity",
  "project_status",
  "source_id"             
               ]
conflict_gdf = conflict_gdf[col_to_keep]
conflict_gdf
# Out:
#     ej_atlas_id           main_id  \
# 9          4135  NL-MAIN-2d8801d6
# 10         4145  ON-MAIN-2e13aaa0
# 15         5599  QC-MAIN-d6748d40
#
#                                             case_name  start_date end_date  \
# 9       Vale Mining in Voisey's Bay, Labrador, Canada     11/1994     None
# 10  Port Colborne Class Action Lawsuit Against Val...     06/2000  04/2012
# 15  Nouveau Mondeâ€™s Matawinie graphite mine in Q...  01/01/2017     None
#
#                                  conflict_description  \
# 9   <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10  <p>In Pearson (later Smith) v. Inco, the large...
# 15  <p>Five kilometers southwest of the municipali...
#
#                                      conflict_details population_affected  \
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...               Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...               Urban
# 15  The project includes 319 mining concessions (c...               Rural
#
#                                 conflict_intensity      project_status  \
# 9   MEDIUM (street protests, visible mobilization)        In operation
# 10                     LOW (some local organising)        In operation
# 15  MEDIUM (street protests, visible mobilization)  Under construction
#
#                                             source_id
# 9   http://journals.librarypublishing.arizona.edu/...
# 10  http://journals.librarypublishing.arizona.edu/...
# 15  http://journals.librarypublishing.arizona.edu/...

# %% [markdown]
# ### Tailings

# %%
lt_main_tailings = match_facilities(main_gdf, tailings_gdf,
                     id_col1='main_id', id_col2='tailing_id',
                     name_col1='facility_name', name_col2='related_mine'
                     )

# %%
matches_main_tailings = one_to_many_relationships(
    lt_main_tailings,
    id_main_col='main_id',
    id_sat_col='tailing_id',
    distance_threshold_m=20000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
tailings_gdf = tailings_gdf.merge(
    matches_main_tailings,
    on="tailing_id",  
    how="left"
)

# %%
# For SQL
tailings_gdf = tailings_gdf[tailings_gdf["main_id"].notna()].copy()

# %%
col_to_keep = [
  "row_id",
  "main_id",
  "year",
  "tailing_id",
  "tsf_name",
  "status",
  "construction_year",
  "raise_type",
  "current_maximum_height",
  "current_tailings_storage",
  "planned_storage_5_years",
  "hazard_categorization",
  "classification_system",
  "geometry", 
  "source_id"             
               ]
tailings_gdf = tailings_gdf[col_to_keep]
tailings_gdf
# Out:
#                  row_id           main_id  year  tailing_id  \
# 0      TAIL-12.0-2019-1  NU-MAIN-730aefe3  2019        12.0
# 1      TAIL-13.0-2019-1  NU-MAIN-730aefe3  2019        13.0
# 2      TAIL-14.0-2019-1  NU-MAIN-730aefe3  2019        14.0
# 3      TAIL-15.0-2019-1  NU-MAIN-8b0264c9  2019        15.0
# 4      TAIL-16.0-2019-1  QC-MAIN-c0660aec  2019        16.0
# ..                  ...               ...   ...         ...
# 215  TAIL-1126.0-2019-1  ON-MAIN-f080c409  2019      1126.0
# 216  TAIL-1127.0-2019-1  ON-MAIN-f080c409  2019      1127.0
# 217  TAIL-1128.0-2019-1  ON-MAIN-f080c409  2019      1128.0
# 218  TAIL-1129.0-2019-1  ON-MAIN-f080c409  2019      1129.0
# 226  TAIL-1243.0-2019-1  QC-MAIN-e7e6a960  2019      1243.0
#
#                   tsf_name  status  construction_year              raise_type  \
# 0               North Cell  Active             2009.0    Downstream, Upstream
# 1               South Cell  Active             2012.0              Downstream
# 2                   In pit  Active             2009.0                    None
# 3            Meliadine TSF  Active             2019.0                    None
# 4                South TSF  Active             2007.0              Not Raised
# ..                     ...     ...                ...                     ...
# 215            R1 Tailings  Active             1985.0  Compacted\nOuter Shell
# 216            R2 Tailings  Active             1985.0  Compacted\nOuter Shell
# 217            R3 Tailings  Active             1985.0  Compacted\nOuter Shell
# 218            R4 Tailings  Active             1990.0  Compacted\nOuter Shell
# 226  Canadian Malartic TSF  Active             2012.0                Upstream
#
#      current_maximum_height current_tailings_storage planned_storage_5_years  \
# 0                      31.0                 14400000                14400000
# 1                      49.0                 10420000                10420000
# 2                       NaN                   850000                  850000
# 3                       5.0                    89000                   89000
# 4                       5.0                  1664000                 1664000
# ..                      ...                      ...                     ...
# 215                    14.0                  2900000                 2900000
# 216                    13.0                 18000000                18000000
# 217                    27.0                 39000000                39000000
# 218                    22.0                 59000000                59000000
# 226                    40.0                 96000000                96000000
#
#     hazard_categorization     classification_system  \
# 0                  Medium  Canadian Dam Association
# 1                  Medium  Canadian Dam Association
# 2                     Low                      None
# 3                  Medium  Canadian Dam Association
# 4                  Medium  Canadian Dam Association
# ..                    ...                       ...
# 215               Extreme  Canadian Dam Association
# 216               Extreme  Canadian Dam Association
# 217               Extreme  Canadian Dam Association
# 218               Extreme  Canadian Dam Association
# 226        Medium to High                CDA/Yamana
#
#                        geometry                  source_id
# 0    POINT (-96.04333 65.02156)  https://tailing.grida.no/
# 1    POINT (-96.03339 65.01378)  https://tailing.grida.no/
# 2    POINT (-96.03254 65.00190)  https://tailing.grida.no/
# 3    POINT (-92.14034 63.02083)  https://tailing.grida.no/
# 4    POINT (-77.84198 48.05434)  https://tailing.grida.no/
# ..                          ...                        ...
# 215  POINT (-81.14058 46.47142)  https://tailing.grida.no/
# 216  POINT (-81.14058 46.47142)  https://tailing.grida.no/
# 217  POINT (-81.14058 46.47142)  https://tailing.grida.no/
# 218  POINT (-81.14058 46.47142)  https://tailing.grida.no/
# 226  POINT (-78.10361 48.11139)  https://tailing.grida.no/
#
# [86 rows x 15 columns]

# %% [markdown]
# ### GHG

# %%
lt_main_ghg = match_facilities(main_gdf, ghg_gdf,
                     id_col1='main_id', id_col2='ghg_id',
                     name_col1='facility_name', name_col2='facility_name_ghg'
                     )

# %%
matches_main_ghg = one_to_many_relationships(
    lt_main_ghg,
    id_main_col='main_id',
    id_sat_col='ghg_id',
    distance_threshold_m=10000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
ghg_gdf = ghg_gdf.merge(
    matches_main_ghg,
    on="ghg_id",  
    how="left"
)

# %%
# For SQL
ghg_gdf = ghg_gdf[ghg_gdf["main_id"].notna()].copy()

# %%
col_to_keep = [
  "row_id",
  "main_id",
  "year",
  "value",
  "unit",
  "compartment_id",
  "substance_id",
  "source_id"             
               ]
ghg_gdf = ghg_gdf[col_to_keep]
ghg_gdf
# Out:
#                row_id           main_id  year   value  \
# 1    GHG-10101-2022-1  NT-MAIN-6c1d6ee6  2022  164.88
# 4    GHG-10188-2022-1  QC-MAIN-084bd95c  2022  293.10
# 7    GHG-10240-2022-1  QC-MAIN-a97821c0  2022  129.26
# 8    GHG-10299-2022-1  QC-MAIN-e25eed27  2022  909.89
# 9    GHG-10350-2022-1  NL-MAIN-b64bae7a  2022  110.93
# ..                ...               ...   ...     ...
# 153  GHG-10791-2022-1  QC-MAIN-c1c7eb99  2022   96.48
# 154  GHG-10810-2022-1  NL-MAIN-d9036091  2022   50.09
# 169  GHG-11723-2022-1  ON-MAIN-2e13aaa0  2022   14.17
# 170  GHG-11730-2022-1  QC-MAIN-92628f16  2022  380.82
# 178  GHG-12298-2022-1  ON-MAIN-63b394c3  2022  330.67
#
#                                                   unit compartment_id  \
# 1    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 4    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 7    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 8    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 9    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# ..                                                 ...            ...
# 153  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 154  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 169  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 170  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 178  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
#
#      substance_id                                          source_id
# 1             NaN  https://www.canada.ca/en/environment-climate-c...
# 4             NaN  https://www.canada.ca/en/environment-climate-c...
# 7             NaN  https://www.canada.ca/en/environment-climate-c...
# 8             NaN  https://www.canada.ca/en/environment-climate-c...
# 9             NaN  https://www.canada.ca/en/environment-climate-c...
# ..            ...                                                ...
# 153           NaN  https://www.canada.ca/en/environment-climate-c...
# 154           NaN  https://www.canada.ca/en/environment-climate-c...
# 169           NaN  https://www.canada.ca/en/environment-climate-c...
# 170           NaN  https://www.canada.ca/en/environment-climate-c...
# 178           NaN  https://www.canada.ca/en/environment-climate-c...
#
# [65 rows x 8 columns]

# %% [markdown]
# ### Pollution

# %%
pollutant_gdf
# Out:
#                   row_id  year  npri_id     facility_name_npri  \
# 0       npri-1568-2023-1  2023     1568           Macassa Mine
# 1       npri-1568-2023-2  2023     1568           Macassa Mine
# 2       npri-1568-2023-3  2023     1568           Macassa Mine
# 3       npri-1568-2023-4  2023     1568           Macassa Mine
# 4       npri-1568-2023-5  2023     1568           Macassa Mine
# ...                  ...   ...      ...                    ...
# 24125   npri-5697-2023-6  2023     5697  Rayette Manufacturing
# 24126   npri-5698-2023-6  2023     5698    Bowes Manufacturing
# 24127  npri-34697-2023-2  2023    34697    541 Bowes Warehouse
# 24128   npri-5697-2023-7  2023     5697  Rayette Manufacturing
# 24129   npri-5698-2023-7  2023     5698    Bowes Manufacturing
#
#         company_name_npri  facility_type  longitude  latitude  \
# 0      Agnico Eagle Mines         mining  -80.08734  48.13032
# 1      Agnico Eagle Mines         mining  -80.08734  48.13032
# 2      Agnico Eagle Mines         mining  -80.08734  48.13032
# 3      Agnico Eagle Mines         mining  -80.08734  48.13032
# 4      Agnico Eagle Mines         mining  -80.08734  48.13032
# ...                   ...            ...        ...       ...
# 24125                None  manufacturing  -79.49600  43.80800
# 24126                None  manufacturing  -79.49480  43.80360
# 24127                None  manufacturing  -79.49707  43.81726
# 24128                None  manufacturing  -79.49600  43.80800
# 24129                None  manufacturing  -79.49480  43.80360
#
#       terrestrial_ecozone                   watershed  \
# 0           Boreal Shield  St. Lawrence Drainage Area
# 1           Boreal Shield  St. Lawrence Drainage Area
# 2           Boreal Shield  St. Lawrence Drainage Area
# 3           Boreal Shield  St. Lawrence Drainage Area
# 4           Boreal Shield  St. Lawrence Drainage Area
# ...                   ...                         ...
# 24125     Mixedwood Plain  St. Lawrence Drainage Area
# 24126     Mixedwood Plain  St. Lawrence Drainage Area
# 24127     Mixedwood Plain  St. Lawrence Drainage Area
# 24128     Mixedwood Plain  St. Lawrence Drainage Area
# 24129     Mixedwood Plain  St. Lawrence Drainage Area
#
#                               substance_name_npri substance_name_ecoinvent  \
# 0                                 Ammonia (total)                  Ammonia
# 1                     Arsenic (and its compounds)                  Arsenic
# 2                                 Carbon monoxide  Carbon monoxide, fossil
# 3                    Chromium (and its compounds)                 Chromium
# 4                      Cobalt (and its compounds)                   Cobalt
# ...                                           ...                      ...
# 24125  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24126  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24127  Speciated VOC - Hydrotreated heavy naphtha                     None
# 24128          Volatile Organic Compounds (Total)                     None
# 24129          Volatile Organic Compounds (Total)                     None
#
#       substance_unit                      emission_type  \
# 0             tonnes  Air Emissions / Émissions à l'air
# 1                 kg  Air Emissions / Émissions à l'air
# 2             tonnes  Air Emissions / Émissions à l'air
# 3             tonnes  Air Emissions / Émissions à l'air
# 4                 kg  Air Emissions / Émissions à l'air
# ...              ...                                ...
# 24125         tonnes                        Grand Total
# 24126         tonnes                        Grand Total
# 24127         tonnes                        Grand Total
# 24128         tonnes                        Grand Total
# 24129         tonnes                        Grand Total
#
#                                         emission_subtype      value  \
# 0                                        Stack Emissions      0.636
# 1                                        Stack Emissions      0.116
# 2                                        Stack Emissions     76.208
# 3                                        Stack Emissions    0.00105
# 4                                        Stack Emissions       0.18
# ...                                                  ...        ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008
# 24126  Total Releases, Disposals and Transfers for Re...     23.418
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719
#
#                                                source_id  \
# 0      https://www.canada.ca/en/environment-climate-c...
# 1      https://www.canada.ca/en/environment-climate-c...
# 2      https://www.canada.ca/en/environment-climate-c...
# 3      https://www.canada.ca/en/environment-climate-c...
# 4      https://www.canada.ca/en/environment-climate-c...
# ...                                                  ...
# 24125  https://www.canada.ca/en/environment-climate-c...
# 24126  https://www.canada.ca/en/environment-climate-c...
# 24127  https://www.canada.ca/en/environment-climate-c...
# 24128  https://www.canada.ca/en/environment-climate-c...
# 24129  https://www.canada.ca/en/environment-climate-c...
#
#                          geometry   substance_id compartment_id
# 0      POINT (-80.08734 48.13032)  SUB1c6e015419  CMP1718f4466d
# 1      POINT (-80.08734 48.13032)  SUB0cbc90a094  CMP1718f4466d
# 2      POINT (-80.08734 48.13032)  SUB642eab0862  CMP1718f4466d
# 3      POINT (-80.08734 48.13032)  SUB7e3f017a30  CMP1718f4466d
# 4      POINT (-80.08734 48.13032)  SUBd94d47b1d8  CMP1718f4466d
# ...                           ...            ...            ...
# 24125  POINT (-79.49600 43.80800)  SUBb215244183  CMP281acc6045
# 24126  POINT (-79.49480 43.80360)  SUBb215244183  CMP281acc6045
# 24127  POINT (-79.49707 43.81726)  SUBb215244183  CMP281acc6045
# 24128  POINT (-79.49600 43.80800)  SUB8319f60a2f  CMP281acc6045
# 24129  POINT (-79.49480 43.80360)  SUB8319f60a2f  CMP281acc6045
#
# [24130 rows x 20 columns]

# %%
lt_main_pollution = match_facilities(main_gdf, pollutant_gdf,
                     id_col1='main_id', id_col2='npri_id',
                     name_col1='facility_name', name_col2='facility_name_npri'
                     )

# %%
matches_main_pollution = one_to_many_relationships(
    lt_main_pollution,
    id_main_col='main_id',
    id_sat_col='npri_id',
    distance_threshold_m=10000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
matches_main_pollution
# Out:
#        npri_id           main_id
# 16814  11588.0  ON-MAIN-fcb287a4
# 45019  11123.0  ON-MAIN-cb85213a
# 11963   6344.0  QC-MAIN-5398dfac
# 44365  11878.0  ON-MAIN-28f3f0fc
# 43960   1471.0  ON-MAIN-2e13aaa0
# ...        ...               ...
# 5206    1106.0  AB-MAIN-9fed34a8
# 40383  10199.0  ON-MAIN-6e9b2449
# 10102  20131.0  BC-MAIN-e34feb4d
# 12656  31260.0  QC-MAIN-5398dfac
# 42023    444.0  ON-MAIN-63b394c3
#
# [80 rows x 2 columns]

# %%
pollutant_gdf = pollutant_gdf.merge(
    matches_main_pollution,
    on="npri_id",  
    how="left"
)

# %%
pollutant_gdf
# Out:
#                   row_id  year  npri_id     facility_name_npri  \
# 0       npri-1568-2023-1  2023     1568           Macassa Mine
# 1       npri-1568-2023-2  2023     1568           Macassa Mine
# 2       npri-1568-2023-3  2023     1568           Macassa Mine
# 3       npri-1568-2023-4  2023     1568           Macassa Mine
# 4       npri-1568-2023-5  2023     1568           Macassa Mine
# ...                  ...   ...      ...                    ...
# 24125   npri-5697-2023-6  2023     5697  Rayette Manufacturing
# 24126   npri-5698-2023-6  2023     5698    Bowes Manufacturing
# 24127  npri-34697-2023-2  2023    34697    541 Bowes Warehouse
# 24128   npri-5697-2023-7  2023     5697  Rayette Manufacturing
# 24129   npri-5698-2023-7  2023     5698    Bowes Manufacturing
#
#         company_name_npri  facility_type  longitude  latitude  \
# 0      Agnico Eagle Mines         mining  -80.08734  48.13032
# 1      Agnico Eagle Mines         mining  -80.08734  48.13032
# 2      Agnico Eagle Mines         mining  -80.08734  48.13032
# 3      Agnico Eagle Mines         mining  -80.08734  48.13032
# 4      Agnico Eagle Mines         mining  -80.08734  48.13032
# ...                   ...            ...        ...       ...
# 24125                None  manufacturing  -79.49600  43.80800
# 24126                None  manufacturing  -79.49480  43.80360
# 24127                None  manufacturing  -79.49707  43.81726
# 24128                None  manufacturing  -79.49600  43.80800
# 24129                None  manufacturing  -79.49480  43.80360
#
#       terrestrial_ecozone                   watershed  ...  \
# 0           Boreal Shield  St. Lawrence Drainage Area  ...
# 1           Boreal Shield  St. Lawrence Drainage Area  ...
# 2           Boreal Shield  St. Lawrence Drainage Area  ...
# 3           Boreal Shield  St. Lawrence Drainage Area  ...
# 4           Boreal Shield  St. Lawrence Drainage Area  ...
# ...                   ...                         ...  ...
# 24125     Mixedwood Plain  St. Lawrence Drainage Area  ...
# 24126     Mixedwood Plain  St. Lawrence Drainage Area  ...
# 24127     Mixedwood Plain  St. Lawrence Drainage Area  ...
# 24128     Mixedwood Plain  St. Lawrence Drainage Area  ...
# 24129     Mixedwood Plain  St. Lawrence Drainage Area  ...
#
#       substance_name_ecoinvent substance_unit  \
# 0                      Ammonia         tonnes
# 1                      Arsenic             kg
# 2      Carbon monoxide, fossil         tonnes
# 3                     Chromium         tonnes
# 4                       Cobalt             kg
# ...                        ...            ...
# 24125                     None         tonnes
# 24126                     None         tonnes
# 24127                     None         tonnes
# 24128                     None         tonnes
# 24129                     None         tonnes
#
#                            emission_type  \
# 0      Air Emissions / Émissions à l'air
# 1      Air Emissions / Émissions à l'air
# 2      Air Emissions / Émissions à l'air
# 3      Air Emissions / Émissions à l'air
# 4      Air Emissions / Émissions à l'air
# ...                                  ...
# 24125                        Grand Total
# 24126                        Grand Total
# 24127                        Grand Total
# 24128                        Grand Total
# 24129                        Grand Total
#
#                                         emission_subtype      value  \
# 0                                        Stack Emissions      0.636
# 1                                        Stack Emissions      0.116
# 2                                        Stack Emissions     76.208
# 3                                        Stack Emissions    0.00105
# 4                                        Stack Emissions       0.18
# ...                                                  ...        ...
# 24125  Total Releases, Disposals and Transfers for Re...    25.1008
# 24126  Total Releases, Disposals and Transfers for Re...     23.418
# 24127  Total Releases, Disposals and Transfers for Re...  16.543746
# 24128  Total Releases, Disposals and Transfers for Re...    12.5823
# 24129  Total Releases, Disposals and Transfers for Re...   11.87719
#
#                                                source_id  \
# 0      https://www.canada.ca/en/environment-climate-c...
# 1      https://www.canada.ca/en/environment-climate-c...
# 2      https://www.canada.ca/en/environment-climate-c...
# 3      https://www.canada.ca/en/environment-climate-c...
# 4      https://www.canada.ca/en/environment-climate-c...
# ...                                                  ...
# 24125  https://www.canada.ca/en/environment-climate-c...
# 24126  https://www.canada.ca/en/environment-climate-c...
# 24127  https://www.canada.ca/en/environment-climate-c...
# 24128  https://www.canada.ca/en/environment-climate-c...
# 24129  https://www.canada.ca/en/environment-climate-c...
#
#                          geometry   substance_id compartment_id  \
# 0      POINT (-80.08734 48.13032)  SUB1c6e015419  CMP1718f4466d
# 1      POINT (-80.08734 48.13032)  SUB0cbc90a094  CMP1718f4466d
# 2      POINT (-80.08734 48.13032)  SUB642eab0862  CMP1718f4466d
# 3      POINT (-80.08734 48.13032)  SUB7e3f017a30  CMP1718f4466d
# 4      POINT (-80.08734 48.13032)  SUBd94d47b1d8  CMP1718f4466d
# ...                           ...            ...            ...
# 24125  POINT (-79.49600 43.80800)  SUBb215244183  CMP281acc6045
# 24126  POINT (-79.49480 43.80360)  SUBb215244183  CMP281acc6045
# 24127  POINT (-79.49707 43.81726)  SUBb215244183  CMP281acc6045
# 24128  POINT (-79.49600 43.80800)  SUB8319f60a2f  CMP281acc6045
# 24129  POINT (-79.49480 43.80360)  SUB8319f60a2f  CMP281acc6045
#
#                 main_id
# 0      ON-MAIN-1f126a43
# 1      ON-MAIN-1f126a43
# 2      ON-MAIN-1f126a43
# 3      ON-MAIN-1f126a43
# 4      ON-MAIN-1f126a43
# ...                 ...
# 24125               NaN
# 24126               NaN
# 24127               NaN
# 24128               NaN
# 24129               NaN
#
# [24130 rows x 21 columns]

# %%
# For SQL
pollutant_gdf = pollutant_gdf[pollutant_gdf["main_id"].notna()].copy()

# %%
# # Adding terrestrial ecozone and watershed to the main_gdf
# main_gdf_b = main_gdf.merge(
#     pollutant_gdf[['main_id', 'terrestrial_ecozone', 'watershed']],
#     on='main_id',
#     how='left'
# )
# 
# # Adding NPRI source for the main_gdf where watershed and terrestrial ecozone are not null
# main_gdf['source_id'] = main_gdf.apply(
#     lambda row: row['source_id'] + ';' + 'https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html' if pd.notna(row['watershed']) or pd.notna(row['terrestrial_ecozone']) else row['source_id'],
#     axis=1
# )

# %%
col_to_keep = [
  "row_id",
  #"npri_id",
  "main_id",
  "year",
  "value",
  "substance_unit",
  "compartment_id",
  "substance_id",
  "source_id"
 ]
pollutant_gdf = pollutant_gdf[col_to_keep]
pollutant_gdf.rename(columns={'substance_unit': 'unit'}, inplace=True)
pollutant_gdf
# Out:
#                     row_id           main_id  year               value  \
# 0         npri-1568-2023-1  ON-MAIN-1f126a43  2023               0.636
# 1         npri-1568-2023-2  ON-MAIN-1f126a43  2023               0.116
# 2         npri-1568-2023-3  ON-MAIN-1f126a43  2023              76.208
# 3         npri-1568-2023-4  ON-MAIN-1f126a43  2023             0.00105
# 4         npri-1568-2023-5  ON-MAIN-1f126a43  2023                0.18
# ...                    ...               ...   ...                 ...
# 24116  npri-28761-2023-117  NL-MAIN-d9036091  2023               4.405
# 24117  npri-28761-2023-118  NL-MAIN-d9036091  2023              0.2475
# 24118  npri-28761-2023-119  NL-MAIN-d9036091  2023  29.277299999999997
# 24119  npri-28761-2023-120  NL-MAIN-d9036091  2023               0.485
# 24120  npri-28761-2023-121  NL-MAIN-d9036091  2023  39.214054000000004
#
#          unit compartment_id   substance_id  \
# 0      tonnes  CMP1718f4466d  SUB1c6e015419
# 1          kg  CMP1718f4466d  SUB0cbc90a094
# 2      tonnes  CMP1718f4466d  SUB642eab0862
# 3      tonnes  CMP1718f4466d  SUB7e3f017a30
# 4          kg  CMP1718f4466d  SUBd94d47b1d8
# ...       ...            ...            ...
# 24116  tonnes  CMP281acc6045  SUB4cedd6b899
# 24117  tonnes  CMP281acc6045  SUBda6a6d231d
# 24118  tonnes  CMP281acc6045  SUB28f44d0e11
# 24119  tonnes  CMP281acc6045  SUBba3b5d11c7
# 24120  tonnes  CMP281acc6045  SUBae95939c3f
#
#                                                source_id
# 0      https://www.canada.ca/en/environment-climate-c...
# 1      https://www.canada.ca/en/environment-climate-c...
# 2      https://www.canada.ca/en/environment-climate-c...
# 3      https://www.canada.ca/en/environment-climate-c...
# 4      https://www.canada.ca/en/environment-climate-c...
# ...                                                  ...
# 24116  https://www.canada.ca/en/environment-climate-c...
# 24117  https://www.canada.ca/en/environment-climate-c...
# 24118  https://www.canada.ca/en/environment-climate-c...
# 24119  https://www.canada.ca/en/environment-climate-c...
# 24120  https://www.canada.ca/en/environment-climate-c...
#
# [13687 rows x 8 columns]

# %%
pollutant_gdf
# Out:
#                     row_id           main_id  year               value  \
# 0         npri-1568-2023-1  ON-MAIN-1f126a43  2023               0.636
# 1         npri-1568-2023-2  ON-MAIN-1f126a43  2023               0.116
# 2         npri-1568-2023-3  ON-MAIN-1f126a43  2023              76.208
# 3         npri-1568-2023-4  ON-MAIN-1f126a43  2023             0.00105
# 4         npri-1568-2023-5  ON-MAIN-1f126a43  2023                0.18
# ...                    ...               ...   ...                 ...
# 24116  npri-28761-2023-117  NL-MAIN-d9036091  2023               4.405
# 24117  npri-28761-2023-118  NL-MAIN-d9036091  2023              0.2475
# 24118  npri-28761-2023-119  NL-MAIN-d9036091  2023  29.277299999999997
# 24119  npri-28761-2023-120  NL-MAIN-d9036091  2023               0.485
# 24120  npri-28761-2023-121  NL-MAIN-d9036091  2023  39.214054000000004
#
#          unit compartment_id   substance_id  \
# 0      tonnes  CMP1718f4466d  SUB1c6e015419
# 1          kg  CMP1718f4466d  SUB0cbc90a094
# 2      tonnes  CMP1718f4466d  SUB642eab0862
# 3      tonnes  CMP1718f4466d  SUB7e3f017a30
# 4          kg  CMP1718f4466d  SUBd94d47b1d8
# ...       ...            ...            ...
# 24116  tonnes  CMP281acc6045  SUB4cedd6b899
# 24117  tonnes  CMP281acc6045  SUBda6a6d231d
# 24118  tonnes  CMP281acc6045  SUB28f44d0e11
# 24119  tonnes  CMP281acc6045  SUBba3b5d11c7
# 24120  tonnes  CMP281acc6045  SUBae95939c3f
#
#                                                source_id
# 0      https://www.canada.ca/en/environment-climate-c...
# 1      https://www.canada.ca/en/environment-climate-c...
# 2      https://www.canada.ca/en/environment-climate-c...
# 3      https://www.canada.ca/en/environment-climate-c...
# 4      https://www.canada.ca/en/environment-climate-c...
# ...                                                  ...
# 24116  https://www.canada.ca/en/environment-climate-c...
# 24117  https://www.canada.ca/en/environment-climate-c...
# 24118  https://www.canada.ca/en/environment-climate-c...
# 24119  https://www.canada.ca/en/environment-climate-c...
# 24120  https://www.canada.ca/en/environment-climate-c...
#
# [13687 rows x 8 columns]

# %% [markdown]
# ### Li et al land occupation

# %%
# li_canada_gdf_copy = li_canada_gdf.copy()
# li_canada_gdf_copy.rename(columns={'geometry': 'geometry_polygon'}, inplace=True)
# li_canada_gdf_copy["geometry"] = gpd.points_from_xy(li_canada_gdf_copy["Longitude"], li_canada_gdf_copy["Latitude"])
# li_canada_gdf_copy = li_canada_gdf_copy.set_geometry("geometry", crs="EPSG:4326")

# %%
# lt_main_li = match_facilities(main_gdf, li_canada_gdf_copy,
#                      id_col1='main_id', id_col2='li_id',
#                      name_col1='facility_name', name_col2='Name'
#                      )
# lt_main_li.to_excel(r'data/Sources/lt_main_li.xlsx', index=False)

# %%
matches_main_li = pd.read_excel(r'data/Sources/lt_main_li.xlsx', sheet_name='for_pandas')

# %%
li_canada_gdf = li_canada_gdf.merge(
    matches_main_li,
    on="li_id",  
    how="left"
)

# %%
li_canada_gdf
# Out:
#               li_id            Name   Latitude   Longitude     P_C  \
# 0    QC-LI-91179bef           Ansil  48.366670  -79.116670  Copper
# 1    ON-LI-b4159d5a    Winston Lake  48.977500  -87.383610    Zinc
# 2    QC-LI-71058cde  Abcourt-Barvue  48.521540  -77.679010    Zinc
# 3    NS-LI-0ef10de8        Sterling  45.729170  -60.436940    Zinc
# 4    QC-LI-daf5c7b6         LaRonde  48.250560  -78.441670    Gold
# ..              ...             ...        ...         ...     ...
# 183  SK-LI-61977a89     Hanson Lake  54.673220 -102.861800  Copper
# 184  BC-LI-f95462e5           Texas  49.408240 -119.111560    Gold
# 185  ON-LI-8e5e6d12           Gowan  48.681165  -81.109475  Copper
# 186  ON-LI-ab2f9062           Genex  48.474010  -81.571480    Gold
# 187  QC-LI-81f5c1bf          Ledden  49.913630  -74.369950  Copper
#
#                           List_of_C       A_S Country        State_Prov  \
# 0           Copper,Gold,Silver,Zinc  Inactive  Canada            Quebec
# 1           Zinc,Copper,Gold,Silver  Inactive  Canada           Ontario
# 2           Zinc,Silver,Gold,Copper    Active  Canada            Quebec
# 3      Zinc,Lead,Copper,Silver,Gold  Inactive  Canada       Nova Scotia
# 4      Gold,Silver,Zinc,Copper,Lead    Active  Canada            Quebec
# ..                              ...       ...     ...               ...
# 183         Copper,Zinc,Lead,Silver    Active  Canada      Saskatchewan
# 184    Gold,Silver,Copper,Lead,Zinc    Active  Canada  British Columbia
# 185       Copper,Silver,Zinc,Nickel    Active  Canada           Ontario
# 186  Gold,Copper,Zinc,Silver,Cobalt    Active  Canada           Ontario
# 187                     Copper,Gold    Active  Canada            Quebec
#
#          Land_use   Cum_Prod          MI  \
# 0    6.430820e+05   646039.0  100.459820
# 1    3.674623e+05    45600.0   12.409435
# 2    8.480085e+05   248738.0   29.332017
# 3    2.375619e+05   486766.0  204.900724
# 4    5.150369e+06   192033.0    3.728529
# ..            ...        ...         ...
# 183  2.547733e+04   207675.0  815.136583
# 184  3.198705e+05   181497.0   56.740774
# 185  2.466126e+07  1195597.0    4.848077
# 186  2.071482e+05   544094.0  262.659331
# 187  1.733646e+06   375998.0   21.688278
#
#                                               geometry  \
# 0    MULTIPOLYGON Z (((-79.08135 48.35734 0.00000, ...
# 1    POLYGON Z ((-87.37186 48.98162 0.00000, -87.37...
# 2    MULTIPOLYGON Z (((-77.66261 48.52210 0.00000, ...
# 3    POLYGON Z ((-60.42757 45.72727 0.00000, -60.42...
# 4    MULTIPOLYGON Z (((-78.43917 48.25134 0.00000, ...
# ..                                                 ...
# 183  POLYGON Z ((-102.85598 54.67964 0.00000, -102....
# 184  POLYGON Z ((-119.09592 49.43913 0.00000, -119....
# 185  MULTIPOLYGON Z (((-81.07836 48.55417 0.00000, ...
# 186  MULTIPOLYGON Z (((-81.56275 48.53520 0.00000, ...
# 187  MULTIPOLYGON Z (((-74.36829 49.95810 0.00000, ...
#
#                                              source_id           main_id
# 0    https://www.nature.com/articles/s41597-025-052...               NaN
# 1    https://www.nature.com/articles/s41597-025-052...  ON-MAIN-3c468faa
# 2    https://www.nature.com/articles/s41597-025-052...  QC-MAIN-5801b453
# 3    https://www.nature.com/articles/s41597-025-052...               NaN
# 4    https://www.nature.com/articles/s41597-025-052...  QC-MAIN-e51eda66
# ..                                                 ...               ...
# 183  https://www.nature.com/articles/s41597-025-052...               NaN
# 184  https://www.nature.com/articles/s41597-025-052...               NaN
# 185  https://www.nature.com/articles/s41597-025-052...               NaN
# 186  https://www.nature.com/articles/s41597-025-052...               NaN
# 187  https://www.nature.com/articles/s41597-025-052...               NaN
#
# [188 rows x 15 columns]

# %%
# For SQL
li_canada_gdf = li_canada_gdf[li_canada_gdf["main_id"].notna()].copy()

# %%
li_canada_gdf
# Out:
#               li_id                Name  Latitude  Longitude        P_C  \
# 1    ON-LI-b4159d5a        Winston Lake  48.97750  -87.38361       Zinc
# 2    QC-LI-71058cde      Abcourt-Barvue  48.52154  -77.67901       Zinc
# 4    QC-LI-daf5c7b6             LaRonde  48.25056  -78.44167       Gold
# 7    BC-LI-356e0fe7          Myra Falls  49.57394 -125.58518       Zinc
# 9    NB-LI-4677c505        Murray Brook  47.52528  -66.43167       Zinc
# 10   QC-LI-81c20425      Sleeping Giant  49.13115  -77.97601       Gold
# 12   ON-LI-28377156        Lac des Iles  49.15774  -89.61886  Palladium
# 13   QC-LI-22e70cb6              Goldex  48.09250  -77.87250       Gold
# 14   QC-LI-07027dd8            Westwood  48.25519  -78.50213       Gold
# 18   ON-LI-0825b8aa            Red Lake  51.06098  -93.73213       Gold
# 21   BC-LI-53364ff0     Copper Mountain  49.33884 -120.53599     Copper
# 27   QC-LI-a160f62a      LaRonde Zone 5  48.25246  -78.47266       Gold
# 38   BC-LI-a5c8b930     Highland Valley  50.48556 -121.04722     Copper
# 39   BC-LI-b39bcd09           Gibraltar  52.51639 -122.28341     Copper
# 43   BC-LI-f2cf05dc        Mount Polley  52.54506 -121.63292     Copper
# 44   BC-LI-62850c01         Eskay Creek  56.64630 -130.44214       Gold
# 45   BC-LI-69fbeec0           New Afton  50.66056 -120.51361       Gold
# 46   QC-LI-c4bafa7b             Horne 5  48.25425  -79.00953       Gold
# 47   BC-LI-38a92ebf      Mount Milligan  55.11806 -124.03111     Copper
# 57   MB-LI-2b2d142c           Lynn Lake  56.82115 -101.03294     Nickel
# 67   ON-LI-232fddc4    Ontario Division  46.49222  -81.06667     Nickel
# 68   ON-LI-232fddc4    Ontario Division  46.49222  -81.06667     Nickel
# 69   QC-LI-a1ac6320             Troilus  51.01024  -74.46643       Gold
# 79   ON-LI-d9b37843    Nickel Rim South  46.65800  -80.79700     Nickel
# 83   ON-LI-535c4fbd    Nickel Rim South  46.65800  -80.79700     Nickel
# 85   BC-LI-ee31292d           Red Chris  57.70019 -129.80495     Copper
# 87   NL-LI-05d5336d        Voisey's Bay  56.33024  -62.09573     Nickel
# 103  ON-LI-2752f4ec  Sudbury Operations  46.63626  -81.39866     Copper
# 114  MB-LI-b5e1ad74          Lalor Lake  54.86562 -100.15120       Zinc
# 119  ON-LI-1c9fdf31          Crean Hill  46.42933  -81.35099     Nickel
# 120  ON-LI-d9dec6c8            Victoria  46.41667  -81.38333     Nickel
# 124  QC-LI-219a2e44             Horne 5  48.25425  -79.00953       Gold
# 130  BC-LI-9c3aa818         Eskay Creek  56.64630 -130.44214       Gold
# 143  ON-LI-1a9a061c         Kidd Claims  48.69000  -81.36000     Copper
# 157  QC-LI-94bd8222        Casa Berardi  49.55453  -79.19476       Gold
# 159  MB-LI-3e566fc3           Lynn Lake  56.82115 -101.03294     Nickel
#
#                                              List_of_C                  A_S  \
# 1                              Zinc,Copper,Gold,Silver             Inactive
# 2                              Zinc,Silver,Gold,Copper               Active
# 4                         Gold,Silver,Zinc,Copper,Lead               Active
# 7                         Zinc,Lead,Copper,Silver,Gold               Active
# 9                         Zinc,Lead,Silver,Copper,Gold               Active
# 10                             Gold,Silver,Copper,Zinc               Active
# 12       Palladium,Platinum,Gold,Copper,Nickel,Rhodium               Active
# 13                                  Gold,Silver,Copper               Active
# 14                             Gold,Copper,Zinc,Silver               Active
# 18                                  Gold,Copper,Silver               Active
# 21                                  Copper,Gold,Silver               Active
# 27                             Gold,Copper,Silver,Zinc               Active
# 38                       Copper,Molybdenum,Silver,Gold               Active
# 39                       Copper,Molybdenum,Silver,Gold               Active
# 43                                  Copper,Gold,Silver               Active
# 44   Gold,Silver,Copper,Lead,Zinc,Antimony,Arsenic,...               Active
# 45                        Gold,Copper,Silver,Palladium               Active
# 46                      Gold,Copper,Zinc,Silver,Nickel               Active
# 47                                  Copper,Gold,Silver               Active
# 57   Nickel,Copper,Cobalt,Platinum,Zinc,Lead,Silver...               Active
# 67   Nickel,Copper,Rhodium,Cobalt,Platinum,Palladiu...               Active
# 68   Nickel,Copper,Rhodium,Cobalt,Platinum,Palladiu...               Active
# 69                                  Gold,Copper,Silver  Temporarily On Hold
# 79   Nickel,Copper,Cobalt,Platinum,Palladium,Gold,S...               Active
# 83   Nickel,Copper,Cobalt,Platinum,Palladium,Gold,S...               Active
# 85                                  Copper,Gold,Silver               Active
# 87                                Nickel,Copper,Cobalt               Active
# 103  Copper,Nickel,Platinum,Palladium,Gold,Cobalt,R...               Active
# 114                            Zinc,Copper,Gold,Silver               Active
# 119       Nickel,Copper,Cobalt,Platinum,Palladium,Gold               Active
# 120  Nickel,Copper,Gold,Silver,Cobalt,Platinum,Pall...               Active
# 124                     Gold,Copper,Zinc,Silver,Nickel               Active
# 130  Gold,Silver,Copper,Lead,Zinc,Antimony,Arsenic,...               Active
# 143                            Copper,Zinc,Lead,Silver             Inactive
# 157                              Gold,Copper,Zinc,Lead             Inactive
# 159  Nickel,Copper,Cobalt,Platinum,Zinc,Lead,Silver...               Active
#
#     Country                 State_Prov      Land_use      Cum_Prod  \
# 1    Canada                    Ontario  3.674623e+05  4.560000e+04
# 2    Canada                     Quebec  8.480085e+05  2.487380e+05
# 4    Canada                     Quebec  5.150369e+06  1.920330e+05
# 7    Canada           British Columbia  1.499690e+06  2.262000e+05
# 9    Canada              New Brunswick  2.552090e+05  1.460550e+05
# 10   Canada                     Quebec  1.113517e+06  1.825560e+05
# 12   Canada                    Ontario  8.409093e+06  5.573147e+04
# 13   Canada                     Quebec  1.341835e+06  4.717560e+05
# 14   Canada                     Quebec  7.249147e+06  4.024100e+05
# 18   Canada                    Ontario  6.139378e+06  1.242835e+06
# 21   Canada           British Columbia  1.323321e+07  1.470000e+06
# 27   Canada                     Quebec  4.240549e+05  1.422730e+05
# 38   Canada           British Columbia  6.392426e+07  8.364983e+06
# 39   Canada           British Columbia  2.252800e+07  1.251920e+06
# 43   Canada           British Columbia  7.967835e+06  2.653931e+05
# 44   Canada           British Columbia  7.707949e+04  1.971670e+05
# 45   Canada           British Columbia  4.950460e+06  9.961360e+05
# 46   Canada                     Quebec  3.704188e+06  9.605290e+05
# 47   Canada           British Columbia  1.260679e+07  3.094550e+05
# 57   Canada                   Manitoba  5.260796e+06  1.311499e+06
# 67   Canada                    Ontario  2.159125e+07  9.420397e+06
# 68   Canada                    Ontario  2.159125e+07  9.420397e+06
# 69   Canada                     Quebec  9.487628e+06  7.329273e+04
# 79   Canada                    Ontario  2.920384e+05  1.485610e+05
# 83   Canada                    Ontario  1.496369e+06  3.468220e+05
# 85   Canada           British Columbia  1.153165e+07  4.374000e+05
# 87   Canada  Newfoundland and Labrador  4.789014e+06  5.588060e+05
# 103  Canada                    Ontario  9.891461e+05  6.000000e+05
# 114  Canada                   Manitoba  3.634383e+05  2.949450e+05
# 119  Canada                    Ontario  3.862308e+05  8.553000e+04
# 120  Canada                    Ontario  2.425190e+05  2.825110e+05
# 124  Canada                     Quebec  2.926809e+06  2.987480e+05
# 130  Canada           British Columbia  1.226440e+05  3.188080e+05
# 143  Canada                    Ontario  4.202254e+06  2.610000e+06
# 157  Canada                     Quebec  6.202897e+06  4.851480e+05
# 159  Canada                   Manitoba  4.096435e+05  3.737930e+05
#
#              MI                                           geometry  \
# 1     12.409435  POLYGON Z ((-87.37186 48.98162 0.00000, -87.37...
# 2     29.332017  MULTIPOLYGON Z (((-77.66261 48.52210 0.00000, ...
# 4      3.728529  MULTIPOLYGON Z (((-78.43917 48.25134 0.00000, ...
# 7     15.083119  POLYGON Z ((-125.59807 49.57709 0.00000, -125....
# 9     57.229572  POLYGON Z ((-66.42615 47.52543 0.00000, -66.42...
# 10    16.394547  POLYGON Z ((-77.97116 49.13362 0.00000, -77.97...
# 12     0.662752  MULTIPOLYGON Z (((-89.65770 49.16201 0.00000, ...
# 13    35.157522  MULTIPOLYGON Z (((-77.86273 48.09418 0.00000, ...
# 14     5.551136  MULTIPOLYGON Z (((-78.54047 48.26526 0.00000, ...
# 18    20.243661  MULTIPOLYGON Z (((-93.75149 51.07450 0.00000, ...
# 21    11.108416  MULTIPOLYGON Z (((-120.53945 49.34078 0.00000,...
# 27    33.550609  POLYGON Z ((-78.46721 48.24976 0.00000, -78.46...
# 38    13.085772  MULTIPOLYGON Z (((-120.99509 50.51731 0.00000,...
# 39     5.557174  MULTIPOLYGON Z (((-122.26933 52.53500 0.00000,...
# 43     3.330806  MULTIPOLYGON Z (((-121.64123 52.53456 0.00000,...
# 44   255.796981  POLYGON Z ((-130.42792 56.65497 0.00000, -130....
# 45    20.122090  POLYGON Z ((-120.50849 50.66585 0.00000, -120....
# 46    25.930891  MULTIPOLYGON Z (((-78.97849 48.26789 0.00000, ...
# 47     2.454670  POLYGON Z ((-123.98510 55.13948 0.00000, -123....
# 57    24.929667  MULTIPOLYGON Z (((-100.97073 56.87094 0.00000,...
# 67    43.630625  MULTIPOLYGON Z (((-81.13563 46.48732 0.00000, ...
# 68    43.630625  MULTIPOLYGON Z (((-81.13563 46.48732 0.00000, ...
# 69     0.772508  MULTIPOLYGON Z (((-74.48351 51.00345 0.00000, ...
# 79    50.870363  MULTIPOLYGON Z (((-80.79782 46.67513 0.00000, ...
# 83    23.177566  MULTIPOLYGON Z (((-80.80209 46.60910 0.00000, ...
# 85     3.793040  MULTIPOLYGON Z (((-129.72184 57.75056 0.00000,...
# 87    11.668498  MULTIPOLYGON Z (((-62.09272 56.37773 0.00000, ...
# 103   60.658382  MULTIPOLYGON Z (((-81.41883 46.66474 0.00000, ...
# 114   81.154078  MULTIPOLYGON Z (((-100.14013 54.86711 0.00000,...
# 119   22.144790  MULTIPOLYGON Z (((-81.35071 46.42285 0.00000, ...
# 120  116.490271  POLYGON Z ((-81.38100 46.41148 0.00000, -81.38...
# 124   10.207294  MULTIPOLYGON Z (((-79.08482 48.22969 0.00000, ...
# 130  259.945835  POLYGON Z ((-130.49620 56.64851 0.00000, -130....
# 143   62.109532  MULTIPOLYGON Z (((-81.36899 48.67882 0.00000, ...
# 157    7.821313  POLYGON Z ((-79.22196 49.57467 0.00000, -79.22...
# 159   91.248363  MULTIPOLYGON Z (((-101.09514 56.81934 0.00000,...
#
#                                              source_id           main_id
# 1    https://www.nature.com/articles/s41597-025-052...  ON-MAIN-3c468faa
# 2    https://www.nature.com/articles/s41597-025-052...  QC-MAIN-5801b453
# 4    https://www.nature.com/articles/s41597-025-052...  QC-MAIN-e51eda66
# 7    https://www.nature.com/articles/s41597-025-052...  BC-MAIN-23155c25
# 9    https://www.nature.com/articles/s41597-025-052...  NB-MAIN-8e04eb21
# 10   https://www.nature.com/articles/s41597-025-052...  QC-MAIN-d29e0839
# 12   https://www.nature.com/articles/s41597-025-052...  ON-MAIN-a3c56a83
# 13   https://www.nature.com/articles/s41597-025-052...  QC-MAIN-c0660aec
# 14   https://www.nature.com/articles/s41597-025-052...  QC-MAIN-02884fb5
# 18   https://www.nature.com/articles/s41597-025-052...  ON-MAIN-7f050560
# 21   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-599152a0
# 27   https://www.nature.com/articles/s41597-025-052...  QC-MAIN-e51eda66
# 38   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-bf503b6b
# 39   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-6b4800fe
# 43   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-3f490561
# 44   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-b1fe389a
# 45   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-aa76f6f2
# 46   https://www.nature.com/articles/s41597-025-052...  QC-MAIN-30c1828c
# 47   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-ed23117f
# 57   https://www.nature.com/articles/s41597-025-052...  MB-MAIN-6fca9d6d
# 67   https://www.nature.com/articles/s41597-025-052...  ON-MAIN-f080c409
# 68   https://www.nature.com/articles/s41597-025-052...  ON-MAIN-de2f9639
# 69   https://www.nature.com/articles/s41597-025-052...  QC-MAIN-b2148882
# 79   https://www.nature.com/articles/s41597-025-052...  ON-MAIN-fcb287a4
# 83   https://www.nature.com/articles/s41597-025-052...  ON-MAIN-fcb287a4
# 85   https://www.nature.com/articles/s41597-025-052...  BC-MAIN-8eb8be0d
# 87   https://www.nature.com/articles/s41597-025-052...  NL-MAIN-2d8801d6
# 103  https://www.nature.com/articles/s41597-025-052...  ON-MAIN-7001a391
# 114  https://www.nature.com/articles/s41597-025-052...  MB-MAIN-be5b3dc8
# 119  https://www.nature.com/articles/s41597-025-052...  ON-MAIN-b1d981ca
# 120  https://www.nature.com/articles/s41597-025-052...  ON-MAIN-9a34108c
# 124  https://www.nature.com/articles/s41597-025-052...  QC-MAIN-30c1828c
# 130  https://www.nature.com/articles/s41597-025-052...  BC-MAIN-b1fe389a
# 143  https://www.nature.com/articles/s41597-025-052...  ON-MAIN-f8313ebd
# 157  https://www.nature.com/articles/s41597-025-052...  QC-MAIN-b86f7d07
# 159  https://www.nature.com/articles/s41597-025-052...  MB-MAIN-6fca9d6d

# %% [markdown]
# ## Point to polygon matching

# %% [markdown]
# ### Protected lands datasets

# %%
from matching_functions import associate_facilities_near_polygons

# %%
wpda_gdf_polygons
# Out:
#         WDPA_PID                                               NAME  \
# 0          611_A               Wood Buffalo National Park Of Canada
# 1          611_B               Wood Buffalo National Park Of Canada
# 2            612             Kluane National Park Reserve Of Canada
# 3          613_B                  Auyuittuq National Park Of Canada
# 4          613_A                  Auyuittuq National Park Of Canada
# ...          ...                                                ...
# 13463  555785733  Grosse Île and the Irish Memorial National His...
# 13464  555785734                 Navy Island National Historic Site
# 13465  555785735  Fort George National Historic Site (Paradise G...
# 13466  555785736                Rideau Canal National Historic Site
# 13467  555785737                            Capital Recreation Area
#
#                           DESIG OWN_TYPE                          MANG_AUTH  \
# 0                 National Park    State                Parks Canada Agency
# 1                 National Park    State                Parks Canada Agency
# 2                 National Park    State                Parks Canada Agency
# 3                 National Park    State                Parks Canada Agency
# 4                 National Park    State                Parks Canada Agency
# ...                         ...      ...                                ...
# 13463  Lieu historique national    State                Parks Canada Agency
# 13464    National Historic Site    State                Parks Canada Agency
# 13465    National Historic Site    State                Parks Canada Agency
# 13466    National Historic Site    State                Parks Canada Agency
# 13467                      OECM    State  National Capital Commission (NCC)
#
#        STATUS_YR                                           geometry  \
# 0           1922  POLYGON ((-112.87253 59.99877, -111.53006 59.7...
# 1           1922  POLYGON ((-112.87253 59.99877, -115.58450 59.9...
# 2           1972  POLYGON ((-141.00187 60.30634, -137.43466 60.7...
# 3           1972  MULTIPOLYGON (((-64.62292 67.13706, -63.92605 ...
# 4           1972  MULTIPOLYGON (((-68.23194 67.76712, -67.56846 ...
# ...          ...                                                ...
# 13463       2023  MULTIPOLYGON (((-70.67843 47.01639, -70.67802 ...
# 13464       2023  POLYGON ((-79.01037 43.04900, -79.00871 43.060...
# 13465       2023  POLYGON ((-79.06782 43.24368, -79.05901 43.248...
# 13466       2023  MULTIPOLYGON (((-76.24341 44.90190, -76.19385 ...
# 13467       2023  POLYGON ((-75.60920 45.33843, -75.61502 45.332...
#
#                              source_id
# 0      https://www.protectedplanet.net
# 1      https://www.protectedplanet.net
# 2      https://www.protectedplanet.net
# 3      https://www.protectedplanet.net
# 4      https://www.protectedplanet.net
# ...                                ...
# 13463  https://www.protectedplanet.net
# 13464  https://www.protectedplanet.net
# 13465  https://www.protectedplanet.net
# 13466  https://www.protectedplanet.net
# 13467  https://www.protectedplanet.net
#
# [13468 rows x 8 columns]

# %%
lt_wpda = associate_facilities_near_polygons(
    main_gdf,
    wpda_gdf_polygons,
    facility_id_col="main_id",
    polygon_id_col="WDPA_PID",
    buffer_km=50,
    crs="EPSG:3978"
)

# %%
wpda_gdf_polygons = wpda_gdf_polygons.merge(lt_wpda, on="WDPA_PID", how="left")

# %%
# For SQL
wpda_gdf_polygons = wpda_gdf_polygons[wpda_gdf_polygons["main_id"].notna()].copy()

# %%
lt_indigenous = associate_facilities_near_polygons(
    main_gdf,
    indigenous_can_gdf,
    facility_id_col="main_id",
    polygon_id_col="indigenous_land_id",
    buffer_km=50,
    crs="EPSG:3978"
)

# %%
indigenous_can_gdf = indigenous_can_gdf.merge(lt_indigenous, on="indigenous_land_id", how="left")

# %%
# For SQL
indigenous_can_gdf = indigenous_can_gdf[indigenous_can_gdf["main_id"].notna()].copy()

# %% [markdown]
# ### Land occupation footprint datasets

# %%
from matching_functions import assign_polygons_to_points
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# 2                None           Agnico Eagle Mines Limited
# 3        GRP-0a2c0d69           Agnico Eagle Mines Limited
# 4                None           Agnico Eagle Mines Limited
# ..                ...                                  ...
# 265              None              Wesdome Gold Mines Ltd.
# 266              None       West High Yield Resources Ltd.
# 267              None  Western Copper and Gold Corporation
# 268              None                                Wyloo
# 269              None                ZincX Resources Corp.
#
#                      company_name_folder    company_id   longitude   latitude  \
# 0                      Abcourt Mines Inc  CMP-0a6a3062  -77.679010  48.521540
# 1                      Abcourt Mines Inc  CMP-0a6a3062  -77.974340  49.132590
# 2             Agnico Eagle Mines Limited  CMP-6265c407  -77.580000  48.040000
# 3             Agnico Eagle Mines Limited  CMP-6265c407  -96.697000  65.415000
# 4             Agnico Eagle Mines Limited  CMP-6265c407  -78.130824  48.122223
# ..                                   ...           ...         ...        ...
# 265               Wesdome Gold Mines Ltd  CMP-3d2c4955  -85.452500  48.110280
# 266        West High Yield Resources Ltd  CMP-1023f9c0 -117.884000  49.082000
# 267  Western Copper and Gold Corporation  CMP-2dac9896 -138.833330  62.733330
# 268                                Wyloo  CMP-65b36728  -86.303800  52.742020
# 269                 ZincX Resources Corp  CMP-3416049b -124.865990  57.380880
#
#                         geometry  ...          province            status  \
# 0     POINT (-77.67901 48.52154)  ...            Quebec  project_facility
# 1     POINT (-77.97434 49.13259)  ...            Quebec   active_facility
# 2     POINT (-77.58000 48.04000)  ...            Quebec  project_facility
# 3     POINT (-96.69700 65.41500)  ...           Nunavut   active_facility
# 4     POINT (-78.13082 48.12222)  ...            Quebec   active_facility
# ..                           ...  ...               ...               ...
# 265   POINT (-85.45250 48.11028)  ...           Ontario   active_facility
# 266  POINT (-117.88400 49.08200)  ...  British Columbia  project_facility
# 267  POINT (-138.83333 62.73333)  ...             Yukon  project_facility
# 268   POINT (-86.30380 52.74202)  ...           Ontario  project_facility
# 269  POINT (-124.86599 57.38088)  ...  British Columbia  project_facility
#
#     activity_status development_stage facility_type  mining_processing_type  \
# 0            Active  Advanced project       project                    None
# 1              None              None        mining            Concentrator
# 2            Active  Advanced project       project                    None
# 3              None              None        mining   Open-pit, underground
# 4              None              None        mining  Open-pit, concentrator
# ..              ...               ...           ...                     ...
# 265            None              None        mining                Open-pit
# 266          Active  Advanced project       project                    None
# 267          Active  Advanced project       project                    None
# 268          Active  Advanced project       project                    None
# 269          Active  Advanced project       project                    None
#
#      commodity_group primary_commodity  \
# 0               None              Zinc
# 1    Precious metals              Gold
# 2               None              Gold
# 3    Precious metals              Gold
# 4    Precious metals              Gold
# ..               ...               ...
# 265  Precious metals              Gold
# 266             None         Magnesium
# 267             None            Copper
# 268             None            Nickel
# 269             None              Zinc
#
#                                    commodities source_id
# 0                                 Zinc, silver      None
# 1                                 Gold, silver      None
# 2                                 Gold, copper      None
# 3                                         Gold      None
# 4                                 Gold, silver      None
# ..                                         ...       ...
# 265                                       Gold      None
# 266                                  Magnesium      None
# 267           Copper, gold, molybdenum, silver      None
# 268  Nickel, copper, gold, platinum, palladium      None
# 269                         Zinc, lead, silver      None
#
# [270 rows x 21 columns]

# %%
assigned_df = assign_polygons_to_points(
    main_gdf,
    tailings_gdf,
    tang_canada_gdf,
    max_dist_km=10
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
assigned_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id  tailing_id  tang_id  distance_km relation_type
# 0    NS-MAIN-c9c77a59         NaN    45954     0.000000   one-to-many
# 1    NS-MAIN-c9c77a59         NaN    45955     1.186584   one-to-many
# 2    NL-MAIN-d9036091         NaN     7631     0.811781   one-to-many
# 3    NL-MAIN-d9036091         NaN     7641     4.647047   one-to-many
# 4    NL-MAIN-d9036091         NaN     7633     0.000000   many-to-one
# ..                ...         ...      ...          ...           ...
# 789  NT-MAIN-6c1d6ee6         NaN    26078     2.857250   one-to-many
# 790  NT-MAIN-6c1d6ee6         NaN    43740     0.833606   one-to-many
# 791  NT-MAIN-6c1d6ee6         NaN     3479     0.000000   one-to-many
# 792  NT-MAIN-6c1d6ee6         NaN    50385     2.150861   one-to-many
# 793  NT-MAIN-6c1d6ee6         NaN    26137     4.650487   one-to-many
#
# [794 rows x 5 columns]

# %%
assigned_df['relation_type'].value_counts()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# relation_type
# one-to-many    707
# many-to-one     56
# one-to-one      31
# Name: count, dtype: int64

# %%
polygon_gdf = tang_canada_gdf.merge(assigned_df, on="tang_id", how="left")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
polygon_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       tang_id                                           geometry  area_km2  \
# 0        6383  POLYGON Z ((1795479.979 -83564.531 0.000, 1795...  0.026130
# 1        6388  POLYGON Z ((1796123.448 -80625.526 0.000, 1796...  0.671399
# 2        6390  POLYGON Z ((1796791.634 -80270.697 0.000, 1796...  0.050909
# 3       45954  POLYGON Z ((2466485.124 185586.547 0.000, 2466...  2.622800
# 4       45955  POLYGON Z ((2465809.682 185862.507 0.000, 2465...  0.441869
# ...       ...                                                ...       ...
# 1915     3399  POLYGON Z ((-717210.659 1915423.857 0.000, -71...  0.541024
# 1916     3401  POLYGON Z ((-715648.337 1916385.463 0.000, -71...  1.053173
# 1917    26364  POLYGON Z ((-717332.782 1916999.286 0.000, -71...  0.079894
# 1918    43739  POLYGON Z ((-713032.430 1919630.086 0.000, -71...  1.519488
# 1919    44287  POLYGON Z ((-466746.640 2074582.808 0.000, -46...  0.121349
#
#                                        source_id           main_id  \
# 0     https://doi.org/10.1038/s43247-023-00805-6               NaN
# 1     https://doi.org/10.1038/s43247-023-00805-6               NaN
# 2     https://doi.org/10.1038/s43247-023-00805-6               NaN
# 3     https://doi.org/10.1038/s43247-023-00805-6  NS-MAIN-c9c77a59
# 4     https://doi.org/10.1038/s43247-023-00805-6  NS-MAIN-c9c77a59
# ...                                          ...               ...
# 1915  https://doi.org/10.1038/s43247-023-00805-6               NaN
# 1916  https://doi.org/10.1038/s43247-023-00805-6               NaN
# 1917  https://doi.org/10.1038/s43247-023-00805-6               NaN
# 1918  https://doi.org/10.1038/s43247-023-00805-6               NaN
# 1919  https://doi.org/10.1038/s43247-023-00805-6               NaN
#
#       tailing_id  distance_km relation_type
# 0            NaN          NaN           NaN
# 1            NaN          NaN           NaN
# 2            NaN          NaN           NaN
# 3            NaN     0.000000   one-to-many
# 4            NaN     1.186584   one-to-many
# ...          ...          ...           ...
# 1915         NaN          NaN           NaN
# 1916         NaN          NaN           NaN
# 1917         NaN          NaN           NaN
# 1918         NaN          NaN           NaN
# 1919         NaN          NaN           NaN
#
# [1920 rows x 8 columns]

# %%
from visualization_functions import plot_polygons_assginment

# %%
plot_polygons_assginment(
    main_gdf,
    tailings_gdf,
    polygon_gdf, 
    output_html="results/data_coverage/facilities_tailings_maps.html"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Map saved to results/data_coverage/facilities_tailings_maps.html

# %% [markdown]
# # Create final tables

# %% [markdown]
# ## Main table

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# 2                None           Agnico Eagle Mines Limited
# 3        GRP-0a2c0d69           Agnico Eagle Mines Limited
# 4                None           Agnico Eagle Mines Limited
# ..                ...                                  ...
# 265              None              Wesdome Gold Mines Ltd.
# 266              None       West High Yield Resources Ltd.
# 267              None  Western Copper and Gold Corporation
# 268              None                                Wyloo
# 269              None                ZincX Resources Corp.
#
#                      company_name_folder    company_id   longitude   latitude  \
# 0                      Abcourt Mines Inc  CMP-0a6a3062  -77.679010  48.521540
# 1                      Abcourt Mines Inc  CMP-0a6a3062  -77.974340  49.132590
# 2             Agnico Eagle Mines Limited  CMP-6265c407  -77.580000  48.040000
# 3             Agnico Eagle Mines Limited  CMP-6265c407  -96.697000  65.415000
# 4             Agnico Eagle Mines Limited  CMP-6265c407  -78.130824  48.122223
# ..                                   ...           ...         ...        ...
# 265               Wesdome Gold Mines Ltd  CMP-3d2c4955  -85.452500  48.110280
# 266        West High Yield Resources Ltd  CMP-1023f9c0 -117.884000  49.082000
# 267  Western Copper and Gold Corporation  CMP-2dac9896 -138.833330  62.733330
# 268                                Wyloo  CMP-65b36728  -86.303800  52.742020
# 269                 ZincX Resources Corp  CMP-3416049b -124.865990  57.380880
#
#                         geometry  ...          province            status  \
# 0     POINT (-77.67901 48.52154)  ...            Quebec  project_facility
# 1     POINT (-77.97434 49.13259)  ...            Quebec   active_facility
# 2     POINT (-77.58000 48.04000)  ...            Quebec  project_facility
# 3     POINT (-96.69700 65.41500)  ...           Nunavut   active_facility
# 4     POINT (-78.13082 48.12222)  ...            Quebec   active_facility
# ..                           ...  ...               ...               ...
# 265   POINT (-85.45250 48.11028)  ...           Ontario   active_facility
# 266  POINT (-117.88400 49.08200)  ...  British Columbia  project_facility
# 267  POINT (-138.83333 62.73333)  ...             Yukon  project_facility
# 268   POINT (-86.30380 52.74202)  ...           Ontario  project_facility
# 269  POINT (-124.86599 57.38088)  ...  British Columbia  project_facility
#
#     activity_status development_stage facility_type  mining_processing_type  \
# 0            Active  Advanced project       project                    None
# 1              None              None        mining            Concentrator
# 2            Active  Advanced project       project                    None
# 3              None              None        mining   Open-pit, underground
# 4              None              None        mining  Open-pit, concentrator
# ..              ...               ...           ...                     ...
# 265            None              None        mining                Open-pit
# 266          Active  Advanced project       project                    None
# 267          Active  Advanced project       project                    None
# 268          Active  Advanced project       project                    None
# 269          Active  Advanced project       project                    None
#
#      commodity_group primary_commodity  \
# 0               None              Zinc
# 1    Precious metals              Gold
# 2               None              Gold
# 3    Precious metals              Gold
# 4    Precious metals              Gold
# ..               ...               ...
# 265  Precious metals              Gold
# 266             None         Magnesium
# 267             None            Copper
# 268             None            Nickel
# 269             None              Zinc
#
#                                    commodities source_id
# 0                                 Zinc, silver      None
# 1                                 Gold, silver      None
# 2                                 Gold, copper      None
# 3                                         Gold      None
# 4                                 Gold, silver      None
# ..                                         ...       ...
# 265                                       Gold      None
# 266                                  Magnesium      None
# 267           Copper, gold, molybdenum, silver      None
# 268  Nickel, copper, gold, platinum, palladium      None
# 269                         Zinc, lead, silver      None
#
# [270 rows x 21 columns]

# %%
ownership_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Ownership')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Integrate ownership information into the main_gdf 
main_gdf = main_gdf.merge(
    ownership_df[['main_id', 'owner(s)', 'operator(s)', 'company_URL', 'company_facility_URL', 'MDO_URL']],
    on='main_id',
    how='left'
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# # Integrate the operation_periods from min_can_gdf into the main_gdf
main_gdf = main_gdf.merge(
     min_can_gdf[['main_id', 'operation_periods']],
     on='main_id',
     how='left'
 )
# 
# # Add the source_id for MinCan only where operation_periods are not null
main_gdf['source_id'] = main_gdf.apply(
     lambda row: row['source_id'] + ';' + 'https://doi.org/10.1038/s41597-024-03116-3' if pd.notna(row['operation_periods']) else row['source_id'],
     axis=1
 )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[295], line 9
#       2 main_gdf = main_gdf.merge(
#       3      min_can_gdf[['main_id', 'operation_periods']],
#       4      on='main_id',
#       5      how='left'
#       6  )
#       7 #
#       8 # # Add the source_id for MinCan only where operation_periods are not null
# ----> 9 main_gdf['source_id'] = main_gdf.apply(
#      10      lambda row: row['source_id'] + ';' + 'https://doi.org/10.1038/s41597-024-03116-3' if pd.notna(row['operation_periods']) else row['source_id'],
#      11      axis=1
#      12  )
#
# File ~\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1571, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1569 @doc(pd.DataFrame)
#    1570 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1571     result = super().apply(
#    1572         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1573     )
#    1574     # pandas <1.4 re-attach last geometry col if lost
#    1575     if (
#    1576         not compat.PANDAS_GE_14
#    1577         and isinstance(result, GeoDataFrame)
#    1578         and result._geometry_column_name is None
#    1579     ):
#
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[295], line 10, in <lambda>(row)
#       2 main_gdf = main_gdf.merge(
#       3      min_can_gdf[['main_id', 'operation_periods']],
#       4      on='main_id',
#       5      how='left'
#       6  )
#       7 #
#       8 # # Add the source_id for MinCan only where operation_periods are not null
#       9 main_gdf['source_id'] = main_gdf.apply(
# ---> 10      lambda row: row['source_id'] + ';' + 'https://doi.org/10.1038/s41597-024-03116-3' if pd.notna(row['operation_periods']) else row['source_id'],
#      11      axis=1
#      12  )
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# 2                None           Agnico Eagle Mines Limited
# 3        GRP-0a2c0d69           Agnico Eagle Mines Limited
# 4                None           Agnico Eagle Mines Limited
# ..                ...                                  ...
# 265              None              Wesdome Gold Mines Ltd.
# 266              None       West High Yield Resources Ltd.
# 267              None  Western Copper and Gold Corporation
# 268              None                                Wyloo
# 269              None                ZincX Resources Corp.
#
#                      company_name_folder    company_id   longitude   latitude  \
# 0                      Abcourt Mines Inc  CMP-0a6a3062  -77.679010  48.521540
# 1                      Abcourt Mines Inc  CMP-0a6a3062  -77.974340  49.132590
# 2             Agnico Eagle Mines Limited  CMP-6265c407  -77.580000  48.040000
# 3             Agnico Eagle Mines Limited  CMP-6265c407  -96.697000  65.415000
# 4             Agnico Eagle Mines Limited  CMP-6265c407  -78.130824  48.122223
# ..                                   ...           ...         ...        ...
# 265               Wesdome Gold Mines Ltd  CMP-3d2c4955  -85.452500  48.110280
# 266        West High Yield Resources Ltd  CMP-1023f9c0 -117.884000  49.082000
# 267  Western Copper and Gold Corporation  CMP-2dac9896 -138.833330  62.733330
# 268                                Wyloo  CMP-65b36728  -86.303800  52.742020
# 269                 ZincX Resources Corp  CMP-3416049b -124.865990  57.380880
#
#                         geometry  ...  commodity_group primary_commodity  \
# 0     POINT (-77.67901 48.52154)  ...             None              Zinc
# 1     POINT (-77.97434 49.13259)  ...  Precious metals              Gold
# 2     POINT (-77.58000 48.04000)  ...             None              Gold
# 3     POINT (-96.69700 65.41500)  ...  Precious metals              Gold
# 4     POINT (-78.13082 48.12222)  ...  Precious metals              Gold
# ..                           ...  ...              ...               ...
# 265   POINT (-85.45250 48.11028)  ...  Precious metals              Gold
# 266  POINT (-117.88400 49.08200)  ...             None         Magnesium
# 267  POINT (-138.83333 62.73333)  ...             None            Copper
# 268   POINT (-86.30380 52.74202)  ...             None            Nickel
# 269  POINT (-124.86599 57.38088)  ...             None              Zinc
#
#                                    commodities  \
# 0                                 Zinc, silver
# 1                                 Gold, silver
# 2                                 Gold, copper
# 3                                         Gold
# 4                                 Gold, silver
# ..                                         ...
# 265                                       Gold
# 266                                  Magnesium
# 267           Copper, gold, molybdenum, silver
# 268  Nickel, copper, gold, platinum, palladium
# 269                         Zinc, lead, silver
#
#                                              source_id  \
# 0    https://open.canada.ca/data/en/dataset/22b2db8...
# 1    https://open.canada.ca/data/en/dataset/000183e...
# 2    https://open.canada.ca/data/en/dataset/22b2db8...
# 3    https://open.canada.ca/data/en/dataset/000183e...
# 4    https://open.canada.ca/data/en/dataset/000183e...
# ..                                                 ...
# 265  https://open.canada.ca/data/en/dataset/000183e...
# 266  https://open.canada.ca/data/en/dataset/22b2db8...
# 267  https://open.canada.ca/data/en/dataset/22b2db8...
# 268  https://open.canada.ca/data/en/dataset/22b2db8...
# 269  https://open.canada.ca/data/en/dataset/22b2db8...
#
#                               owner(s)                 operator(s)  \
# 0                                  NaN                         NaN
# 1             Abcourt Mines Inc (100%)           Abcourt Mines Inc
# 2                                  NaN                         NaN
# 3    Agnico Eagle Mines Limited (100%)  Agnico Eagle Mines Limited
# 4    Agnico Eagle Mines Limited (100%)  Agnico Eagle Mines Limited
# ..                                 ...                         ...
# 265      Wesdome Gold Mines Ltd (100%)                         NaN
# 266                                NaN                         NaN
# 267                                NaN                         NaN
# 268                                NaN                         NaN
# 269                                NaN                         NaN
#
#                                            company_URL  \
# 0                                                  NaN
# 1                                https://abcourt.info/
# 2            https://agnicoeagle.com/Home/default.aspx
# 3            https://agnicoeagle.com/Home/default.aspx
# 4            https://agnicoeagle.com/Home/default.aspx
# ..                                                 ...
# 265  https://www.wesdome.com/English/overview/defau...
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#                                   company_facility_URL  \
# 0                                                  NaN
# 1    https://abcourt.info/projects/the-sleeping-gia...
# 2    https://www.agnicoeagle.com/English/operations...
# 3    https://www.agnicoeagle.com/English/operations...
# 4    https://www.agnicoeagle.com/English/operations...
# ..                                                 ...
# 265  https://www.wesdome.com/English/operations/kie...
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#                                                MDO_URL  \
# 0                                                  NaN
# 1    https://miningdataonline.com/property/1589/Sle...
# 2    https://miningdataonline.com/property/47/Meado...
# 3    https://miningdataonline.com/property/46/LaRon...
# 4    https://miningdataonline.com/property/13/Detou...
# ..                                                 ...
# 265  https://miningdataonline.com/property/3048/Kie...
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#                    operation_periods
# 0                                NaN
# 1    1956–1959; 1974–1975; 1988–open
# 2                                NaN
# 3                          2019–open
# 4               1935–1965; 2011–open
# ..                               ...
# 265                        2002–open
# 266                              NaN
# 267                              NaN
# 268                              NaN
# 269                              NaN
#
# [270 rows x 27 columns]

# %%
main_gdf.rename(columns={
    'company_name_folder': 'company_name',
    'company_facility_URL': 'facility_URL'
}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
column_order = [
       'main_id', 'facility_name', 'facility_group_id', 'facility_group_name', 'company_id', 'company_name',
       'city', 'province', 'geometry',
       'status', 'activity_status', 'development_stage', 'facility_type', 'mining_processing_type',
       'commodity_group', 'commodities',
       'owner(s)', 'operator(s)', 'operation_periods', 
       'company_URL', 'facility_URL', 'MDO_URL', 
       'source_id'
]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Fix column orders
main_gdf = main_gdf[column_order].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_id  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue              None
# 1    QC-MAIN-d29e0839     Sleeping Giant              None
# 2    QC-MAIN-f1ff4920       Akasaba West              None
# 3    NU-MAIN-4ea8ac9d             Amaruq      GRP-0a2c0d69
# 4    QC-MAIN-e7e6a960  Canadian Malartic              None
# ..                ...                ...               ...
# 265  ON-MAIN-c5fefb01              Mishi              None
# 266  BC-MAIN-feb13c30       Record Ridge              None
# 267  YT-MAIN-5e0d8b48             Casino              None
# 268  ON-MAIN-12c68d49       Eagle's Nest              None
# 269  BC-MAIN-891d3cb5               Akie              None
#
#     facility_group_name    company_id                         company_name  \
# 0                  None  CMP-0a6a3062                    Abcourt Mines Inc
# 1                  None  CMP-0a6a3062                    Abcourt Mines Inc
# 2                  None  CMP-6265c407           Agnico Eagle Mines Limited
# 3    Meadowbank complex  CMP-6265c407           Agnico Eagle Mines Limited
# 4                  None  CMP-6265c407           Agnico Eagle Mines Limited
# ..                  ...           ...                                  ...
# 265                None  CMP-3d2c4955               Wesdome Gold Mines Ltd
# 266                None  CMP-1023f9c0        West High Yield Resources Ltd
# 267                None  CMP-2dac9896  Western Copper and Gold Corporation
# 268                None  CMP-65b36728                                Wyloo
# 269                None  CMP-3416049b                 ZincX Resources Corp
#
#               city          province                     geometry  \
# 0             None            Quebec   POINT (-77.67901 48.52154)
# 1    north of Amos            Quebec   POINT (-77.97434 49.13259)
# 2             None            Quebec   POINT (-77.58000 48.04000)
# 3       Baker Lake           Nunavut   POINT (-96.69700 65.41500)
# 4         Malartic            Quebec   POINT (-78.13082 48.12222)
# ..             ...               ...                          ...
# 265           Wawa           Ontario   POINT (-85.45250 48.11028)
# 266           None  British Columbia  POINT (-117.88400 49.08200)
# 267           None             Yukon  POINT (-138.83333 62.73333)
# 268           None           Ontario   POINT (-86.30380 52.74202)
# 269           None  British Columbia  POINT (-124.86599 57.38088)
#
#                status  ...  mining_processing_type  commodity_group  \
# 0    project_facility  ...                    None             None
# 1     active_facility  ...            Concentrator  Precious metals
# 2    project_facility  ...                    None             None
# 3     active_facility  ...   Open-pit, underground  Precious metals
# 4     active_facility  ...  Open-pit, concentrator  Precious metals
# ..                ...  ...                     ...              ...
# 265   active_facility  ...                Open-pit  Precious metals
# 266  project_facility  ...                    None             None
# 267  project_facility  ...                    None             None
# 268  project_facility  ...                    None             None
# 269  project_facility  ...                    None             None
#
#                                    commodities  \
# 0                                 Zinc, silver
# 1                                 Gold, silver
# 2                                 Gold, copper
# 3                                         Gold
# 4                                 Gold, silver
# ..                                         ...
# 265                                       Gold
# 266                                  Magnesium
# 267           Copper, gold, molybdenum, silver
# 268  Nickel, copper, gold, platinum, palladium
# 269                         Zinc, lead, silver
#
#                               owner(s)                 operator(s)  \
# 0                                  NaN                         NaN
# 1             Abcourt Mines Inc (100%)           Abcourt Mines Inc
# 2                                  NaN                         NaN
# 3    Agnico Eagle Mines Limited (100%)  Agnico Eagle Mines Limited
# 4    Agnico Eagle Mines Limited (100%)  Agnico Eagle Mines Limited
# ..                                 ...                         ...
# 265      Wesdome Gold Mines Ltd (100%)                         NaN
# 266                                NaN                         NaN
# 267                                NaN                         NaN
# 268                                NaN                         NaN
# 269                                NaN                         NaN
#
#                    operation_periods  \
# 0                                NaN
# 1    1956–1959; 1974–1975; 1988–open
# 2                                NaN
# 3                          2019–open
# 4               1935–1965; 2011–open
# ..                               ...
# 265                        2002–open
# 266                              NaN
# 267                              NaN
# 268                              NaN
# 269                              NaN
#
#                                            company_URL  \
# 0                                                  NaN
# 1                                https://abcourt.info/
# 2            https://agnicoeagle.com/Home/default.aspx
# 3            https://agnicoeagle.com/Home/default.aspx
# 4            https://agnicoeagle.com/Home/default.aspx
# ..                                                 ...
# 265  https://www.wesdome.com/English/overview/defau...
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#                                           facility_URL  \
# 0                                                  NaN
# 1    https://abcourt.info/projects/the-sleeping-gia...
# 2    https://www.agnicoeagle.com/English/operations...
# 3    https://www.agnicoeagle.com/English/operations...
# 4    https://www.agnicoeagle.com/English/operations...
# ..                                                 ...
# 265  https://www.wesdome.com/English/operations/kie...
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#                                                MDO_URL source_id
# 0                                                  NaN      None
# 1    https://miningdataonline.com/property/1589/Sle...      None
# 2    https://miningdataonline.com/property/47/Meado...      None
# 3    https://miningdataonline.com/property/46/LaRon...      None
# 4    https://miningdataonline.com/property/13/Detou...      None
# ..                                                 ...       ...
# 265  https://miningdataonline.com/property/3048/Kie...      None
# 266                                                NaN      None
# 267                                                NaN      None
# 268                                                NaN      None
# 269                                                NaN      None
#
# [270 rows x 23 columns]

# %% [markdown]
# ## Environment table

# %% [markdown]
# ### CTrace dataset

# %%
ctrace_ghg_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ctrace_id  year  emissions_quantity         gas  \
# 6     1754055  2023        5.610000e+03  co2e_100yr
# 7     1754056  2023        6.403000e+03  co2e_100yr
# 8     1754057  2023        2.299160e+05  co2e_100yr
# 9     1754058  2023        2.639000e+03  co2e_100yr
# 11    1754060  2023        4.225000e+03  co2e_100yr
# 12    1754061  2023        1.316380e+05  co2e_100yr
# 16    1754066  2023        2.412130e+06  co2e_100yr
# 17    1754067  2023        0.000000e+00  co2e_100yr
# 25    1754077  2023        6.711600e+04  co2e_100yr
# 29    1754081  2023        7.782000e+03  co2e_100yr
# 30    1754082  2023        0.000000e+00  co2e_100yr
# 31    1754083  2023        0.000000e+00  co2e_100yr
# 32    1754084  2023        7.956600e+04  co2e_100yr
# 33    1754085  2023        7.137900e+04  co2e_100yr
# 34    1754086  2023        5.400000e+02  co2e_100yr
# 35    1754087  2023        1.590800e+04  co2e_100yr
# 43    1754096  2023        8.219000e+03  co2e_100yr
# 44    1754097  2023        8.451100e+04  co2e_100yr
# 51    1754104  2023        3.367000e+03  co2e_100yr
# 52    1754105  2023        0.000000e+00  co2e_100yr
# 54   25486533  2023        1.620000e+04  co2e_100yr
# 55   25486534  2023        5.914500e+04  co2e_100yr
# 56   36395102  2023        5.760720e+05  co2e_100yr
#
#                                             source_id  substance_id  \
# 6   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 7   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 8   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 9   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 11  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 12  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 16  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 17  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 25  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 29  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 30  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 31  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 32  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 33  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 34  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 35  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 43  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 44  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 51  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 52  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 54  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 55  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 56  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
#
#    compartment_id           main_id
# 6   CMPf3265e9fca  ON-MAIN-6e9b2449
# 7   CMPf3265e9fca  ON-MAIN-63b394c3
# 8   CMPf3265e9fca  BC-MAIN-599152a0
# 9   CMPf3265e9fca  ON-MAIN-52224e1e
# 11  CMPf3265e9fca  ON-MAIN-48fe2205
# 12  CMPf3265e9fca  BC-MAIN-6b4800fe
# 16  CMPf3265e9fca  BC-MAIN-bf503b6b
# 17  CMPf3265e9fca  QC-MAIN-30c1828c
# 25  CMPf3265e9fca  QC-MAIN-e51eda66
# 29  CMPf3265e9fca  ON-MAIN-7001a391
# 30  CMPf3265e9fca  NL-MAIN-c139de6d
# 31  CMPf3265e9fca  YT-MAIN-752fbcae
# 32  CMPf3265e9fca  BC-MAIN-ed23117f
# 33  CMPf3265e9fca  BC-MAIN-3f490561
# 34  CMPf3265e9fca  BC-MAIN-23155c25
# 35  CMPf3265e9fca  BC-MAIN-aa76f6f2
# 43  CMPf3265e9fca  QC-MAIN-a97821c0
# 44  CMPf3265e9fca  BC-MAIN-8eb8be0d
# 51  CMPf3265e9fca  ON-MAIN-28f3f0fc
# 52  CMPf3265e9fca  QC-MAIN-b2148882
# 54  CMPf3265e9fca  ON-MAIN-f8313ebd
# 55  CMPf3265e9fca  ON-MAIN-a3c56a83
# 56  CMPf3265e9fca  NL-MAIN-b64bae7a

# %%
ctrace_ghg_gdf.rename(columns={
    'ctrace_id': 'env_id',
    'emissions_quantity': 'value',
    'gas': 'unit'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_ghg_gdf['unit'] = ctrace_ghg_gdf['unit'].replace({'co2e_100yr': 'tCO2eq'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_ghg_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       env_id  year         value    unit  \
# 6    1754055  2023  5.610000e+03  tCO2eq
# 7    1754056  2023  6.403000e+03  tCO2eq
# 8    1754057  2023  2.299160e+05  tCO2eq
# 9    1754058  2023  2.639000e+03  tCO2eq
# 11   1754060  2023  4.225000e+03  tCO2eq
# 12   1754061  2023  1.316380e+05  tCO2eq
# 16   1754066  2023  2.412130e+06  tCO2eq
# 17   1754067  2023  0.000000e+00  tCO2eq
# 25   1754077  2023  6.711600e+04  tCO2eq
# 29   1754081  2023  7.782000e+03  tCO2eq
# 30   1754082  2023  0.000000e+00  tCO2eq
# 31   1754083  2023  0.000000e+00  tCO2eq
# 32   1754084  2023  7.956600e+04  tCO2eq
# 33   1754085  2023  7.137900e+04  tCO2eq
# 34   1754086  2023  5.400000e+02  tCO2eq
# 35   1754087  2023  1.590800e+04  tCO2eq
# 43   1754096  2023  8.219000e+03  tCO2eq
# 44   1754097  2023  8.451100e+04  tCO2eq
# 51   1754104  2023  3.367000e+03  tCO2eq
# 52   1754105  2023  0.000000e+00  tCO2eq
# 54  25486533  2023  1.620000e+04  tCO2eq
# 55  25486534  2023  5.914500e+04  tCO2eq
# 56  36395102  2023  5.760720e+05  tCO2eq
#
#                                             source_id  substance_id  \
# 6   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 7   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 8   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 9   Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 11  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 12  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 16  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 17  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 25  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 29  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 30  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 31  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 32  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 33  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 34  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 35  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 43  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 44  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 51  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 52  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 54  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 55  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
# 56  Jolleys, M. et al (2024). Mineral Extraction s...           NaN
#
#    compartment_id           main_id
# 6   CMPf3265e9fca  ON-MAIN-6e9b2449
# 7   CMPf3265e9fca  ON-MAIN-63b394c3
# 8   CMPf3265e9fca  BC-MAIN-599152a0
# 9   CMPf3265e9fca  ON-MAIN-52224e1e
# 11  CMPf3265e9fca  ON-MAIN-48fe2205
# 12  CMPf3265e9fca  BC-MAIN-6b4800fe
# 16  CMPf3265e9fca  BC-MAIN-bf503b6b
# 17  CMPf3265e9fca  QC-MAIN-30c1828c
# 25  CMPf3265e9fca  QC-MAIN-e51eda66
# 29  CMPf3265e9fca  ON-MAIN-7001a391
# 30  CMPf3265e9fca  NL-MAIN-c139de6d
# 31  CMPf3265e9fca  YT-MAIN-752fbcae
# 32  CMPf3265e9fca  BC-MAIN-ed23117f
# 33  CMPf3265e9fca  BC-MAIN-3f490561
# 34  CMPf3265e9fca  BC-MAIN-23155c25
# 35  CMPf3265e9fca  BC-MAIN-aa76f6f2
# 43  CMPf3265e9fca  QC-MAIN-a97821c0
# 44  CMPf3265e9fca  BC-MAIN-8eb8be0d
# 51  CMPf3265e9fca  ON-MAIN-28f3f0fc
# 52  CMPf3265e9fca  QC-MAIN-b2148882
# 54  CMPf3265e9fca  ON-MAIN-f8313ebd
# 55  CMPf3265e9fca  ON-MAIN-a3c56a83
# 56  CMPf3265e9fca  NL-MAIN-b64bae7a

# %% [markdown]
# ### NPRI dataset

# %%
pollutant_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                     row_id           main_id  year               value  \
# 0         npri-1568-2023-1  ON-MAIN-1f126a43  2023               0.636
# 1         npri-1568-2023-2  ON-MAIN-1f126a43  2023               0.116
# 2         npri-1568-2023-3  ON-MAIN-1f126a43  2023              76.208
# 3         npri-1568-2023-4  ON-MAIN-1f126a43  2023             0.00105
# 4         npri-1568-2023-5  ON-MAIN-1f126a43  2023                0.18
# ...                    ...               ...   ...                 ...
# 24116  npri-28761-2023-117  NL-MAIN-d9036091  2023               4.405
# 24117  npri-28761-2023-118  NL-MAIN-d9036091  2023              0.2475
# 24118  npri-28761-2023-119  NL-MAIN-d9036091  2023  29.277299999999997
# 24119  npri-28761-2023-120  NL-MAIN-d9036091  2023               0.485
# 24120  npri-28761-2023-121  NL-MAIN-d9036091  2023  39.214054000000004
#
#          unit compartment_id   substance_id  \
# 0      tonnes  CMP1718f4466d  SUB1c6e015419
# 1          kg  CMP1718f4466d  SUB0cbc90a094
# 2      tonnes  CMP1718f4466d  SUB642eab0862
# 3      tonnes  CMP1718f4466d  SUB7e3f017a30
# 4          kg  CMP1718f4466d  SUBd94d47b1d8
# ...       ...            ...            ...
# 24116  tonnes  CMP281acc6045  SUB4cedd6b899
# 24117  tonnes  CMP281acc6045  SUBda6a6d231d
# 24118  tonnes  CMP281acc6045  SUB28f44d0e11
# 24119  tonnes  CMP281acc6045  SUBba3b5d11c7
# 24120  tonnes  CMP281acc6045  SUBae95939c3f
#
#                                                source_id
# 0      https://www.canada.ca/en/environment-climate-c...
# 1      https://www.canada.ca/en/environment-climate-c...
# 2      https://www.canada.ca/en/environment-climate-c...
# 3      https://www.canada.ca/en/environment-climate-c...
# 4      https://www.canada.ca/en/environment-climate-c...
# ...                                                  ...
# 24116  https://www.canada.ca/en/environment-climate-c...
# 24117  https://www.canada.ca/en/environment-climate-c...
# 24118  https://www.canada.ca/en/environment-climate-c...
# 24119  https://www.canada.ca/en/environment-climate-c...
# 24120  https://www.canada.ca/en/environment-climate-c...
#
# [13687 rows x 8 columns]

# %%
pollutant_gdf.rename(columns={
    'row_id': 'env_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### GHG dataset

# %%
ghg_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                row_id           main_id  year   value  \
# 1    GHG-10101-2022-1  NT-MAIN-6c1d6ee6  2022  164.88
# 4    GHG-10188-2022-1  QC-MAIN-084bd95c  2022  293.10
# 7    GHG-10240-2022-1  QC-MAIN-a97821c0  2022  129.26
# 8    GHG-10299-2022-1  QC-MAIN-e25eed27  2022  909.89
# 9    GHG-10350-2022-1  NL-MAIN-b64bae7a  2022  110.93
# ..                ...               ...   ...     ...
# 153  GHG-10791-2022-1  QC-MAIN-c1c7eb99  2022   96.48
# 154  GHG-10810-2022-1  NL-MAIN-d9036091  2022   50.09
# 169  GHG-11723-2022-1  ON-MAIN-2e13aaa0  2022   14.17
# 170  GHG-11730-2022-1  QC-MAIN-92628f16  2022  380.82
# 178  GHG-12298-2022-1  ON-MAIN-63b394c3  2022  330.67
#
#                                                   unit compartment_id  \
# 1    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 4    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 7    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 8    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 9    kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# ..                                                 ...            ...
# 153  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 154  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 169  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 170  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
# 178  kilotonnes of carbon dioxide equivalents (kt C...  CMPf3265e9fca
#
#      substance_id                                          source_id
# 1             NaN  https://www.canada.ca/en/environment-climate-c...
# 4             NaN  https://www.canada.ca/en/environment-climate-c...
# 7             NaN  https://www.canada.ca/en/environment-climate-c...
# 8             NaN  https://www.canada.ca/en/environment-climate-c...
# 9             NaN  https://www.canada.ca/en/environment-climate-c...
# ..            ...                                                ...
# 153           NaN  https://www.canada.ca/en/environment-climate-c...
# 154           NaN  https://www.canada.ca/en/environment-climate-c...
# 169           NaN  https://www.canada.ca/en/environment-climate-c...
# 170           NaN  https://www.canada.ca/en/environment-climate-c...
# 178           NaN  https://www.canada.ca/en/environment-climate-c...
#
# [65 rows x 8 columns]

# %%
ghg_gdf.rename(columns={'row_id': 'env_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ghg_gdf['unit'] = ghg_gdf['unit'].replace({'kilotonnes of carbon dioxide equivalents (kt CO2 eq)': 'ktCO2eq'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Manually collected data

# %%
env_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    row_id  year reporting_level      reported_company_nrcan  \
# 0     ENV-1f126a43-2023-1  2023   Site-specific  Agnico Eagle Mines Limited
# 1     ENV-1f126a43-2023-2  2023   Site-specific  Agnico Eagle Mines Limited
# 2     ENV-e7e6a960-2023-1  2023   Site-specific  Agnico Eagle Mines Limited
# 3     ENV-e7e6a960-2023-2  2023   Site-specific  Agnico Eagle Mines Limited
# 4     ENV-8b0264c9-2023-1  2023   Site-specific  Agnico Eagle Mines Limited
# ..                    ...   ...             ...                         ...
# 745  ENV-9de9bb0d-2023-19  2023   Site-specific      Wesdome Gold Mines Ltd
# 746  ENV-c5fefb01-2023-16  2023   Site-specific      Wesdome Gold Mines Ltd
# 747  ENV-c5fefb01-2023-17  2023   Site-specific      Wesdome Gold Mines Ltd
# 748  ENV-c5fefb01-2023-18  2023   Site-specific      Wesdome Gold Mines Ltd
# 749  ENV-c5fefb01-2023-19  2023   Site-specific      Wesdome Gold Mines Ltd
#
#                   name           main_id facility_group_id company_id  \
# 0    Canadian Malartic  ON-MAIN-1f126a43                 -        NaN
# 1    Canadian Malartic  ON-MAIN-1f126a43                 -        NaN
# 2          Detour Lake  QC-MAIN-e7e6a960                 -        NaN
# 3          Detour Lake  QC-MAIN-e7e6a960                 -        NaN
# 4               Goldex  NU-MAIN-8b0264c9                 -        NaN
# ..                 ...               ...               ...        ...
# 745        Eagle River  QC-MAIN-9de9bb0d                 -        NaN
# 746              Kiena  ON-MAIN-c5fefb01                 -        NaN
# 747              Kiena  ON-MAIN-c5fefb01                 -        NaN
# 748              Kiena  ON-MAIN-c5fefb01                 -        NaN
# 749              Kiena  ON-MAIN-c5fefb01                 -        NaN
#
#     facility_type     mining_processing_type  ...  \
# 0          mining  Underground, concentrator  ...
# 1          mining  Underground, concentrator  ...
# 2          mining     Open-pit, concentrator  ...
# 3          mining     Open-pit, concentrator  ...
# 4          mining  Underground, concentrator  ...
# ..            ...                        ...  ...
# 745        mining  Underground, concentrator  ...
# 746        mining     Open-pit, concentrator  ...
# 747        mining     Open-pit, concentrator  ...
# 748        mining     Open-pit, concentrator  ...
# 749        mining     Open-pit, concentrator  ...
#
#                               subflow_type substance_name unit   value  \
# 0                                        -            SOx    t     315
# 1                                        -            NOx    t    4802
# 2                                        -            SOx    t     486
# 3                                        -            NOx    t    7414
# 4                                        -            SOx    t      38
# ..                                     ...            ...  ...     ...
# 745                 Total water discharged              -   m3  324347
# 746                       Water withdrawal              -   m3  168115
# 747  Water withdrawal|Freshwater withdrawn              -   m3  168115
# 748                Total water consumption              -   m3   82144
# 749                 Total water discharged              -   m3  536420
#
#                                                comment  \
# 0    "In absence of site-level monitoring emission ...
# 1    "In absence of site-level monitoring emission ...
# 2    "In absence of site-level monitoring emission ...
# 3    "In absence of site-level monitoring emission ...
# 4    "In absence of site-level monitoring emission ...
# ..                                                 ...
# 745                                                NaN
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
#
#                                         source  \
# 0    2023-Sustainability-Performance_data.xlsx
# 1    2023-Sustainability-Performance_data.xlsx
# 2    2023-Sustainability-Performance_data.xlsx
# 3    2023-Sustainability-Performance_data.xlsx
# 4    2023-Sustainability-Performance_data.xlsx
# ..                                         ...
# 745                  2023-ESG-Data-Tables.xlsx
# 746                  2023-ESG-Data-Tables.xlsx
# 747                  2023-ESG-Data-Tables.xlsx
# 748                  2023-ESG-Data-Tables.xlsx
# 749                  2023-ESG-Data-Tables.xlsx
#
#                                              source_id   substance_id  \
# 0    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB2c1715b8f1
# 1    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB515573c582
# 2    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB2c1715b8f1
# 3    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB515573c582
# 4    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB2c1715b8f1
# ..                                                 ...            ...
# 745       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 746       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 747       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 748       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 749       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
#
#     compartment_pathway compartment_id
# 0           Unspecified  CMPf3265e9fca
# 1           Unspecified  CMPf3265e9fca
# 2           Unspecified  CMPf3265e9fca
# 3           Unspecified  CMPf3265e9fca
# 4           Unspecified  CMPf3265e9fca
# ..                  ...            ...
# 745         Unspecified  CMP68bd334352
# 746         Unspecified  CMP68bd334352
# 747         Unspecified  CMP68bd334352
# 748         Unspecified  CMP68bd334352
# 749         Unspecified  CMP68bd334352
#
# [750 rows x 23 columns]

# %%
env_df.rename(columns={'row_id': 'env_id'}, inplace=True)
env_df.drop(columns=['reporting_level', 'reported_company_nrcan', 'name', 'facility_type', 'mining_processing_type', 'commodity','compartment', 'flow_type','subflow_type', 'substance_name', 'source', 'compartment_pathway'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    env_id  year           main_id facility_group_id  \
# 0     ENV-1f126a43-2023-1  2023  ON-MAIN-1f126a43                 -
# 1     ENV-1f126a43-2023-2  2023  ON-MAIN-1f126a43                 -
# 2     ENV-e7e6a960-2023-1  2023  QC-MAIN-e7e6a960                 -
# 3     ENV-e7e6a960-2023-2  2023  QC-MAIN-e7e6a960                 -
# 4     ENV-8b0264c9-2023-1  2023  NU-MAIN-8b0264c9                 -
# ..                    ...   ...               ...               ...
# 745  ENV-9de9bb0d-2023-19  2023  QC-MAIN-9de9bb0d                 -
# 746  ENV-c5fefb01-2023-16  2023  ON-MAIN-c5fefb01                 -
# 747  ENV-c5fefb01-2023-17  2023  ON-MAIN-c5fefb01                 -
# 748  ENV-c5fefb01-2023-18  2023  ON-MAIN-c5fefb01                 -
# 749  ENV-c5fefb01-2023-19  2023  ON-MAIN-c5fefb01                 -
#
#     company_id unit   value  \
# 0          NaN    t     315
# 1          NaN    t    4802
# 2          NaN    t     486
# 3          NaN    t    7414
# 4          NaN    t      38
# ..         ...  ...     ...
# 745        NaN   m3  324347
# 746        NaN   m3  168115
# 747        NaN   m3  168115
# 748        NaN   m3   82144
# 749        NaN   m3  536420
#
#                                                comment  \
# 0    "In absence of site-level monitoring emission ...
# 1    "In absence of site-level monitoring emission ...
# 2    "In absence of site-level monitoring emission ...
# 3    "In absence of site-level monitoring emission ...
# 4    "In absence of site-level monitoring emission ...
# ..                                                 ...
# 745                                                NaN
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
#
#                                              source_id   substance_id  \
# 0    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB2c1715b8f1
# 1    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB515573c582
# 2    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB2c1715b8f1
# 3    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB515573c582
# 4    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...  SUB2c1715b8f1
# ..                                                 ...            ...
# 745       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 746       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 747       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 748       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
# 749       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables            NaN
#
#     compartment_id
# 0    CMPf3265e9fca
# 1    CMPf3265e9fca
# 2    CMPf3265e9fca
# 3    CMPf3265e9fca
# 4    CMPf3265e9fca
# ..             ...
# 745  CMP68bd334352
# 746  CMP68bd334352
# 747  CMP68bd334352
# 748  CMP68bd334352
# 749  CMP68bd334352
#
# [750 rows x 11 columns]

# %% [markdown]
# ### Concatenate all environment data into a single table

# %%
env_table = pd.concat(
    [ctrace_ghg_gdf, pollutant_gdf, ghg_gdf, env_df],
    ignore_index=True
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      env_id  year          value    unit  \
# 0                   1754055  2023    5610.000024  tCO2eq
# 1                   1754056  2023    6403.000027  tCO2eq
# 2                   1754057  2023  229916.000984  tCO2eq
# 3                   1754058  2023    2639.000011  tCO2eq
# 4                   1754060  2023    4225.000018  tCO2eq
# ...                     ...   ...            ...     ...
# 14520  ENV-9de9bb0d-2023-19  2023         324347      m3
# 14521  ENV-c5fefb01-2023-16  2023         168115      m3
# 14522  ENV-c5fefb01-2023-17  2023         168115      m3
# 14523  ENV-c5fefb01-2023-18  2023          82144      m3
# 14524  ENV-c5fefb01-2023-19  2023         536420      m3
#
#                                                source_id substance_id  \
# 0      Jolleys, M. et al (2024). Mineral Extraction s...          NaN
# 1      Jolleys, M. et al (2024). Mineral Extraction s...          NaN
# 2      Jolleys, M. et al (2024). Mineral Extraction s...          NaN
# 3      Jolleys, M. et al (2024). Mineral Extraction s...          NaN
# 4      Jolleys, M. et al (2024). Mineral Extraction s...          NaN
# ...                                                  ...          ...
# 14520       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 14521       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 14522       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 14523       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 14524       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
#
#       compartment_id           main_id facility_group_id company_id comment
# 0      CMPf3265e9fca  ON-MAIN-6e9b2449               NaN        NaN     NaN
# 1      CMPf3265e9fca  ON-MAIN-63b394c3               NaN        NaN     NaN
# 2      CMPf3265e9fca  BC-MAIN-599152a0               NaN        NaN     NaN
# 3      CMPf3265e9fca  ON-MAIN-52224e1e               NaN        NaN     NaN
# 4      CMPf3265e9fca  ON-MAIN-48fe2205               NaN        NaN     NaN
# ...              ...               ...               ...        ...     ...
# 14520  CMP68bd334352  QC-MAIN-9de9bb0d                 -        NaN     NaN
# 14521  CMP68bd334352  ON-MAIN-c5fefb01                 -        NaN     NaN
# 14522  CMP68bd334352  ON-MAIN-c5fefb01                 -        NaN     NaN
# 14523  CMP68bd334352  ON-MAIN-c5fefb01                 -        NaN     NaN
# 14524  CMP68bd334352  ON-MAIN-c5fefb01                 -        NaN     NaN
#
# [14525 rows x 11 columns]

# %%
env_table.columns
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Index(['env_id', 'year', 'value', 'unit', 'source_id', 'substance_id',
#        'compartment_id', 'main_id', 'facility_group_id', 'company_id',
#        'comment'],
#       dtype='object')

# %%
column_order = ['env_id', 'year', 'compartment_id', 'substance_id', 'unit', 'value', 'comment', 'main_id','facility_group_id', 'company_id', 'source_id']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table = env_table[column_order]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      env_id  year compartment_id substance_id    unit  \
# 0                   1754055  2023  CMPf3265e9fca          NaN  tCO2eq
# 1                   1754056  2023  CMPf3265e9fca          NaN  tCO2eq
# 2                   1754057  2023  CMPf3265e9fca          NaN  tCO2eq
# 3                   1754058  2023  CMPf3265e9fca          NaN  tCO2eq
# 4                   1754060  2023  CMPf3265e9fca          NaN  tCO2eq
# ...                     ...   ...            ...          ...     ...
# 14520  ENV-9de9bb0d-2023-19  2023  CMP68bd334352          NaN      m3
# 14521  ENV-c5fefb01-2023-16  2023  CMP68bd334352          NaN      m3
# 14522  ENV-c5fefb01-2023-17  2023  CMP68bd334352          NaN      m3
# 14523  ENV-c5fefb01-2023-18  2023  CMP68bd334352          NaN      m3
# 14524  ENV-c5fefb01-2023-19  2023  CMP68bd334352          NaN      m3
#
#                value comment           main_id facility_group_id company_id  \
# 0        5610.000024     NaN  ON-MAIN-6e9b2449               NaN        NaN
# 1        6403.000027     NaN  ON-MAIN-63b394c3               NaN        NaN
# 2      229916.000984     NaN  BC-MAIN-599152a0               NaN        NaN
# 3        2639.000011     NaN  ON-MAIN-52224e1e               NaN        NaN
# 4        4225.000018     NaN  ON-MAIN-48fe2205               NaN        NaN
# ...              ...     ...               ...               ...        ...
# 14520         324347     NaN  QC-MAIN-9de9bb0d                 -        NaN
# 14521         168115     NaN  ON-MAIN-c5fefb01                 -        NaN
# 14522         168115     NaN  ON-MAIN-c5fefb01                 -        NaN
# 14523          82144     NaN  ON-MAIN-c5fefb01                 -        NaN
# 14524         536420     NaN  ON-MAIN-c5fefb01                 -        NaN
#
#                                                source_id
# 0      Jolleys, M. et al (2024). Mineral Extraction s...
# 1      Jolleys, M. et al (2024). Mineral Extraction s...
# 2      Jolleys, M. et al (2024). Mineral Extraction s...
# 3      Jolleys, M. et al (2024). Mineral Extraction s...
# 4      Jolleys, M. et al (2024). Mineral Extraction s...
# ...                                                  ...
# 14520       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 14521       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 14522       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 14523       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
# 14524       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables
#
# [14525 rows x 11 columns]

# %% [markdown]
# ## Production table

# %% [markdown]
# ### Manually collected data

# %%
production_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        row_id  year          level geography  \
# 0         PROD-UNKNOWN-2023-1  2023  Company-level     World
# 1         PROD-UNKNOWN-2023-2  2023  Company-level     World
# 2    PROD-CMP-140e111b-2023-1  2023  Company-level     World
# 3    PROD-CMP-c08ac7d7-2023-1  2023  Company-level     World
# 4    PROD-CMP-c08ac7d7-2023-2  2023  Company-level     World
# ..                        ...   ...            ...       ...
# 339      PROD-687b8c8d-2023-2  2023  Site-specific    Canada
# 340      PROD-687b8c8d-2023-3  2023  Site-specific    Canada
# 341      PROD-687b8c8d-2023-4  2023  Site-specific    Canada
# 342      PROD-687b8c8d-2023-5  2023  Site-specific    Canada
# 343      PROD-687b8c8d-2023-6  2023  Site-specific    Canada
#
#     reported_company_nrcan            name           main_id  \
# 0                 Glencore               -                 -
# 1                 Glencore               -                 -
# 2        Alcoa Corporation               -                 -
# 3        Champion Iron Ltd               -                 -
# 4        Champion Iron Ltd               -                 -
# ..                     ...             ...               ...
# 339        Alamos Gold Inc  Young-Davidson  ON-MAIN-687b8c8d
# 340        Alamos Gold Inc  Young-Davidson  ON-MAIN-687b8c8d
# 341        Alamos Gold Inc  Young-Davidson  ON-MAIN-687b8c8d
# 342        Alamos Gold Inc  Young-Davidson  ON-MAIN-687b8c8d
# 343        Alamos Gold Inc  Young-Davidson  ON-MAIN-687b8c8d
#
#     facility_group_id    company_id  facility_type  ...  \
# 0                   -           NaN       Refinery  ...
# 1                   -           NaN       Refinery  ...
# 2                 NaN  CMP-140e111b  manufacturing  ...
# 3                   -  CMP-c08ac7d7         mining  ...
# 4                   -  CMP-c08ac7d7         mining  ...
# ..                ...           ...            ...  ...
# 339                 -           NaN         mining  ...
# 340                 -           NaN         mining  ...
# 341                 -           NaN         mining  ...
# 342                 -           NaN         mining  ...
# 343                 -           NaN         mining  ...
#
#                                      commodities_nrcan commodity  \
# 0    Copper (cathodes), gold, silver, tellurium, se...    Copper
# 1    Copper (cathodes), gold, silver, tellurium, se...    Copper
# 2                                             Aluminum  Aluminum
# 3                                                 Iron      Iron
# 4                                                 Iron      Iron
# ..                                                 ...       ...
# 339                                               Gold      Gold
# 340                                               Gold      Gold
# 341                                               Gold      Gold
# 342                                               Gold      Gold
# 343                                               Gold      Gold
#
#                  reference_point        material_type            data_type  \
# 0         Refined metal produced  Refinery production           Production
# 1         Refined metal produced  Refinery production           Production
# 2    Intermediate metal produced  Aluminum production           Production
# 3                     Usable ore          Concentrate           Production
# 4               Total extraction            Ore mined           Production
# ..                           ...                  ...                  ...
# 339             Total extraction            Ore mined           Production
# 340                    Crude ore        Ore processed           Production
# 341                    Crude ore           Mill grade  Technical attribute
# 342                    Crude ore   Mill recovery rate  Technical attribute
# 343                    Crude ore            Ore grade  Technical attribute
#
#     unit       value                                            comment  \
# 0     kt      443.30  Includes production by Horne and CCR but also ...
# 1     kt      507.30  Includes production by Horne and CCR but also ...
# 2    kmt     2114.00                                                NaN
# 3     Mt       14.16                                                NaN
# 4     Mt       40.87                               Ore mined and hauled
# ..   ...         ...                                                ...
# 339    t  2878155.00                                                NaN
# 340    t  2878047.00                                                NaN
# 341    ?        2.20                                                NaN
# 342    %       90.00                                                NaN
# 343    ?        2.20                                                NaN
#
#                                         source  \
# 0    GLEN_2024-FY_ProductionReport_tables.xlsx
# 1    GLEN_2024-FY_ProductionReport_tables.xlsx
# 2                 4Q23-Alcoa-Financial-Results
# 3                 cil-23sr-esg-databookvf.xlsx
# 4                 cil-23sr-esg-databookvf.xlsx
# ..                                         ...
# 339                             Data_2023.xlsx
# 340                             Data_2023.xlsx
# 341                             Data_2023.xlsx
# 342                             Data_2023.xlsx
# 343                             Data_2023.xlsx
#
#                                              source_id
# 0    SRC_Glencore_GLEN_2024-FY_ProductionReport_tables
# 1    SRC_Glencore_GLEN_2024-FY_ProductionReport_tables
# 2    SRC_AlcoaCorporation_4Q23-Alcoa-Financial-Results
# 3          SRC_ChampionIronLtd_cil-23sr-esg-databookvf
# 4          SRC_ChampionIronLtd_cil-23sr-esg-databookvf
# ..                                                 ...
# 339                        SRC_AlamosGoldInc_Data_2023
# 340                        SRC_AlamosGoldInc_Data_2023
# 341                        SRC_AlamosGoldInc_Data_2023
# 342                        SRC_AlamosGoldInc_Data_2023
# 343                        SRC_AlamosGoldInc_Data_2023
#
# [344 rows x 21 columns]

# %%
production_df.rename(columns={'row_id': 'prod_id'}, inplace=True)
production_df.drop(columns=['level', 'reported_company_nrcan', 'name', 
                            'facility_type', 'mining_processing_type', 'commodities_nrcan', 'source'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                       prod_id  year geography           main_id  \
# 0         PROD-UNKNOWN-2023-1  2023     World                 -
# 1         PROD-UNKNOWN-2023-2  2023     World                 -
# 2    PROD-CMP-140e111b-2023-1  2023     World                 -
# 3    PROD-CMP-c08ac7d7-2023-1  2023     World                 -
# 4    PROD-CMP-c08ac7d7-2023-2  2023     World                 -
# ..                        ...   ...       ...               ...
# 339      PROD-687b8c8d-2023-2  2023    Canada  ON-MAIN-687b8c8d
# 340      PROD-687b8c8d-2023-3  2023    Canada  ON-MAIN-687b8c8d
# 341      PROD-687b8c8d-2023-4  2023    Canada  ON-MAIN-687b8c8d
# 342      PROD-687b8c8d-2023-5  2023    Canada  ON-MAIN-687b8c8d
# 343      PROD-687b8c8d-2023-6  2023    Canada  ON-MAIN-687b8c8d
#
#     facility_group_id    company_id commodity              reference_point  \
# 0                   -           NaN    Copper       Refined metal produced
# 1                   -           NaN    Copper       Refined metal produced
# 2                 NaN  CMP-140e111b  Aluminum  Intermediate metal produced
# 3                   -  CMP-c08ac7d7      Iron                   Usable ore
# 4                   -  CMP-c08ac7d7      Iron             Total extraction
# ..                ...           ...       ...                          ...
# 339                 -           NaN      Gold             Total extraction
# 340                 -           NaN      Gold                    Crude ore
# 341                 -           NaN      Gold                    Crude ore
# 342                 -           NaN      Gold                    Crude ore
# 343                 -           NaN      Gold                    Crude ore
#
#            material_type            data_type unit       value  \
# 0    Refinery production           Production   kt      443.30
# 1    Refinery production           Production   kt      507.30
# 2    Aluminum production           Production  kmt     2114.00
# 3            Concentrate           Production   Mt       14.16
# 4              Ore mined           Production   Mt       40.87
# ..                   ...                  ...  ...         ...
# 339            Ore mined           Production    t  2878155.00
# 340        Ore processed           Production    t  2878047.00
# 341           Mill grade  Technical attribute    ?        2.20
# 342   Mill recovery rate  Technical attribute    %       90.00
# 343            Ore grade  Technical attribute    ?        2.20
#
#                                                comment  \
# 0    Includes production by Horne and CCR but also ...
# 1    Includes production by Horne and CCR but also ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                 Ore mined and hauled
# ..                                                 ...
# 339                                                NaN
# 340                                                NaN
# 341                                                NaN
# 342                                                NaN
# 343                                                NaN
#
#                                              source_id
# 0    SRC_Glencore_GLEN_2024-FY_ProductionReport_tables
# 1    SRC_Glencore_GLEN_2024-FY_ProductionReport_tables
# 2    SRC_AlcoaCorporation_4Q23-Alcoa-Financial-Results
# 3          SRC_ChampionIronLtd_cil-23sr-esg-databookvf
# 4          SRC_ChampionIronLtd_cil-23sr-esg-databookvf
# ..                                                 ...
# 339                        SRC_AlamosGoldInc_Data_2023
# 340                        SRC_AlamosGoldInc_Data_2023
# 341                        SRC_AlamosGoldInc_Data_2023
# 342                        SRC_AlamosGoldInc_Data_2023
# 343                        SRC_AlamosGoldInc_Data_2023
#
# [344 rows x 14 columns]

# %%
from constants import unit_conversion
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Apply a function to convert the 'value' column to tonnes
# But we need to do that only for the 'Production' data_type and don't do it for any other data_type
production_df['value_tonnes'] = production_df.apply(
    lambda row: row['value'] * unit_conversion.get(row['unit'], 1) if row['data_type'] == 'Production' else np.nan, 
    axis=1
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### CTrace dataset

# %%
ctrace_prod_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ctrace_id  year      activity   activity_units      capacity  \
# 6     1754055  2023  8.630000e+05  t of copper ore  4.624000e+06
# 7     1754056  2023  9.850000e+05  t of copper ore  3.554700e+07
# 8     1754057  2023  1.457500e+07  t of copper ore  3.670000e+08
# 9     1754058  2023  4.060000e+05  t of copper ore  1.104100e+07
# 11    1754060  2023  6.500000e+05  t of copper ore  4.822000e+06
# 12    1754061  2023  8.810000e+07  t of copper ore  6.450000e+08
# 16    1754066  2023  7.288600e+07  t of copper ore  2.631000e+08
# 17    1754067  2023  0.000000e+00  t of copper ore  8.787959e+07
# 25    1754077  2023  1.501481e+06  t of copper ore  1.988200e+07
# 29    1754081  2023  5.279710e+05  t of copper ore  8.787959e+07
# 30    1754082  2023  0.000000e+00  t of copper ore  7.413000e+06
# 31    1754083  2023  0.000000e+00  t of copper ore  2.313000e+06
# 32    1754084  2023  2.127800e+07  t of copper ore  2.500250e+08
# 33    1754085  2023  5.948239e+06  t of copper ore  4.902900e+07
# 34    1754086  2023  4.500000e+04  t of copper ore  4.110000e+06
# 35    1754087  2023  2.993000e+06  t of copper ore  3.408700e+07
# 43    1754096  2023  6.848790e+05  t of copper ore  1.500000e+07
# 44    1754097  2023  6.887709e+06  t of copper ore  4.549000e+08
# 51    1754104  2023  5.180000e+05  t of copper ore  2.453000e+06
# 52    1754105  2023  0.000000e+00  t of copper ore  8.787959e+07
# 54   25486533  2023  1.350000e+06  t of copper ore  2.500000e+06
# 55   25486534  2023  3.798000e+06  t of copper ore  2.200000e+07
# 56   36395102  2023  1.578280e+07    t of iron ore  4.789430e+08
#
#    capacity_units                                          source_id  \
# 6          tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 7          tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 8          tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 9          tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 11         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 12         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 16         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 17         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 25         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 29         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 30         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 31         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 32         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 33         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 34         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 35         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 43         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 44         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 51         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 52         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 54         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 55         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
# 56         tonnes  Jolleys, M. et al (2024). Mineral Extraction s...
#
#     substance_id compartment_id           main_id
# 6            NaN  CMPf3265e9fca  ON-MAIN-6e9b2449
# 7            NaN  CMPf3265e9fca  ON-MAIN-63b394c3
# 8            NaN  CMPf3265e9fca  BC-MAIN-599152a0
# 9            NaN  CMPf3265e9fca  ON-MAIN-52224e1e
# 11           NaN  CMPf3265e9fca  ON-MAIN-48fe2205
# 12           NaN  CMPf3265e9fca  BC-MAIN-6b4800fe
# 16           NaN  CMPf3265e9fca  BC-MAIN-bf503b6b
# 17           NaN  CMPf3265e9fca  QC-MAIN-30c1828c
# 25           NaN  CMPf3265e9fca  QC-MAIN-e51eda66
# 29           NaN  CMPf3265e9fca  ON-MAIN-7001a391
# 30           NaN  CMPf3265e9fca  NL-MAIN-c139de6d
# 31           NaN  CMPf3265e9fca  YT-MAIN-752fbcae
# 32           NaN  CMPf3265e9fca  BC-MAIN-ed23117f
# 33           NaN  CMPf3265e9fca  BC-MAIN-3f490561
# 34           NaN  CMPf3265e9fca  BC-MAIN-23155c25
# 35           NaN  CMPf3265e9fca  BC-MAIN-aa76f6f2
# 43           NaN  CMPf3265e9fca  QC-MAIN-a97821c0
# 44           NaN  CMPf3265e9fca  BC-MAIN-8eb8be0d
# 51           NaN  CMPf3265e9fca  ON-MAIN-28f3f0fc
# 52           NaN  CMPf3265e9fca  QC-MAIN-b2148882
# 54           NaN  CMPf3265e9fca  ON-MAIN-f8313ebd
# 55           NaN  CMPf3265e9fca  ON-MAIN-a3c56a83
# 56           NaN  CMPf3265e9fca  NL-MAIN-b64bae7a

# %%
# Save units before melting
activity_units = ctrace_prod_gdf['activity_units']
capacity_units = ctrace_prod_gdf['capacity_units']

# Melt
ctrace_prod_gdf = pd.melt(
    ctrace_prod_gdf,
    id_vars=['ctrace_id', 'year', 'source_id', 'main_id'],
    value_vars=['activity', 'capacity'],
    var_name='data_type',
    value_name='value'
)

# Set data_type labels
ctrace_prod_gdf['data_type'] = ctrace_prod_gdf['data_type'].replace({
    'activity': 'Production',
    'capacity': 'Capacity'
})

# Concatenate units in correct order (activity first, then capacity)
ctrace_prod_gdf['unit'] = list(activity_units) + list(capacity_units)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_prod_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ctrace_id  year                                          source_id  \
# 0     1754055  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 1     1754056  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 2     1754057  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 3     1754058  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 4     1754060  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 5     1754061  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 6     1754066  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 7     1754067  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 8     1754077  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 9     1754081  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 10    1754082  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 11    1754083  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 12    1754084  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 13    1754085  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 14    1754086  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 15    1754087  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 16    1754096  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 17    1754097  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 18    1754104  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 19    1754105  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 20   25486533  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 21   25486534  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 22   36395102  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 23    1754055  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 24    1754056  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 25    1754057  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 26    1754058  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 27    1754060  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 28    1754061  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 29    1754066  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 30    1754067  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 31    1754077  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 32    1754081  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 33    1754082  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 34    1754083  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 35    1754084  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 36    1754085  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 37    1754086  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 38    1754087  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 39    1754096  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 40    1754097  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 41    1754104  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 42    1754105  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 43   25486533  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 44   25486534  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 45   36395102  2023  Jolleys, M. et al (2024). Mineral Extraction s...
#
#              main_id   data_type         value             unit
# 0   ON-MAIN-6e9b2449  Production  8.630000e+05  t of copper ore
# 1   ON-MAIN-63b394c3  Production  9.850000e+05  t of copper ore
# 2   BC-MAIN-599152a0  Production  1.457500e+07  t of copper ore
# 3   ON-MAIN-52224e1e  Production  4.060000e+05  t of copper ore
# 4   ON-MAIN-48fe2205  Production  6.500000e+05  t of copper ore
# 5   BC-MAIN-6b4800fe  Production  8.810000e+07  t of copper ore
# 6   BC-MAIN-bf503b6b  Production  7.288600e+07  t of copper ore
# 7   QC-MAIN-30c1828c  Production  0.000000e+00  t of copper ore
# 8   QC-MAIN-e51eda66  Production  1.501481e+06  t of copper ore
# 9   ON-MAIN-7001a391  Production  5.279710e+05  t of copper ore
# 10  NL-MAIN-c139de6d  Production  0.000000e+00  t of copper ore
# 11  YT-MAIN-752fbcae  Production  0.000000e+00  t of copper ore
# 12  BC-MAIN-ed23117f  Production  2.127800e+07  t of copper ore
# 13  BC-MAIN-3f490561  Production  5.948239e+06  t of copper ore
# 14  BC-MAIN-23155c25  Production  4.500000e+04  t of copper ore
# 15  BC-MAIN-aa76f6f2  Production  2.993000e+06  t of copper ore
# 16  QC-MAIN-a97821c0  Production  6.848790e+05  t of copper ore
# 17  BC-MAIN-8eb8be0d  Production  6.887709e+06  t of copper ore
# 18  ON-MAIN-28f3f0fc  Production  5.180000e+05  t of copper ore
# 19  QC-MAIN-b2148882  Production  0.000000e+00  t of copper ore
# 20  ON-MAIN-f8313ebd  Production  1.350000e+06  t of copper ore
# 21  ON-MAIN-a3c56a83  Production  3.798000e+06  t of copper ore
# 22  NL-MAIN-b64bae7a  Production  1.578280e+07    t of iron ore
# 23  ON-MAIN-6e9b2449    Capacity  4.624000e+06           tonnes
# 24  ON-MAIN-63b394c3    Capacity  3.554700e+07           tonnes
# 25  BC-MAIN-599152a0    Capacity  3.670000e+08           tonnes
# 26  ON-MAIN-52224e1e    Capacity  1.104100e+07           tonnes
# 27  ON-MAIN-48fe2205    Capacity  4.822000e+06           tonnes
# 28  BC-MAIN-6b4800fe    Capacity  6.450000e+08           tonnes
# 29  BC-MAIN-bf503b6b    Capacity  2.631000e+08           tonnes
# 30  QC-MAIN-30c1828c    Capacity  8.787959e+07           tonnes
# 31  QC-MAIN-e51eda66    Capacity  1.988200e+07           tonnes
# 32  ON-MAIN-7001a391    Capacity  8.787959e+07           tonnes
# 33  NL-MAIN-c139de6d    Capacity  7.413000e+06           tonnes
# 34  YT-MAIN-752fbcae    Capacity  2.313000e+06           tonnes
# 35  BC-MAIN-ed23117f    Capacity  2.500250e+08           tonnes
# 36  BC-MAIN-3f490561    Capacity  4.902900e+07           tonnes
# 37  BC-MAIN-23155c25    Capacity  4.110000e+06           tonnes
# 38  BC-MAIN-aa76f6f2    Capacity  3.408700e+07           tonnes
# 39  QC-MAIN-a97821c0    Capacity  1.500000e+07           tonnes
# 40  BC-MAIN-8eb8be0d    Capacity  4.549000e+08           tonnes
# 41  ON-MAIN-28f3f0fc    Capacity  2.453000e+06           tonnes
# 42  QC-MAIN-b2148882    Capacity  8.787959e+07           tonnes
# 43  ON-MAIN-f8313ebd    Capacity  2.500000e+06           tonnes
# 44  ON-MAIN-a3c56a83    Capacity  2.200000e+07           tonnes
# 45  NL-MAIN-b64bae7a    Capacity  4.789430e+08           tonnes

# %%
ctrace_prod_gdf.rename(columns={'ctrace_id': 'prod_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# We add the missing columns
ctrace_prod_gdf['geography'] = 'Canada'
ctrace_prod_gdf['reference_point'] = 'Crude ore'
ctrace_prod_gdf['value_tonnes'] = ctrace_prod_gdf['value'] # they are always in tonnes
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Add a commodity column with would be = Copper if unit column = 't of copper ore' and = 'Iron' if unit column = 't of iron ore'
ctrace_prod_gdf['commodity'] = ctrace_prod_gdf['unit'].apply(
    lambda x: 'Copper' if 'copper' in x.lower() else ('Iron' if 'iron' in x.lower() else None)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_prod_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      prod_id  year                                          source_id  \
# 0    1754055  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 1    1754056  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 2    1754057  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 3    1754058  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 4    1754060  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 5    1754061  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 6    1754066  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 7    1754067  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 8    1754077  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 9    1754081  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 10   1754082  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 11   1754083  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 12   1754084  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 13   1754085  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 14   1754086  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 15   1754087  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 16   1754096  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 17   1754097  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 18   1754104  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 19   1754105  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 20  25486533  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 21  25486534  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 22  36395102  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 23   1754055  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 24   1754056  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 25   1754057  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 26   1754058  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 27   1754060  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 28   1754061  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 29   1754066  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 30   1754067  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 31   1754077  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 32   1754081  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 33   1754082  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 34   1754083  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 35   1754084  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 36   1754085  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 37   1754086  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 38   1754087  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 39   1754096  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 40   1754097  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 41   1754104  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 42   1754105  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 43  25486533  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 44  25486534  2023  Jolleys, M. et al (2024). Mineral Extraction s...
# 45  36395102  2023  Jolleys, M. et al (2024). Mineral Extraction s...
#
#              main_id   data_type         value             unit geography  \
# 0   ON-MAIN-6e9b2449  Production  8.630000e+05  t of copper ore    Canada
# 1   ON-MAIN-63b394c3  Production  9.850000e+05  t of copper ore    Canada
# 2   BC-MAIN-599152a0  Production  1.457500e+07  t of copper ore    Canada
# 3   ON-MAIN-52224e1e  Production  4.060000e+05  t of copper ore    Canada
# 4   ON-MAIN-48fe2205  Production  6.500000e+05  t of copper ore    Canada
# 5   BC-MAIN-6b4800fe  Production  8.810000e+07  t of copper ore    Canada
# 6   BC-MAIN-bf503b6b  Production  7.288600e+07  t of copper ore    Canada
# 7   QC-MAIN-30c1828c  Production  0.000000e+00  t of copper ore    Canada
# 8   QC-MAIN-e51eda66  Production  1.501481e+06  t of copper ore    Canada
# 9   ON-MAIN-7001a391  Production  5.279710e+05  t of copper ore    Canada
# 10  NL-MAIN-c139de6d  Production  0.000000e+00  t of copper ore    Canada
# 11  YT-MAIN-752fbcae  Production  0.000000e+00  t of copper ore    Canada
# 12  BC-MAIN-ed23117f  Production  2.127800e+07  t of copper ore    Canada
# 13  BC-MAIN-3f490561  Production  5.948239e+06  t of copper ore    Canada
# 14  BC-MAIN-23155c25  Production  4.500000e+04  t of copper ore    Canada
# 15  BC-MAIN-aa76f6f2  Production  2.993000e+06  t of copper ore    Canada
# 16  QC-MAIN-a97821c0  Production  6.848790e+05  t of copper ore    Canada
# 17  BC-MAIN-8eb8be0d  Production  6.887709e+06  t of copper ore    Canada
# 18  ON-MAIN-28f3f0fc  Production  5.180000e+05  t of copper ore    Canada
# 19  QC-MAIN-b2148882  Production  0.000000e+00  t of copper ore    Canada
# 20  ON-MAIN-f8313ebd  Production  1.350000e+06  t of copper ore    Canada
# 21  ON-MAIN-a3c56a83  Production  3.798000e+06  t of copper ore    Canada
# 22  NL-MAIN-b64bae7a  Production  1.578280e+07    t of iron ore    Canada
# 23  ON-MAIN-6e9b2449    Capacity  4.624000e+06           tonnes    Canada
# 24  ON-MAIN-63b394c3    Capacity  3.554700e+07           tonnes    Canada
# 25  BC-MAIN-599152a0    Capacity  3.670000e+08           tonnes    Canada
# 26  ON-MAIN-52224e1e    Capacity  1.104100e+07           tonnes    Canada
# 27  ON-MAIN-48fe2205    Capacity  4.822000e+06           tonnes    Canada
# 28  BC-MAIN-6b4800fe    Capacity  6.450000e+08           tonnes    Canada
# 29  BC-MAIN-bf503b6b    Capacity  2.631000e+08           tonnes    Canada
# 30  QC-MAIN-30c1828c    Capacity  8.787959e+07           tonnes    Canada
# 31  QC-MAIN-e51eda66    Capacity  1.988200e+07           tonnes    Canada
# 32  ON-MAIN-7001a391    Capacity  8.787959e+07           tonnes    Canada
# 33  NL-MAIN-c139de6d    Capacity  7.413000e+06           tonnes    Canada
# 34  YT-MAIN-752fbcae    Capacity  2.313000e+06           tonnes    Canada
# 35  BC-MAIN-ed23117f    Capacity  2.500250e+08           tonnes    Canada
# 36  BC-MAIN-3f490561    Capacity  4.902900e+07           tonnes    Canada
# 37  BC-MAIN-23155c25    Capacity  4.110000e+06           tonnes    Canada
# 38  BC-MAIN-aa76f6f2    Capacity  3.408700e+07           tonnes    Canada
# 39  QC-MAIN-a97821c0    Capacity  1.500000e+07           tonnes    Canada
# 40  BC-MAIN-8eb8be0d    Capacity  4.549000e+08           tonnes    Canada
# 41  ON-MAIN-28f3f0fc    Capacity  2.453000e+06           tonnes    Canada
# 42  QC-MAIN-b2148882    Capacity  8.787959e+07           tonnes    Canada
# 43  ON-MAIN-f8313ebd    Capacity  2.500000e+06           tonnes    Canada
# 44  ON-MAIN-a3c56a83    Capacity  2.200000e+07           tonnes    Canada
# 45  NL-MAIN-b64bae7a    Capacity  4.789430e+08           tonnes    Canada
#
#    reference_point  value_tonnes commodity
# 0        Crude ore  8.630000e+05    Copper
# 1        Crude ore  9.850000e+05    Copper
# 2        Crude ore  1.457500e+07    Copper
# 3        Crude ore  4.060000e+05    Copper
# 4        Crude ore  6.500000e+05    Copper
# 5        Crude ore  8.810000e+07    Copper
# 6        Crude ore  7.288600e+07    Copper
# 7        Crude ore  0.000000e+00    Copper
# 8        Crude ore  1.501481e+06    Copper
# 9        Crude ore  5.279710e+05    Copper
# 10       Crude ore  0.000000e+00    Copper
# 11       Crude ore  0.000000e+00    Copper
# 12       Crude ore  2.127800e+07    Copper
# 13       Crude ore  5.948239e+06    Copper
# 14       Crude ore  4.500000e+04    Copper
# 15       Crude ore  2.993000e+06    Copper
# 16       Crude ore  6.848790e+05    Copper
# 17       Crude ore  6.887709e+06    Copper
# 18       Crude ore  5.180000e+05    Copper
# 19       Crude ore  0.000000e+00    Copper
# 20       Crude ore  1.350000e+06    Copper
# 21       Crude ore  3.798000e+06    Copper
# 22       Crude ore  1.578280e+07      Iron
# 23       Crude ore  4.624000e+06      None
# 24       Crude ore  3.554700e+07      None
# 25       Crude ore  3.670000e+08      None
# 26       Crude ore  1.104100e+07      None
# 27       Crude ore  4.822000e+06      None
# 28       Crude ore  6.450000e+08      None
# 29       Crude ore  2.631000e+08      None
# 30       Crude ore  8.787959e+07      None
# 31       Crude ore  1.988200e+07      None
# 32       Crude ore  8.787959e+07      None
# 33       Crude ore  7.413000e+06      None
# 34       Crude ore  2.313000e+06      None
# 35       Crude ore  2.500250e+08      None
# 36       Crude ore  4.902900e+07      None
# 37       Crude ore  4.110000e+06      None
# 38       Crude ore  3.408700e+07      None
# 39       Crude ore  1.500000e+07      None
# 40       Crude ore  4.549000e+08      None
# 41       Crude ore  2.453000e+06      None
# 42       Crude ore  8.787959e+07      None
# 43       Crude ore  2.500000e+06      None
# 44       Crude ore  2.200000e+07      None
# 45       Crude ore  4.789430e+08      None

# %% [markdown]
# ### Concatenate all production data into a single table

# %%
# Concatenate production and ctrace data 
production_table = pd.concat([production_df, ctrace_prod_gdf], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_table.columns
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Index(['prod_id', 'year', 'geography', 'main_id', 'facility_group_id',
#        'company_id', 'commodity', 'reference_point', 'material_type',
#        'data_type', 'unit', 'value', 'comment', 'source_id', 'value_tonnes'],
#       dtype='object')

# %%
column_order = ['prod_id', 'year', 'geography', 
                'commodity', 'reference_point', 'material_type', 'data_type', 
                'unit', 'value', 'value_tonnes', 'comment', 
                'main_id', 'facility_group_id','company_id', 'source_id']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_table = production_table[column_order]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                       prod_id  year geography commodity  \
# 0         PROD-UNKNOWN-2023-1  2023     World    Copper
# 1         PROD-UNKNOWN-2023-2  2023     World    Copper
# 2    PROD-CMP-140e111b-2023-1  2023     World  Aluminum
# 3    PROD-CMP-c08ac7d7-2023-1  2023     World      Iron
# 4    PROD-CMP-c08ac7d7-2023-2  2023     World      Iron
# ..                        ...   ...       ...       ...
# 385                   1754104  2023    Canada      None
# 386                   1754105  2023    Canada      None
# 387                  25486533  2023    Canada      None
# 388                  25486534  2023    Canada      None
# 389                  36395102  2023    Canada      None
#
#                  reference_point        material_type   data_type    unit  \
# 0         Refined metal produced  Refinery production  Production      kt
# 1         Refined metal produced  Refinery production  Production      kt
# 2    Intermediate metal produced  Aluminum production  Production     kmt
# 3                     Usable ore          Concentrate  Production      Mt
# 4               Total extraction            Ore mined  Production      Mt
# ..                           ...                  ...         ...     ...
# 385                    Crude ore                  NaN    Capacity  tonnes
# 386                    Crude ore                  NaN    Capacity  tonnes
# 387                    Crude ore                  NaN    Capacity  tonnes
# 388                    Crude ore                  NaN    Capacity  tonnes
# 389                    Crude ore                  NaN    Capacity  tonnes
#
#             value  value_tonnes  \
# 0    4.433000e+02  4.433000e+05
# 1    5.073000e+02  5.073000e+05
# 2    2.114000e+03  2.114000e+12
# 3    1.416000e+01  1.416000e+01
# 4    4.087000e+01  4.087000e+01
# ..            ...           ...
# 385  2.453000e+06  2.453000e+06
# 386  8.787959e+07  8.787959e+07
# 387  2.500000e+06  2.500000e+06
# 388  2.200000e+07  2.200000e+07
# 389  4.789430e+08  4.789430e+08
#
#                                                comment           main_id  \
# 0    Includes production by Horne and CCR but also ...                 -
# 1    Includes production by Horne and CCR but also ...                 -
# 2                                                  NaN                 -
# 3                                                  NaN                 -
# 4                                 Ore mined and hauled                 -
# ..                                                 ...               ...
# 385                                                NaN  ON-MAIN-28f3f0fc
# 386                                                NaN  QC-MAIN-b2148882
# 387                                                NaN  ON-MAIN-f8313ebd
# 388                                                NaN  ON-MAIN-a3c56a83
# 389                                                NaN  NL-MAIN-b64bae7a
#
#     facility_group_id    company_id  \
# 0                   -           NaN
# 1                   -           NaN
# 2                 NaN  CMP-140e111b
# 3                   -  CMP-c08ac7d7
# 4                   -  CMP-c08ac7d7
# ..                ...           ...
# 385               NaN           NaN
# 386               NaN           NaN
# 387               NaN           NaN
# 388               NaN           NaN
# 389               NaN           NaN
#
#                                              source_id
# 0    SRC_Glencore_GLEN_2024-FY_ProductionReport_tables
# 1    SRC_Glencore_GLEN_2024-FY_ProductionReport_tables
# 2    SRC_AlcoaCorporation_4Q23-Alcoa-Financial-Results
# 3          SRC_ChampionIronLtd_cil-23sr-esg-databookvf
# 4          SRC_ChampionIronLtd_cil-23sr-esg-databookvf
# ..                                                 ...
# 385  Jolleys, M. et al (2024). Mineral Extraction s...
# 386  Jolleys, M. et al (2024). Mineral Extraction s...
# 387  Jolleys, M. et al (2024). Mineral Extraction s...
# 388  Jolleys, M. et al (2024). Mineral Extraction s...
# 389  Jolleys, M. et al (2024). Mineral Extraction s...
#
# [390 rows x 15 columns]

# %%
production_table['main_id'].value_counts()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# main_id
# -                   64
# MB-MAIN-da0b5c3d    21
# BC-MAIN-599152a0    16
# MB-MAIN-0898e255    15
# BC-MAIN-ed23117f    12
#                     ..
# QC-MAIN-a555d9b9     1
# NU-MAIN-5154702a     1
# ON-MAIN-aeafbb59     1
# ON-MAIN-aeafbb60     1
# QC-MAIN-e7e6a964     1
# Name: count, Length: 89, dtype: int64

# %% [markdown]
# ## Protected & Indigenous table

# %%
protected_mapping = {
    "WDPA_PID": "protected_area_id",
    "NAME": "land_name",
    "DESIG": "land_type",
    "STATUS_YR": "date"
}

indigenous_mapping = {
    "indigenous_land_id": "protected_area_id",
    "Name": "land_name",
    "Category": "land_type",
    "Data_Date": "date"
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
protected_clean = wpda_gdf_polygons.rename(columns=protected_mapping)[["protected_area_id", "land_name", "land_type", "distance_km", "geometry", "main_id", "source_id"]].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
indigenous_clean = indigenous_can_gdf.rename(columns=indigenous_mapping)[["protected_area_id", "land_name", "land_type", "distance_km", "geometry", "main_id", "source_id"]].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
target_crs = "EPSG:4326"
protected_clean = protected_clean.to_crs(target_crs)
indigenous_clean = indigenous_clean.to_crs(target_crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
protected_land_table = pd.concat([protected_clean, indigenous_clean], ignore_index=True)
protected_land_table = gpd.GeoDataFrame(protected_land_table, geometry="geometry", crs=wpda_gdf_polygons.crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
protected_land_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      protected_area_id                                land_name  \
# 0                611_B     Wood Buffalo National Park Of Canada
# 1                  615            Banff National Park Of Canada
# 2                  616  Nahanni National Park Reserve Of Canada
# 3                  616  Nahanni National Park Reserve Of Canada
# 4                  620         Pukaskwa National Park Of Canada
# ...                ...                                      ...
# 8790   ZZ-IND-40a2ea30        Six Nations Indian Reserve No. 40
# 8791   ZZ-IND-40a2ea30        Six Nations Indian Reserve No. 40
# 8792   ZZ-IND-4e299f50                             Mashteuiatsh
# 8793   ZZ-IND-74ac0e34                                  Nisga'a
# 8794   ZZ-IND-74ac0e34                                  Nisga'a
#
#                        land_type  distance_km           main_id  \
# 0                  National Park       27.397  NT-MAIN-b99d4cb2
# 1                  National Park        2.153  AB-MAIN-8434dce0
# 2                  National Park        0.000  NT-MAIN-b3681e03
# 3                  National Park       31.820  YT-MAIN-03a159d7
# 4                  National Park       19.001  ON-MAIN-6e9be24e
# ...                          ...          ...               ...
# 8790              Indian Reserve       25.954  ON-MAIN-020a683c
# 8791              Indian Reserve       20.924  ON-MAIN-b2e5c9bb
# 8792              Indian Reserve       39.343  QC-MAIN-3aa117d8
# 8793  First Nations Treaty Lands       16.458  BC-MAIN-3ef4f421
# 8794  First Nations Treaty Lands       43.499  BC-MAIN-51068f3b
#
#                             source_id
# 0     https://www.protectedplanet.net
# 1     https://www.protectedplanet.net
# 2     https://www.protectedplanet.net
# 3     https://www.protectedplanet.net
# 4     https://www.protectedplanet.net
# ...                               ...
# 8790       http://www.landmarkmap.org
# 8791       http://www.landmarkmap.org
# 8792       http://www.landmarkmap.org
# 8793       http://www.landmarkmap.org
# 8794       http://www.landmarkmap.org
#
# [8795 rows x 6 columns]

# %%
protected_land_table['protected_area_id'].value_counts()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# protected_area_id
# 555705169          27
# 555651780          20
# ZZ-IND-2c6adbc5    16
# 19932              16
# 555515830          15
#                    ..
# 555569718           1
# 555569719           1
# 555569722           1
# 555569726           1
# 555621605_B         1
# Name: count, Length: 3938, dtype: int64

# %% [markdown]
# ## Land cover table

# %%
land_cover_table = land_cover_gdf.copy()
land_cover_table['npv_biome_type'] = npv_gdf['biome_type']
land_cover_table['source_id'] = land_cover_table['source_id'].astype(str) + ';' + npv_gdf['source_id'].astype(str)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from db_creation_function import assign_row_id
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_cover_table = assign_row_id(land_cover_table,
                                 facility_id_col='main_id', 
                                 prefix='land_cover_id')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_cover_table.drop(columns=['name', 'geometry'], inplace=True)
land_cover_table.rename(columns={'row_id': 'land_cover_id'}, inplace=True)
land_cover_table = land_cover_table[['land_cover_id', 'year', 'modis_land_cover',
       'esa_land_cover', 'npv_biome_type', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_cover_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                 land_cover_id  year             modis_land_cover  \
# 0    land_cover_id-5801b453-1  2021               Woody Savannas
# 1    land_cover_id-d29e0839-1  2021               Woody Savannas
# 2    land_cover_id-f1ff4920-1  2021               Woody Savannas
# 3    land_cover_id-4ea8ac9d-1  2021                   Grasslands
# 4    land_cover_id-e7e6a960-1  2021                   Grasslands
# ..                        ...   ...                          ...
# 265  land_cover_id-c5fefb01-1  2021               Woody Savannas
# 266  land_cover_id-feb13c30-1  2021               Woody Savannas
# 267  land_cover_id-5e0d8b48-1  2021              Open Shrublands
# 268  land_cover_id-12c68d49-1  2021               Woody Savannas
# 269  land_cover_id-891d3cb5-1  2021  Evergreen Needleleaf Forest
#
#              esa_land_cover                    npv_biome_type  \
# 0                  Built-up                              None
# 1    Bare/Sparse Vegetation                 Cool Mixed Forest
# 2                Tree Cover                 Cool Mixed Forest
# 3             Moss & Lichen                              None
# 4    Bare/Sparse Vegetation                 Cool Mixed Forest
# ..                      ...                               ...
# 265  Permanent Water Bodies                 Cool Mixed Forest
# 266              Tree Cover  Cool Evergreen Needleleaf Forest
# 267               Grassland  Cold Evergreen Needleleaf Forest
# 268               Grassland                 Cool Mixed Forest
# 269              Tree Cover  Cold Evergreen Needleleaf Forest
#
#               main_id                                          source_id
# 0    QC-MAIN-5801b453  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 1    QC-MAIN-d29e0839  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 2    QC-MAIN-f1ff4920  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 3    NU-MAIN-4ea8ac9d  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 4    QC-MAIN-e7e6a960  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# ..                ...                                                ...
# 265  ON-MAIN-c5fefb01  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 266  BC-MAIN-feb13c30  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 267  YT-MAIN-5e0d8b48  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 268  ON-MAIN-12c68d49  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
# 269  BC-MAIN-891d3cb5  https://doi.org/10.5067/MODIS/MCD12Q1.061 + ht...
#
# [270 rows x 7 columns]

# %% [markdown]
# ## Environmental intensity table

# %%
env_int_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      env_int_id  year reporting_level  \
# 0   ENV_INT-GRP-0a2c0d69-2023-1  2023  Facility-group
# 1   ENV_INT-GRP-0a2c0d69-2023-2  2023  Facility-group
# 2       ENV_INT-4ea8ac9d-2023-1  2023   Site-specific
# 3       ENV_INT-4ea8ac9d-2023-2  2023   Site-specific
# 4       ENV_INT-730aefe3-2023-1  2023   Site-specific
# ..                          ...   ...             ...
# 91      ENV_INT-9de9bb0d-2023-2  2023   Site-specific
# 92      ENV_INT-9de9bb0d-2023-3  2023   Site-specific
# 93      ENV_INT-9de9bb0d-2023-4  2023   Site-specific
# 94      ENV_INT-9de9bb0d-2023-5  2023   Site-specific
# 95      ENV_INT-9de9bb0d-2023-6  2023   Site-specific
#
#         reported_company_nrcan         name           main_id  \
# 0   Agnico Eagle Mines Limited   Meadowbank                 -
# 1   Agnico Eagle Mines Limited   Meadowbank                 -
# 2   Agnico Eagle Mines Limited      LaRonde  NU-MAIN-4ea8ac9d
# 3   Agnico Eagle Mines Limited      LaRonde  NU-MAIN-4ea8ac9d
# 4   Agnico Eagle Mines Limited      Macassa  NU-MAIN-730aefe3
# ..                         ...          ...               ...
# 91      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 92      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 93      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 94      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 95      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
#
#    facility_group_id company_id facility_type  \
# 0       GRP-0a2c0d69        NaN        mining
# 1       GRP-0a2c0d69        NaN        mining
# 2                  -        NaN        mining
# 3                  -        NaN        mining
# 4                  -        NaN        mining
# ..               ...        ...           ...
# 91                 -        NaN        mining
# 92                 -        NaN        mining
# 93                 -        NaN        mining
# 94                 -        NaN        mining
# 95                 -        NaN        mining
#
#                  mining_processing_type  ...  \
# 0   Open-pit, underground, concentrator  ...
# 1   Open-pit, underground, concentrator  ...
# 2   Open-pit, underground, concentrator  ...
# 3   Open-pit, underground, concentrator  ...
# 4                          Concentrator  ...
# ..                                  ...  ...
# 91            Underground, concentrator  ...
# 92            Underground, concentrator  ...
# 93            Underground, concentrator  ...
# 94            Underground, concentrator  ...
# 95            Underground, concentrator  ...
#
#                                  flow_type substance_name  \
# 0   Freshwater withdrawn for use intensity              -
# 1   Freshwater withdrawn for use intensity              -
# 2   Freshwater withdrawn for use intensity              -
# 3   Freshwater withdrawn for use intensity              -
# 4   Freshwater withdrawn for use intensity              -
# ..                                     ...            ...
# 91                                scope1+2              -
# 92                         Water intensity              -
# 93                         Water intensity              -
# 94                                scope1+2              -
# 95                                scope1+2              -
#
#                               unit     value comment  \
# 0   m3 of water/t of ore processed  0.252115     NaN
# 1           m3 of water/oz of gold  2.244304     NaN
# 2   m3 of water/t of ore processed  0.559341     NaN
# 3           m3 of water/oz of gold  4.849037     NaN
# 4   m3 of water/t of ore processed  0.437068     NaN
# ..                             ...       ...     ...
# 91              tCO2eq/oz produced  0.170000     NaN
# 92                     m3/t milled  0.130000     NaN
# 93                  m3/oz produced  0.330000     NaN
# 94                 tCO2eq/t milled  0.070000     NaN
# 95              tCO2eq/oz produced  0.170000     NaN
#
#                                                source  \
# 0   Agnico-Eagle-2023-Sustainability-Performance-D...
# 1   Agnico-Eagle-2023-Sustainability-Performance-D...
# 2   Agnico-Eagle-2023-Sustainability-Performance-D...
# 3   Agnico-Eagle-2023-Sustainability-Performance-D...
# 4   Agnico-Eagle-2023-Sustainability-Performance-D...
# ..                                                ...
# 91                          2023-ESG-Data-Tables.xlsx
# 92                          2023-ESG-Data-Tables.xlsx
# 93                          2023-ESG-Data-Tables.xlsx
# 94                          2023-ESG-Data-Tables.xlsx
# 95                          2023-ESG-Data-Tables.xlsx
#
#                                             source_id substance_id  \
# 0   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 1   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 2   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 3   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 4   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# ..                                                ...          ...
# 91       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 92       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 93       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 94       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 95       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
#
#    compartment_pathway compartment_id
# 0          Unspecified  CMP68bd334352
# 1          Unspecified  CMP68bd334352
# 2          Unspecified  CMP68bd334352
# 3          Unspecified  CMP68bd334352
# 4          Unspecified  CMP68bd334352
# ..                 ...            ...
# 91         Unspecified  CMPf3265e9fca
# 92         Unspecified  CMP68bd334352
# 93         Unspecified  CMP68bd334352
# 94         Unspecified  CMPf3265e9fca
# 95         Unspecified  CMPf3265e9fca
#
# [96 rows x 22 columns]

# %%
#env_int_table = env_int_df.rename(columns={'row_id': 'env_int_id'}, inplace=True)
env_int_table = env_int_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_int_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      env_int_id  year reporting_level  \
# 0   ENV_INT-GRP-0a2c0d69-2023-1  2023  Facility-group
# 1   ENV_INT-GRP-0a2c0d69-2023-2  2023  Facility-group
# 2       ENV_INT-4ea8ac9d-2023-1  2023   Site-specific
# 3       ENV_INT-4ea8ac9d-2023-2  2023   Site-specific
# 4       ENV_INT-730aefe3-2023-1  2023   Site-specific
# ..                          ...   ...             ...
# 91      ENV_INT-9de9bb0d-2023-2  2023   Site-specific
# 92      ENV_INT-9de9bb0d-2023-3  2023   Site-specific
# 93      ENV_INT-9de9bb0d-2023-4  2023   Site-specific
# 94      ENV_INT-9de9bb0d-2023-5  2023   Site-specific
# 95      ENV_INT-9de9bb0d-2023-6  2023   Site-specific
#
#         reported_company_nrcan         name           main_id  \
# 0   Agnico Eagle Mines Limited   Meadowbank                 -
# 1   Agnico Eagle Mines Limited   Meadowbank                 -
# 2   Agnico Eagle Mines Limited      LaRonde  NU-MAIN-4ea8ac9d
# 3   Agnico Eagle Mines Limited      LaRonde  NU-MAIN-4ea8ac9d
# 4   Agnico Eagle Mines Limited      Macassa  NU-MAIN-730aefe3
# ..                         ...          ...               ...
# 91      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 92      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 93      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 94      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
# 95      Wesdome Gold Mines Ltd  Eagle River  QC-MAIN-9de9bb0d
#
#    facility_group_id company_id facility_type  \
# 0       GRP-0a2c0d69        NaN        mining
# 1       GRP-0a2c0d69        NaN        mining
# 2                  -        NaN        mining
# 3                  -        NaN        mining
# 4                  -        NaN        mining
# ..               ...        ...           ...
# 91                 -        NaN        mining
# 92                 -        NaN        mining
# 93                 -        NaN        mining
# 94                 -        NaN        mining
# 95                 -        NaN        mining
#
#                  mining_processing_type  ...  \
# 0   Open-pit, underground, concentrator  ...
# 1   Open-pit, underground, concentrator  ...
# 2   Open-pit, underground, concentrator  ...
# 3   Open-pit, underground, concentrator  ...
# 4                          Concentrator  ...
# ..                                  ...  ...
# 91            Underground, concentrator  ...
# 92            Underground, concentrator  ...
# 93            Underground, concentrator  ...
# 94            Underground, concentrator  ...
# 95            Underground, concentrator  ...
#
#                                  flow_type substance_name  \
# 0   Freshwater withdrawn for use intensity              -
# 1   Freshwater withdrawn for use intensity              -
# 2   Freshwater withdrawn for use intensity              -
# 3   Freshwater withdrawn for use intensity              -
# 4   Freshwater withdrawn for use intensity              -
# ..                                     ...            ...
# 91                                scope1+2              -
# 92                         Water intensity              -
# 93                         Water intensity              -
# 94                                scope1+2              -
# 95                                scope1+2              -
#
#                               unit     value comment  \
# 0   m3 of water/t of ore processed  0.252115     NaN
# 1           m3 of water/oz of gold  2.244304     NaN
# 2   m3 of water/t of ore processed  0.559341     NaN
# 3           m3 of water/oz of gold  4.849037     NaN
# 4   m3 of water/t of ore processed  0.437068     NaN
# ..                             ...       ...     ...
# 91              tCO2eq/oz produced  0.170000     NaN
# 92                     m3/t milled  0.130000     NaN
# 93                  m3/oz produced  0.330000     NaN
# 94                 tCO2eq/t milled  0.070000     NaN
# 95              tCO2eq/oz produced  0.170000     NaN
#
#                                                source  \
# 0   Agnico-Eagle-2023-Sustainability-Performance-D...
# 1   Agnico-Eagle-2023-Sustainability-Performance-D...
# 2   Agnico-Eagle-2023-Sustainability-Performance-D...
# 3   Agnico-Eagle-2023-Sustainability-Performance-D...
# 4   Agnico-Eagle-2023-Sustainability-Performance-D...
# ..                                                ...
# 91                          2023-ESG-Data-Tables.xlsx
# 92                          2023-ESG-Data-Tables.xlsx
# 93                          2023-ESG-Data-Tables.xlsx
# 94                          2023-ESG-Data-Tables.xlsx
# 95                          2023-ESG-Data-Tables.xlsx
#
#                                             source_id substance_id  \
# 0   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 1   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 2   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 3   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# 4   SRC_AgnicoEagleMinesLimited_Agnico-Eagle-2023-...          NaN
# ..                                                ...          ...
# 91       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 92       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 93       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 94       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
# 95       SRC_WesdomeGoldMinesLtd_2023-ESG-Data-Tables          NaN
#
#    compartment_pathway compartment_id
# 0          Unspecified  CMP68bd334352
# 1          Unspecified  CMP68bd334352
# 2          Unspecified  CMP68bd334352
# 3          Unspecified  CMP68bd334352
# 4          Unspecified  CMP68bd334352
# ..                 ...            ...
# 91         Unspecified  CMPf3265e9fca
# 92         Unspecified  CMP68bd334352
# 93         Unspecified  CMP68bd334352
# 94         Unspecified  CMPf3265e9fca
# 95         Unspecified  CMPf3265e9fca
#
# [96 rows x 22 columns]

# %%
col_to_keep = [
    'env_int_id', 'year', 'compartment_id', 'flow_type', 'substance_id', 'unit', 'value', 'comment',
    'main_id', 'facility_group_id', 'company_id', 'source_id'
]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_int_table = env_int_table[col_to_keep]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Reserves and resources table

# %%
reserves_table = reserves_df.rename(columns={'row_id': 'reserves_id'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
reserves_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               reserves_id  year reporting_level  \
# 0     RES-d29e0839-2022-1  2022   Site-specific
# 1     RES-d29e0839-2022-2  2022   Site-specific
# 2     RES-e7e6a960-2024-1  2024   Site-specific
# 3     RES-e7e6a960-2024-2  2024   Site-specific
# 4     RES-e7e6a960-2024-3  2024   Site-specific
# ..                    ...   ...             ...
# 389  RES-dd723db4-2023-12  2023   Site-specific
# 390  RES-dd723db4-2023-13  2023   Site-specific
# 391  RES-dd723db4-2023-14  2023   Site-specific
# 392  RES-dd723db4-2023-15  2023   Site-specific
# 393  RES-dd723db4-2023-16  2023   Site-specific
#
#               reported_company_nrcan            name           main_id  \
# 0                  Abcourt Mines Inc  Sleeping Giant  QC-MAIN-d29e0839
# 1                  Abcourt Mines Inc  Sleeping Giant  QC-MAIN-d29e0839
# 2         Agnico Eagle Mines Limited     Detour Lake  QC-MAIN-e7e6a960
# 3         Agnico Eagle Mines Limited     Detour Lake  QC-MAIN-e7e6a960
# 4         Agnico Eagle Mines Limited     Detour Lake  QC-MAIN-e7e6a960
# ..                               ...             ...               ...
# 389  Iron Ore Company of Canada Inc.      Carol Lake  NL-MAIN-dd723db4
# 390  Iron Ore Company of Canada Inc.      Carol Lake  NL-MAIN-dd723db4
# 391  Iron Ore Company of Canada Inc.      Carol Lake  NL-MAIN-dd723db4
# 392  Iron Ore Company of Canada Inc.      Carol Lake  NL-MAIN-dd723db4
# 393  Iron Ore Company of Canada Inc.      Carol Lake  NL-MAIN-dd723db4
#
#     facility_group_id facility_type  mining_processing_type        commodity  \
# 0                   -        mining            Concentrator             Gold
# 1                   -        mining            Concentrator             Gold
# 2                   -        mining  Open-pit, concentrator             Gold
# 3                   -        mining  Open-pit, concentrator             Gold
# 4                   -        mining  Open-pit, concentrator             Gold
# ..                ...           ...                     ...              ...
# 389                 -        mining  Open-pit, concentrator       Phosphorus
# 390                 -        mining  Open-pit, concentrator             Iron
# 391                 -        mining  Open-pit, concentrator  Silicon dioxide
# 392                 -        mining  Open-pit, concentrator   Aluminum oxide
# 393                 -        mining  Open-pit, concentrator       Phosphorus
#
#      ... ore_unit grade grade_unit metal_content metal_content_unit norm  \
# 0    ...       Mt  7.14        g/t      173300.0                 oz  NaN
# 1    ...       Mt  8.74        g/t      248300.0                 oz  NaN
# 2    ...       kt  0.81        g/t        3333.0             kOz Au  NaN
# 3    ...       kt  0.73        g/t       15718.0             kOz Au  NaN
# 4    ...       kt   1.1        g/t        1201.0             kOz Au  NaN
# ..   ...      ...   ...        ...           ...                ...  ...
# 389  ...      NaN  0.03        % P           NaN                NaN  NaN
# 390  ...      NaN  38.2       % Fe           NaN                NaN  NaN
# 391  ...      NaN  37.8      %SiO2           NaN                NaN  NaN
# 392  ...      NaN   0.2    % Al2O3           NaN                NaN  NaN
# 393  ...      NaN  0.03        % P           NaN                NaN  NaN
#
#      recovery_rate                comment                         source  \
# 0              NaN                    NaN  TR_Abcourt_Geant_Dormant_2023
# 1              NaN                    NaN  TR_Abcourt_Geant_Dormant_2023
# 2             92.0                    NaN                      2024_MRMR
# 3             92.0                    NaN                      2024_MRMR
# 4              NaN                    NaN                      2024_MRMR
# ..             ...                    ...                            ...
# 389            NaN  Reported by Rio Tinto     rt-fact-book-addendum.xlsx
# 390            NaN  Reported by Rio Tinto     rt-fact-book-addendum.xlsx
# 391            NaN  Reported by Rio Tinto     rt-fact-book-addendum.xlsx
# 392            NaN  Reported by Rio Tinto     rt-fact-book-addendum.xlsx
# 393            NaN                    NaN                            NaN
#
#                                              source_id
# 0    SRC_AbcourtMinesInc_TR_Abcourt_Geant_Dormant_2023
# 1    SRC_AbcourtMinesInc_TR_Abcourt_Geant_Dormant_2023
# 2                SRC_AgnicoEagleMinesLimited_2024_MRMR
# 3                SRC_AgnicoEagleMinesLimited_2024_MRMR
# 4                SRC_AgnicoEagleMinesLimited_2024_MRMR
# ..                                                 ...
# 389  SRC_IronOreCompanyofCanadaInc._rt-fact-book-ad...
# 390  SRC_IronOreCompanyofCanadaInc._rt-fact-book-ad...
# 391  SRC_IronOreCompanyofCanadaInc._rt-fact-book-ad...
# 392  SRC_IronOreCompanyofCanadaInc._rt-fact-book-ad...
# 393                 SRC_IronOreCompanyofCanadaInc._nan
#
# [394 rows x 23 columns]

# %%
reserves_table = reserves_table[['reserves_id', 'year', 'commodity', 'reserves_resources', 'reserves_resources_type', 'ore', 'ore_unit', 'grade', 'grade_unit', 'metal_content', 'metal_content_unit', 'recovery_rate', 'comment', 'main_id', 'facility_group_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Energy table

# %%
#energy_table = energy_df.rename(columns={'row_id': 'nrj_id'})
energy_table = energy_table[['nrj_id', 'year', 'energy_type', 'unit', 'value', 'main_id', 'facility_group_id', 'company_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
energy_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        nrj_id  year                          energy_type  \
# 0         NRJ-e7e6a960-2023-1  2023                     Fuel consumption
# 1         NRJ-e7e6a960-2023-2  2023                               Diesel
# 2         NRJ-e7e6a960-2023-3  2023                Light Fuel & Gasoline
# 3         NRJ-e7e6a960-2023-4  2023                              Propane
# 4         NRJ-e7e6a960-2023-5  2023                           Explosives
# ..                        ...   ...                                  ...
# 264       NRJ-c5fefb01-2023-7  2023                     Energy intensity
# 265       NRJ-c5fefb01-2023-8  2023                     Energy intensity
# 266  NRJ-CMP-d5f1c66b-2023-18  2023    Energy intensity of metals mining
# 267  NRJ-CMP-d5f1c66b-2023-19  2023  Energy intensity of metals smelting
# 268   NRJ-CMP-7a096012-2024-1  2024                                  NaN
#
#             unit    value           main_id facility_group_id    company_id  \
# 0             GJ  4266454  QC-MAIN-e7e6a960                 -           NaN
# 1             GJ  3947008  QC-MAIN-e7e6a960                 -           NaN
# 2             GJ    71904  QC-MAIN-e7e6a960                 -           NaN
# 3             GJ   182468  QC-MAIN-e7e6a960                 -           NaN
# 4             GJ    65074  QC-MAIN-e7e6a960                 -           NaN
# ..           ...      ...               ...               ...           ...
# 264  GJ/t milled     1.07  ON-MAIN-c5fefb01                 -           NaN
# 265        GJ/oz     5.78  ON-MAIN-c5fefb01                 -           NaN
# 266   GJ/t Cu-eq     40.3                 -                 -  CMP-d5f1c66b
# 267   GJ/t Cu-eq     30.3                 -                 -  CMP-d5f1c66b
# 268          NaN      NaN                 -                 -  CMP-7a096012
#
#                                              source_id
# 0    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...
# 1    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...
# 2    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...
# 3    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...
# 4    SRC_AgnicoEagleMinesLimited_2023-Sustainabilit...
# ..                                                 ...
# 264             SRC_WesdomeGoldMinesLtd._ESG_data_2023
# 265             SRC_WesdomeGoldMinesLtd._ESG_data_2023
# 266                    SRC_Glencore_2024+ESG+data+book
# 267                    SRC_Glencore_2024+ESG+data+book
# 268          SRC_RioTinto_2024-sustainability-factbook
#
# [269 rows x 9 columns]

# %% [markdown]
# ## Tailings table

# %%
tailings_table = tailings_gdf.rename(columns={'row_id': 'tailing_id',
                             'current_tailings_storage': 'current_storage'})
tailings_table = tailings_table[['tailing_id', 'year', 'tsf_name', 'status', 'construction_year', 
                             'raise_type', 'current_maximum_height', 'current_storage', 'hazard_categorization', 
                             'classification_system', 'geometry', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Land occupation table

# %%
# Change the Land-use values from m2 to km2
li_canada_gdf['area_km2'] = li_canada_gdf['Land_use'].apply(lambda x: x / 1e6 if pd.notna(x) else x)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Land_use'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[275], line 2
#       1 # Change the Land-use values from m2 to km2
# ----> 2 li_canada_gdf['area_km2'] = li_canada_gdf['Land_use'].apply(lambda x: x / 1e6 if pd.notna(x) else x)
#
# File ~\anaconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
#    1464         and key == ""
#    (...)
#    1467         and not is_geometry_type(result)
#    1468     ):
#
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\gis\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Land_use'

# %%
li_canada_gdf.rename(columns={'li_id': 'land_occupation_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
li_canada_gdf = li_canada_gdf[['land_occupation_id', 'area_km2', 'geometry', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tang_gdf = polygon_gdf.rename(columns={'tang_id': 'land_occupation_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
polygon_gdf = polygon_gdf.to_crs(li_canada_gdf.crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Add the li_canada_gdf to the polygon_gdf
land_occupation_table = pd.concat([polygon_gdf, li_canada_gdf], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_occupation_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      land_occupation_id                                           geometry  \
# 0                  6383  POLYGON Z ((-71.95867 45.31898 0.00000, -71.95...
# 1                  6388  POLYGON Z ((-71.93803 45.34130 0.00000, -71.93...
# 2                  6390  POLYGON Z ((-71.92860 45.34214 0.00000, -71.92...
# 3                 45954  POLYGON Z ((-62.92042 44.98666 0.00000, -62.91...
# 4                 45955  POLYGON Z ((-62.92613 44.99168 0.00000, -62.92...
# ...                 ...                                                ...
# 1951     QC-LI-219a2e44  MULTIPOLYGON Z (((-79.08482 48.22969 0.00000, ...
# 1952     BC-LI-9c3aa818  POLYGON Z ((-130.49620 56.64851 0.00000, -130....
# 1953     ON-LI-1a9a061c  MULTIPOLYGON Z (((-81.36899 48.67882 0.00000, ...
# 1954     QC-LI-94bd8222  POLYGON Z ((-79.22196 49.57467 0.00000, -79.22...
# 1955     MB-LI-3e566fc3  MULTIPOLYGON Z (((-101.09514 56.81934 0.00000,...
#
#       area_km2                                          source_id  \
# 0     0.026130         https://doi.org/10.1038/s43247-023-00805-6
# 1     0.671399         https://doi.org/10.1038/s43247-023-00805-6
# 2     0.050909         https://doi.org/10.1038/s43247-023-00805-6
# 3     2.622800         https://doi.org/10.1038/s43247-023-00805-6
# 4     0.441869         https://doi.org/10.1038/s43247-023-00805-6
# ...        ...                                                ...
# 1951  2.926809  https://www.nature.com/articles/s41597-025-052...
# 1952  0.122644  https://www.nature.com/articles/s41597-025-052...
# 1953  4.202254  https://www.nature.com/articles/s41597-025-052...
# 1954  6.202897  https://www.nature.com/articles/s41597-025-052...
# 1955  0.409644  https://www.nature.com/articles/s41597-025-052...
#
#                main_id  tailing_id  distance_km relation_type
# 0                  NaN         NaN          NaN           NaN
# 1                  NaN         NaN          NaN           NaN
# 2                  NaN         NaN          NaN           NaN
# 3     NS-MAIN-c9c77a59         NaN     0.000000   one-to-many
# 4     NS-MAIN-c9c77a59         NaN     1.186584   one-to-many
# ...                ...         ...          ...           ...
# 1951  QC-MAIN-30c1828c         NaN          NaN           NaN
# 1952  BC-MAIN-b1fe389a         NaN          NaN           NaN
# 1953  ON-MAIN-f8313ebd         NaN          NaN           NaN
# 1954  QC-MAIN-b86f7d07         NaN          NaN           NaN
# 1955  MB-MAIN-6fca9d6d         NaN          NaN           NaN
#
# [1956 rows x 8 columns]

# %%
land_occupation_table = land_occupation_table[['land_occupation_id', 'area_km2', 'geometry', 'distance_km', 'main_id', 'tailing_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Drop duplicates caused by tailing id, so drop duplicates only on the 
land_occupation_table = land_occupation_table.drop_duplicates(subset=['land_occupation_id'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_occupation_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      land_occupation_id  area_km2  distance_km           main_id  tailing_id  \
# 0                  6383  0.026130          NaN               NaN         NaN
# 1                  6388  0.671399          NaN               NaN         NaN
# 2                  6390  0.050909          NaN               NaN         NaN
# 3                 45954  2.622800     0.000000  NS-MAIN-c9c77a59         NaN
# 4                 45955  0.441869     1.186584  NS-MAIN-c9c77a59         NaN
# ...                 ...       ...          ...               ...         ...
# 1951     QC-LI-219a2e44  2.926809          NaN  QC-MAIN-30c1828c         NaN
# 1952     BC-LI-9c3aa818  0.122644          NaN  BC-MAIN-b1fe389a         NaN
# 1953     ON-LI-1a9a061c  4.202254          NaN  ON-MAIN-f8313ebd         NaN
# 1954     QC-LI-94bd8222  6.202897          NaN  QC-MAIN-b86f7d07         NaN
# 1955     MB-LI-3e566fc3  0.409644          NaN  MB-MAIN-6fca9d6d         NaN
#
#                                               source_id
# 0            https://doi.org/10.1038/s43247-023-00805-6
# 1            https://doi.org/10.1038/s43247-023-00805-6
# 2            https://doi.org/10.1038/s43247-023-00805-6
# 3            https://doi.org/10.1038/s43247-023-00805-6
# 4            https://doi.org/10.1038/s43247-023-00805-6
# ...                                                 ...
# 1951  https://www.nature.com/articles/s41597-025-052...
# 1952  https://www.nature.com/articles/s41597-025-052...
# 1953  https://www.nature.com/articles/s41597-025-052...
# 1954  https://www.nature.com/articles/s41597-025-052...
# 1955  https://www.nature.com/articles/s41597-025-052...
#
# [1920 rows x 6 columns]

# %% [markdown]
# ## By-product

# %%
bth_table = bth_df.drop(columns=['facility_name'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bth_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    host by_product        ratio           main_id  \
# 0    Pt         Te     0.007718  ON-MAIN-a3c56a83
# 1    Pt         Se     0.322126  ON-MAIN-a3c56a83
# 2    Pt         Pd     0.748792  ON-MAIN-a3c56a83
# 3    Pt         Sb     0.000140  ON-MAIN-a3c56a83
# 4    Pt         Cd     0.003384  ON-MAIN-a3c56a83
# 5    Pt         Cu   464.022279  ON-MAIN-a3c56a83
# 6    Pt         Ni   520.996018  ON-MAIN-a3c56a83
# 7    Pt         Bi     0.000957  ON-MAIN-a3c56a83
# 8    Pt         Au     0.117581  ON-MAIN-a3c56a83
# 9    Pt         Co    44.429615  ON-MAIN-a3c56a83
# 10   Cu         Ag     0.002674  ON-MAIN-f8313ebd
# 11   Cu         In     0.002522  ON-MAIN-f8313ebd
# 12   Cu         Zn     2.558461  ON-MAIN-f8313ebd
# 13   Cu         Ag     0.000264  BC-MAIN-aa76f6f2
# 14   Cu         Au     0.000080  BC-MAIN-aa76f6f2
# 15   Au         Cu  5471.571796  BC-MAIN-ed23117f
# 16   Au         Ag     3.900797  QC-MAIN-e51eda66
# 17   Au         Cu   506.207255  QC-MAIN-e51eda66
# 18   Au         Zn  1796.149997  QC-MAIN-e51eda66
# 19   Cu         Ag     0.000293  BC-MAIN-3f490561
# 20   Cu         Au     0.000107  BC-MAIN-3f490561
# 21   Cu         Ag     0.001037  BC-MAIN-b4655afb
# 22   Cu         Au     0.000058  BC-MAIN-b4655afb
# 23   Cu         Mo     0.031455  BC-MAIN-6b4800fe
# 24   Cu         Re     0.000016  BC-MAIN-6b4800fe
# 25   Cu         Ag     0.000339  BC-MAIN-8eb8be0d
# 26   Cu         Au     0.000104  BC-MAIN-8eb8be0d
# 27   Ni         Pt     0.000029  QC-MAIN-a97821c0
# 28   Ni         Pd     0.000072  QC-MAIN-a97821c0
# 29   Ni         Cu     0.289924  QC-MAIN-a97821c0
# 30   Ni         Co     0.022447  QC-MAIN-a97821c0
#
#                                            source_id
# 0   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 1   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 2   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 3   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 4   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 5   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 6   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 7   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 8   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 9   https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 10  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 11  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 12  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 13  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 14  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 15  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 16  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 17  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 18  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 19  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 20  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 21  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 22  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 23  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 24  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 25  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 26  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 27  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 28  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 29  https://pubs.acs.org/doi/10.1021/acs.est.4c05293
# 30  https://pubs.acs.org/doi/10.1021/acs.est.4c05293

# %% [markdown]
# ## Archetypes table

# %%
archetype_table = archetypes_df.rename(columns={'row_id': 'archetype_id'})
archetype_table = archetype_table[['archetype_id', 'deposit_type', 'mining_depth', 'mining_method', 'processing_method', 'main_id', 'facility_group_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetype_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        archetype_id                                       deposit_type  \
# 0   ARCH-d29e0839-1                                                VMS
# 1   ARCH-1f126a43-1                          Disseminated gold deposit
# 2   ARCH-e7e6a960-1  Disseminated and structurally controlled lode ...
# 3   ARCH-8b0264c9-1            Vein / narrow vein\nSkarn\nHydrothermal
# 4   ARCH-4ea8ac9d-1  Polymetallic massive sulphide and lode gold de...
# ..              ...                                                ...
# 72  ARCH-63b394c3-1                                           Magmatic
# 73  ARCH-e05ed9fe-1              Vein / narrow vein\nIntrusion related
# 74  ARCH-9de9bb0d-1                    Mesothermal\nVein / narrow vein
# 75  ARCH-c5fefb01-1  Vein / narrow vein\nBreccia pipe / Stockwork\n...
# 76  ARCH-cb85213a-1                    Vein / narrow vein\nMesothermal
#
#    mining_depth                                      mining_method  \
# 0           NaN  Shrinkage stoping\nRoom-and-pillar\nLonghole s...
# 1           NaN  Open pit, conventional truck and shovel; remot...
# 2           NaN     Open pit, conventional truck and shovel method
# 3           NaN          Truck & Shovel / Loader\nLonghole stoping
# 4           NaN  Longitudinal and transverse longhole open stop...
# ..          ...                                                ...
# 72          NaN  Slot-Slash\nMechanized Cut & Fill\nTransverse ...
# 73          NaN                            Truck & Shovel / Loader
# 74          NaN  Longhole stoping\nAlimak\nSub-level open stopi...
# 75          NaN             Longhole stoping\nLongitudinal retreat
# 76          NaN                            Truck & Shovel / Loader
#
#                                     processing_method           main_id  \
# 0                                                 NaN  QC-MAIN-d29e0839
# 1   Conventional crushing, grinding, gravity conce...  ON-MAIN-1f126a43
# 2   Crushing, grinding, gravity concentration, cya...  QC-MAIN-e7e6a960
# 3                                                 NaN  NU-MAIN-8b0264c9
# 4                                                 NaN  NU-MAIN-4ea8ac9d
# ..                                                ...               ...
# 72                                                NaN  ON-MAIN-63b394c3
# 73                                                NaN  YT-MAIN-e05ed9fe
# 74                                                NaN  QC-MAIN-9de9bb0d
# 75                                                NaN  ON-MAIN-c5fefb01
# 76                                                NaN  ON-MAIN-cb85213a
#
#    facility_group_id                            source_id
# 0                  -              SRC_AbcourtMinesInc_MDO
# 1                  -  SRC_AgnicoEagleMinesLimited_TR_2021
# 2                  -  SRC_AgnicoEagleMinesLimited_TR_2021
# 3                  -      SRC_AgnicoEagleMinesLimited_MDO
# 4                  -  SRC_AgnicoEagleMinesLimited_TR_2023
# ..               ...                                  ...
# 72                 -                         SRC_Vale_MDO
# 73                 -      SRC_VictoriaGoldCorporation_MDO
# 74                 -          SRC_WesdomeGoldMinesLtd_MDO
# 75                 -          SRC_WesdomeGoldMinesLtd_MDO
# 76                 -          SRC_WesdomeGoldMinesLtd_MDO
#
# [77 rows x 8 columns]

# %% [markdown]
# ## Water risk table

# %%
water_risk_table = water_risk_gdf.rename(columns={'row_id': 'water_risk_id'})
water_risk_table = water_risk_table[['water_risk_id', 'indicator', 'value', 'year', 'scenario', 'value', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
water_risk_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                             water_risk_id  \
# 0     water_risk-5801b453-2020-baseline-1
# 1     water_risk-5801b453-2020-baseline-2
# 2     water_risk-5801b453-2020-baseline-3
# 3     water_risk-5801b453-2020-baseline-4
# 4     water_risk-5801b453-2020-baseline-5
# ...                                   ...
# 8635       water_risk-891d3cb5-2080-pes-2
# 8636       water_risk-891d3cb5-2080-pes-3
# 8637       water_risk-891d3cb5-2080-opt-1
# 8638       water_risk-891d3cb5-2080-opt-2
# 8639       water_risk-891d3cb5-2080-opt-3
#
#                                    indicator                      value  year  \
# 0                         Water Stress Label                 Low (<10%)  2020
# 1                      Water Depletion Label                  Low (<5%)  2020
# 2              Interannual Variability Label  Medium - High (0.50-0.75)  2020
# 3            Groundwater Table Decline Label        Insignificant Trend  2020
# 4     Coastal Eutrophication Potential Label                  Low (<-5)  2020
# ...                                      ...                        ...   ...
# 8635                   Water Depletion Label                  Low (<5%)  2080
# 8636           Interannual Variability Label   Low - Medium (0.25-0.50)  2080
# 8637                      Water Stress Label                 Low (<10%)  2080
# 8638                   Water Depletion Label                  Low (<5%)  2080
# 8639           Interannual Variability Label   Low - Medium (0.25-0.50)  2080
#
#       scenario                      value           main_id  \
# 0     baseline                 Low (<10%)  QC-MAIN-5801b453
# 1     baseline                  Low (<5%)  QC-MAIN-5801b453
# 2     baseline  Medium - High (0.50-0.75)  QC-MAIN-5801b453
# 3     baseline        Insignificant Trend  QC-MAIN-5801b453
# 4     baseline                  Low (<-5)  QC-MAIN-5801b453
# ...        ...                        ...               ...
# 8635       pes                  Low (<5%)  BC-MAIN-891d3cb5
# 8636       pes   Low - Medium (0.25-0.50)  BC-MAIN-891d3cb5
# 8637       opt                 Low (<10%)  BC-MAIN-891d3cb5
# 8638       opt                  Low (<5%)  BC-MAIN-891d3cb5
# 8639       opt   Low - Medium (0.25-0.50)  BC-MAIN-891d3cb5
#
#                                               source_id
# 0     https://www.wri.org/data/aqueduct-global-maps-...
# 1     https://www.wri.org/data/aqueduct-global-maps-...
# 2     https://www.wri.org/data/aqueduct-global-maps-...
# 3     https://www.wri.org/data/aqueduct-global-maps-...
# 4     https://www.wri.org/data/aqueduct-global-maps-...
# ...                                                 ...
# 8635  https://www.wri.org/data/aqueduct-global-maps-...
# 8636  https://www.wri.org/data/aqueduct-global-maps-...
# 8637  https://www.wri.org/data/aqueduct-global-maps-...
# 8638  https://www.wri.org/data/aqueduct-global-maps-...
# 8639  https://www.wri.org/data/aqueduct-global-maps-...
#
# [8640 rows x 8 columns]

# %% [markdown]
# ## Climate categories table

# %%
climate_category_table = climate_category_gdf.rename(columns={'row_id': 'climate_category_id'})
climate_category_table = climate_category_table[['climate_category_id', 'year', 'scenario', 'category', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
climate_category_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      climate_category_id       year    scenario  \
# 0     CC-5801b453-1991_2020-historical-1  1991_2020  historical
# 1     CC-d29e0839-1991_2020-historical-1  1991_2020  historical
# 2     CC-f1ff4920-1991_2020-historical-1  1991_2020  historical
# 3     CC-4ea8ac9d-1991_2020-historical-1  1991_2020  historical
# 4     CC-e7e6a960-1991_2020-historical-1  1991_2020  historical
# ...                                  ...        ...         ...
# 2425      CC-c5fefb01-2071_2099-ssp585-1  2071_2099      ssp585
# 2426      CC-feb13c30-2071_2099-ssp585-1  2071_2099      ssp585
# 2427      CC-5e0d8b48-2071_2099-ssp585-1  2071_2099      ssp585
# 2428      CC-12c68d49-2071_2099-ssp585-1  2071_2099      ssp585
# 2429      CC-891d3cb5-2071_2099-ssp585-1  2071_2099      ssp585
#
#                                     category           main_id  \
# 0     Dfb - Cold, no dry season, warm summer  QC-MAIN-5801b453
# 1     Dfb - Cold, no dry season, warm summer  QC-MAIN-d29e0839
# 2     Dfb - Cold, no dry season, warm summer  QC-MAIN-f1ff4920
# 3     Dfc - Cold, no dry season, cold summer  NU-MAIN-4ea8ac9d
# 4     Dfb - Cold, no dry season, warm summer  QC-MAIN-e7e6a960
# ...                                      ...               ...
# 2425  Dfb - Cold, no dry season, warm summer  ON-MAIN-c5fefb01
# 2426     Dsb - Cold, dry summer, warm summer  BC-MAIN-feb13c30
# 2427  Dfc - Cold, no dry season, cold summer  YT-MAIN-5e0d8b48
# 2428   Dfa - Cold, no dry season, hot summer  ON-MAIN-12c68d49
# 2429  Dfc - Cold, no dry season, cold summer  BC-MAIN-891d3cb5
#
#                                        source_id
# 0     https://doi.org/10.1038/s41597-023-02549-6
# 1     https://doi.org/10.1038/s41597-023-02549-6
# 2     https://doi.org/10.1038/s41597-023-02549-6
# 3     https://doi.org/10.1038/s41597-023-02549-6
# 4     https://doi.org/10.1038/s41597-023-02549-6
# ...                                          ...
# 2425  https://doi.org/10.1038/s41597-023-02549-6
# 2426  https://doi.org/10.1038/s41597-023-02549-6
# 2427  https://doi.org/10.1038/s41597-023-02549-6
# 2428  https://doi.org/10.1038/s41597-023-02549-6
# 2429  https://doi.org/10.1038/s41597-023-02549-6
#
# [2430 rows x 6 columns]

# %% [markdown]
# ## Weather table

# %%
weather_table = weather_gdf.rename(columns={'row_id': 'weather_id'})
weather_table = weather_table[['weather_id', 'year', 'variable', 'value', 'unit', 'scenario', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
weather_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                            weather_id  year                 variable  \
# 0      weather-5801b453-2025-ssp126-1  2025  Daily Temperature Range
# 1      weather-5801b453-2030-ssp126-1  2030  Daily Temperature Range
# 2      weather-5801b453-2035-ssp126-1  2035  Daily Temperature Range
# 3      weather-5801b453-2040-ssp126-1  2040  Daily Temperature Range
# 4      weather-5801b453-2045-ssp126-1  2045  Daily Temperature Range
# ...                               ...   ...                      ...
# 34555  weather-891d3cb5-2080-ssp585-2  2080     Annual Precipitation
# 34556  weather-891d3cb5-2085-ssp585-2  2085     Annual Precipitation
# 34557  weather-891d3cb5-2090-ssp585-2  2090     Annual Precipitation
# 34558  weather-891d3cb5-2095-ssp585-2  2095     Annual Precipitation
# 34559  weather-891d3cb5-2100-ssp585-2  2100     Annual Precipitation
#
#             value unit scenario           main_id  \
# 0       11.632902   °C   ssp126  QC-MAIN-5801b453
# 1       11.683678   °C   ssp126  QC-MAIN-5801b453
# 2       11.695585   °C   ssp126  QC-MAIN-5801b453
# 3       11.721719   °C   ssp126  QC-MAIN-5801b453
# 4       11.564794   °C   ssp126  QC-MAIN-5801b453
# ...           ...  ...      ...               ...
# 34555  807.612915   mm   ssp585  BC-MAIN-891d3cb5
# 34556  790.696106   mm   ssp585  BC-MAIN-891d3cb5
# 34557  800.068237   mm   ssp585  BC-MAIN-891d3cb5
# 34558  817.156982   mm   ssp585  BC-MAIN-891d3cb5
# 34559  841.397217   mm   ssp585  BC-MAIN-891d3cb5
#
#                                                source_id
# 0      https://climate-scenarios.canada.ca/?page=CanD...
# 1      https://climate-scenarios.canada.ca/?page=CanD...
# 2      https://climate-scenarios.canada.ca/?page=CanD...
# 3      https://climate-scenarios.canada.ca/?page=CanD...
# 4      https://climate-scenarios.canada.ca/?page=CanD...
# ...                                                  ...
# 34555  https://climate-scenarios.canada.ca/?page=CanD...
# 34556  https://climate-scenarios.canada.ca/?page=CanD...
# 34557  https://climate-scenarios.canada.ca/?page=CanD...
# 34558  https://climate-scenarios.canada.ca/?page=CanD...
# 34559  https://climate-scenarios.canada.ca/?page=CanD...
#
# [34560 rows x 8 columns]

# %% [markdown]
# ## Conflict table

# %%
conflict_table = conflict_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
conflict_table = conflict_table[['ej_atlas_id', 'case_name', 'start_date', 'end_date', 
                             'conflict_description', 'conflict_details', 'population_affected',
                             'conflict_intensity', 'project_status', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
conflict_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ej_atlas_id                                          case_name  \
# 9          4135      Vale Mining in Voisey's Bay, Labrador, Canada
# 10         4145  Port Colborne Class Action Lawsuit Against Val...
# 15         5599  Nouveau Mondeâ€™s Matawinie graphite mine in Q...
#
#     start_date end_date                               conflict_description  \
# 9      11/1994     None  <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10     06/2000  04/2012  <p>In Pearson (later Smith) v. Inco, the large...
# 15  01/01/2017     None  <p>Five kilometers southwest of the municipali...
#
#                                      conflict_details population_affected  \
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...               Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...               Urban
# 15  The project includes 319 mining concessions (c...               Rural
#
#                                 conflict_intensity      project_status  \
# 9   MEDIUM (street protests, visible mobilization)        In operation
# 10                     LOW (some local organising)        In operation
# 15  MEDIUM (street protests, visible mobilization)  Under construction
#
#              main_id                                          source_id
# 9   NL-MAIN-2d8801d6  http://journals.librarypublishing.arizona.edu/...
# 10  ON-MAIN-2e13aaa0  http://journals.librarypublishing.arizona.edu/...
# 15  QC-MAIN-d6748d40  http://journals.librarypublishing.arizona.edu/...

# %% [markdown]
# ## Population table

# %%
population_table = population_gdf.rename(columns={'row_id': 'population_id'})
population_table = population_table[['population_id', 'year', 'buffer_size', 'total_population', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
population_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    population_id  year buffer_size  total_population  \
# 0     population-5801b453-2025-1  2025        10km       1305.901860
# 1     population-5801b453-2025-2  2025        50km      63977.830574
# 2     population-5801b453-2030-1  2030        10km       1338.088985
# 3     population-5801b453-2030-2  2030        50km      65434.154098
# 4     population-d29e0839-2025-1  2025        10km          0.000000
# ...                          ...   ...         ...               ...
# 1075  population-12c68d49-2030-2  2030        50km          0.000000
# 1076  population-891d3cb5-2025-1  2025        10km          0.000000
# 1077  population-891d3cb5-2025-2  2025        50km        297.622460
# 1078  population-891d3cb5-2030-1  2030        10km          0.000000
# 1079  population-891d3cb5-2030-2  2030        50km        309.797150
#
#                main_id                                          source_id
# 0     QC-MAIN-5801b453  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 1     QC-MAIN-5801b453  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 2     QC-MAIN-5801b453  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 3     QC-MAIN-5801b453  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 4     QC-MAIN-d29e0839  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# ...                ...                                                ...
# 1075  ON-MAIN-12c68d49  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 1076  BC-MAIN-891d3cb5  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 1077  BC-MAIN-891d3cb5  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 1078  BC-MAIN-891d3cb5  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
# 1079  BC-MAIN-891d3cb5  https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F4...
#
# [1080 rows x 6 columns]

# %% [markdown]
# ## Peatland table

# %%
peatland_table = peatland_gdf[['peatland_presence', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
peatland_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        peatland_presence           main_id  \
# 0                No data  QC-MAIN-5801b453
# 1    peat in soil mosaic  QC-MAIN-d29e0839
# 2         peat dominated  QC-MAIN-f1ff4920
# 3                No data  NU-MAIN-4ea8ac9d
# 4                No data  QC-MAIN-e7e6a960
# ..                   ...               ...
# 265              No data  ON-MAIN-c5fefb01
# 266              No data  BC-MAIN-feb13c30
# 267              No data  YT-MAIN-5e0d8b48
# 268       peat dominated  ON-MAIN-12c68d49
# 269              No data  BC-MAIN-891d3cb5
#
#                                              source_id
# 0    https://greifswaldmoor.de/global-peatland-data...
# 1    https://greifswaldmoor.de/global-peatland-data...
# 2    https://greifswaldmoor.de/global-peatland-data...
# 3    https://greifswaldmoor.de/global-peatland-data...
# 4    https://greifswaldmoor.de/global-peatland-data...
# ..                                                 ...
# 265  https://greifswaldmoor.de/global-peatland-data...
# 266  https://greifswaldmoor.de/global-peatland-data...
# 267  https://greifswaldmoor.de/global-peatland-data...
# 268  https://greifswaldmoor.de/global-peatland-data...
# 269  https://greifswaldmoor.de/global-peatland-data...
#
# [270 rows x 3 columns]

# %% [markdown]
# ## Prioritization area table

# %%
prioritization_area_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name                     geometry  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue   POINT (-77.67901 48.52154)
# 1    QC-MAIN-d29e0839     Sleeping Giant   POINT (-77.97434 49.13259)
# 2    QC-MAIN-f1ff4920       Akasaba West   POINT (-77.58000 48.04000)
# 3    NU-MAIN-4ea8ac9d             Amaruq   POINT (-96.69700 65.41500)
# 4    QC-MAIN-e7e6a960  Canadian Malartic   POINT (-78.13082 48.12222)
# ..                ...                ...                          ...
# 265  ON-MAIN-c5fefb01              Mishi   POINT (-85.45250 48.11028)
# 266  BC-MAIN-feb13c30       Record Ridge  POINT (-117.88400 49.08200)
# 267  YT-MAIN-5e0d8b48             Casino  POINT (-138.83333 62.73333)
# 268  ON-MAIN-12c68d49       Eagle's Nest   POINT (-86.30380 52.74202)
# 269  BC-MAIN-891d3cb5               Akie  POINT (-124.86599 57.38088)
#
#      jung_priority_point  jung_priority_mean_50km  \
# 0              25.926612                22.025641
# 1              13.000000                15.775000
# 2              20.618888                21.125000
# 3              63.927000                58.076923
# 4              21.186758                21.166667
# ..                   ...                      ...
# 265            21.298652                19.614286
# 266            47.846798                41.093333
# 267            67.371530                66.961039
# 268            14.300865                14.189873
# 269            35.079117                35.333333
#
#                                   source_id
# 0    https://doi.org/10.5281/zenodo.5006332
# 1    https://doi.org/10.5281/zenodo.5006332
# 2    https://doi.org/10.5281/zenodo.5006332
# 3    https://doi.org/10.5281/zenodo.5006332
# 4    https://doi.org/10.5281/zenodo.5006332
# ..                                      ...
# 265  https://doi.org/10.5281/zenodo.5006332
# 266  https://doi.org/10.5281/zenodo.5006332
# 267  https://doi.org/10.5281/zenodo.5006332
# 268  https://doi.org/10.5281/zenodo.5006332
# 269  https://doi.org/10.5281/zenodo.5006332
#
# [270 rows x 6 columns]

# %%
prioritization_conservation_area_table = prioritization_area_gdf.rename(columns={
    'jung_priority_point': 'score_1_km',
    'jung_priority_mean_50km': 'mean_score_50_km',})
prioritization_conservation_area_table = prioritization_conservation_area_table[['score_1_km', 'mean_score_50_km', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
prioritization_conservation_area_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      score_1_km  mean_score_50_km           main_id  \
# 0     25.926612         22.025641  QC-MAIN-5801b453
# 1     13.000000         15.775000  QC-MAIN-d29e0839
# 2     20.618888         21.125000  QC-MAIN-f1ff4920
# 3     63.927000         58.076923  NU-MAIN-4ea8ac9d
# 4     21.186758         21.166667  QC-MAIN-e7e6a960
# ..          ...               ...               ...
# 265   21.298652         19.614286  ON-MAIN-c5fefb01
# 266   47.846798         41.093333  BC-MAIN-feb13c30
# 267   67.371530         66.961039  YT-MAIN-5e0d8b48
# 268   14.300865         14.189873  ON-MAIN-12c68d49
# 269   35.079117         35.333333  BC-MAIN-891d3cb5
#
#                                   source_id
# 0    https://doi.org/10.5281/zenodo.5006332
# 1    https://doi.org/10.5281/zenodo.5006332
# 2    https://doi.org/10.5281/zenodo.5006332
# 3    https://doi.org/10.5281/zenodo.5006332
# 4    https://doi.org/10.5281/zenodo.5006332
# ..                                      ...
# 265  https://doi.org/10.5281/zenodo.5006332
# 266  https://doi.org/10.5281/zenodo.5006332
# 267  https://doi.org/10.5281/zenodo.5006332
# 268  https://doi.org/10.5281/zenodo.5006332
# 269  https://doi.org/10.5281/zenodo.5006332
#
# [270 rows x 4 columns]

# %% [markdown]
# # Exports

# %% [markdown]
# ## Exports tables to CSV

# %%
# Export all the tables to CSV
main_gdf.to_csv(r'database/CSV/main_table.csv', index=False, encoding="utf-8-sig")
production_table.to_csv(r'database/CSV/production_table.csv', index=False, encoding="utf-8-sig")
env_table.to_csv(r'database/CSV/env_table.csv', index=False, encoding="utf-8-sig")
land_cover_table.to_csv(r'database/CSV/land_cover_table.csv', index=False, encoding="utf-8-sig")
env_int_df.to_csv(r'database/CSV/env_int_table.csv', index=False, encoding="utf-8-sig")
reserves_df.to_csv(r'database/CSV/reserves_table.csv', index=False, encoding="utf-8-sig")
energy_df.to_csv(r'database/csv/energy_table.csv', index=False, encoding="utf-8-sig")
tailings_gdf.to_csv(r'database/CSV/tailings_table.csv', index=False, encoding="utf-8-sig")
polygon_gdf.to_csv(r'database/CSV/land_occupation_table.csv', index=False, encoding="utf-8-sig")
archetypes_df.to_csv(r'database/CSV/archetypes_table.csv', index=False, encoding="utf-8-sig")
water_risk_gdf.to_csv(r'database/CSV/water_risk_table.csv', index=False, encoding="utf-8-sig")
climate_category_gdf.to_csv(r'database/CSV/climate_category_table.csv', index=False, encoding="utf-8-sig")
weather_gdf.to_csv(r'database/CSV/weather_table.csv', index=False, encoding="utf-8-sig")
conflict_gdf.to_csv(r'database/CSV/conflict_table.csv', index=False, encoding="utf-8-sig")
population_gdf.to_csv(r'database/CSV/population_table.csv', index=False, encoding="utf-8-sig")
peatland_gdf.to_csv(r'database/CSV/peatland_table.csv', index=False, encoding="utf-8-sig")
prioritization_area_gdf.to_csv(r'database/CSV/prioritization_area_table.csv', index=False, encoding="utf-8-sig")
bth_df.to_csv(r'database/CSV/bth_table.csv', index=False, encoding="utf-8-sig")
protected_land_table.to_csv(r'database/CSV/protected_land_table.csv', index=False, encoding="utf-8-sig")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# We remove the geometry column to avoid issues with large file size
#protected_land_table.drop(columns=['geometry'], inplace=True)
protected_land_table.to_csv(r'database/CSV/protected_land_table.csv', index=False, encoding="utf-8-sig")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Export DB to SQLite

# %%
from matching_functions import create_and_populate_database
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tables_dict = {
    "Main": main_gdf,
    
    "Sources": source_table, 
    "Substances": substance_table,
    "Compartments": compartment_table,
    
    "Reserves_resources": reserves_table,
    "Production": production_table,
    "Energy": energy_table,
    "Environmental_flows": env_table,
    "Environmental_intensity": env_int_table,
    "Archetypes": archetype_table,
    
    "Tailings": tailings_table,
    "Land_occupation": land_occupation_table,
    "By_products": bth_table,
    
    "Water_risk": water_risk_table,
    "Climate_category": climate_category_table,
    "Weather": weather_table,
    "Land_cover": land_cover_table,
    "Conflict": conflict_table,
    "Population": population_table,
    "Peatland": peatland_table,
    "Prioritization_conservation_areas": prioritization_conservation_area_table,
    "Protected_indigenous_lands": protected_land_table,
    
}

# Run the function
create_and_populate_database(
    db_path="database/metallican.sqlite",
    schema_path="database/schema.sql",
    tables_dict=tables_dict,
    keep_geometry_tables=["main", "tailings", "polygons"]
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Old database 'database/metallican11.sqlite' deleted
# ✅ Empty database structure created at 'database/metallican11.sqlite'
# 🔄 Converting geometries...
# ✅ Geometries handled (kept only where needed)
# ✅ New connection opened
# ✅ Inserted 270 rows into 'Main'
# ✅ Inserted 205 rows into 'Sources'
# ✅ Inserted 174 rows into 'Substances'
# ✅ Inserted 41 rows into 'Compartments'
# ✅ Inserted 394 rows into 'Reserves_resources'
# ✅ Inserted 390 rows into 'Production'
# ✅ Inserted 269 rows into 'Energy'
# ✅ Inserted 14525 rows into 'Environmental_flows'
# ✅ Inserted 96 rows into 'Environmental_intensity'
# ✅ Inserted 77 rows into 'Archetypes'
# ✅ Inserted 86 rows into 'Tailings'
# ✅ Inserted 1920 rows into 'Land_occupation'
# ✅ Inserted 31 rows into 'By_products'
# ✅ Inserted 8640 rows into 'Water_risk'
# ✅ Inserted 2430 rows into 'Climate_category'
# ✅ Inserted 34560 rows into 'Weather'
# ✅ Inserted 270 rows into 'Land_cover'
# ✅ Inserted 3 rows into 'Conflict'
# ✅ Inserted 1080 rows into 'Population'
# ✅ Inserted 270 rows into 'Peatland'
# ✅ Inserted 270 rows into 'Prioritization_conservation_areas'
# ✅ Inserted 8795 rows into 'Protected_indigenous_lands'
# ✅ No foreign key problems found!
# ✅ Connection closed properly
