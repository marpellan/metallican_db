# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %% [markdown]
# # Imports

# %%
main_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/main_gdf.parquet")
tailings_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/tailings_gdf.parquet")
min_can_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/min_can_gdf.parquet")
ctrace_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/ctrace_gdf.parquet")
conflict_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/conflict_gdf.parquet")
ghg_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/ghg_gdf_updated.parquet")
npri_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/pollutant_gdf.parquet")
climate_category_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/climate_category_gdf.parquet")
weather_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/weather_gdf.parquet")
peatland_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/peatland_gdf.parquet")
prioritization_area_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/prioritization_area_gdf.parquet")
population_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/population_gdf.parquet")
water_risk_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/water_risk_gdf.parquet")
land_cover_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/land_cover_gdf.parquet")
npv_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/npv_gdf.parquet")
indigenous_can_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/indigenous_can_gdf.parquet")
wpda_gdf_polygons = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/wpda_gdf_polygons.parquet")
tang_canada_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/tang_canada_gdf.parquet")
li_canada_gdf = gpd.read_parquet("data/Tables/Raw_datasets/GeoParquet/li_canada_gdf.parquet")
carbon_stock_gdf = pd.read_parquet("data/Tables/Raw_datasets/GeoParquet/carbon_stock_gdf.parquet")
bth_df = pd.read_excel(r'data/Mappings/BtH_mapped_sites.xlsx')

# %%
# From manually collected data
production_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Production')
tech_attributes_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Technical_attributes')
reserves_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Reserves')
technosphere_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='NRJ_mat')
env_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Env')
waste_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Waste')                       
intensity_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Intensity')
archetypes_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Archetype')

# %%
from db_creation_function import assign_row_id_to_collected_data

# %%
# We need to assign row_ids to the manually collected data
production_df = assign_row_id_to_collected_data(production_df, 
                  facility_id_col='main_id',
                  prefix='PROD',
                  year_col='year'           
                  )

tech_attributes_df = assign_row_id_to_collected_data(tech_attributes_df, 
                  facility_id_col='main_id',
                  prefix='TA',
                  year_col='year'           
                  )
reserves_df = assign_row_id_to_collected_data(reserves_df, 
                  facility_id_col='main_id',
                  prefix='RES',
                  year_col='year'           
                  )

technosphere_df = assign_row_id_to_collected_data(technosphere_df, 
                  facility_id_col='main_id',
                  prefix='TECH',
                  year_col='year'           
                  )

env_df = assign_row_id_to_collected_data(env_df, 
                  facility_id_col='main_id',
                  prefix='ENV',
                  year_col='year'           
                  )

waste_df = assign_row_id_to_collected_data(waste_df, 
                  facility_id_col='main_id',
                  prefix='WASTE',
                  year_col='year'           
                  )

intensity_df = assign_row_id_to_collected_data(intensity_df, 
                  facility_id_col='main_id',
                  prefix='INT',
                  year_col='year'           
                  )

archetypes_df = assign_row_id_to_collected_data(archetypes_df, 
                  facility_id_col='main_id',
                  prefix='ARCH',
                  )

# %% [markdown]
# # Small cleaning

# %%
# In the main_gdf, for facility_name = Raglan, remove the the facility_group_name and facility_group_id as it not part of INO in the new production data
main_gdf.loc[main_gdf['facility_name'] == 'Raglan', ['facility_group_name', 'facility_group_id']] = None

# %%
group_name = "Cigar Lake + McClean Lake"
group_id = "GRP-91aaa60b"

# Assign to both facilities
main_gdf.loc[
    main_gdf["facility_name"].isin(["Cigar Lake", "McClean Lake"]),
    ["facility_group_name", "facility_group_id"]
] = [group_name, group_id]

# %%
npri_gdf['emission_type'] = npri_gdf['emission_type'].replace({
    'Air Emissions / Émissions à l\'air': 'Air',
    'Water Releases / Rejets à l\'eau': 'Water',
    'Land Releases /  Rejets au sol': 'Land',
    'On-Site Disposal / Élimination sur le site': 'On-Site Disposal',
    'Off-Site Disposal / Élimination hors site': 'Off-Site Disposal',
    'Transfers for Treatment / Transferts pour traitement': 'Transfers for Treatment',
    'Transfers for Recycling / Transferts pour recyclage': 'Transfers for Recycling',
})

# %%
npri_gdf['emission_subtype'] = npri_gdf['emission_subtype'].replace({
    'Receiving Waterbody (French)': 'Waterbody',
    'Receiving Waterbody (English)': 'Waterbody'})

# %%
# Differentiate between biosphere and technosphere compartments
biosphere = ["Air", "Water", 'Land']
technosphere = ['On-Site Disposal', 'Off-Site Disposal', 'Transfers for Treatment', 'Transfers for Recycling']

pollutant_npri_gdf = npri_gdf[npri_gdf['emission_type'].isin(biosphere)].copy()
waste_npri_gdf = npri_gdf[npri_gdf['emission_type'].isin(technosphere)].copy()

# %%
pollutant_npri_gdf.rename(columns={
    'emission_type': 'compartment_name',
    'emission_subtype': 'release_pathway'
}, inplace=True)

# %%
waste_npri_gdf.rename(
    columns={
        'emission_type': 'flow_direction',
        'emission_subtype': 'release_pathway'
    }, inplace=True
)

# %% [markdown]
# # Create auxiliary tables

# %% [markdown]
# ## Source table

# %%
# For the main table
source_map = {
    "project": "https://open.canada.ca/data/en/dataset/22b2db8a-dc12-47f2-9737-99d3da921751",
    "mining": "https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720",
    "manufacturing": "https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720"
}
main_gdf["source_id"] = main_gdf["facility_type"].map(source_map)
main_gdf
# Out:
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# ...

# %%
# For the datasets
tailings_gdf["source_id"] = 'https://tailing.grida.no/'
min_can_gdf["source_id"] = '10.1038/s41597-024-03116-3'
ctrace_gdf["source_id"] = 'https://github.com/climatetracecoalition/methodology-documents/tree/main/2024/Mineral%20Extraction'
conflict_gdf["source_id"] = 'http://journals.librarypublishing.arizona.edu/jpe/article/id/1932/'
ghg_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/environmental-indicators/greenhouse-gas-emissions/large-facilities.html; https://open.canada.ca/data/en/dataset/a8ba14b7-7f23-462a-bdbb-83b0ef629823'
pollutant_npri_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html'
waste_npri_gdf["source_id"] = 'https://www.canada.ca/en/environment-climate-change/services/national-pollutant-release-inventory/tools-resources-data/exploredata.html'
prioritization_area_gdf['source_id'] = 'https://doi.org/10.5281/zenodo.5006332'
climate_category_gdf['source_id'] = 'https://doi.org/10.1038/s41597-023-02549-6'
weather_gdf['source_id'] = 'https://climate-scenarios.canada.ca/?page=CanDCS6-indices'
peatland_gdf['source_id'] = 'https://greifswaldmoor.de/global-peatland-database-en.html'
population_gdf['source_id'] = 'https://doi.org/10.2905/2FF68A52-5B5B-4A22-8F40-C41DA8332CFE' 
water_risk_gdf['source_id'] = 'https://www.wri.org/data/aqueduct-global-maps-40-data'
land_cover_gdf['source_id'] = 'https://doi.org/10.5067/MODIS/MCD12Q1.061 + https://doi.org/10.5281/zenodo.7254221'
npv_gdf['source_id'] = 'https://doi.org/10.7717/peerj.5457'
indigenous_can_gdf['source_id'] = 'http://www.landmarkmap.org'
wpda_gdf_polygons['source_id'] = 'https://www.protectedplanet.net'
tang_canada_gdf['source_id'] = 'https://doi.org/10.1038/s43247-023-00805-6'
li_canada_gdf['source_id'] = 'https://www.nature.com/articles/s41597-025-05296-y'
bth_df['source_id'] = 'https://pubs.acs.org/doi/10.1021/acs.est.4c05293'
carbon_stock_gdf['source_id'] = 'https://zenodo.org/records/15777016'
archetypes_df['source_id'] = archetypes_df['source'] + ' ; ' + 'https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/145496'

# %%
from db_creation_function import add_source_id_to_collected_data

# %%
production_df = add_source_id_to_collected_data(production_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

tech_attributes_df = add_source_id_to_collected_data(tech_attributes_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

reserves_df = add_source_id_to_collected_data(reserves_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

technosphere_df = add_source_id_to_collected_data(technosphere_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

env_df = add_source_id_to_collected_data(env_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

waste_df = add_source_id_to_collected_data(waste_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

intensity_df = add_source_id_to_collected_data(intensity_df, 
                                    company_col="reported_company_nrcan", 
                                    facility_col="name", 
                                    source_col="source")

# %%
from db_creation_function import create_source_table_from_datasets

# %%
dataset_dict = {
    "Global Tailings Portal": tailings_gdf,
    "A Comprehensive Historical and Geolocalized Database of Mining Activities in Canada": min_can_gdf,
    "Jolleys, M. et al (2024). Mineral Extraction sector: Mining and Quarrying Emissions from Copper, Iron, Bauxite, Rock and Sand, Hypervine, UK, Climate TRACE Emissions Inventory": ctrace_gdf,
    "Environmental Justice Atlas": conflict_gdf,
    "GHG from large facilities": ghg_gdf,
    "National Pollutant Inventory Report (NPRI)": npri_gdf,
    "Areas of global importance for conserving terrestrial biodiversity, carbon and water": prioritization_area_gdf,
    "High-Resolution (1 km) Koppen-Geiger Maps for 1901–2099 Based on Constrained CMIP6 Projections": climate_category_gdf,
    "CMIP6 statistically downscaled climate indices (CanDCS-M6)": weather_gdf,
    "Global Peatland Database": peatland_gdf,
    "Global Human Settlement Layer (GHSL)": population_gdf,
    "Aqueduct 4.0": water_risk_gdf,
    "Modis Land Cover and ESA World Cover": land_cover_gdf,
    "Potential Natural Vegetation (NPV)": npv_gdf,
    "Indigenous Peoples’ and Local Community Lands and Territories": indigenous_can_gdf,
    "World Database on Protected Areas (WDPA)": wpda_gdf_polygons,
    "Global Mining Footprint Mapped from High-Resolution Satellite Imagery": tang_canada_gdf,
    "Machine learning-enhanced monitoring of global copper mining areas": li_canada_gdf,
    "Byproduct-to-Host Ratios for Assessing the Accessibility of Mineral Resources": bth_df,
    "Mining Data Online: Critical Minerals Mapping Initiative": archetypes_df
}

manual_dfs = [main_gdf, production_df, tech_attributes_df, reserves_df, technosphere_df, env_df, waste_df, intensity_df, archetypes_df]
source_table = create_source_table_from_datasets(dataset_dict, manual_dfs)

# %%
source_table
# Out:
#                                              source_id source_provenance  \
# 0                           10.1038/s41597-024-03116-3           dataset
# 1    https://www.wri.org/data/aqueduct-global-maps-...           dataset
# 2               https://doi.org/10.5281/zenodo.5006332           dataset
# 3     https://pubs.acs.org/doi/10.1021/acs.est.4c05293           dataset
# 4    https://climate-scenarios.canada.ca/?page=CanD...           dataset
# ..                                                 ...               ...
# 230  https://www.hecla.com/operations/hecla-keno-hi...           website
# 231  https://www.orano.group/canada/en/our-uranium-...           website
# 232  https://www.tasekomines.com/investors/news/tas...           website
# 233  https://www.tasekomines.com/properties/reserve...           website
# 234  https://www.teck.com/media/Teck-Highland-Valle...           website
#
#                                            source_name
# ...

# %%
# Add manually the 3 sources from the main table
source_table = pd.concat([
    source_table,
    pd.DataFrame([
        {
            'source_id': 'https://open.canada.ca/data/en/dataset/22b2db8a-dc12-47f2-9737-99d3da921751',
            'source_provenance': 'dataset',
            'source_name': 'Critical minerals advanced projects, mines and processing facilities in Canada '
        },
        {
            'source_id': 'https://open.canada.ca/data/en/dataset/000183ed-8864-42f0-ae43-c4313a860720',
            'source_provenance': 'dataset',
            'source_name': 'Principal Mineral Areas, Producing Mines, and Oil and Gas Fields (900A) '
        }
    ])
], ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
source_table.to_csv(r'database/CSV/sources_table.csv', index=False)

# %% [markdown]
# ## Substance table

# %%
# Get unique substance name and cas number in a new df
npri_substance_df = npri_gdf[['substance_name_npri', 'cas_number']].drop_duplicates().copy()

# %%
# Add a type column = 'Group of substances' if the cas_number starts with 'NA' and = 'Substance' if not 
npri_substance_df = npri_substance_df.assign(
    type=lambda x: np.where(x['cas_number'].str.startswith('NA'), 'Group of substances', 'Substance')
)

# %%
npri_substance_df.rename(columns={
    'substance_name_npri': 'substance_name',
    'cas_number': 'substance_id',
    'type': 'substance_type'
}, inplace=True)

# %%
# Reorganize the columns
npri_substance_df = npri_substance_df[['substance_id', 'substance_type', 'substance_name']].copy()

# %%
env_substance_df = env_df[['substance_type', 'substance_name', 'cas_number']].drop_duplicates().copy()

# %%
# Add a type column = 'Group of substances' if the cas_number starts with 'NA' and = 'Substance' if not
env_substance_df = env_substance_df.assign(
    substance_type=lambda x: np.where(x['cas_number'].str.startswith('NA'), 'Group of substances', 'Substance')
)

# %%
env_substance_df = env_substance_df.dropna(how='all').copy()

# %%
env_substance_df.rename(columns={'cas_number': 'substance_id'}, inplace=True)

# %%
# Reorganize the columns
env_substance_df = env_substance_df[['substance_id', 'substance_type', 'substance_name']].copy()

# %%
# Put the two dataframes together
substance_table = pd.concat([npri_substance_df, env_substance_df], ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
# Drop row where substance name is Speciated VOC - Benzene to avoid duplicates
substance_table = substance_table[substance_table['substance_name'] != 'Speciated VOC - Benzene'].copy()

# %%
substance_table
# Out:
#          substance_id       substance_type  \
# 0             NA - 16  Group of substances
# 1             NA - 02  Group of substances
# 2            630-08-0            Substance
# 3             NA - 04  Group of substances
# 4             NA - 05  Group of substances
# ..                ...                  ...
# 110           2025884  Group of substances
# 111          NA - PAH  Group of substances
# 112        10024-97-2            Substance
# 113         NA - PFCs  Group of substances
# 114  NA - Particulate  Group of substances
#
#                              substance_name
# 0                           Ammonia (total)
# 1               Arsenic (and its compounds)
# 2                           Carbon monoxide
# 3              Chromium (and its compounds)
# 4                Cobalt (and its compounds)
# ..                                      ...
# 110                                     SO2
# 111  Polycyclic aromatic hydrocarbons (PAH)
# ...

# %%
# For CTrace and GHG datasets, put the substance_id as 'NA - GHG'
ctrace_gdf['substance_id'] = 'NA - GHG'
#ghg_gdf['substance_id'] = 'NA - GHG'

# %%
substance_id_ghg_map = {
    'CO2': '124-38-9',
    'CH4': '74-82-8',
    'N2O': '10024-97-2',
    'CO2eq': 'NA - GHG'
}
ghg_gdf['substance_id'] = ghg_gdf['substance'].map(substance_id_ghg_map)

# %%
ghg_gdf
# Out:
#                  row_id  year  ghg_id     facility_name_ghg   longitude  \
# 0      GHG-10010-2023-1  2023   10010  Rio Tinto Alcan Inc. -128.695310
# 1      GHG-10010-2023-2  2023   10010  Rio Tinto Alcan Inc. -128.695310
# 2      GHG-10010-2023-3  2023   10010  Rio Tinto Alcan Inc. -128.695310
# 3      GHG-10011-2023-1  2023   10011      Algoma Steel Inc  -84.363700
# 4      GHG-10011-2023-2  2023   10011      Algoma Steel Inc  -84.363700
# ...                 ...   ...     ...                   ...         ...
# 1459   GHG-12553-2023-9  2023   12553        Red Chris Mine -129.767640
# 1460   GHG-12555-2023-9  2023   12555       Moly-Cop Canada -120.096490
# 1461  GHG-12678-2023-13  2023   12678       Greenstone Mine  -86.928990
# 1462   GHG-12752-2023-5  2023   12752               Fayolle  -78.525139
# 1463  GHG-12841-2023-13  2023   12841        Goose Property -106.433340
#
#        latitude              city          province  \
# ...

# %%
substance_id_ghg_map = {
    'CO2': '124-38-9',
    'CH4': '74-82-8',
    'N2O': '10024-97-2'
}

substance_id_ghg_df = pd.DataFrame(
    [
        {
            "substance_id": v,
            "substance_type": "Substance",
            "substance_name": k
        }
        for k, v in substance_id_ghg_map.items()
    ]
)

# %%
# Put the two dataframes together
substance_table = pd.concat([substance_table, substance_id_ghg_df], ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
substance_table.to_csv(r'database/CSV/substances_table.csv', index=False)

# %%
substance_table
# Out:
#          substance_id       substance_type                substance_name
# 0             NA - 16  Group of substances               Ammonia (total)
# 1             NA - 02  Group of substances   Arsenic (and its compounds)
# 2            630-08-0            Substance               Carbon monoxide
# 3             NA - 04  Group of substances  Chromium (and its compounds)
# 4             NA - 05  Group of substances    Cobalt (and its compounds)
# ..                ...                  ...                           ...
# 111        10024-97-2            Substance                           N2O
# 112         NA - PFCs  Group of substances                          PFCs
# 113  NA - Particulate  Group of substances                   Particulate
# 114          124-38-9            Substance                           CO2
# 115           74-82-8            Substance                           CH4
#
# [116 rows x 3 columns]

# %% [markdown]
# ## Compartment table

# %% [markdown]
# ### Assign compartment_id to the relevant datasets

# %%
# For CTrace and GHG datasets, we assign the compartment_id corresponding to 'Air' and 'Unspecified' pathway
# For land occupation datasets, we will assign the compartment_id corresponding to 'Land' and 'Unspecified' pathway
ctrace_gdf['compartment_name'] = 'Air' #comp3c458811
ghg_gdf['compartment_name'] = 'Air'
li_canada_gdf['compartment_name']= 'Land'
tang_canada_gdf['compartment_name'] = 'Land'

# %% [markdown]
# # Matching

# %% [markdown]
# ## Point to point matching

# %%
from matching_functions import match_facilities, one_to_many_relationships

# %% [markdown]
# ### MinCan

# %%
# Let's keep only Active mines
min_can_gdf = min_can_gdf[min_can_gdf['mine_status'] == 'Active'].copy()

# %% [markdown]
# Some mines in MinCan dataset have very slightly different name (e.g. LaRonde - Zone 5 and LaRonde), the same name but one without town (e.g. Detour Lake) or several companies for the same mines.

# %%
# min_can_id = ON-MINCAN-6316d452 = Detour Lake = 2013 - open
# min_can_id = ON-MINCAN-7b832414 = Detour Lake = 1983 - open
# min_can_id = QC-MINCAN-775312a1 = LaRonde - Zone 5 = 2018 - open
# min_can_id = QC-MINCAN-8321e85e = LaRonde = 1988 - open

# %%
# We delete the duplicates, aligned with information from MDO for Detour Lake and LaRonde
min_can_gdf = min_can_gdf[~min_can_gdf['mincan_id'].isin(['ON-MINCAN-6316d452', 'QC-MINCAN-775312a1'])].copy()

# %%
min_can_gdf
# Out:
#               mincan_id               namemine                       town  \
# 7    ON-MINCAN-ccf2bf99                  Haley                     Haley
# 13   NB-MINCAN-63ccd128    Stratmat (Halfmile)                       None
# 18   ON-MINCAN-9abb16ea       Calcite Division                      Perth
# 23   QC-MINCAN-06b1f129    Parent Mica Deposit                      Suzor
# 24   QC-MINCAN-227d3d18             Charlevoix  Charlevoix (Saint-Urbain)
# ..                  ...                    ...                        ...
# 923  BC-MINCAN-d8cf3b3a                   None               Fort Langley
# 924  AB-MINCAN-bab4efd2                   None                     Exshaw
# 927  SK-MINCAN-2aefa179                   None                Hudson Bay
# 935  NT-MINCAN-ea720725  Panda (Ekati Project)                Lac de Gras
# 936  QC-MINCAN-8f0f7e05               Ardorbec                  Danville
#
#                   province   latitude   longitude  \
# ...

# %%
lt_main_mincan = match_facilities(main_gdf, min_can_gdf,
                     id_col1='main_id', id_col2='mincan_id',
                     name_col1='facility_name', name_col2='namemine'
                     )

# %%
lt_main_mincan.to_csv(r'data/Mappings/LT/lt_main_mincan.csv', index=False)

# %%
# matches_main_mincan = one_to_many_relationships(
#     lt_main_mincan,
#     id_main_col='main_id',
#     id_sat_col='mincan_id',
#     distance_threshold_m=2000,
#     similarity_threshold=80,
#     similarity_metric="token_set"
# )
matches_main_mincan = pd.read_excel(r'data/Mappings/mapping_mincan.xlsx', sheet_name='mapping')

# %%
min_can_gdf = min_can_gdf.merge(
    matches_main_mincan,
    on="mincan_id", 
    how="left"
)

# %%
# For SQL
min_can_gdf = min_can_gdf[min_can_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["mincan_id", "main_id", "mine_status", "operation_periods"]
min_can_gdf = min_can_gdf[col_to_keep]
min_can_gdf
# Out:
#               mincan_id           main_id mine_status  \
# 11   QC-MINCAN-494c7715  QC-MAIN-9de9bb0d      Active
# 21   BC-MINCAN-8cc41b53  BC-MAIN-6b4800fe      Active
# 28   QC-MINCAN-8321e85e  QC-MAIN-e51eda66      Active
# 29   ON-MINCAN-97f916de  ON-MAIN-c5fefb01      Active
# 31   ON-MINCAN-49811fe2  ON-MAIN-687b8c8d      Active
# 34   QC-MINCAN-44904232  QC-MAIN-c0660aec      Active
# 38   ON-MINCAN-019a0826  ON-MAIN-4e0734b5      Active
# 39   NU-MINCAN-1d9e43a7  NU-MAIN-730aefe3      Active
# 41   ON-MINCAN-643672f4  ON-MAIN-f3e6ff08      Active
# 42   SK-MINCAN-5ac4b2dd  SK-MAIN-22ce14be      Active
# 44   BC-MINCAN-72fabc94  BC-MAIN-aa76f6f2      Active
# 47   MB-MINCAN-15965632  MB-MAIN-be5b3dc8      Active
# 48   ON-MINCAN-07ece30d  ON-MAIN-28f3f0fc      Active
# 50   QC-MINCAN-efafa693  QC-MAIN-02884fb5      Active
# 51   BC-MINCAN-4eaf1f96  BC-MAIN-ed23117f      Active
# 53   QC-MINCAN-1c16c912  QC-MAIN-6dc537e6      Active
# ...

# %% [markdown]
# ### CTrace

# %%
lt_main_ctrace = match_facilities(main_gdf, ctrace_gdf,
                     id_col1='main_id', id_col2='ctrace_id',
                     name_col1='facility_name', name_col2='source_name'
                     )

# %%
lt_main_ctrace.to_csv(r'data/Mappings/LT/lt_main_ctrace.csv', index=False)

# %%
# matches_main_ctrace = one_to_many_relationships(
#     lt_main_ctrace,
#     id_main_col='main_id',
#     id_sat_col='ctrace_id',
#     distance_threshold_m=2000,
#     similarity_threshold=80,
#     similarity_metric="token_set"
# )
matches_main_ctrace = pd.read_excel(r'data/Mappings/mapping_ctrace.xlsx', sheet_name='mapping')

# %%
matches_main_ctrace
# Out:
#     ctrace_id           main_id
# 0     1754055  ON-MAIN-6e9b2449
# 1     1754056  ON-MAIN-f080c409
# 2     1754057  BC-MAIN-599152a0
# 3     1754058  ON-MAIN-52224e1e
# 4     1754060  ON-MAIN-48fe2205
# 5     1754061  BC-MAIN-6b4800fe
# 6     1754066  BC-MAIN-bf503b6b
# 7     1754067  QC-MAIN-30c1828c
# 8     1754071  BC-MAIN-e34feb4d
# 9     1754075  MB-MAIN-be5b3dc8
# 10    1754077  QC-MAIN-e51eda66
# 11    1754081  ON-MAIN-7001a391
# 12    1754082  NL-MAIN-c139de6d
# 13    1754083  YT-MAIN-752fbcae
# 14    1754084  BC-MAIN-ed23117f
# 15    1754085  BC-MAIN-3f490561
# 16    1754086  BC-MAIN-23155c25
# 17    1754087  BC-MAIN-aa76f6f2
# 18    1754096  QC-MAIN-a97821c0
# 19    1754097  BC-MAIN-8eb8be0d
# 20    1754102  ON-MAIN-40ce0593
# 21    1754103  MB-MAIN-e0a6250e
# 22    1754104  ON-MAIN-28f3f0fc
# 23    1754105  QC-MAIN-b2148882
# 24    1754106  NL-MAIN-2d8801d6
# 25   25486533  ON-MAIN-f8313ebd
# 26   25486534  ON-MAIN-a3c56a83
# 27   36395102  NL-MAIN-b64bae7a

# %%
ctrace_gdf = ctrace_gdf.merge(
    matches_main_ctrace,
    on="ctrace_id", 
    how="left"
)

# %%
# For SQL
ctrace_gdf = ctrace_gdf[ctrace_gdf["main_id"].notna()].copy()

# %%
col_to_keep = [
'ctrace_id', 
'year',
'emissions_quantity', 
'gas',
'activity', 'activity_units', 
'capacity', 'capacity_units', 
'source_id',  'substance_id', 'compartment_name',
'main_id'           
]
ctrace_gdf = ctrace_gdf[col_to_keep]
ctrace_gdf
# Out:
#     ctrace_id  year  emissions_quantity         gas      activity  \
# 6     1754055  2023        5.610000e+03  co2e_100yr  8.630000e+05
# 7     1754056  2023        6.403000e+03  co2e_100yr  9.850000e+05
# 8     1754057  2023        2.299160e+05  co2e_100yr  1.457500e+07
# 9     1754058  2023        2.639000e+03  co2e_100yr  4.060000e+05
# 11    1754060  2023        4.225000e+03  co2e_100yr  6.500000e+05
# 12    1754061  2023        1.316380e+05  co2e_100yr  8.810000e+07
# 16    1754066  2023        2.412130e+06  co2e_100yr  7.288600e+07
# 17    1754067  2023        0.000000e+00  co2e_100yr  0.000000e+00
# 21    1754071  2023        0.000000e+00  co2e_100yr  0.000000e+00
# 23    1754075  2023        2.408400e+04  co2e_100yr  1.526729e+06
# 25    1754077  2023        6.711600e+04  co2e_100yr  1.501481e+06
# 29    1754081  2023        7.782000e+03  co2e_100yr  5.279710e+05
# 30    1754082  2023        0.000000e+00  co2e_100yr  0.000000e+00
# ...

# %%
# We separate emissions and production data
ctrace_ghg_gdf = ctrace_gdf.drop(columns=['activity', 'activity_units', 'capacity', 'capacity_units'])
ctrace_prod_gdf = ctrace_gdf.drop(columns=['emissions_quantity', 'gas'])

# %% [markdown]
# ### Conflict

# %%
lt_main_conflict = match_facilities(main_gdf, conflict_gdf,
                     id_col1='main_id', id_col2='ej_atlas_id',
                     name_col1='facility_name', name_col2='facility_name_ejatlas'
                     )

# %%
matches_main_conflict = one_to_many_relationships(
    lt_main_conflict,
    id_main_col='main_id',
    id_sat_col='ej_atlas_id',
    distance_threshold_m=20000,
    similarity_threshold=80,
    similarity_metric="token_set"  # "partial" or "token_set"
)

# %%
conflict_gdf = conflict_gdf.merge(
    matches_main_conflict,
    on="ej_atlas_id",  
    how="left"
)

# %%
# For SQL
conflict_gdf = conflict_gdf[conflict_gdf["main_id"].notna()].copy()

# %%
col_to_keep = ["ej_atlas_id",
  "main_id",
  "case_name",
  "start_date",
  "end_date",
  "conflict_description",
  "conflict_details",
  "population_affected",
  "conflict_intensity",
  "project_status",
  "source_id"             
               ]
conflict_gdf = conflict_gdf[col_to_keep]
conflict_gdf
# Out:
#     ej_atlas_id           main_id  \
# 9          4135  NL-MAIN-2d8801d6
# 10         4145  ON-MAIN-2e13aaa0
# 15         5599  QC-MAIN-d6748d40
#
#                                             case_name  start_date end_date  \
# 9       Vale Mining in Voisey's Bay, Labrador, Canada     11/1994     None
# 10  Port Colborne Class Action Lawsuit Against Val...     06/2000  04/2012
# 15  Nouveau Mondeâ€™s Matawinie graphite mine in Q...  01/01/2017     None
#
#                                  conflict_description  \
# 9   <p>Voiseyâ€™s Bay nickel mine in Labrador was ...
# 10  <p>In Pearson (later Smith) v. Inco, the large...
# 15  <p>Five kilometers southwest of the municipali...
#
#                                      conflict_details population_affected  \
# 9   Voiseyâ€™s Bay is a â€œ6,000 tonnes-per-day fa...               Rural
# 10  Raw materials from Valeâ€™s Sudbury mining ope...               Urban
# 15  The project includes 319 mining concessions (c...               Rural
#
# ...

# %% [markdown]
# ### Tailings

# %%
lt_main_tailings = match_facilities(main_gdf, tailings_gdf,
                     id_col1='main_id', id_col2='tailing_id',
                     name_col1='facility_name', name_col2='related_mine'
                     )

# %%
lt_main_tailings.to_csv(r'data/Mappings/LT/lt_main_tailings.csv', index=False)

# %%
# matches_main_tailings = one_to_many_relationships(
#     lt_main_tailings,
#     id_main_col='main_id',
#     id_sat_col='tailing_id',
#     distance_threshold_m=20000,
#     similarity_threshold=80,
#     similarity_metric="token_set"  # "partial" or "token_set"
# )
matches_main_tailings = pd.read_excel(r'data/Mappings/mapping_tailing.xlsx', sheet_name='mapping')

# %%
tailings_gdf = tailings_gdf.merge(
    matches_main_tailings,
    on="tailing_id",  
    how="left"
)

# %%
# For SQL
tailings_gdf = tailings_gdf[tailings_gdf["main_id"].notna()].copy()

# %%
col_to_keep = [
  "row_id",
  "main_id",
  "year",
  "tailing_id",
  "tsf_name",
  "status",
  "construction_year",
  "raise_type",
  "current_maximum_height",
  "current_tailings_storage",
  "planned_storage_5_years",
  "hazard_categorization",
  "classification_system",
  "geometry", 
  "source_id"             
               ]
tailings_gdf = tailings_gdf[col_to_keep]
tailings_gdf
# Out:
#                  row_id           main_id  year  tailing_id  \
# 0      TAIL-12.0-2019-1  NU-MAIN-730aefe3  2019        12.0
# 1      TAIL-13.0-2019-1  NU-MAIN-730aefe3  2019        13.0
# 2      TAIL-14.0-2019-1  NU-MAIN-730aefe3  2019        14.0
# 3      TAIL-15.0-2019-1  NU-MAIN-8b0264c9  2019        15.0
# 4      TAIL-16.0-2019-1  QC-MAIN-c0660aec  2019        16.0
# ..                  ...               ...   ...         ...
# 215  TAIL-1126.0-2019-1  ON-MAIN-f080c409  2019      1126.0
# 216  TAIL-1127.0-2019-1  ON-MAIN-f080c409  2019      1127.0
# 217  TAIL-1128.0-2019-1  ON-MAIN-f080c409  2019      1128.0
# 218  TAIL-1129.0-2019-1  ON-MAIN-f080c409  2019      1129.0
# 226  TAIL-1243.0-2019-1  QC-MAIN-e7e6a960  2019      1243.0
#
#                   tsf_name  status  construction_year              raise_type  \
# 0               North Cell  Active             2009.0    Downstream, Upstream
# 1               South Cell  Active             2012.0              Downstream
# ...

# %% [markdown]
# ### GHG

# %%
lt_main_ghg = match_facilities(main_gdf, ghg_gdf,
                     id_col1='main_id', id_col2='ghg_id',
                     name_col1='facility_name', name_col2='facility_name_ghg'
                     )

# %%
lt_main_ghg.to_csv(r'data/Mappings/LT/lt_main_ghg.csv', index=False)

# %%
# matches_main_ghg = one_to_many_relationships(
#     lt_main_ghg,
#     id_main_col='main_id',
#     id_sat_col='ghg_id',
#     distance_threshold_m=10000,
#     similarity_threshold=80,
#     similarity_metric="token_set"  # "partial" or "token_set"
# )
matches_main_ghg = pd.read_excel(r'data/Mappings/mapping_ghg.xlsx', sheet_name='mapping')

# %%
ghg_gdf = ghg_gdf.merge(
    matches_main_ghg,
    on="ghg_id",  
    how="left"
)

# %%
# For SQL
ghg_gdf = ghg_gdf[ghg_gdf["main_id"].notna()].copy()

# %%
ghg_gdf
# Out:
#                  row_id  year  ghg_id  \
# 3      GHG-10011-2023-1  2023   10011
# 4      GHG-10011-2023-2  2023   10011
# 5      GHG-10011-2023-3  2023   10011
# 6      GHG-10011-2023-4  2023   10011
# 7      GHG-10012-2023-1  2023   10012
# ...                 ...   ...     ...
# 1517  GHG-11989-2023-13  2023   11989
# 1523  GHG-12298-2023-13  2023   12298
# 1524  GHG-12304-2023-13  2023   12304
# 1526   GHG-12459-2023-9  2023   12459
# 1528   GHG-12553-2023-9  2023   12553
#
#                                       facility_name_ghg  longitude  latitude  \
# 3                                      Algoma Steel Inc  -84.36370  46.52170
# 4                                      Algoma Steel Inc  -84.36370  46.52170
# 5                                      Algoma Steel Inc  -84.36370  46.52170
# 6                                      Algoma Steel Inc  -84.36370  46.52170
# 7                              Aluminerie Alouette inc.  -66.44160  50.15830
# ...

# %%
col_to_keep = [
  "row_id",
  "main_id",
  "year",
  "emission_source",
  "value",
  "unit",
  "compartment_name",
  "substance_id",
  "source_id"             
               ]
ghg_gdf = ghg_gdf[col_to_keep]
ghg_gdf
# Out:
#                  row_id           main_id  year             emission_source  \
# 3      GHG-10011-2023-1  ON-MAIN-eab8c362  2023          Flaring / Torchage
# 4      GHG-10011-2023-2  ON-MAIN-eab8c362  2023  Stationary Fuel Combustion
# 5      GHG-10011-2023-3  ON-MAIN-eab8c362  2023        Industrial Processes
# 6      GHG-10011-2023-4  ON-MAIN-eab8c362  2023      On-site Transportation
# 7      GHG-10012-2023-1  QC-MAIN-8d6616b4  2023  Stationary Fuel Combustion
# ...                 ...               ...   ...                         ...
# 1517  GHG-11989-2023-13  QC-MAIN-1eee4ace  2023                       Total
# 1523  GHG-12298-2023-13  ON-MAIN-63b394c3  2023                       Total
# 1524  GHG-12304-2023-13  ON-MAIN-cb85213a  2023                       Total
# 1526   GHG-12459-2023-9  YT-MAIN-e05ed9fe  2023                       Total
# 1528   GHG-12553-2023-9  BC-MAIN-8eb8be0d  2023                       Total
#
#              value unit compartment_name substance_id  \
# ...

# %% [markdown]
# ### NPRI - pollutants

# %%
lt_main_pollution = match_facilities(main_gdf, pollutant_npri_gdf,
                     id_col1='main_id', id_col2='npri_id',
                     name_col1='facility_name', name_col2='facility_name_npri'
                     )

# %%
lt_main_pollution.to_csv(r'data/Mappings/LT/lt_main_pollution.csv', index=False)

# %%
# matches_main_pollution = one_to_many_relationships(
#     lt_main_pollution,
#     id_main_col='main_id',
#     id_sat_col='npri_id',
#     distance_threshold_m=10000,
#     similarity_threshold=80,
#     similarity_metric="token_set"  # "partial" or "token_set"
# )
matches_main_pollution = pd.read_excel(r'data/Mappings/mapping_npri.xlsx', sheet_name='mapping')

# %%
pollutant_npri_gdf = pollutant_npri_gdf.merge(
    matches_main_pollution,
    on="npri_id",  
    how="left"
)

# %%
pollutant_npri_gdf
# Out:
#                   row_id  year  npri_id  \
# 0       npri-1568-2023-1  2023     1568
# 1       npri-1568-2023-2  2023     1568
# 2       npri-1568-2023-3  2023     1568
# 3       npri-1568-2023-4  2023     1568
# 4       npri-1568-2023-5  2023     1568
# ...                  ...   ...      ...
# 6572  npri-2740-2023-108  2023     2740
# 6573  npri-2740-2023-109  2023     2740
# 6574  npri-2740-2023-110  2023     2740
# 6575  npri-2740-2023-111  2023     2740
# 6576  npri-2740-2023-112  2023     2740
#
#                            facility_name_npri   company_name_npri  \
# 0                                Macassa Mine  Agnico Eagle Mines
# 1                                Macassa Mine  Agnico Eagle Mines
# 2                                Macassa Mine  Agnico Eagle Mines
# 3                                Macassa Mine  Agnico Eagle Mines
# 4                                Macassa Mine  Agnico Eagle Mines
# ...                                       ...                 ...
# ...

# %%
pollutant_npri_gdf.rename(columns={'cas_number': 'substance_id'}, inplace=True)

# %%
# For SQL
pollutant_npri_gdf = pollutant_npri_gdf[pollutant_npri_gdf["main_id"].notna()].copy()

# %%
pollutant_npri_gdf
# Out:
#                   row_id  year  npri_id  \
# 0       npri-1568-2023-1  2023     1568
# 1       npri-1568-2023-2  2023     1568
# 2       npri-1568-2023-3  2023     1568
# 3       npri-1568-2023-4  2023     1568
# 4       npri-1568-2023-5  2023     1568
# ...                  ...   ...      ...
# 6572  npri-2740-2023-108  2023     2740
# 6573  npri-2740-2023-109  2023     2740
# 6574  npri-2740-2023-110  2023     2740
# 6575  npri-2740-2023-111  2023     2740
# 6576  npri-2740-2023-112  2023     2740
#
#                            facility_name_npri   company_name_npri  \
# 0                                Macassa Mine  Agnico Eagle Mines
# 1                                Macassa Mine  Agnico Eagle Mines
# 2                                Macassa Mine  Agnico Eagle Mines
# 3                                Macassa Mine  Agnico Eagle Mines
# 4                                Macassa Mine  Agnico Eagle Mines
# ...                                       ...                 ...
# ...

# %%
col_to_keep = [
  "row_id",
  #"npri_id",
  "main_id",
  "year",
  "value",
  "substance_unit",
  "compartment_name",
  "substance_id",
  "release_pathway",  
  "source_id"
 ]
pollutant_npri_gdf = pollutant_npri_gdf[col_to_keep]
pollutant_npri_gdf.rename(columns={'substance_unit': 'unit'}, inplace=True)
pollutant_npri_gdf
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_14524\2324261120.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pollutant_npri_gdf.rename(columns={'substance_unit': 'unit'}, inplace=True)
#                   row_id           main_id  year    value    unit  \
# 0       npri-1568-2023-1  ON-MAIN-1f126a43  2023    0.636  tonnes
# 1       npri-1568-2023-2  ON-MAIN-1f126a43  2023    0.116      kg
# 2       npri-1568-2023-3  ON-MAIN-1f126a43  2023   76.208  tonnes
# 3       npri-1568-2023-4  ON-MAIN-1f126a43  2023  0.00105  tonnes
# 4       npri-1568-2023-5  ON-MAIN-1f126a43  2023     0.18      kg
# ...                  ...               ...   ...      ...     ...
# 6572  npri-2740-2023-108  SK-MAIN-26b9aaf3  2023     0.01      kg
# 6573  npri-2740-2023-109  SK-MAIN-26b9aaf3  2023   0.1503      kg
# ...

# %% [markdown]
# ### NPRI - waste

# %%
matches_main_waste = pd.read_excel(r'data/Mappings/mapping_npri.xlsx', sheet_name='mapping')

# %%
waste_npri_gdf = waste_npri_gdf.merge(
    matches_main_waste,
    on="npri_id",
    how="left"
)

# %%
waste_npri_gdf
# Out:
#                   row_id  year  npri_id  \
# 0     npri-2000-2023-156  2023     2000
# 1     npri-5448-2023-181  2023     5448
# 2     npri-34791-2023-58  2023    34791
# 3     npri-34791-2023-59  2023    34791
# 4     npri-1568-2023-171  2023     1568
# ...                  ...   ...      ...
# 1945  npri-3824-2023-206  2023     3824
# 1946  npri-3824-2023-207  2023     3824
# 1947  npri-3824-2023-208  2023     3824
# 1948   npri-3812-2023-34  2023     3812
# 1949   npri-2256-2023-54  2023     2256
#
#                               facility_name_npri  \
# 0             Usine de Bouletage de Port-Cartier
# 1                                    Mine Raglan
# 2                                  Sullivan Mine
# 3                                  Sullivan Mine
# 4                                   Macassa Mine
# ...                                          ...
# 1945  Gerdau Ameristeel Corporation, Whitby Mill
# 1946  Gerdau Ameristeel Corporation, Whitby Mill
# ...

# %%
waste_npri_gdf.rename(columns={'cas_number': 'substance_id'}, inplace=True)

# %%
# For SQL
waste_npri_gdf = waste_npri_gdf[waste_npri_gdf["main_id"].notna()].copy()

# %%
waste_npri_gdf
# Out:
#                   row_id  year  npri_id  \
# 0     npri-2000-2023-156  2023     2000
# 1     npri-5448-2023-181  2023     5448
# 4     npri-1568-2023-171  2023     1568
# 5     npri-1568-2023-172  2023     1568
# 6     npri-1568-2023-173  2023     1568
# ...                  ...   ...      ...
# 1943  npri-3824-2023-204  2023     3824
# 1944  npri-3824-2023-205  2023     3824
# 1945  npri-3824-2023-206  2023     3824
# 1946  npri-3824-2023-207  2023     3824
# 1947  npri-3824-2023-208  2023     3824
#
#                               facility_name_npri  \
# 0             Usine de Bouletage de Port-Cartier
# 1                                    Mine Raglan
# 4                                   Macassa Mine
# 5                                   Macassa Mine
# 6                                   Macassa Mine
# ...                                          ...
# 1943  Gerdau Ameristeel Corporation, Whitby Mill
# 1944  Gerdau Ameristeel Corporation, Whitby Mill
# ...

# %%
col_to_keep = [
  "row_id",
  #"npri_id",
  "main_id",
  "year",
  "value",
  "substance_unit",
  #"compartment_id",
  "substance_id",
  "flow_direction",
  "release_pathway",
  "source_id"
 ]
waste_npri_gdf = waste_npri_gdf[col_to_keep]
waste_npri_gdf.rename(columns={'substance_unit': 'unit'}, inplace=True)
waste_npri_gdf
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_14524\3382832434.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waste_npri_gdf.rename(columns={'substance_unit': 'unit'}, inplace=True)
#                   row_id           main_id  year    value    unit  \
# 0     npri-2000-2023-156  QC-MAIN-e25eed27  2023   21.075  tonnes
# 1     npri-5448-2023-181  QC-MAIN-a97821c0  2023   27.466  tonnes
# 4     npri-1568-2023-171  ON-MAIN-1f126a43  2023   13.733  tonnes
# 5     npri-1568-2023-172  ON-MAIN-1f126a43  2023   3166.0      kg
# 6     npri-1568-2023-173  ON-MAIN-1f126a43  2023     34.0      kg
# ...                  ...               ...   ...      ...     ...
# 1943  npri-3824-2023-204  ON-MAIN-21b6ab35  2023  60.3109  tonnes
# 1944  npri-3824-2023-205  ON-MAIN-21b6ab35  2023   0.0885      kg
# ...

# %% [markdown]
# ### Li et al land occupation

# %%
# li_canada_gdf_copy = li_canada_gdf.copy()
# li_canada_gdf_copy.rename(columns={'geometry': 'geometry_polygon'}, inplace=True)
# li_canada_gdf_copy["geometry"] = gpd.points_from_xy(li_canada_gdf_copy["Longitude"], li_canada_gdf_copy["Latitude"])
# li_canada_gdf_copy = li_canada_gdf_copy.set_geometry("geometry", crs="EPSG:4326")

# %%
# lt_main_li = match_facilities(main_gdf, li_canada_gdf_copy,
#                      id_col1='main_id', id_col2='li_id',
#                      name_col1='facility_name', name_col2='Name'
#                      )
# lt_main_li.to_excel(r'data/Sources/lt_main_li.xlsx', index=False)

# %%
matches_main_li = pd.read_excel(r'data/Sources/lt_main_li.xlsx', sheet_name='for_pandas')

# %%
li_canada_gdf = li_canada_gdf.merge(
    matches_main_li,
    on="li_id",  
    how="left"
)

# %%
li_canada_gdf
# Out:
#               li_id            Name   Latitude   Longitude     P_C  \
# 0    QC-LI-91179bef           Ansil  48.366670  -79.116670  Copper
# 1    ON-LI-b4159d5a    Winston Lake  48.977500  -87.383610    Zinc
# 2    QC-LI-71058cde  Abcourt-Barvue  48.521540  -77.679010    Zinc
# 3    NS-LI-0ef10de8        Sterling  45.729170  -60.436940    Zinc
# 4    QC-LI-daf5c7b6         LaRonde  48.250560  -78.441670    Gold
# ..              ...             ...        ...         ...     ...
# 183  SK-LI-61977a89     Hanson Lake  54.673220 -102.861800  Copper
# 184  BC-LI-f95462e5           Texas  49.408240 -119.111560    Gold
# 185  ON-LI-8e5e6d12           Gowan  48.681165  -81.109475  Copper
# 186  ON-LI-ab2f9062           Genex  48.474010  -81.571480    Gold
# 187  QC-LI-81f5c1bf          Ledden  49.913630  -74.369950  Copper
#
#                           List_of_C       A_S Country        State_Prov  \
# 0           Copper,Gold,Silver,Zinc  Inactive  Canada            Quebec
# ...

# %%
# For SQL
li_canada_gdf = li_canada_gdf[li_canada_gdf["main_id"].notna()].copy()

# %%
li_canada_gdf
# Out:
#               li_id                Name  Latitude  Longitude        P_C  \
# 1    ON-LI-b4159d5a        Winston Lake  48.97750  -87.38361       Zinc
# 2    QC-LI-71058cde      Abcourt-Barvue  48.52154  -77.67901       Zinc
# 4    QC-LI-daf5c7b6             LaRonde  48.25056  -78.44167       Gold
# 7    BC-LI-356e0fe7          Myra Falls  49.57394 -125.58518       Zinc
# 9    NB-LI-4677c505        Murray Brook  47.52528  -66.43167       Zinc
# 10   QC-LI-81c20425      Sleeping Giant  49.13115  -77.97601       Gold
# 12   ON-LI-28377156        Lac des Iles  49.15774  -89.61886  Palladium
# 13   QC-LI-22e70cb6              Goldex  48.09250  -77.87250       Gold
# 14   QC-LI-07027dd8            Westwood  48.25519  -78.50213       Gold
# 18   ON-LI-0825b8aa            Red Lake  51.06098  -93.73213       Gold
# 21   BC-LI-53364ff0     Copper Mountain  49.33884 -120.53599     Copper
# 27   QC-LI-a160f62a      LaRonde Zone 5  48.25246  -78.47266       Gold
# ...

# %% [markdown]
# ## Point to polygon matching

# %% [markdown]
# ### Protected lands datasets

# %%
from matching_functions import associate_facilities_near_polygons

# %%
wpda_gdf_polygons
# Out:
#         WDPA_PID                                               NAME  \
# 0          611_A               Wood Buffalo National Park Of Canada
# 1          611_B               Wood Buffalo National Park Of Canada
# 2            612             Kluane National Park Reserve Of Canada
# 3          613_B                  Auyuittuq National Park Of Canada
# 4          613_A                  Auyuittuq National Park Of Canada
# ...          ...                                                ...
# 13463  555785733  Grosse Île and the Irish Memorial National His...
# 13464  555785734                 Navy Island National Historic Site
# 13465  555785735  Fort George National Historic Site (Paradise G...
# 13466  555785736                Rideau Canal National Historic Site
# 13467  555785737                            Capital Recreation Area
#
#                           DESIG OWN_TYPE                          MANG_AUTH  \
# ...

# %%
lt_wpda = associate_facilities_near_polygons(
    main_gdf,
    wpda_gdf_polygons,
    facility_id_col="main_id",
    polygon_id_col="WDPA_PID",
    buffer_km=50,
    crs="EPSG:3978"
)

# %%
wpda_gdf_polygons = wpda_gdf_polygons.merge(lt_wpda, on="WDPA_PID", how="left")

# %%
# For SQL
wpda_gdf_polygons = wpda_gdf_polygons[wpda_gdf_polygons["main_id"].notna()].copy()

# %%
lt_indigenous = associate_facilities_near_polygons(
    main_gdf,
    indigenous_can_gdf,
    facility_id_col="main_id",
    polygon_id_col="indigenous_land_id",
    buffer_km=50,
    crs="EPSG:3978"
)

# %%
indigenous_can_gdf = indigenous_can_gdf.merge(lt_indigenous, on="indigenous_land_id", how="left")

# %%
# For SQL
indigenous_can_gdf = indigenous_can_gdf[indigenous_can_gdf["main_id"].notna()].copy()

# %% [markdown]
# ### Land occupation footprint datasets

# %%
from matching_functions import assign_polygons_to_points

# %%
main_gdf
# Out:
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# 2    QC-MAIN-f1ff4920       Akasaba West                None
# 3    NU-MAIN-4ea8ac9d             Amaruq  Meadowbank complex
# 4    QC-MAIN-e7e6a960  Canadian Malartic                None
# ..                ...                ...                 ...
# 265  ON-MAIN-c5fefb01              Mishi                None
# 266  BC-MAIN-feb13c30       Record Ridge                None
# 267  YT-MAIN-5e0d8b48             Casino                None
# 268  ON-MAIN-12c68d49       Eagle's Nest                None
# 269  BC-MAIN-891d3cb5               Akie                None
#
#     facility_group_id                     reported_company  \
# 0                None                   Abcourt Mines Inc.
# 1                None                   Abcourt Mines Inc.
# ...

# %%
assigned_df = assign_polygons_to_points(
    main_gdf,
    tailings_gdf,
    tang_canada_gdf,
    max_dist_km=10
)

# %%
assigned_df
# Out:
#               main_id  tailing_id  tang_id  distance_km relation_type
# 0    NS-MAIN-c9c77a59         NaN    45954     0.000000   one-to-many
# 1    NS-MAIN-c9c77a59         NaN    45955     1.186584   one-to-many
# 2    NL-MAIN-d9036091         NaN     7631     0.811781   one-to-many
# 3    NL-MAIN-d9036091         NaN     7641     4.647047   one-to-many
# 4    NL-MAIN-d9036091         NaN     7633     0.000000   many-to-one
# ..                ...         ...      ...          ...           ...
# 789  NT-MAIN-6c1d6ee6         NaN    26078     2.857250   one-to-many
# 790  NT-MAIN-6c1d6ee6         NaN    43740     0.833606   one-to-many
# 791  NT-MAIN-6c1d6ee6         NaN     3479     0.000000   one-to-many
# 792  NT-MAIN-6c1d6ee6         NaN    50385     2.150861   one-to-many
# 793  NT-MAIN-6c1d6ee6         NaN    26137     4.650487   one-to-many
#
# [794 rows x 5 columns]

# %%
assigned_df['relation_type'].value_counts()
# Out:
# relation_type
# one-to-many    704
# many-to-one     56
# one-to-one      34
# Name: count, dtype: int64

# %%
polygon_gdf = tang_canada_gdf.merge(assigned_df, on="tang_id", how="left")

# %%
polygon_gdf
# Out:
#       tang_id                                           geometry  area_km2  \
# 0        6383  POLYGON Z ((1795479.979 -83564.531 0.000, 1795...  0.026130
# 1        6388  POLYGON Z ((1796123.448 -80625.526 0.000, 1796...  0.671399
# 2        6390  POLYGON Z ((1796791.634 -80270.697 0.000, 1796...  0.050909
# 3       45954  POLYGON Z ((2466485.124 185586.547 0.000, 2466...  2.622800
# 4       45955  POLYGON Z ((2465809.682 185862.507 0.000, 2465...  0.441869
# ...       ...                                                ...       ...
# 1915     3399  POLYGON Z ((-717210.659 1915423.857 0.000, -71...  0.541024
# 1916     3401  POLYGON Z ((-715648.337 1916385.463 0.000, -71...  1.053173
# 1917    26364  POLYGON Z ((-717332.782 1916999.286 0.000, -71...  0.079894
# 1918    43739  POLYGON Z ((-713032.430 1919630.086 0.000, -71...  1.519488
# 1919    44287  POLYGON Z ((-466746.640 2074582.808 0.000, -46...  0.121349
#
#                                        source_id compartment_name  \
# ...

# %%
from visualization_functions import plot_polygons_assginment

# %%
plot_polygons_assginment(
    main_gdf,
    tailings_gdf,
    polygon_gdf, 
    output_html="results/data_coverage/facilities_tailings_maps.html"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Map saved to results/data_coverage/facilities_tailings_maps.html

# %% [markdown]
# # Create final tables

# %% [markdown]
# ## Main table

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# ...

# %%
ownership_df = pd.read_excel(r'data/Tables/extracted_data.xlsx', sheet_name='Ownership')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Integrate ownership information into the main_gdf 
main_gdf = main_gdf.merge(
    ownership_df[['main_id', 'owner(s)', 'operator(s)', 'company_URL', 'company_facility_URL', 'MDO_URL']],
    on='main_id',
    how='left'
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# # Integrate the operation_periods from min_can_gdf into the main_gdf
main_gdf = main_gdf.merge(
     min_can_gdf[['main_id', 'operation_periods']],
     on='main_id',
     how='left'
 )
# 
# # Add the source_id for MinCan only where operation_periods are not null
main_gdf['source_id'] = main_gdf.apply(
     lambda row: row['source_id'] + ';' + 'https://doi.org/10.1038/s41597-024-03116-3' if pd.notna(row['operation_periods']) else row['source_id'],
     axis=1
 )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_name  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue                None
# 1    QC-MAIN-d29e0839     Sleeping Giant                None
# ...

# %%
main_gdf.rename(columns={
    'company_name_folder': 'company_name',
    'company_facility_URL': 'facility_URL'
}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
column_order = [
       'main_id', 'facility_name', 'facility_group_id', 'facility_group_name', 'company_id', 'company_name',
       'city', 'province', 'geometry',
       'status', 'activity_status', 'development_stage', 'facility_type', 'mining_processing_type',
       'commodity_group', 'commodities',
       'owner(s)', 'operator(s)', 'operation_periods', 
       'company_URL', 'facility_URL', 'MDO_URL', 
       'source_id'
]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Fix column orders
main_gdf = main_gdf[column_order].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
main_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name facility_group_id  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue              None
# 1    QC-MAIN-d29e0839     Sleeping Giant              None
# ...

# %% [markdown]
# ## Environment table

# %% [markdown]
# ### CTrace dataset

# %%
ctrace_ghg_gdf.rename(columns={
    'ctrace_id': 'env_id',
    'emissions_quantity': 'value',
    'gas': 'unit'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_ghg_gdf['unit'] = ctrace_ghg_gdf['unit'].replace({'co2e_100yr': 'tCO2eq'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_ghg_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       env_id  year         value    unit  \
# 6    1754055  2023  5.610000e+03  tCO2eq
# 7    1754056  2023  6.403000e+03  tCO2eq
# 8    1754057  2023  2.299160e+05  tCO2eq
# 9    1754058  2023  2.639000e+03  tCO2eq
# ...

# %%
ctrace_gdf['flow_direction'] = 'Emission'
ctrace_gdf['release_pathway'] = 'Unspecified'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### NPRI datasets

# %%
pollutant_npri_gdf.rename(columns={
    'row_id': 'env_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
pollutant_npri_gdf['flow_direction'] = 'Emission'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
waste_npri_gdf.rename(columns={
    'row_id': 'env_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
waste_npri_gdf['compartment_id'] = ''
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### GHG dataset

# %%
ghg_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  row_id           main_id  year             emission_source  \
# 3      GHG-10011-2023-1  ON-MAIN-eab8c362  2023          Flaring / Torchage
# ...

# %%
ghg_gdf.rename(columns={'row_id': 'env_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ghg_gdf.rename(columns={'emission_source': 'release_pathway'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ghg_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  env_id           main_id  year             release_pathway  \
# 3      GHG-10011-2023-1  ON-MAIN-eab8c362  2023          Flaring / Torchage
# ...

# %%
ghg_gdf['flow_direction'] = 'Emission'
#ghg_gdf['release_pathway'] = 'Unspecified'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Manually collected data

# %%
env_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    row_id  year reporting_level      reported_company_nrcan  \
# 0     ENV-857b7b89-2023-1  2023   Site-specific         Newmont Corporation
# ...

# %%
env_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    row_id  year reporting_level      reported_company_nrcan  \
# 0     ENV-857b7b89-2023-1  2023   Site-specific         Newmont Corporation
# ...

# %%
env_df.rename(columns={'row_id': 'env_id', 'cas_number': 'substance_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    env_id  year reporting_level      reported_company_nrcan  \
# 0     ENV-857b7b89-2023-1  2023   Site-specific         Newmont Corporation
# ...

# %%
env_df.drop(columns=['reporting_level', 'reported_company_nrcan', 'name', 'facility_type', 'mining_processing_type', 'commodity', 'substance_type', 'substance_name', 'subflow_type', 'source'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    env_id  year           main_id facility_group_id  \
# 0     ENV-857b7b89-2023-1  2023  BC-MAIN-857b7b89               NaN
# 1     ENV-857b7b89-2023-2  2023  BC-MAIN-857b7b89               NaN
# ...

# %% [markdown]
# ### Concatenate all environment data into a single table

# %%
env_table = pd.concat(
    [ctrace_ghg_gdf, pollutant_npri_gdf, ghg_gdf, env_df],
    ignore_index=True
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                     env_id  year          value    unit  \
# 0                  1754055  2023    5610.000024  tCO2eq
# 1                  1754056  2023    6403.000027  tCO2eq
# ...

# %%
env_table.columns
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Index(['env_id', 'year', 'value', 'unit', 'source_id', 'substance_id',
#        'compartment_name', 'main_id', 'release_pathway', 'flow_direction',
#        'facility_group_id', 'company_id', 'comment'],
#       dtype='object')

# %%
column_order = ['env_id', 'year', 'compartment_name', 'substance_id', 'flow_direction', 'release_pathway', 'unit', 'value', 'comment', 'main_id','facility_group_id', 'company_id', 'source_id']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table = env_table[column_order]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                     env_id  year compartment_name substance_id  \
# 0                  1754055  2023              Air     NA - GHG
# 1                  1754056  2023              Air     NA - GHG
# ...

# %% [markdown]
# ## Production table

# %% [markdown]
# ### Manually collected data

# %%
production_df.rename(columns={'row_id': 'prod_id'}, inplace=True)
production_df.drop(columns=['level', 'reported_company_nrcan', 'name', 
                            'facility_type', 'mining_processing_type', 'commodities_nrcan', 'source'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Put the unit in lower case for conversion
production_df['unit'] = production_df['unit'].str.lower()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from constants import unit_conversion
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Apply a function to convert the 'value' column to tonnes
# But we need to do that only for the 'Production' data_type and don't do it for any other data_type
production_df['value_tonnes'] = production_df.apply(
    lambda row: row['value'] * unit_conversion.get(row['unit'], 1) if row['data_type'] == 'Production' else np.nan, 
    axis=1
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### CTrace dataset

# %%
ctrace_prod_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ctrace_id  year      activity   activity_units      capacity  \
# 6     1754055  2023  8.630000e+05  t of copper ore  4.624000e+06
# 7     1754056  2023  9.850000e+05  t of copper ore  3.554700e+07
# ...

# %%
# Save units before melting
activity_units = ctrace_prod_gdf['activity_units']
capacity_units = ctrace_prod_gdf['capacity_units']

# Melt
ctrace_prod_gdf = pd.melt(
    ctrace_prod_gdf,
    id_vars=['ctrace_id', 'year', 'source_id', 'main_id'],
    value_vars=['activity', 'capacity'],
    var_name='data_type',
    value_name='value'
)

# Set data_type labels
ctrace_prod_gdf['data_type'] = ctrace_prod_gdf['data_type'].replace({
    'activity': 'Production',
    'capacity': 'Capacity'
})

# Concatenate units in correct order (activity first, then capacity)
ctrace_prod_gdf['unit'] = list(activity_units) + list(capacity_units)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_prod_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ctrace_id  year                                          source_id  \
# 0     1754055  2023  https://github.com/climatetracecoalition/metho...
# 1     1754056  2023  https://github.com/climatetracecoalition/metho...
# ...

# %%
# Rename ctrace_id to add either _prod or _cap based on the data_type column
ctrace_prod_gdf['ctrace_id'] = ctrace_prod_gdf.apply(
    lambda row: f"{row['ctrace_id']}_prod" if row['data_type'] == 'Production' else f"{row['ctrace_id']}_cap",
    axis=1
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_prod_gdf['ctrace_id'].value_counts()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ctrace_id
# 1754055_prod     1
# 1754056_prod     1
# 1754057_cap      1
# 1754058_cap      1
# 1754060_cap      1
# 1754061_cap      1
# 1754066_cap      1
# 1754067_cap      1
# 1754071_cap      1
# 1754075_cap      1
# ...

# %%
ctrace_prod_gdf['unit'].value_counts()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# unit
# tonnes             28
# t of copper ore    27
# t of iron ore       1
# Name: count, dtype: int64

# %%
ctrace_prod_gdf.rename(columns={'ctrace_id': 'prod_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# We add the missing columns
ctrace_prod_gdf['geography'] = 'Canada'
ctrace_prod_gdf['reference_point'] = 'Crude ore'
ctrace_prod_gdf['value_tonnes'] = ctrace_prod_gdf['value'] # they are always in tonnes
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Add a commodity column with would be = Copper if unit column = 't of copper ore' and = 'Iron' if unit column = 't of iron ore'
ctrace_prod_gdf['commodity'] = ctrace_prod_gdf['unit'].apply(
    lambda x: 'Copper' if 'copper' in x.lower() else ('Iron' if 'iron' in x.lower() else None)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ctrace_prod_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           prod_id  year                                          source_id  \
# 0    1754055_prod  2023  https://github.com/climatetracecoalition/metho...
# ...

# %% [markdown]
# ### Concatenate all production data into a single table

# %%
# Concatenate production and ctrace data 
production_table = pd.concat([production_df, ctrace_prod_gdf], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_table.columns
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Index(['prod_id', 'year', 'geography', 'main_id', 'facility_group_id',
#        'company_id', 'commodity', 'reference_point', 'material_type',
#        'data_type', 'method', 'unit', 'value', 'comment', 'source_id',
# ...

# %%
column_order = ['prod_id', 'year', 'geography', 
                'commodity', 'reference_point', 'material_type', 'data_type', 
                'unit', 'value', 'value_tonnes', 'comment', 
                'main_id', 'facility_group_id','company_id', 'source_id']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_table = production_table[column_order]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
production_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                   prod_id  year geography commodity  \
# 0    PROD-3aa117d8-2023-1  2023    Canada  Aluminum
# 1    PROD-3aa117d8-2023-2  2023    Canada  Aluminum
# 2    PROD-8d6616b4-2023-1  2023    Canada  Aluminum
# ...

# %% [markdown]
# ## Tech attributes table

# %%
tech_attributes_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  row_id  year          level geography  \
# 0    TA-089f3c60-2022-1  2022  Site-specific    Canada
# 1    TA-857b7b89-2023-1  2023  Site-specific    Canada
# ...

# %%
tech_attributes_df.rename(columns={'row_id': 'tech_attr_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tech_attributes_table = tech_attributes_df[['tech_attr_id', 'year', 'commodity', 'reference_point', 'material_type', 'method', 'unit', 'value', 'comment', 'main_id', 'facility_group_id', 'company_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Protected & Indigenous table

# %%
protected_mapping = {
    "WDPA_PID": "protected_area_id",
    "NAME": "land_name",
    "DESIG": "land_type",
    "STATUS_YR": "date"
}

indigenous_mapping = {
    "indigenous_land_id": "protected_area_id",
    "Name": "land_name",
    "Category": "land_type",
    "Data_Date": "date"
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
protected_clean = wpda_gdf_polygons.rename(columns=protected_mapping)[["protected_area_id", "land_name", "land_type", "distance_km", "geometry", "main_id", "source_id"]].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
indigenous_clean = indigenous_can_gdf.rename(columns=indigenous_mapping)[["protected_area_id", "land_name", "land_type", "distance_km", "geometry", "main_id", "source_id"]].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
target_crs = "EPSG:4326"
protected_clean = protected_clean.to_crs(target_crs)
indigenous_clean = indigenous_clean.to_crs(target_crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
protected_land_table = pd.concat([protected_clean, indigenous_clean], ignore_index=True)
protected_land_table = gpd.GeoDataFrame(protected_land_table, geometry="geometry", crs=wpda_gdf_polygons.crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
protected_land_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      protected_area_id                                land_name  \
# 0                611_B     Wood Buffalo National Park Of Canada
# 1                  615            Banff National Park Of Canada
# ...

# %% [markdown]
# ## Land cover table

# %%
land_cover_table = land_cover_gdf.copy()
land_cover_table['npv_biome_type'] = npv_gdf['biome_type']
#land_cover_table['source_id'] = land_cover_table['source_id'].astype(str) + ';' + npv_gdf['source_id'].astype(str)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from db_creation_function import assign_row_id
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_cover_table = assign_row_id(land_cover_table,
                                 facility_id_col='main_id', 
                                 prefix='land_cover_id')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_cover_table.drop(columns=['name', 'geometry'], inplace=True)
land_cover_table.rename(columns={'row_id': 'land_cover_id'}, inplace=True)
land_cover_table = land_cover_table[['land_cover_id', 'year', 'modis_land_cover',
       'esa_land_cover', 'npv_biome_type', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_cover_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                 land_cover_id  year             modis_land_cover  \
# 0    land_cover_id-5801b453-1  2021               Woody Savannas
# 1    land_cover_id-d29e0839-1  2021               Woody Savannas
# ...

# %% [markdown]
# ## Intensity table

# %%
intensity_df.rename(columns={'row_id': 'intensity_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
intensity_table = intensity_df[['intensity_id', 'year', 'commodity', 'type', 'subtype', 'unit', 'value', 'comment', 'main_id', 'facility_group_id', 'company_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
intensity_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                 intensity_id  year commodity    type             subtype  \
# 0        INT-687b8c8d-2023-1  2023      Gold     GHG           scope1+2?
# 1        INT-687b8c8d-2023-2  2023      Gold     GHG           scope1+2?
# ...

# %% [markdown]
# ## Reserves and resources table

# %%
reserves_table = reserves_df.rename(columns={'row_id': 'reserves_id'})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
reserves_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  reserves_id  year reporting_level reported_company_nrcan  \
# 0    RES-GRP-1402249f-2024-1  2024  Facility-group          ArcelorMittal
# ...

# %%
reserves_table = reserves_table[['reserves_id', 'year', 'commodity', 'reserves_resources', 'reserves_resources_type', 'ore', 'ore_unit', 'grade', 'grade_unit', 'metal_content', 'metal_content_unit', 'recovery_rate', 'comment', 'main_id', 'facility_group_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Technosphere table

# %%
technosphere_df.rename(columns={'row_id': 'technosphere_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
technosphere_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               technosphere_id    year reporting_level reported_company_nrcan  \
# 0    TECH-857b7b89-2023.0-1.0  2023.0   Site-specific    Newmont Corporation
# ...

# %%
#energy_table = energy_df.rename(columns={'row_id': 'nrj_id'})
technosphere_table = technosphere_df[['technosphere_id', 'year', 'flow_type', 'subflow_type', 'unit', 'value', 'comment', 'main_id', 'facility_group_id', 'company_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
technosphere_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               technosphere_id    year     flow_type  \
# 0    TECH-857b7b89-2023.0-1.0  2023.0        Energy
# 1    TECH-857b7b89-2023.0-2.0  2023.0        Energy
# 2    TECH-857b7b89-2023.0-3.0  2023.0        Energy
# ...

# %%
technosphere_table['unit'].unique()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# array(['GJ', 'kWh', 'MWh', 'gallons', 'pounds', 'TJ', 'kl', 't', 'l',
#        'm3', 'GWh', 'kg'], dtype=object)

# %% [markdown]
# ## Waste table

# %%
waste_df.rename(columns={'row_id': 'waste_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
waste_table = waste_df[['waste_id', 'year', 'flow_type', 'subflow_type', 'unit', 'value', 'comment', 'main_id', 'facility_group_id', 'company_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
waste_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                  waste_id  year flow_type                  subflow_type unit  \
# 0   WASTE-e7e6a960-2023-1  2023     waste         Total waste generated    t
# ...

# %% [markdown]
# ## Tailings table

# %%
tailings_gdf.drop(columns=['row_id'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tailings_table = tailings_gdf.rename(columns={'current_tailings_storage': 'current_storage'})
tailings_table = tailings_table[['tailing_id', 'year', 'tsf_name', 'status', 'construction_year', 
                             'raise_type', 'current_maximum_height', 'current_storage', 'hazard_categorization', 
                             'classification_system', 'geometry', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tailings_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      tailing_id  year               tsf_name  status  construction_year  \
# 0          12.0  2019             North Cell  Active             2009.0
# 1          13.0  2019             South Cell  Active             2012.0
# ...

# %% [markdown]
# ## Land occupation table

# %%
# Change the Land-use values from m2 to km2
li_canada_gdf['area_km2'] = li_canada_gdf['Land_use'].apply(lambda x: x / 1e6 if pd.notna(x) else x)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
li_canada_gdf.rename(columns={'li_id': 'land_occupation_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
li_canada_gdf = li_canada_gdf[['land_occupation_id', 'area_km2', 'geometry', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tang_gdf = polygon_gdf.rename(columns={'tang_id': 'land_occupation_id'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
polygon_gdf = polygon_gdf.to_crs(li_canada_gdf.crs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Add the li_canada_gdf to the polygon_gdf
land_occupation_table = pd.concat([polygon_gdf, li_canada_gdf], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_occupation_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      land_occupation_id                                           geometry  \
# 0                  6383  POLYGON Z ((-71.95867 45.31898 0.00000, -71.95...
# ...

# %%
land_occupation_table = land_occupation_table[['land_occupation_id', 'area_km2', 'geometry', 'distance_km', 'main_id', 'tailing_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Drop duplicates caused by tailing id, so drop duplicates only on the 
land_occupation_table = land_occupation_table.drop_duplicates(subset=['land_occupation_id'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Drop rows where main_id and tailing_id are NaN
land_occupation_table.dropna(subset=['main_id', 'tailing_id'], how='all', inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
land_occupation_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      land_occupation_id  area_km2  \
# 3                 45954  2.622800
# 4                 45955  0.441869
# 7                  7631  0.209038
# 8                  7641  0.113569
# 9                  7633  0.213592
# ...

# %% [markdown]
# ## By-product

# %%
bth_table = bth_df.drop(columns=['facility_name'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bth_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    host by_product        ratio           main_id  \
# 0    Pt         Te     0.007718  ON-MAIN-a3c56a83
# 1    Pt         Se     0.322126  ON-MAIN-a3c56a83
# 2    Pt         Pd     0.748792  ON-MAIN-a3c56a83
# ...

# %% [markdown]
# ## Archetypes table

# %%
archetypes_df.rename(columns={'row_id': 'archetype_id',
                              'mining_processing_type_nrcan': 'mining_method',
                              'mining_method_cleaned': 'mining_submethod',
                              'likely_ore_type': 'ore_type'
                              }, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetypes_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#            archetype_id TR_available       reported_company_nrcan  \
# 0       ARCH-3f490561-1          Yes  Imperial Metals Corporation
# 1       ARCH-4724f4ba-1          NaN    Gold Mountain Mining Corp
# ...

# %%
def combine_cmmi_deposit(row):
    values = []
    if pd.notna(row['deposit_cmmi']):
        values.append(str(row['deposit_cmmi']))
    if pd.notna(row['deposit_gr_cmmi']):
        values.append(str(row['deposit_gr_cmmi']))
    if pd.notna(row['deposit_type_cmmi']):
        values.append(str(row['deposit_type_cmmi']))
    return ';'.join(values) if values else ''
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetypes_df['deposit_cmmi_combined'] = archetypes_df.apply(combine_cmmi_deposit, axis=1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetypes_df.drop(columns=['deposit_cmmi', 'deposit_gr_cmmi', 'deposit_type_cmmi'], inplace=True)
archetypes_df.rename(columns={'deposit_cmmi_combined': 'deposit_cmmi'}, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetypes_df['deposit_mdo'] = archetypes_df['deposit_mdo'].str.replace(r'[\n]+', ', ', regex=True)
archetypes_df['deposit_mdo'] = archetypes_df['deposit_mdo'].str.replace(r'\s+', ' ', regex=True)
archetypes_df['deposit_mdo'] = archetypes_df['deposit_mdo'].str.strip()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetype_table = archetypes_df[['archetype_id', 'deposit_cmmi', 'deposit_mdo', 'ore_type', 'mining_method', 'mining_submethod', 'main_id', 'facility_group_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
archetype_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#            archetype_id                                       deposit_cmmi  \
# 0       ARCH-3f490561-1
# 1       ARCH-4724f4ba-1
# 2       ARCH-599152a0-1
# 3       ARCH-6b4800fe-1
# 4       ARCH-8eb8be0d-1
# ...

# %% [markdown]
# ## Water risk table

# %%
water_risk_table = water_risk_gdf.rename(columns={'row_id': 'water_risk_id'})
water_risk_table = water_risk_table[['water_risk_id', 'indicator', 'year', 'scenario', 'value', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
water_risk_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                             water_risk_id  \
# 0     water_risk-5801b453-2020-baseline-1
# 1     water_risk-5801b453-2020-baseline-2
# 2     water_risk-5801b453-2020-baseline-3
# 3     water_risk-5801b453-2020-baseline-4
# ...

# %%
water_risk_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                             water_risk_id  \
# 0     water_risk-5801b453-2020-baseline-1
# 1     water_risk-5801b453-2020-baseline-2
# 2     water_risk-5801b453-2020-baseline-3
# 3     water_risk-5801b453-2020-baseline-4
# ...

# %% [markdown]
# ## Climate categories table

# %%
climate_category_table = climate_category_gdf.rename(columns={'row_id': 'climate_category_id'})
climate_category_table = climate_category_table[['climate_category_id', 'year', 'scenario', 'category', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
climate_category_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      climate_category_id       year    scenario  \
# 0     CC-5801b453-1991_2020-historical-1  1991_2020  historical
# 1     CC-d29e0839-1991_2020-historical-1  1991_2020  historical
# ...

# %% [markdown]
# ## Weather table

# %%
weather_table = weather_gdf.rename(columns={'row_id': 'weather_id'})
weather_table = weather_table[['weather_id', 'year', 'variable', 'value', 'unit', 'scenario', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
weather_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                            weather_id  year                 variable  \
# 0      weather-5801b453-2025-ssp126-1  2025  Daily Temperature Range
# 1      weather-5801b453-2030-ssp126-1  2030  Daily Temperature Range
# ...

# %% [markdown]
# ## Conflict table

# %%
conflict_table = conflict_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
conflict_table = conflict_table[['ej_atlas_id', 'case_name', 'start_date', 'end_date', 
                             'conflict_description', 'conflict_details', 'population_affected',
                             'conflict_intensity', 'project_status', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
conflict_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     ej_atlas_id                                          case_name  \
# 9          4135      Vale Mining in Voisey's Bay, Labrador, Canada
# 10         4145  Port Colborne Class Action Lawsuit Against Val...
# ...

# %% [markdown]
# ## Population table

# %%
population_table = population_gdf.rename(columns={'row_id': 'population_id'})
population_table = population_table[['population_id', 'year', 'buffer_size', 'total_population', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
population_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                    population_id  year buffer_size  total_population  \
# 0     population-5801b453-2025-1  2025        10km       1305.901860
# 1     population-5801b453-2025-2  2025        50km      63977.830574
# ...

# %% [markdown]
# ## Peatland table

# %%
peatland_table = peatland_gdf[['peatland_presence', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
peatland_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        peatland_presence           main_id  \
# 0                No data  QC-MAIN-5801b453
# 1    peat in soil mosaic  QC-MAIN-d29e0839
# 2         peat dominated  QC-MAIN-f1ff4920
# 3                No data  NU-MAIN-4ea8ac9d
# ...

# %% [markdown]
# ## Prioritization area table

# %%
prioritization_area_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               main_id      facility_name                     geometry  \
# 0    QC-MAIN-5801b453     Abcourt-Barvue   POINT (-77.67901 48.52154)
# 1    QC-MAIN-d29e0839     Sleeping Giant   POINT (-77.97434 49.13259)
# ...

# %%
prioritization_conservation_area_table = prioritization_area_gdf.rename(columns={
    'jung_priority_point': 'score_1_km',
    'jung_priority_mean_50km': 'mean_score_50_km',})
prioritization_conservation_area_table = prioritization_conservation_area_table[['score_1_km', 'mean_score_50_km', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
prioritization_conservation_area_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      score_1_km  mean_score_50_km           main_id  \
# 0     25.926612         22.025641  QC-MAIN-5801b453
# 1     13.000000         15.775000  QC-MAIN-d29e0839
# 2     20.618888         21.125000  QC-MAIN-f1ff4920
# ...

# %% [markdown]
# ## Carbon stock table

# %%
from db_creation_function import assign_row_id
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
carbon_stock_gdf = assign_row_id(carbon_stock_gdf,
                  facility_id_col='main_id',
                  prefix='carbon_stock'
                  )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
carbon_stock_gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        row_id           main_id  pool   variable   unit  \
# 0     carbon_stock-35d0dc71-1  AB-MAIN-35d0dc71  agbc    area_ha     ha
# 1     carbon_stock-35d0dc71-2  AB-MAIN-35d0dc71  agbc   mean_act  tC/ha
# ...

# %%
carbon_stock_table = carbon_stock_gdf.rename(columns={'row_id': 'carbon_stock_ecosystems_id'})
carbon_stock_table = carbon_stock_table[['carbon_stock_ecosystems_id', 'pool', 'variable', 'unit', 'value', 'main_id', 'source_id']]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Update the facility group id

# %%
def update_facility_group_id(biosphere_df, main_df):
    """
    Update facility_group_id in biosphere_df with values from main_df where facility_group_id is NaN.

    Parameters:
    - biosphere_df: DataFrame with columns 'main_id' and 'facility_group_id' (may contain NaN)
    - main_df: DataFrame with columns 'main_id' and 'facility_group_id' (source of truth)

    Returns:
    - Updated biosphere_df
    """
    # Merge and update
    biosphere_df = biosphere_df.merge(
        main_df[['main_id', 'facility_group_id']],
        on='main_id',
        how='left',
        suffixes=('', '_from_main')
    )
    biosphere_df['facility_group_id'] = biosphere_df['facility_group_id'].fillna(
       biosphere_df['facility_group_id_from_main']
    )
    biosphere_df = biosphere_df.drop(columns=['facility_group_id_from_main'])
    return biosphere_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def update_facility_group_id_carbon(biosphere_df, main_df):
    """
    Update facility_group_id in biosphere_df with values from main_df where facility_group_id is NaN.

    Parameters:
    - biosphere_df: DataFrame with columns 'main_id' and 'facility_group_id' (may contain NaN)
    - main_df: DataFrame with columns 'main_id' and 'facility_group_id' (source of truth)

    Returns:
    - Updated biosphere_df
    """
    # Merge and update
    biosphere_df = biosphere_df.merge(
        main_df[['main_id', 'facility_group_id']],
        on='main_id',
        how='left',
        suffixes=('', '_from_main')
    )
    #biosphere_df['facility_group_id'] = biosphere_df['facility_group_id'].fillna(
    #    biosphere_df['facility_group_id_from_main']
    #)
    #biosphere_df = biosphere_df.drop(columns=['facility_group_id_from_main'])
    return biosphere_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def update_company_id(biosphere_df, main_df):
    """
    Update company_id in biosphere_df with values from main_df where company_id is NaN.

    Parameters:
    - biosphere_df: DataFrame with columns 'main_id' and 'company_id' (may contain NaN)
    - main_df: DataFrame with columns 'main_id' and 'company_id' (source of truth)

    Returns:
    - Updated biosphere_df
    """
    # Merge and update
    biosphere_df = biosphere_df.merge(
        main_df[['main_id', 'company_id']],
        on='main_id',
        how='left',
        suffixes=('', '_from_main')
    )
    biosphere_df['company_id'] = biosphere_df['company_id'].fillna(
        biosphere_df['company_id_from_main']
    )
    biosphere_df = biosphere_df.drop(columns=['company_id_from_main'])
    return biosphere_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_table = update_facility_group_id(env_table, main_gdf)
reserves_table = update_facility_group_id(reserves_table, main_gdf)
tech_attributes_table = update_facility_group_id(tech_attributes_table, main_gdf)
production_table = update_facility_group_id(production_table, main_gdf)
technosphere_table = update_facility_group_id(technosphere_table, main_gdf)
waste_table = update_facility_group_id(waste_table, main_gdf)
intensity_table = update_facility_group_id(intensity_table, main_gdf)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
carbon_stock_table = update_facility_group_id_carbon(carbon_stock_table, main_gdf)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
carbon_stock_table = carbon_stock_table[
    ['carbon_stock_ecosystems_id', 'pool', 'variable', 'unit', 'value',
       'main_id', 'facility_group_id', 'source_id']
]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
carbon_stock_table.columns
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Index(['carbon_stock_ecosystems_id', 'pool', 'variable', 'unit', 'value',
#        'main_id', 'facility_group_id', 'source_id'],
#       dtype='object')

# %%
env_table = update_company_id(env_table, main_gdf)
#reserves_table = update_company_id(reserves_table, main_gdf)
tech_attributes_table = update_company_id(tech_attributes_table, main_gdf)
production_table = update_company_id(production_table, main_gdf)
technosphere_table = update_company_id(technosphere_table, main_gdf)
waste_table = update_company_id(waste_table, main_gdf)
intensity_table = update_company_id(intensity_table, main_gdf)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Exports

# %% [markdown]
# ## Exports tables to CSV

# %%
# Export all the tables to CSV
main_gdf.to_csv(r'database/CSV/main_table.csv', index=False, encoding="utf-8-sig")
production_table.to_csv(r'database/CSV/production_table.csv', index=False, encoding="utf-8-sig")
env_table.to_csv(r'database/CSV/environmental_flows_table.csv', index=False, encoding="utf-8-sig")
tech_attributes_table.to_csv(r'database/CSV/tech_attributes_table.csv', index=False, encoding="utf-8-sig")
land_cover_table.to_csv(r'database/CSV/land_cover_table.csv', index=False, encoding="utf-8-sig")
waste_table.to_csv(r'database/CSV/waste_table.csv', index=False, encoding="utf-8-sig")
intensity_table.to_csv(r'database/CSV/intensity_table.csv', index=False, encoding="utf-8-sig")
reserves_table.to_csv(r'database/CSV/reserves_table.csv', index=False, encoding="utf-8-sig")
technosphere_table.to_csv(r'database/csv/materials_energy_table.csv', index=False, encoding="utf-8-sig")
tailings_table.to_csv(r'database/CSV/tailings_table.csv', index=False, encoding="utf-8-sig")
land_occupation_table.to_csv(r'database/CSV/land_occupation_table.csv', index=False, encoding="utf-8-sig")
archetype_table.to_csv(r'database/CSV/archetypes_table.csv', index=False, encoding="utf-8-sig")
water_risk_table.to_csv(r'database/CSV/water_risk_table.csv', index=False, encoding="utf-8-sig")
climate_category_table.to_csv(r'database/CSV/climate_category_table.csv', index=False, encoding="utf-8-sig")
weather_table.to_csv(r'database/CSV/weather_table.csv', index=False, encoding="utf-8-sig")
conflict_table.to_csv(r'database/CSV/conflict_table.csv', index=False, encoding="utf-8-sig")
population_table.to_csv(r'database/CSV/population_table.csv', index=False, encoding="utf-8-sig")
peatland_table.to_csv(r'database/CSV/peatland_table.csv', index=False, encoding="utf-8-sig")
prioritization_conservation_area_table.to_csv(r'database/CSV/prioritization_area_table.csv', index=False, encoding="utf-8-sig")
bth_table.to_csv(r'database/CSV/bth_table.csv', index=False, encoding="utf-8-sig")
carbon_stock_table.to_csv(r'database/CSV/carbon_stock_ecosystems_table.csv', index=False, encoding="utf-8-sig")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# We remove the geometry column to avoid issues with large file size
protected_land_table_csv = protected_land_table.copy()
protected_land_table_csv.drop(columns=['geometry'], inplace=True)
protected_land_table_csv.to_csv(r'database/CSV/protected_land_table.csv', index=False, encoding="utf-8-sig")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Export DB to SQLite

# %%
from matching_functions import create_and_populate_database
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
tables_dict = {
    "Sources": source_table,
    "Main": main_gdf,
    "Substances": substance_table,

    "Reserves_resources": reserves_table,
    "Production": production_table,
    "Technical_attributes": tech_attributes_table,
    "Materials and energy": technosphere_table,
    "Environmental_flows": env_table,
    "Intensity": intensity_table,
    "Waste": waste_table,
    "Archetypes": archetype_table,

    "Tailings": tailings_table,
    "Land_occupation": land_occupation_table,
    "By_products": bth_table,
    
    "Water_risk": water_risk_table,
    "Climate_category": climate_category_table,
    "Weather": weather_table,
    "Land_cover": land_cover_table,
    "Conflict": conflict_table,
    "Population": population_table,
    "Peatland": peatland_table,
    "Prioritization_conservation_areas": prioritization_conservation_area_table,
    "Protected_indigenous_lands": protected_land_table,
    "Carbon_stock_ecosystems": carbon_stock_table,
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# To avoid foreign key issues, we transform NaN to None for the main_id, facility_group_id, source_id columns in all dfs
for table_name, df in tables_dict.items():
    for col in ['main_id', 'facility_group_id', 'source_id']:
        if col in df.columns:
            df[col] = df[col].where(pd.notna(df[col]), None)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
create_and_populate_database(
    db_path="database/metallican.sqlite",
    schema_path="database/schema.sql",
    tables_dict=tables_dict,
    keep_geometry_tables=["Main", "Tailings", "Land_occupation"]
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Old database 'database/metallican.sqlite' deleted
# ✅ Empty database structure created at 'database/metallican.sqlite'
# 🔄 Converting geometries...
# ✅ Geometries handled (kept only where needed)
# ✅ New connection opened
# ...
